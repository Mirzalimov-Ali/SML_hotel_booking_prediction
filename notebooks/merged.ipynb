# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import numpy as np
import os

# %%
os.chdir(r'C:\SML_Projects\SML_hotelBooking_cancelling_prediction')

# %%
x_train = pd.read_csv('data/engineered/engineered_x_train.csv')
x_test = pd.read_csv('data/engineered/engineered_x_test.csv')

y_train = pd.read_csv('data/split/y_train.csv')
y_test = pd.read_csv('data/split/y_test.csv')

# %%
train_df = pd.concat([x_train, y_train], axis=1)
test_df = pd.concat([x_test, y_test], axis=1)

df = pd.concat([train_df, test_df], axis=0, ignore_index=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 58 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   lead_time                       119390 non-null  float64
#  2   arrival_date_month              119390 non-null  object
#  3   arrival_date_week_number        119390 non-null  float64
#  4   arrival_date_day_of_month       119390 non-null  float64
#  5   stays_in_weekend_nights         119390 non-null  float64
#  6   stays_in_week_nights            119390 non-null  float64
#  7   adults                          119390 non-null  float64
#  8   children                        119390 non-null  float64
#  9   babies                          119390 non-null  float64
#  10  meal                            119390 non-null  object
#  11  country                         119390 non-null  object
#  12  market_segment                  119390 non-null  object
#  13  distribution_channel            119390 non-null  object
#  14  is_repeated_guest               119390 non-null  float64
#  15  previous_cancellations          119390 non-null  float64
#  16  previous_bookings_not_canceled  119390 non-null  float64
#  17  reserved_room_type              119390 non-null  object
#  18  assigned_room_type              119390 non-null  object
#  19  booking_changes                 119390 non-null  float64
#  20  deposit_type                    119390 non-null  object
#  21  agent                           119390 non-null  float64
#  22  days_in_waiting_list            119390 non-null  float64
#  23  customer_type                   119390 non-null  object
#  24  adr                             119390 non-null  float64
#  25  required_car_parking_spaces     119390 non-null  float64
#  26  total_of_special_requests       119390 non-null  float64
#  27  city                            119390 non-null  object
#  28  total_nights                    119390 non-null  float64
#  29  lead_time_log                   119390 non-null  float64
#  30  is_extreme_lead                 119390 non-null  int64
#  31  total_guests                    119390 non-null  float64
#  32  is_free_booking                 119390 non-null  int64
#  33  has_previous_cancel             119390 non-null  int64
#  34  is_loyal_customer               119390 non-null  int64
#  35  room_changed                    119390 non-null  int64
#  36  has_agent                       119390 non-null  int64
#  37  is_short_stay                   119390 non-null  int64
#  38  is_long_stay                    119390 non-null  int64
#  39  weekend_ratio                   119390 non-null  float64
#  40  is_last_minute                  119390 non-null  int64
#  41  adr_x_lead_time                 119390 non-null  float64
#  42  high_adr                        119390 non-null  int64
#  43  adr_per_person                  119390 non-null  float64
#  44  is_suspicious_price             119390 non-null  int64
#  45  has_children                    119390 non-null  int64
#  46  has_babies                      119390 non-null  int64
#  47  solo_traveler                   119390 non-null  int64
#  48  many_booking_changes            119390 non-null  int64
#  49  was_waitlisted                  119390 non-null  int64
#  50  many_special_requests           119390 non-null  int64
#  51  needs_parking                   119390 non-null  int64
#  52  is_high_season                  119390 non-null  int64
#  53  online_booking                  119390 non-null  int64
#  54  agent_booking                   119390 non-null  int64
#  55  risky_customer                  119390 non-null  int64
#  56  room_mismatch_online            119390 non-null  int64
#  57  is_canceled                     119390 non-null  int64
# dtypes: float64(23), int64(24), object(11)
# memory usage: 52.8+ MB

# %%
os.makedirs('data/merged', exist_ok=True)

df.to_csv('data/merged/merged_dataset.csv', index=False)

# %%
merged_df = pd.read_csv('data/merged/merged_dataset.csv')

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 58 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   lead_time                       119390 non-null  float64
#  2   arrival_date_month              119390 non-null  object
#  3   arrival_date_week_number        119390 non-null  float64
#  4   arrival_date_day_of_month       119390 non-null  float64
#  5   stays_in_weekend_nights         119390 non-null  float64
#  6   stays_in_week_nights            119390 non-null  float64
#  7   adults                          119390 non-null  float64
#  8   children                        119390 non-null  float64
#  9   babies                          119390 non-null  float64
#  10  meal                            119390 non-null  object
#  11  country                         119390 non-null  object
#  12  market_segment                  119390 non-null  object
#  13  distribution_channel            119390 non-null  object
#  14  is_repeated_guest               119390 non-null  float64
#  15  previous_cancellations          119390 non-null  float64
#  16  previous_bookings_not_canceled  119390 non-null  float64
#  17  reserved_room_type              119390 non-null  object
#  18  assigned_room_type              119390 non-null  object
#  19  booking_changes                 119390 non-null  float64
#  20  deposit_type                    119390 non-null  object
#  21  agent                           119390 non-null  float64
#  22  days_in_waiting_list            119390 non-null  float64
#  23  customer_type                   119390 non-null  object
#  24  adr                             119390 non-null  float64
#  25  required_car_parking_spaces     119390 non-null  float64
#  26  total_of_special_requests       119390 non-null  float64
#  27  city                            119390 non-null  object
#  28  total_nights                    119390 non-null  float64
#  29  lead_time_log                   119390 non-null  float64
#  30  is_extreme_lead                 119390 non-null  int64
#  31  total_guests                    119390 non-null  float64
#  32  is_free_booking                 119390 non-null  int64
#  33  has_previous_cancel             119390 non-null  int64
#  34  is_loyal_customer               119390 non-null  int64
#  35  room_changed                    119390 non-null  int64
#  36  has_agent                       119390 non-null  int64
#  37  is_short_stay                   119390 non-null  int64
#  38  is_long_stay                    119390 non-null  int64
#  39  weekend_ratio                   119390 non-null  float64
#  40  is_last_minute                  119390 non-null  int64
#  41  adr_x_lead_time                 119390 non-null  float64
#  42  high_adr                        119390 non-null  int64
#  43  adr_per_person                  119390 non-null  float64
#  44  is_suspicious_price             119390 non-null  int64
#  45  has_children                    119390 non-null  int64
#  46  has_babies                      119390 non-null  int64
#  47  solo_traveler                   119390 non-null  int64
#  48  many_booking_changes            119390 non-null  int64
#  49  was_waitlisted                  119390 non-null  int64
#  50  many_special_requests           119390 non-null  int64
#  51  needs_parking                   119390 non-null  int64
#  52  is_high_season                  119390 non-null  int64
#  53  online_booking                  119390 non-null  int64
#  54  agent_booking                   119390 non-null  int64
#  55  risky_customer                  119390 non-null  int64
#  56  room_mismatch_online            119390 non-null  int64
#  57  is_canceled                     119390 non-null  int64
# dtypes: float64(23), int64(24), object(11)
# memory usage: 52.8+ MB
