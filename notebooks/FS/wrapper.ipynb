# %% [markdown]
# ## 🔹 Wrapper Method Training — Algorithm Families Overview
#
# #### 📌 Ushbu bosqichda **Wrapper feature selection** qo'llanilib, **FS - Wrapper Method** asosida **classification** uchun **jami 25 ta algoritm** turli model oilalaridan foydalanilgan.
#
#
# Quyida loyihada qo‘llanilgan **asosiy algoritm oilalari** keltirilgan:
#
# - 📏 **Linear Models**
# - 🌳 **Tree-Based Models**
# - 🧠 **Ensemble Models**
# - 👥 **Neighbors-Based Models**
# - 📐 **Support Vector Machine (SVM) Models**
# - 🌀 **Kernel-Based Models**
# - 🧬 **Neural Network Models**
# - 🎯 **Naive & Simple Baseline Models**
#
# 📈 Ushbu yondashuv feature selection’ning model performansiga bo‘lgan
# **dastlabki va tezkor ta’sirini baholash** imkonini beradi.
#
# 🌐 Ushbu model oilalari klassik **baseline** yondashuvlardan tortib,
# zamonaviy **ensemble** va **kernel-based** modellargacha bo‘lgan
# keng qamrovli yechimlarni o‘z ichiga oladi.
#
# 🔍 Barcha modellar o‘zaro solishtirish, barqarorlikni baholash
# va **eng optimal modelni aniqlash** maqsadida birgalikda sinovdan o‘tkazilgan.

# %%
import pandas as pd
import os
import numpy as np

# %%
os.chdir(r'C:\SML_Projects\SML_hotelBooking_cancelling_prediction')

# %%
x_train = pd.read_csv('data/preprocessed/preprocessed_x_train.csv')
x_test = pd.read_csv('data/preprocessed/preprocessed_x_test.csv')

y_train = pd.read_csv('data/split/y_train.csv')
y_test = pd.read_csv('data/split/y_test.csv')

# %%
from sklearn.model_selection import KFold, cross_val_score
from sklearn.metrics import accuracy_score, classification_report, precision_score, recall_score, f1_score
from sklearn.feature_selection import RFE

# %%
kf = KFold(n_splits=3, shuffle=True, random_state=42)

# %% [markdown]
# ### 📌 1. Linear Models
# **Jami: `4ta` algoritm**
#
# - **Logistic Regression**
# - **Ridge Classifier**
# - **SGD Classifier**
# - **Passive Aggressive Classifier**

# %%
# LINEAR MODELS - CLASSIFICATION (4ta)
from sklearn.linear_model import (
    LogisticRegression,
    RidgeClassifier,
    SGDClassifier,
    PassiveAggressiveClassifier
)

# %% [markdown]
# ## Logistic Regression

# %%
lr = LogisticRegression(max_iter=1000)
rfe = RFE(lr, n_features_to_select=10)

rfe.fit(x_train, y_train)
selected_features = x_train.columns[rfe.support_]

lr.fit(x_train[selected_features], y_train)
y_pred = lr.predict(x_test[selected_features])

lr_score = accuracy_score(y_test, y_pred)

lr_precision = precision_score(y_test, y_pred)
lr_recall = recall_score(y_test, y_pred)
lr_f1 = f1_score(y_test, y_pred)

lr_scores = cross_val_score(lr, x_train[selected_features], y_train, cv=kf, scoring='f1_macro')

print(f'Logistic Regression score: {lr_score}')

print(f'\nPrecision: {lr_precision}')
print(f'Recall: {lr_recall}')
print(f'F1-score: {lr_f1}')

print("\nK-Fold mean:", lr_scores.mean())
print("K-Fold std:", lr_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("\nSelected features:", list(selected_features))
# Out:
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Logistic Regression score: 0.7947483038780467
#
# Precision: 0.8928571428571429
# Recall: 0.5155501058967785
# F1-score: 0.6536640520104586
#
# K-Fold mean: 0.7463206208529681
# K-Fold std: 0.002357213546846621
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.77      0.96      0.85     14907
#            1       0.89      0.52      0.65      8971
#
#     accuracy                           0.79     23878
#    macro avg       0.83      0.74      0.75     23878
# weighted avg       0.81      0.79      0.78     23878
#
#
# Selected features: ['market_segment', 'previous_bookings_not_canceled', 'booking_changes', 'deposit_type', 'adr', 'total_of_special_requests', 'total_guests', 'has_previous_cancel', 'adr_x_lead_time', 'needs_parking']

# %% [markdown]
# ## RidgeClassifier

# %%
ridge = RidgeClassifier()
rfe = RFE(ridge, n_features_to_select=10)

rfe.fit(x_train, y_train)
selected_features = x_train.columns[rfe.support_]

ridge.fit(x_train[selected_features], y_train)
y_pred = ridge.predict(x_test[selected_features])

ridge_score = accuracy_score(y_test, y_pred)

ridge_precision = precision_score(y_test, y_pred)
ridge_recall = recall_score(y_test, y_pred)
ridge_f1 = f1_score(y_test, y_pred)

ridge_scores = cross_val_score(ridge, x_train[selected_features], y_train, cv=kf, scoring='f1_macro')

print(f'RidgeClassifier score: {ridge_score}')

print(f'\nPrecision: {ridge_precision}')
print(f'Recall: {ridge_recall}')
print(f'F1-score: {ridge_f1}')

print("\nK-Fold mean:", ridge_scores.mean())
print("K-Fold std:", ridge_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("\nSelected features:", list(selected_features))
# Out:
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_ridge.py:1306: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_ridge.py:1306: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_ridge.py:1306: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_ridge.py:1306: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_ridge.py:1306: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_ridge.py:1306: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_ridge.py:1306: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_ridge.py:1306: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_ridge.py:1306: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_ridge.py:1306: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_ridge.py:1306: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_ridge.py:1306: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_ridge.py:1306: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_ridge.py:1306: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_ridge.py:1306: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_ridge.py:1306: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_ridge.py:1306: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_ridge.py:1306: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_ridge.py:1306: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_ridge.py:1306: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_ridge.py:1306: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_ridge.py:1306: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_ridge.py:1306: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_ridge.py:1306: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_ridge.py:1306: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_ridge.py:1306: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_ridge.py:1306: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_ridge.py:1306: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_ridge.py:1306: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_ridge.py:1306: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_ridge.py:1306: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_ridge.py:1306: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_ridge.py:1306: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_ridge.py:1306: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_ridge.py:1306: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_ridge.py:1306: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# RidgeClassifier score: 0.7819331602311751
#
# Precision: 0.8869243421052632
# Recall: 0.48088284472188164
# F1-score: 0.6236357065413806
#
# K-Fold mean: 0.731086408480427
# K-Fold std: 0.0012854952727369073
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.76      0.96      0.85     14907
#            1       0.89      0.48      0.62      8971
#
#     accuracy                           0.78     23878
#    macro avg       0.82      0.72      0.74     23878
# weighted avg       0.80      0.78      0.76     23878
#
#
# Selected features: ['country', 'market_segment', 'previous_bookings_not_canceled', 'booking_changes', 'deposit_type', 'total_of_special_requests', 'total_guests', 'adr_per_person', 'has_previous_cancel', 'adr_x_lead_time']
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_ridge.py:1306: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_ridge.py:1306: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_ridge.py:1306: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_ridge.py:1306: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_ridge.py:1306: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_ridge.py:1306: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_ridge.py:1306: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_ridge.py:1306: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_ridge.py:1306: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# ## SGDClassifier

# %%
sgdc = SGDClassifier()
rfe = RFE(sgdc, n_features_to_select=10)

rfe.fit(x_train, y_train)
selected_features = x_train.columns[rfe.support_]

sgdc.fit(x_train[selected_features], y_train)
y_pred = sgdc.predict(x_test[selected_features])

sgdc_score = accuracy_score(y_test, y_pred)

sgdc_precision = precision_score(y_test, y_pred)
sgdc_recall = recall_score(y_test, y_pred)
sgdc_f1 = f1_score(y_test, y_pred)

sgdc_scores = cross_val_score(sgdc, x_train[selected_features], y_train, cv=kf, scoring='f1_macro')

print(f'SGDClassifier score: {sgdc_score}')

print(f'\nPrecision: {sgdc_precision}')
print(f'Recall: {sgdc_recall}')
print(f'F1-score: {sgdc_f1}')

print("\nK-Fold mean:", sgdc_scores.mean())
print("K-Fold std:", sgdc_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("\nSelected features:", list(selected_features))
# Out:
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SGDClassifier score: 0.7653488566881649
#
# Precision: 0.9711807498601007
# Recall: 0.38691338758220933
# F1-score: 0.5533678756476684
#
# K-Fold mean: 0.6929904335754188
# K-Fold std: 0.002453512353920818
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.73      0.99      0.84     14907
#            1       0.97      0.39      0.55      8971
#
#     accuracy                           0.77     23878
#    macro avg       0.85      0.69      0.70     23878
# weighted avg       0.82      0.77      0.73     23878
#
#
# Selected features: ['adults', 'children', 'previous_bookings_not_canceled', 'booking_changes', 'deposit_type', 'total_of_special_requests', 'total_guests', 'has_previous_cancel', 'adr_x_lead_time', 'needs_parking']
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# ## PassiveAggressive

# %%
pac = PassiveAggressiveClassifier()
rfe = RFE(pac, n_features_to_select=10)

rfe.fit(x_train, y_train)
selected_features = x_train.columns[rfe.support_]

pac.fit(x_train[selected_features], y_train)
y_pred = pac.predict(x_test[selected_features])

pac_score = accuracy_score(y_test, y_pred)

pac_precision = precision_score(y_test, y_pred)
pac_recall = recall_score(y_test, y_pred)
pac_f1 = f1_score(y_test, y_pred)

pac_scores = cross_val_score(pac, x_train, y_train, cv=kf, scoring='f1_macro')

print(f'PassiveAggressiveClassifier score: {pac_score}')

print(f'\nPrecision: {pac_precision}')
print(f'Recall: {pac_recall}')
print(f'F1-score: {pac_f1}')

print("\nK-Fold mean:", pac_scores.mean())
print("K-Fold std:", pac_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("\nSelected features:", list(selected_features))
# Out:
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# PassiveAggressiveClassifier score: 0.792068012396348
#
# Precision: 0.785246368555967
# Recall: 0.6146471965221268
# F1-score: 0.6895516788595011
#
# K-Fold mean: 0.6910931167774351
# K-Fold std: 0.03333998853997828
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.90      0.84     14907
#            1       0.79      0.61      0.69      8971
#
#     accuracy                           0.79     23878
#    macro avg       0.79      0.76      0.77     23878
# weighted avg       0.79      0.79      0.79     23878
#
#
# Selected features: ['market_segment', 'previous_bookings_not_canceled', 'booking_changes', 'deposit_type', 'total_of_special_requests', 'total_guests', 'adr_per_person', 'has_previous_cancel', 'adr_x_lead_time', 'needs_parking']

# %% [markdown]
# ## 🌲 2. Tree-Based Models
#
# **Jami: `1ta` algoritm**
#
# - **Decision Tree**

# %%
# Tree MODELS (1ta)
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# ## Decision Tree

# %%
dt = DecisionTreeClassifier(max_depth=10, min_samples_split=5,random_state=42)
rfe = RFE(dt, n_features_to_select=10)

rfe.fit(x_train, y_train)
selected_features = x_train.columns[rfe.support_]

dt.fit(x_train[selected_features], y_train)
y_pred = dt.predict(x_test[selected_features])

dt_score = accuracy_score(y_test, y_pred)

dt_precision = precision_score(y_test, y_pred)
dt_recall = recall_score(y_test, y_pred)
dt_f1 = f1_score(y_test, y_pred)

dt_scores = cross_val_score(dt, x_train[selected_features], y_train, cv=kf, scoring='f1_macro')

print(f'DecisionTree score: {dt_score}')

print(f'\nPrecision: {dt_precision}')
print(f'Recall: {dt_recall}')
print(f'F1-score: {dt_f1}')

print("\nK-Fold mean:", dt_scores.mean())
print("K-Fold std:", dt_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("\nSelected features:", list(selected_features))
# Out:
# DecisionTree score: 0.8363347013987771
#
# Precision: 0.8460697197539303
# Recall: 0.6898896444097647
# F1-score: 0.7600392975561833
#
# K-Fold mean: 0.8202508453881254
# K-Fold std: 0.004758452234811852
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.92      0.88     14907
#            1       0.85      0.69      0.76      8971
#
#     accuracy                           0.84     23878
#    macro avg       0.84      0.81      0.82     23878
# weighted avg       0.84      0.84      0.83     23878
#
#
# Selected features: ['country', 'market_segment', 'deposit_type', 'agent', 'customer_type', 'total_of_special_requests', 'lead_time_log', 'has_previous_cancel', 'room_changed', 'needs_parking']

# %% [markdown]
# ## 🧠 3. Ensemble Models
#
# **Jami: `12ta` algoritm**
#
# ### 📦 Bagging Family (4ta)
# - **Random Forest**
# - **Bagging Classifier**
# - **Extra Trees**
# - **Bagged Decision Tree**
#
# ### 🚀 Boosting Family (6ta)
# - **Gradient Boosting**
# - **Hist Gradient Boosting**
# - **AdaBoost**
# - **CatBoost**
# - **XGBoost**
# - **LightGBM**
#
# ### 🧩 Meta-Ensemble Methods
# - **Stacking**
# - **Voting**

# %%
# Bagging MODELS (3ta)
from sklearn.ensemble import (
    RandomForestClassifier,
    BaggingClassifier,
    ExtraTreesClassifier
)

# %% [markdown]
# # RandomForest

# %%
rf = RandomForestClassifier(n_estimators=300, max_depth=15, n_jobs=-1, random_state=42)
rfe = RFE(rf, n_features_to_select=10)

rfe.fit(x_train, y_train)
selected_features = x_train.columns[rfe.support_]

rf.fit(x_train[selected_features], y_train)
y_pred = rf.predict(x_test[selected_features])

rf_score = accuracy_score(y_test, y_pred)

rf_precision = precision_score(y_test, y_pred)
rf_recall = recall_score(y_test, y_pred)
rf_f1 = f1_score(y_test, y_pred)


rf_scores = cross_val_score(rf, x_train[selected_features], y_train, cv=kf, scoring='f1_macro')

print(f'RandomForest score: {rf_score}')

print(f'\nPrecision: {rf_precision}')
print(f'Recall: {rf_recall}')
print(f'F1-score: {rf_f1}')

print("\nK-Fold mean:", rf_scores.mean())
print("K-Fold std:", rf_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("\nSelected features:", list(selected_features))
# Out:
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForest score: 0.856604405729123
#
# Precision: 0.8523694575022234
# Recall: 0.7478541968565378
# F1-score: 0.7966987293670585
#
# K-Fold mean: 0.8362134211022688
# K-Fold std: 0.002047359843050365
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.92      0.89     14907
#            1       0.85      0.75      0.80      8971
#
#     accuracy                           0.86     23878
#    macro avg       0.86      0.83      0.84     23878
# weighted avg       0.86      0.86      0.85     23878
#
#
# Selected features: ['lead_time', 'country', 'market_segment', 'deposit_type', 'agent', 'adr', 'total_of_special_requests', 'lead_time_log', 'has_previous_cancel', 'adr_x_lead_time']

# %% [markdown]
# ## Bagging

# %%
bag = BaggingClassifier(n_estimators=200, random_state=42)

bag.fit(x_train, y_train)
y_pred = bag.predict(x_test)

bag_score = accuracy_score(y_test, y_pred)

bag_precision = precision_score(y_test, y_pred)
bag_recall = recall_score(y_test, y_pred)
bag_f1 = f1_score(y_test, y_pred)

bag_scores = cross_val_score(bag, x_train, y_train, cv=kf, scoring='f1_macro')

print(f'Bagging score: {bag_score}')

print(f'\nPrecision: {bag_precision}')
print(f'Recall: {bag_recall}')
print(f'F1-score: {bag_f1}')

print("\nK-Fold mean:", bag_scores.mean())
print("K-Fold std:", bag_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\ensemble\_bagging.py:930: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\ensemble\_bagging.py:930: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\ensemble\_bagging.py:930: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\ensemble\_bagging.py:930: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Bagging score: 0.8833235614373063
#
# Precision: 0.8696951583980873
# Recall: 0.8109463827889868
# F1-score: 0.8392939547761883
#
# K-Fold mean: 0.863529776425735
# K-Fold std: 0.0020729048508812413
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91     14907
#            1       0.87      0.81      0.84      8971
#
#     accuracy                           0.88     23878
#    macro avg       0.88      0.87      0.87     23878
# weighted avg       0.88      0.88      0.88     23878

# %% [markdown]
# ## Bagged DT

# %%
bag_dt = BaggingClassifier(
    estimator=DecisionTreeClassifier(max_depth=10),
    n_estimators=100,
    random_state=42
)

bag_dt.fit(x_train, y_train)
y_pred = bag_dt.predict(x_test)

bag_dt_score = accuracy_score(y_test, y_pred)

bag_dt_precision = precision_score(y_test, y_pred)
bag_dt_recall = recall_score(y_test, y_pred)
bag_dt_f1 = f1_score(y_test, y_pred)

bag_dt_scores = cross_val_score(bag_dt, x_train, y_train, cv=kf, scoring='f1_macro')

print(f'Bagged DT score: {bag_dt_score}')

print(f'\nPrecision: {bag_dt_precision}')
print(f'Recall: {bag_dt_recall}')
print(f'F1-score: {bag_dt_f1}')

print("\nK-Fold mean:", bag_dt_scores.mean())
print("K-Fold std:", bag_dt_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\ensemble\_bagging.py:930: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\ensemble\_bagging.py:930: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\ensemble\_bagging.py:930: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\ensemble\_bagging.py:930: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Bagged DT score: 0.8475584219783902
#
# Precision: 0.8260550458715596
# Recall: 0.75275888975588
# F1-score: 0.7877055873089933
#
# K-Fold mean: 0.8300327625670718
# K-Fold std: 0.0035730433703317376
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.90      0.88     14907
#            1       0.83      0.75      0.79      8971
#
#     accuracy                           0.85     23878
#    macro avg       0.84      0.83      0.83     23878
# weighted avg       0.85      0.85      0.85     23878

# %% [markdown]
# ## ExtraTrees

# %%
et = ExtraTreesClassifier(n_estimators=200, max_depth=15, random_state=42)
rfe = RFE(et, n_features_to_select=10)

rfe.fit(x_train, y_train)
selected_features = x_train.columns[rfe.support_]

et.fit(x_train[selected_features], y_train)
y_pred = et.predict(x_test[selected_features])

et_score = accuracy_score(y_test, y_pred)

et_precision = precision_score(y_test, y_pred)
et_recall = recall_score(y_test, y_pred)
et_f1 = f1_score(y_test, y_pred)

et_scores = cross_val_score(et, x_train[selected_features], y_train, cv=kf, scoring='f1_macro')

print(f'ExtraTrees score: {et_score}')

print(f'\nPrecision: {et_precision}')
print(f'Recall: {et_recall}')
print(f'F1-score: {et_f1}')

print("\nK-Fold mean:", et_scores.mean())
print("K-Fold std:", et_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("\nSelected features:", list(selected_features))
# Out:
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# ExtraTrees score: 0.8380936426836418
#
# Precision: 0.8340531344064913
# Recall: 0.710400178352469
# F1-score: 0.7672766674692993
#
# K-Fold mean: 0.8157075857895514
# K-Fold std: 0.002068896991407561
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.84      0.91      0.88     14907
#            1       0.83      0.71      0.77      8971
#
#     accuracy                           0.84     23878
#    macro avg       0.84      0.81      0.82     23878
# weighted avg       0.84      0.84      0.84     23878
#
#
# Selected features: ['country', 'market_segment', 'deposit_type', 'customer_type', 'total_of_special_requests', 'lead_time_log', 'has_previous_cancel', 'room_changed', 'is_last_minute', 'needs_parking']

# %%
# Boosting MODELS (6ta)
from sklearn.ensemble import (
    GradientBoostingClassifier,
    HistGradientBoostingClassifier,
    AdaBoostClassifier
)

from catboost import CatBoostClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

# %% [markdown]
# # Gradient Boosting

# %%
gb = GradientBoostingClassifier(n_estimators=300, learning_rate=0.05, max_depth=3, random_state=42)
rfe = RFE(gb, n_features_to_select=10)

rfe.fit(x_train, y_train)
selected_features = x_train.columns[rfe.support_]

gb.fit(x_train[selected_features], y_train)
y_pred = gb.predict(x_test[selected_features])

gb_score = accuracy_score(y_test, y_pred)

gb_precision = precision_score(y_test, y_pred)
gb_recall = recall_score(y_test, y_pred)
gb_f1 = f1_score(y_test, y_pred)

gb_scores = cross_val_score(gb, x_train[selected_features], y_train, cv=kf, scoring='f1_macro')

print(f'GradientBoosting score: {gb_score}')

print(f'\nPrecision: {gb_precision}')
print(f'Recall: {gb_recall}')
print(f'F1-score: {gb_f1}')

print("\nK-Fold mean:", gb_scores.mean())
print("K-Fold std:", gb_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("\nSelected features:", list(selected_features))
# Out:
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GradientBoosting score: 0.8462601557919424
#
# Precision: 0.8315815815815816
# Recall: 0.7408315683870249
# F1-score: 0.7835878087602429
#
# K-Fold mean: 0.8277748586703492
# K-Fold std: 0.001974827496031213
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.91      0.88     14907
#            1       0.83      0.74      0.78      8971
#
#     accuracy                           0.85     23878
#    macro avg       0.84      0.83      0.83     23878
# weighted avg       0.85      0.85      0.84     23878
#
#
# Selected features: ['country', 'market_segment', 'deposit_type', 'agent', 'required_car_parking_spaces', 'total_of_special_requests', 'lead_time_log', 'has_previous_cancel', 'room_changed', 'adr_x_lead_time']

# %% [markdown]
# # Hist Gradient Boosting

# %%
hgb = HistGradientBoostingClassifier(max_iter=300, learning_rate=0.05, max_depth=7, random_state=42)

hgb.fit(x_train, y_train)
y_pred = hgb.predict(x_test)

hgb_score = accuracy_score(y_test, y_pred)

hgb_precision = precision_score(y_test, y_pred)
hgb_recall = recall_score(y_test, y_pred)
hgb_f1 = f1_score(y_test, y_pred)

hgb_scores = cross_val_score(hgb, x_train, y_train, cv=kf, scoring='f1_macro')

print(f'HistGradientBoosting score: {hgb_score}')

print(f'\nPrecision: {hgb_precision}')
print(f'Recall: {hgb_recall}')
print(f'F1-score: {hgb_f1}')

print("\nK-Fold mean:", hgb_scores.mean())
print("K-Fold std:", hgb_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# HistGradientBoosting score: 0.8755339643186196
#
# Precision: 0.8629159104658197
# Recall: 0.7950061308661241
# F1-score: 0.8275702019029937
#
# K-Fold mean: 0.8573226123804484
# K-Fold std: 0.00225542328399786
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.92      0.90     14907
#            1       0.86      0.80      0.83      8971
#
#     accuracy                           0.88     23878
#    macro avg       0.87      0.86      0.87     23878
# weighted avg       0.87      0.88      0.87     23878

# %% [markdown]
# ## XGBoost

# %%
xgb = XGBClassifier(
    n_estimators=500,
    max_depth=6,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42
)

rfe = RFE(xgb, n_features_to_select=10)

rfe.fit(x_train, y_train)
selected_features = x_train.columns[rfe.support_]

xgb.fit(x_train[selected_features], y_train)
y_pred = xgb.predict(x_test[selected_features])

xgb_score = accuracy_score(y_test, y_pred)

xgb_precision = precision_score(y_test, y_pred)
xgb_recall = recall_score(y_test, y_pred)
xgb_f1 = f1_score(y_test, y_pred)

xgb_scores = cross_val_score(xgb, x_train[selected_features], y_train, cv=kf, scoring='f1_macro')

print(f'XGBoost score: {xgb_score}')

print(f'\nPrecision: {xgb_precision}')
print(f'Recall: {xgb_recall}')
print(f'F1-score: {xgb_f1}')

print("\nK-Fold mean:", xgb_scores.mean())
print("K-Fold std:", xgb_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("\nSelected features:", list(selected_features))
# Out:
# XGBoost score: 0.8401876204037189
#
# Precision: 0.822711906848629
# Recall: 0.7324712963995096
# F1-score: 0.7749734638518693
#
# K-Fold mean: 0.8180884438526951
# K-Fold std: 0.001696306682050892
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.91      0.88     14907
#            1       0.82      0.73      0.77      8971
#
#     accuracy                           0.84     23878
#    macro avg       0.84      0.82      0.83     23878
# weighted avg       0.84      0.84      0.84     23878
#
#
# Selected features: ['country', 'market_segment', 'previous_cancellations', 'deposit_type', 'agent', 'required_car_parking_spaces', 'total_of_special_requests', 'has_previous_cancel', 'room_changed', 'needs_parking']

# %% [markdown]
# ## AdaBoost

# %%
ab = AdaBoostClassifier(n_estimators=300, learning_rate=0.05, random_state=42)
rfe = RFE(ab, n_features_to_select=10)

rfe.fit(x_train, y_train)
selected_features = x_train.columns[rfe.support_]

ab.fit(x_train[selected_features], y_train)
y_pred = ab.predict(x_test[selected_features])

ab_score = accuracy_score(y_test, y_pred)

ab_precision = precision_score(y_test, y_pred)
ab_recall = recall_score(y_test, y_pred)
ab_f1 = f1_score(y_test, y_pred)

ab_scores = cross_val_score(ab, x_train[selected_features], y_train, cv=kf, scoring='f1_macro')

print(f'AdaBoost score: {ab_score}')

print(f'\nPrecision: {ab_precision}')
print(f'Recall: {ab_recall}')
print(f'F1-score: {ab_f1}')

print("\nK-Fold mean:", ab_scores.mean())
print("K-Fold std:", ab_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("\nSelected features:", list(selected_features))
# Out:
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# AdaBoost score: 0.7483876371555407
#
# Precision: 0.98749588680487
# Recall: 0.33452234979378
# F1-score: 0.49975020815986676
#
# K-Fold mean: 0.6698549538364471
# K-Fold std: 0.01295692921489107
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.71      1.00      0.83     14907
#            1       0.99      0.33      0.50      8971
#
#     accuracy                           0.75     23878
#    macro avg       0.85      0.67      0.67     23878
# weighted avg       0.82      0.75      0.71     23878
#
#
# Selected features: ['lead_time', 'country', 'previous_cancellations', 'deposit_type', 'required_car_parking_spaces', 'lead_time_log', 'has_previous_cancel', 'room_changed', 'adr_x_lead_time', 'needs_parking']

# %% [markdown]
# ## LightGBM

# %%
lgbm = LGBMClassifier(n_estimators=500, learning_rate=0.05, num_leaves=31, subsample=0.8, colsample_bytree=0.8, random_state=42)
rfe = RFE(lgbm, n_features_to_select=10)

rfe.fit(x_train, y_train)
selected_features = x_train.columns[rfe.support_]

lgbm.fit(x_train[selected_features], y_train)
y_pred = lgbm.predict(x_test[selected_features])

lgbm_score = accuracy_score(y_test, y_pred)

lgbm_precision = precision_score(y_test, y_pred)
lgbm_recall = recall_score(y_test, y_pred)
lgbm_f1 = f1_score(y_test, y_pred)

lgbm_scores = cross_val_score(lgbm, x_train[selected_features], y_train, cv=kf, scoring='f1_macro')

print(f'\nLightGBM score: {lgbm_score}')

print(f'\nPrecision: {lgbm_precision}')
print(f'Recall: {lgbm_recall}')
print(f'F1-score: {lgbm_f1}')

print("\nK-Fold mean:", lgbm_scores.mean())
print("K-Fold std:", lgbm_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("\nSelected features:", list(selected_features))
# Out:
# [LightGBM] [Info] Number of positive: 35253, number of negative: 60259
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005419 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2145
# [LightGBM] [Info] Number of data points in the train set: 95512, number of used features: 49
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.369095 -> initscore=-0.536101
# [LightGBM] [Info] Start training from score -0.536101
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Number of positive: 35253, number of negative: 60259
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005880 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2143
# [LightGBM] [Info] Number of data points in the train set: 95512, number of used features: 48
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.369095 -> initscore=-0.536101
# [LightGBM] [Info] Start training from score -0.536101
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Number of positive: 35253, number of negative: 60259
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005303 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2143
# [LightGBM] [Info] Number of data points in the train set: 95512, number of used features: 48
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.369095 -> initscore=-0.536101
# [LightGBM] [Info] Start training from score -0.536101
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Number of positive: 35253, number of negative: 60259
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005421 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2141
# [LightGBM] [Info] Number of data points in the train set: 95512, number of used features: 47
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.369095 -> initscore=-0.536101
# [LightGBM] [Info] Start training from score -0.536101
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Number of positive: 35253, number of negative: 60259
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004996 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2139
# [LightGBM] [Info] Number of data points in the train set: 95512, number of used features: 46
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.369095 -> initscore=-0.536101
# [LightGBM] [Info] Start training from score -0.536101
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Number of positive: 35253, number of negative: 60259
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005405 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2137
# [LightGBM] [Info] Number of data points in the train set: 95512, number of used features: 45
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.369095 -> initscore=-0.536101
# [LightGBM] [Info] Start training from score -0.536101
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Number of positive: 35253, number of negative: 60259
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004515 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2135
# [LightGBM] [Info] Number of data points in the train set: 95512, number of used features: 44
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.369095 -> initscore=-0.536101
# [LightGBM] [Info] Start training from score -0.536101
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Number of positive: 35253, number of negative: 60259
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005089 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2133
# [LightGBM] [Info] Number of data points in the train set: 95512, number of used features: 43
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.369095 -> initscore=-0.536101
# [LightGBM] [Info] Start training from score -0.536101
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Number of positive: 35253, number of negative: 60259
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005447 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2129
# [LightGBM] [Info] Number of data points in the train set: 95512, number of used features: 42
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.369095 -> initscore=-0.536101
# [LightGBM] [Info] Start training from score -0.536101
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Number of positive: 35253, number of negative: 60259
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004372 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2127
# [LightGBM] [Info] Number of data points in the train set: 95512, number of used features: 41
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.369095 -> initscore=-0.536101
# [LightGBM] [Info] Start training from score -0.536101
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Number of positive: 35253, number of negative: 60259
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004694 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2125
# [LightGBM] [Info] Number of data points in the train set: 95512, number of used features: 40
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.369095 -> initscore=-0.536101
# [LightGBM] [Info] Start training from score -0.536101
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Number of positive: 35253, number of negative: 60259
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004746 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2123
# [LightGBM] [Info] Number of data points in the train set: 95512, number of used features: 39
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.369095 -> initscore=-0.536101
# [LightGBM] [Info] Start training from score -0.536101
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Number of positive: 35253, number of negative: 60259
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004782 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2121
# [LightGBM] [Info] Number of data points in the train set: 95512, number of used features: 38
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.369095 -> initscore=-0.536101
# [LightGBM] [Info] Start training from score -0.536101
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Number of positive: 35253, number of negative: 60259
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004977 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2119
# [LightGBM] [Info] Number of data points in the train set: 95512, number of used features: 37
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.369095 -> initscore=-0.536101
# [LightGBM] [Info] Start training from score -0.536101
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Number of positive: 35253, number of negative: 60259
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004091 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2117
# [LightGBM] [Info] Number of data points in the train set: 95512, number of used features: 36
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.369095 -> initscore=-0.536101
# [LightGBM] [Info] Start training from score -0.536101
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Number of positive: 35253, number of negative: 60259
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004272 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2115
# [LightGBM] [Info] Number of data points in the train set: 95512, number of used features: 35
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.369095 -> initscore=-0.536101
# [LightGBM] [Info] Start training from score -0.536101
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Number of positive: 35253, number of negative: 60259
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003985 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2113
# [LightGBM] [Info] Number of data points in the train set: 95512, number of used features: 34
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.369095 -> initscore=-0.536101
# [LightGBM] [Info] Start training from score -0.536101
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Number of positive: 35253, number of negative: 60259
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003449 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2107
# [LightGBM] [Info] Number of data points in the train set: 95512, number of used features: 33
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.369095 -> initscore=-0.536101
# [LightGBM] [Info] Start training from score -0.536101
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Number of positive: 35253, number of negative: 60259
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004644 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2105
# [LightGBM] [Info] Number of data points in the train set: 95512, number of used features: 32
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.369095 -> initscore=-0.536101
# [LightGBM] [Info] Start training from score -0.536101
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Number of positive: 35253, number of negative: 60259
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003810 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2006
# [LightGBM] [Info] Number of data points in the train set: 95512, number of used features: 31
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.369095 -> initscore=-0.536101
# [LightGBM] [Info] Start training from score -0.536101
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Number of positive: 35253, number of negative: 60259
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004107 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2004
# [LightGBM] [Info] Number of data points in the train set: 95512, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.369095 -> initscore=-0.536101
# [LightGBM] [Info] Start training from score -0.536101
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Number of positive: 35253, number of negative: 60259
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003160 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1995
# [LightGBM] [Info] Number of data points in the train set: 95512, number of used features: 29
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.369095 -> initscore=-0.536101
# [LightGBM] [Info] Start training from score -0.536101
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Number of positive: 35253, number of negative: 60259
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003475 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1980
# [LightGBM] [Info] Number of data points in the train set: 95512, number of used features: 28
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.369095 -> initscore=-0.536101
# [LightGBM] [Info] Start training from score -0.536101
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Number of positive: 35253, number of negative: 60259
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003775 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1977
# [LightGBM] [Info] Number of data points in the train set: 95512, number of used features: 27
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.369095 -> initscore=-0.536101
# [LightGBM] [Info] Start training from score -0.536101
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Number of positive: 35253, number of negative: 60259
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003039 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1935
# [LightGBM] [Info] Number of data points in the train set: 95512, number of used features: 26
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.369095 -> initscore=-0.536101
# [LightGBM] [Info] Start training from score -0.536101
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Number of positive: 35253, number of negative: 60259
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003502 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1924
# [LightGBM] [Info] Number of data points in the train set: 95512, number of used features: 25
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.369095 -> initscore=-0.536101
# [LightGBM] [Info] Start training from score -0.536101
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Number of positive: 35253, number of negative: 60259
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.008500 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1919
# [LightGBM] [Info] Number of data points in the train set: 95512, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.369095 -> initscore=-0.536101
# [LightGBM] [Info] Start training from score -0.536101
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Number of positive: 35253, number of negative: 60259
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.009278 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1915
# [LightGBM] [Info] Number of data points in the train set: 95512, number of used features: 23
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.369095 -> initscore=-0.536101
# [LightGBM] [Info] Start training from score -0.536101
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Number of positive: 35253, number of negative: 60259
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.010434 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1900
# [LightGBM] [Info] Number of data points in the train set: 95512, number of used features: 22
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.369095 -> initscore=-0.536101
# [LightGBM] [Info] Start training from score -0.536101
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Number of positive: 35253, number of negative: 60259
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002703 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1888
# [LightGBM] [Info] Number of data points in the train set: 95512, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.369095 -> initscore=-0.536101
# [LightGBM] [Info] Start training from score -0.536101
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Number of positive: 35253, number of negative: 60259
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002975 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1874
# [LightGBM] [Info] Number of data points in the train set: 95512, number of used features: 20
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.369095 -> initscore=-0.536101
# [LightGBM] [Info] Start training from score -0.536101
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Number of positive: 35253, number of negative: 60259
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002274 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1869
# [LightGBM] [Info] Number of data points in the train set: 95512, number of used features: 19
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.369095 -> initscore=-0.536101
# [LightGBM] [Info] Start training from score -0.536101
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Number of positive: 35253, number of negative: 60259
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002207 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1852
# [LightGBM] [Info] Number of data points in the train set: 95512, number of used features: 18
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.369095 -> initscore=-0.536101
# [LightGBM] [Info] Start training from score -0.536101
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Number of positive: 35253, number of negative: 60259
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002289 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1842
# [LightGBM] [Info] Number of data points in the train set: 95512, number of used features: 17
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.369095 -> initscore=-0.536101
# [LightGBM] [Info] Start training from score -0.536101
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Number of positive: 35253, number of negative: 60259
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002001 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1587
# [LightGBM] [Info] Number of data points in the train set: 95512, number of used features: 16
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.369095 -> initscore=-0.536101
# [LightGBM] [Info] Start training from score -0.536101
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Number of positive: 35253, number of negative: 60259
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001708 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1559
# [LightGBM] [Info] Number of data points in the train set: 95512, number of used features: 15
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.369095 -> initscore=-0.536101
# [LightGBM] [Info] Start training from score -0.536101
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Number of positive: 35253, number of negative: 60259
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002457 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1553
# [LightGBM] [Info] Number of data points in the train set: 95512, number of used features: 14
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.369095 -> initscore=-0.536101
# [LightGBM] [Info] Start training from score -0.536101
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Number of positive: 35253, number of negative: 60259
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001967 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1522
# [LightGBM] [Info] Number of data points in the train set: 95512, number of used features: 13
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.369095 -> initscore=-0.536101
# [LightGBM] [Info] Start training from score -0.536101
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Number of positive: 35253, number of negative: 60259
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000317 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1518
# [LightGBM] [Info] Number of data points in the train set: 95512, number of used features: 12
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.369095 -> initscore=-0.536101
# [LightGBM] [Info] Start training from score -0.536101
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Number of positive: 35253, number of negative: 60259
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001090 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1507
# [LightGBM] [Info] Number of data points in the train set: 95512, number of used features: 11
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.369095 -> initscore=-0.536101
# [LightGBM] [Info] Start training from score -0.536101
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Number of positive: 35253, number of negative: 60259
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002193 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1477
# [LightGBM] [Info] Number of data points in the train set: 95512, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.369095 -> initscore=-0.536101
# [LightGBM] [Info] Start training from score -0.536101
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Number of positive: 35253, number of negative: 60259
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000412 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1477
# [LightGBM] [Info] Number of data points in the train set: 95512, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.369095 -> initscore=-0.536101
# [LightGBM] [Info] Start training from score -0.536101
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Number of positive: 23553, number of negative: 40121
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000986 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1462
# [LightGBM] [Info] Number of data points in the train set: 63674, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.369900 -> initscore=-0.532647
# [LightGBM] [Info] Start training from score -0.532647
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Number of positive: 23477, number of negative: 40198
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001056 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1461
# [LightGBM] [Info] Number of data points in the train set: 63675, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.368700 -> initscore=-0.537796
# [LightGBM] [Info] Start training from score -0.537796
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Number of positive: 23476, number of negative: 40199
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000247 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1465
# [LightGBM] [Info] Number of data points in the train set: 63675, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.368685 -> initscore=-0.537863
# [LightGBM] [Info] Start training from score -0.537863
#
# LightGBM score: 0.8245665466119441
#
# Precision: 0.8186300639658849
# Recall: 0.6847620109240887
# F1-score: 0.7457359635811837
#
# K-Fold mean: 0.7963145357113373
# K-Fold std: 0.0032780912124363735
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.91      0.87     14907
#            1       0.82      0.68      0.75      8971
#
#     accuracy                           0.82     23878
#    macro avg       0.82      0.80      0.81     23878
# weighted avg       0.82      0.82      0.82     23878
#
#
# Selected features: ['lead_time', 'arrival_date_week_number', 'country', 'market_segment', 'agent', 'adr', 'total_nights', 'adr_per_person', 'weekend_ratio', 'adr_x_lead_time']

# %% [markdown]
# ## CatBoost

# %%
cat = CatBoostClassifier(iterations=500, depth=8,learning_rate=0.05, random_state=42)
rfe = RFE(cat, n_features_to_select=10)

rfe.fit(x_train, y_train)
selected_features = x_train.columns[rfe.support_]

cat.fit(x_train[selected_features], y_train)
y_pred = cat.predict(x_test[selected_features])

cat_score = accuracy_score(y_test, y_pred)

cat_precision = precision_score(y_test, y_pred)
cat_recall = recall_score(y_test, y_pred)
cat_f1 = f1_score(y_test, y_pred)

cat_scores = cross_val_score(cat, x_train[selected_features], y_train, cv=kf, scoring='f1_macro')

print(f'CatBoost score: {cat_score}')

print(f'\nPrecision: {cat_precision}')
print(f'Recall: {cat_recall}')
print(f'F1-score: {cat_f1}')

print("\nK-Fold mean:", cat_scores.mean())
print("K-Fold std:", cat_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("\nSelected features:", list(selected_features))
# Out:
# 0:	learn: 0.6420115	total: 169ms	remaining: 1m 24s
# 1:	learn: 0.5947196	total: 180ms	remaining: 44.8s
# 2:	learn: 0.5581536	total: 191ms	remaining: 31.6s
# 3:	learn: 0.5303284	total: 202ms	remaining: 25s
# 4:	learn: 0.5064711	total: 211ms	remaining: 20.9s
# 5:	learn: 0.4877656	total: 222ms	remaining: 18.3s
# 6:	learn: 0.4709348	total: 233ms	remaining: 16.4s
# 7:	learn: 0.4570079	total: 243ms	remaining: 14.9s
# 8:	learn: 0.4453800	total: 254ms	remaining: 13.9s
# 9:	learn: 0.4348332	total: 265ms	remaining: 13s
# 10:	learn: 0.4258842	total: 276ms	remaining: 12.3s
# 11:	learn: 0.4176835	total: 287ms	remaining: 11.7s
# 12:	learn: 0.4114668	total: 297ms	remaining: 11.1s
# 13:	learn: 0.4054910	total: 322ms	remaining: 11.2s
# 14:	learn: 0.3977870	total: 332ms	remaining: 10.7s
# 15:	learn: 0.3929081	total: 343ms	remaining: 10.4s
# 16:	learn: 0.3885163	total: 354ms	remaining: 10.1s
# 17:	learn: 0.3840380	total: 364ms	remaining: 9.74s
# 18:	learn: 0.3815239	total: 374ms	remaining: 9.46s
# 19:	learn: 0.3764762	total: 385ms	remaining: 9.23s
# 20:	learn: 0.3724470	total: 395ms	remaining: 9.01s
# 21:	learn: 0.3691544	total: 406ms	remaining: 8.82s
# 22:	learn: 0.3662890	total: 416ms	remaining: 8.63s
# 23:	learn: 0.3631711	total: 426ms	remaining: 8.44s
# 24:	learn: 0.3614970	total: 436ms	remaining: 8.29s
# 25:	learn: 0.3583266	total: 447ms	remaining: 8.15s
# 26:	learn: 0.3556531	total: 458ms	remaining: 8.02s
# 27:	learn: 0.3537729	total: 470ms	remaining: 7.92s
# 28:	learn: 0.3518955	total: 482ms	remaining: 7.83s
# 29:	learn: 0.3503624	total: 492ms	remaining: 7.71s
# 30:	learn: 0.3489252	total: 504ms	remaining: 7.62s
# 31:	learn: 0.3472765	total: 514ms	remaining: 7.52s
# 32:	learn: 0.3458894	total: 525ms	remaining: 7.42s
# 33:	learn: 0.3441071	total: 534ms	remaining: 7.32s
# 34:	learn: 0.3428176	total: 545ms	remaining: 7.24s
# 35:	learn: 0.3415587	total: 555ms	remaining: 7.16s
# 36:	learn: 0.3406835	total: 566ms	remaining: 7.08s
# 37:	learn: 0.3391325	total: 577ms	remaining: 7.01s
# 38:	learn: 0.3380868	total: 588ms	remaining: 6.95s
# 39:	learn: 0.3373404	total: 598ms	remaining: 6.87s
# 40:	learn: 0.3361851	total: 609ms	remaining: 6.81s
# 41:	learn: 0.3348598	total: 619ms	remaining: 6.75s
# 42:	learn: 0.3343110	total: 629ms	remaining: 6.68s
# 43:	learn: 0.3335122	total: 640ms	remaining: 6.63s
# 44:	learn: 0.3328088	total: 650ms	remaining: 6.57s
# 45:	learn: 0.3322473	total: 660ms	remaining: 6.51s
# 46:	learn: 0.3307970	total: 670ms	remaining: 6.46s
# 47:	learn: 0.3295044	total: 681ms	remaining: 6.41s
# 48:	learn: 0.3282344	total: 691ms	remaining: 6.36s
# 49:	learn: 0.3271349	total: 702ms	remaining: 6.31s
# 50:	learn: 0.3264453	total: 712ms	remaining: 6.27s
# 51:	learn: 0.3256375	total: 722ms	remaining: 6.22s
# 52:	learn: 0.3252455	total: 732ms	remaining: 6.18s
# 53:	learn: 0.3242060	total: 743ms	remaining: 6.13s
# 54:	learn: 0.3236279	total: 753ms	remaining: 6.09s
# 55:	learn: 0.3229831	total: 764ms	remaining: 6.05s
# 56:	learn: 0.3225582	total: 774ms	remaining: 6.01s
# 57:	learn: 0.3221692	total: 784ms	remaining: 5.97s
# 58:	learn: 0.3218149	total: 794ms	remaining: 5.93s
# 59:	learn: 0.3212440	total: 804ms	remaining: 5.9s
# 60:	learn: 0.3208166	total: 814ms	remaining: 5.86s
# 61:	learn: 0.3202026	total: 823ms	remaining: 5.82s
# 62:	learn: 0.3196925	total: 834ms	remaining: 5.78s
# 63:	learn: 0.3192411	total: 844ms	remaining: 5.75s
# 64:	learn: 0.3189525	total: 854ms	remaining: 5.72s
# 65:	learn: 0.3183502	total: 865ms	remaining: 5.69s
# 66:	learn: 0.3173746	total: 875ms	remaining: 5.65s
# 67:	learn: 0.3171153	total: 884ms	remaining: 5.61s
# 68:	learn: 0.3166864	total: 895ms	remaining: 5.59s
# 69:	learn: 0.3157873	total: 905ms	remaining: 5.56s
# 70:	learn: 0.3153539	total: 915ms	remaining: 5.53s
# 71:	learn: 0.3150231	total: 925ms	remaining: 5.5s
# 72:	learn: 0.3143463	total: 935ms	remaining: 5.47s
# 73:	learn: 0.3139225	total: 946ms	remaining: 5.45s
# 74:	learn: 0.3135907	total: 956ms	remaining: 5.42s
# 75:	learn: 0.3130416	total: 966ms	remaining: 5.39s
# 76:	learn: 0.3127417	total: 976ms	remaining: 5.36s
# 77:	learn: 0.3123659	total: 986ms	remaining: 5.33s
# 78:	learn: 0.3120183	total: 996ms	remaining: 5.31s
# 79:	learn: 0.3116570	total: 1.01s	remaining: 5.28s
# 80:	learn: 0.3113306	total: 1.02s	remaining: 5.26s
# 81:	learn: 0.3110687	total: 1.03s	remaining: 5.24s
# 82:	learn: 0.3107745	total: 1.04s	remaining: 5.21s
# 83:	learn: 0.3104878	total: 1.05s	remaining: 5.19s
# 84:	learn: 0.3098917	total: 1.06s	remaining: 5.16s
# 85:	learn: 0.3092939	total: 1.07s	remaining: 5.14s
# 86:	learn: 0.3090578	total: 1.08s	remaining: 5.12s
# 87:	learn: 0.3084450	total: 1.09s	remaining: 5.1s
# 88:	learn: 0.3080951	total: 1.1s	remaining: 5.08s
# 89:	learn: 0.3073866	total: 1.11s	remaining: 5.06s
# 90:	learn: 0.3070151	total: 1.12s	remaining: 5.04s
# 91:	learn: 0.3068356	total: 1.13s	remaining: 5.02s
# 92:	learn: 0.3066104	total: 1.14s	remaining: 4.99s
# 93:	learn: 0.3062811	total: 1.15s	remaining: 4.97s
# 94:	learn: 0.3061215	total: 1.16s	remaining: 4.94s
# 95:	learn: 0.3060043	total: 1.17s	remaining: 4.92s
# 96:	learn: 0.3053985	total: 1.18s	remaining: 4.9s
# 97:	learn: 0.3052206	total: 1.19s	remaining: 4.88s
# 98:	learn: 0.3049783	total: 1.2s	remaining: 4.86s
# 99:	learn: 0.3046365	total: 1.21s	remaining: 4.84s
# 100:	learn: 0.3039873	total: 1.22s	remaining: 4.82s
# 101:	learn: 0.3037881	total: 1.23s	remaining: 4.8s
# 102:	learn: 0.3036496	total: 1.24s	remaining: 4.78s
# 103:	learn: 0.3033708	total: 1.25s	remaining: 4.76s
# 104:	learn: 0.3031807	total: 1.26s	remaining: 4.74s
# 105:	learn: 0.3028688	total: 1.27s	remaining: 4.72s
# 106:	learn: 0.3025616	total: 1.28s	remaining: 4.7s
# 107:	learn: 0.3023050	total: 1.29s	remaining: 4.68s
# 108:	learn: 0.3019910	total: 1.3s	remaining: 4.66s
# 109:	learn: 0.3018202	total: 1.31s	remaining: 4.64s
# 110:	learn: 0.3016034	total: 1.32s	remaining: 4.62s
# 111:	learn: 0.3014421	total: 1.33s	remaining: 4.6s
# 112:	learn: 0.3012772	total: 1.34s	remaining: 4.58s
# 113:	learn: 0.3007682	total: 1.35s	remaining: 4.56s
# 114:	learn: 0.3005553	total: 1.36s	remaining: 4.54s
# 115:	learn: 0.3003883	total: 1.37s	remaining: 4.53s
# 116:	learn: 0.3001167	total: 1.38s	remaining: 4.51s
# 117:	learn: 0.2999315	total: 1.39s	remaining: 4.49s
# 118:	learn: 0.2996585	total: 1.4s	remaining: 4.48s
# 119:	learn: 0.2994655	total: 1.41s	remaining: 4.46s
# 120:	learn: 0.2993632	total: 1.42s	remaining: 4.44s
# 121:	learn: 0.2991204	total: 1.43s	remaining: 4.42s
# 122:	learn: 0.2989216	total: 1.44s	remaining: 4.41s
# 123:	learn: 0.2985363	total: 1.45s	remaining: 4.39s
# 124:	learn: 0.2982795	total: 1.46s	remaining: 4.38s
# 125:	learn: 0.2980765	total: 1.47s	remaining: 4.37s
# 126:	learn: 0.2976429	total: 1.48s	remaining: 4.35s
# 127:	learn: 0.2974451	total: 1.49s	remaining: 4.33s
# 128:	learn: 0.2971744	total: 1.5s	remaining: 4.32s
# 129:	learn: 0.2969860	total: 1.51s	remaining: 4.3s
# 130:	learn: 0.2968494	total: 1.52s	remaining: 4.28s
# 131:	learn: 0.2966388	total: 1.53s	remaining: 4.26s
# 132:	learn: 0.2963556	total: 1.54s	remaining: 4.25s
# 133:	learn: 0.2961808	total: 1.55s	remaining: 4.24s
# 134:	learn: 0.2959890	total: 1.56s	remaining: 4.23s
# 135:	learn: 0.2959375	total: 1.57s	remaining: 4.21s
# 136:	learn: 0.2956840	total: 1.58s	remaining: 4.19s
# 137:	learn: 0.2956146	total: 1.59s	remaining: 4.18s
# 138:	learn: 0.2953712	total: 1.6s	remaining: 4.16s
# 139:	learn: 0.2949915	total: 1.61s	remaining: 4.15s
# 140:	learn: 0.2948202	total: 1.62s	remaining: 4.13s
# 141:	learn: 0.2947222	total: 1.63s	remaining: 4.11s
# 142:	learn: 0.2945103	total: 1.64s	remaining: 4.1s
# 143:	learn: 0.2940899	total: 1.65s	remaining: 4.09s
# 144:	learn: 0.2940240	total: 1.66s	remaining: 4.07s
# 145:	learn: 0.2939281	total: 1.67s	remaining: 4.05s
# 146:	learn: 0.2937279	total: 1.68s	remaining: 4.04s
# 147:	learn: 0.2936412	total: 1.69s	remaining: 4.02s
# 148:	learn: 0.2934514	total: 1.7s	remaining: 4.01s
# 149:	learn: 0.2932966	total: 1.71s	remaining: 4s
# 150:	learn: 0.2931811	total: 1.72s	remaining: 3.98s
# 151:	learn: 0.2929119	total: 1.73s	remaining: 3.97s
# 152:	learn: 0.2927867	total: 1.74s	remaining: 3.95s
# 153:	learn: 0.2925614	total: 1.75s	remaining: 3.94s
# 154:	learn: 0.2923945	total: 1.76s	remaining: 3.92s
# 155:	learn: 0.2922162	total: 1.77s	remaining: 3.91s
# 156:	learn: 0.2921493	total: 1.78s	remaining: 3.89s
# 157:	learn: 0.2919189	total: 1.79s	remaining: 3.88s
# 158:	learn: 0.2917690	total: 1.8s	remaining: 3.86s
# 159:	learn: 0.2916065	total: 1.81s	remaining: 3.85s
# 160:	learn: 0.2915274	total: 1.82s	remaining: 3.83s
# 161:	learn: 0.2914053	total: 1.83s	remaining: 3.82s
# 162:	learn: 0.2910006	total: 1.84s	remaining: 3.81s
# 163:	learn: 0.2907684	total: 1.85s	remaining: 3.79s
# 164:	learn: 0.2907506	total: 1.86s	remaining: 3.78s
# 165:	learn: 0.2904313	total: 1.87s	remaining: 3.77s
# 166:	learn: 0.2902710	total: 1.88s	remaining: 3.75s
# 167:	learn: 0.2901029	total: 1.89s	remaining: 3.74s
# 168:	learn: 0.2900047	total: 1.9s	remaining: 3.73s
# 169:	learn: 0.2898057	total: 1.91s	remaining: 3.71s
# 170:	learn: 0.2896791	total: 1.92s	remaining: 3.7s
# 171:	learn: 0.2894442	total: 1.93s	remaining: 3.69s
# 172:	learn: 0.2892855	total: 1.94s	remaining: 3.67s
# 173:	learn: 0.2891070	total: 1.95s	remaining: 3.66s
# 174:	learn: 0.2890099	total: 1.96s	remaining: 3.65s
# 175:	learn: 0.2886872	total: 1.97s	remaining: 3.63s
# 176:	learn: 0.2885433	total: 1.98s	remaining: 3.62s
# 177:	learn: 0.2884461	total: 2s	remaining: 3.61s
# 178:	learn: 0.2882014	total: 2s	remaining: 3.6s
# 179:	learn: 0.2879823	total: 2.02s	remaining: 3.58s
# 180:	learn: 0.2878477	total: 2.03s	remaining: 3.57s
# 181:	learn: 0.2877376	total: 2.04s	remaining: 3.56s
# 182:	learn: 0.2876544	total: 2.05s	remaining: 3.55s
# 183:	learn: 0.2875675	total: 2.06s	remaining: 3.53s
# 184:	learn: 0.2873534	total: 2.07s	remaining: 3.52s
# 185:	learn: 0.2872867	total: 2.08s	remaining: 3.51s
# 186:	learn: 0.2871444	total: 2.09s	remaining: 3.49s
# 187:	learn: 0.2870504	total: 2.1s	remaining: 3.48s
# 188:	learn: 0.2866473	total: 2.11s	remaining: 3.47s
# 189:	learn: 0.2864084	total: 2.12s	remaining: 3.46s
# 190:	learn: 0.2862901	total: 2.13s	remaining: 3.44s
# 191:	learn: 0.2860582	total: 2.14s	remaining: 3.43s
# 192:	learn: 0.2859582	total: 2.15s	remaining: 3.42s
# 193:	learn: 0.2857934	total: 2.16s	remaining: 3.4s
# 194:	learn: 0.2856940	total: 2.17s	remaining: 3.39s
# 195:	learn: 0.2855706	total: 2.18s	remaining: 3.38s
# 196:	learn: 0.2854575	total: 2.19s	remaining: 3.36s
# 197:	learn: 0.2853104	total: 2.2s	remaining: 3.35s
# 198:	learn: 0.2851806	total: 2.21s	remaining: 3.34s
# 199:	learn: 0.2850760	total: 2.22s	remaining: 3.32s
# 200:	learn: 0.2849381	total: 2.23s	remaining: 3.31s
# 201:	learn: 0.2847206	total: 2.24s	remaining: 3.3s
# 202:	learn: 0.2845489	total: 2.25s	remaining: 3.29s
# 203:	learn: 0.2844519	total: 2.26s	remaining: 3.27s
# 204:	learn: 0.2843069	total: 2.27s	remaining: 3.26s
# 205:	learn: 0.2842020	total: 2.28s	remaining: 3.25s
# 206:	learn: 0.2840465	total: 2.29s	remaining: 3.24s
# 207:	learn: 0.2837531	total: 2.3s	remaining: 3.22s
# 208:	learn: 0.2836633	total: 2.31s	remaining: 3.21s
# 209:	learn: 0.2835520	total: 2.32s	remaining: 3.2s
# 210:	learn: 0.2833524	total: 2.33s	remaining: 3.19s
# 211:	learn: 0.2832280	total: 2.34s	remaining: 3.17s
# 212:	learn: 0.2831445	total: 2.35s	remaining: 3.16s
# 213:	learn: 0.2830150	total: 2.36s	remaining: 3.15s
# 214:	learn: 0.2828567	total: 2.37s	remaining: 3.14s
# 215:	learn: 0.2827485	total: 2.38s	remaining: 3.13s
# 216:	learn: 0.2825642	total: 2.39s	remaining: 3.11s
# 217:	learn: 0.2823376	total: 2.4s	remaining: 3.1s
# 218:	learn: 0.2821895	total: 2.41s	remaining: 3.09s
# 219:	learn: 0.2821296	total: 2.42s	remaining: 3.08s
# 220:	learn: 0.2820537	total: 2.43s	remaining: 3.06s
# 221:	learn: 0.2819737	total: 2.44s	remaining: 3.05s
# 222:	learn: 0.2818749	total: 2.45s	remaining: 3.04s
# 223:	learn: 0.2817476	total: 2.46s	remaining: 3.03s
# 224:	learn: 0.2816708	total: 2.47s	remaining: 3.02s
# 225:	learn: 0.2815181	total: 2.48s	remaining: 3s
# 226:	learn: 0.2814220	total: 2.49s	remaining: 2.99s
# 227:	learn: 0.2813194	total: 2.5s	remaining: 2.98s
# 228:	learn: 0.2809905	total: 2.51s	remaining: 2.97s
# 229:	learn: 0.2808660	total: 2.52s	remaining: 2.96s
# 230:	learn: 0.2805588	total: 2.53s	remaining: 2.94s
# 231:	learn: 0.2803881	total: 2.54s	remaining: 2.93s
# 232:	learn: 0.2803008	total: 2.55s	remaining: 2.92s
# 233:	learn: 0.2801585	total: 2.56s	remaining: 2.91s
# 234:	learn: 0.2800772	total: 2.57s	remaining: 2.9s
# 235:	learn: 0.2798887	total: 2.58s	remaining: 2.88s
# 236:	learn: 0.2797682	total: 2.59s	remaining: 2.87s
# 237:	learn: 0.2796866	total: 2.6s	remaining: 2.86s
# 238:	learn: 0.2796194	total: 2.61s	remaining: 2.85s
# 239:	learn: 0.2795158	total: 2.62s	remaining: 2.84s
# 240:	learn: 0.2794055	total: 2.63s	remaining: 2.83s
# 241:	learn: 0.2791708	total: 2.64s	remaining: 2.81s
# 242:	learn: 0.2790586	total: 2.65s	remaining: 2.8s
# 243:	learn: 0.2789068	total: 2.66s	remaining: 2.79s
# 244:	learn: 0.2788299	total: 2.67s	remaining: 2.78s
# 245:	learn: 0.2787196	total: 2.68s	remaining: 2.77s
# 246:	learn: 0.2786310	total: 2.69s	remaining: 2.76s
# 247:	learn: 0.2783381	total: 2.7s	remaining: 2.74s
# 248:	learn: 0.2782330	total: 2.71s	remaining: 2.73s
# 249:	learn: 0.2781584	total: 2.72s	remaining: 2.72s
# 250:	learn: 0.2779799	total: 2.73s	remaining: 2.71s
# 251:	learn: 0.2778182	total: 2.74s	remaining: 2.7s
# 252:	learn: 0.2777582	total: 2.75s	remaining: 2.69s
# 253:	learn: 0.2776764	total: 2.76s	remaining: 2.67s
# 254:	learn: 0.2775952	total: 2.77s	remaining: 2.66s
# 255:	learn: 0.2774376	total: 2.78s	remaining: 2.65s
# 256:	learn: 0.2772656	total: 2.79s	remaining: 2.64s
# 257:	learn: 0.2770749	total: 2.8s	remaining: 2.63s
# 258:	learn: 0.2769471	total: 2.81s	remaining: 2.62s
# 259:	learn: 0.2768634	total: 2.82s	remaining: 2.61s
# 260:	learn: 0.2767541	total: 2.83s	remaining: 2.59s
# 261:	learn: 0.2765996	total: 2.84s	remaining: 2.58s
# 262:	learn: 0.2764478	total: 2.86s	remaining: 2.57s
# 263:	learn: 0.2763576	total: 2.87s	remaining: 2.56s
# 264:	learn: 0.2762430	total: 2.88s	remaining: 2.55s
# 265:	learn: 0.2761548	total: 2.88s	remaining: 2.54s
# 266:	learn: 0.2760440	total: 2.9s	remaining: 2.53s
# 267:	learn: 0.2758080	total: 2.9s	remaining: 2.51s
# 268:	learn: 0.2756413	total: 2.92s	remaining: 2.5s
# 269:	learn: 0.2755746	total: 2.92s	remaining: 2.49s
# 270:	learn: 0.2753864	total: 2.94s	remaining: 2.48s
# 271:	learn: 0.2752346	total: 2.94s	remaining: 2.47s
# 272:	learn: 0.2751449	total: 2.96s	remaining: 2.46s
# 273:	learn: 0.2750404	total: 2.96s	remaining: 2.44s
# 274:	learn: 0.2748964	total: 2.98s	remaining: 2.43s
# 275:	learn: 0.2747683	total: 2.99s	remaining: 2.43s
# 276:	learn: 0.2746405	total: 3s	remaining: 2.42s
# 277:	learn: 0.2745146	total: 3.01s	remaining: 2.4s
# 278:	learn: 0.2743928	total: 3.02s	remaining: 2.39s
# 279:	learn: 0.2742521	total: 3.03s	remaining: 2.38s
# 280:	learn: 0.2741044	total: 3.04s	remaining: 2.37s
# 281:	learn: 0.2739713	total: 3.05s	remaining: 2.36s
# 282:	learn: 0.2738469	total: 3.06s	remaining: 2.35s
# 283:	learn: 0.2737619	total: 3.07s	remaining: 2.34s
# 284:	learn: 0.2736190	total: 3.08s	remaining: 2.33s
# 285:	learn: 0.2735750	total: 3.09s	remaining: 2.31s
# 286:	learn: 0.2734724	total: 3.1s	remaining: 2.3s
# 287:	learn: 0.2733651	total: 3.11s	remaining: 2.29s
# 288:	learn: 0.2732435	total: 3.12s	remaining: 2.28s
# 289:	learn: 0.2731467	total: 3.13s	remaining: 2.27s
# 290:	learn: 0.2730768	total: 3.14s	remaining: 2.26s
# 291:	learn: 0.2729741	total: 3.15s	remaining: 2.25s
# 292:	learn: 0.2728688	total: 3.16s	remaining: 2.23s
# 293:	learn: 0.2727984	total: 3.17s	remaining: 2.22s
# 294:	learn: 0.2727009	total: 3.18s	remaining: 2.21s
# 295:	learn: 0.2726396	total: 3.19s	remaining: 2.2s
# 296:	learn: 0.2723923	total: 3.2s	remaining: 2.19s
# 297:	learn: 0.2723365	total: 3.21s	remaining: 2.18s
# 298:	learn: 0.2721805	total: 3.22s	remaining: 2.17s
# 299:	learn: 0.2720357	total: 3.23s	remaining: 2.16s
# 300:	learn: 0.2718494	total: 3.24s	remaining: 2.15s
# 301:	learn: 0.2717935	total: 3.25s	remaining: 2.13s
# 302:	learn: 0.2717245	total: 3.27s	remaining: 2.12s
# 303:	learn: 0.2716158	total: 3.27s	remaining: 2.11s
# 304:	learn: 0.2714727	total: 3.29s	remaining: 2.1s
# 305:	learn: 0.2713644	total: 3.3s	remaining: 2.09s
# 306:	learn: 0.2712841	total: 3.31s	remaining: 2.08s
# 307:	learn: 0.2711673	total: 3.32s	remaining: 2.07s
# 308:	learn: 0.2710766	total: 3.33s	remaining: 2.06s
# 309:	learn: 0.2709333	total: 3.34s	remaining: 2.04s
# 310:	learn: 0.2708303	total: 3.35s	remaining: 2.04s
# 311:	learn: 0.2707128	total: 3.36s	remaining: 2.02s
# 312:	learn: 0.2706183	total: 3.37s	remaining: 2.01s
# 313:	learn: 0.2705110	total: 3.38s	remaining: 2s
# 314:	learn: 0.2703718	total: 3.39s	remaining: 1.99s
# 315:	learn: 0.2701810	total: 3.4s	remaining: 1.98s
# 316:	learn: 0.2700642	total: 3.41s	remaining: 1.97s
# 317:	learn: 0.2699897	total: 3.42s	remaining: 1.96s
# 318:	learn: 0.2698824	total: 3.43s	remaining: 1.95s
# 319:	learn: 0.2697459	total: 3.44s	remaining: 1.94s
# 320:	learn: 0.2696420	total: 3.45s	remaining: 1.92s
# 321:	learn: 0.2695371	total: 3.46s	remaining: 1.91s
# 322:	learn: 0.2694197	total: 3.47s	remaining: 1.9s
# 323:	learn: 0.2691806	total: 3.48s	remaining: 1.89s
# 324:	learn: 0.2690864	total: 3.49s	remaining: 1.88s
# 325:	learn: 0.2690354	total: 3.5s	remaining: 1.87s
# 326:	learn: 0.2688936	total: 3.51s	remaining: 1.86s
# 327:	learn: 0.2687677	total: 3.52s	remaining: 1.85s
# 328:	learn: 0.2686728	total: 3.53s	remaining: 1.84s
# 329:	learn: 0.2685858	total: 3.54s	remaining: 1.82s
# 330:	learn: 0.2684042	total: 3.55s	remaining: 1.81s
# 331:	learn: 0.2683576	total: 3.56s	remaining: 1.8s
# 332:	learn: 0.2682608	total: 3.57s	remaining: 1.79s
# 333:	learn: 0.2681458	total: 3.58s	remaining: 1.78s
# 334:	learn: 0.2680070	total: 3.59s	remaining: 1.77s
# 335:	learn: 0.2679351	total: 3.6s	remaining: 1.76s
# 336:	learn: 0.2678116	total: 3.62s	remaining: 1.75s
# 337:	learn: 0.2677135	total: 3.62s	remaining: 1.74s
# 338:	learn: 0.2675995	total: 3.63s	remaining: 1.73s
# 339:	learn: 0.2675435	total: 3.64s	remaining: 1.71s
# 340:	learn: 0.2674763	total: 3.65s	remaining: 1.7s
# 341:	learn: 0.2673690	total: 3.66s	remaining: 1.69s
# 342:	learn: 0.2673072	total: 3.67s	remaining: 1.68s
# 343:	learn: 0.2671871	total: 3.68s	remaining: 1.67s
# 344:	learn: 0.2671273	total: 3.69s	remaining: 1.66s
# 345:	learn: 0.2670249	total: 3.7s	remaining: 1.65s
# 346:	learn: 0.2668664	total: 3.71s	remaining: 1.64s
# 347:	learn: 0.2667632	total: 3.72s	remaining: 1.63s
# 348:	learn: 0.2666301	total: 3.73s	remaining: 1.61s
# 349:	learn: 0.2665593	total: 3.74s	remaining: 1.6s
# 350:	learn: 0.2664377	total: 3.75s	remaining: 1.59s
# 351:	learn: 0.2663994	total: 3.76s	remaining: 1.58s
# 352:	learn: 0.2662844	total: 3.77s	remaining: 1.57s
# 353:	learn: 0.2661898	total: 3.78s	remaining: 1.56s
# 354:	learn: 0.2660253	total: 3.79s	remaining: 1.55s
# 355:	learn: 0.2659076	total: 3.8s	remaining: 1.54s
# 356:	learn: 0.2658200	total: 3.81s	remaining: 1.53s
# 357:	learn: 0.2657419	total: 3.82s	remaining: 1.52s
# 358:	learn: 0.2656544	total: 3.83s	remaining: 1.51s
# 359:	learn: 0.2655349	total: 3.85s	remaining: 1.5s
# 360:	learn: 0.2654296	total: 3.86s	remaining: 1.48s
# 361:	learn: 0.2653358	total: 3.87s	remaining: 1.47s
# 362:	learn: 0.2652536	total: 3.88s	remaining: 1.46s
# 363:	learn: 0.2651459	total: 3.89s	remaining: 1.45s
# 364:	learn: 0.2650751	total: 3.9s	remaining: 1.44s
# 365:	learn: 0.2649497	total: 3.91s	remaining: 1.43s
# 366:	learn: 0.2648713	total: 3.92s	remaining: 1.42s
# 367:	learn: 0.2647695	total: 3.93s	remaining: 1.41s
# 368:	learn: 0.2646040	total: 3.94s	remaining: 1.4s
# 369:	learn: 0.2644424	total: 3.95s	remaining: 1.39s
# 370:	learn: 0.2643668	total: 3.96s	remaining: 1.38s
# 371:	learn: 0.2642793	total: 3.97s	remaining: 1.36s
# 372:	learn: 0.2641946	total: 3.98s	remaining: 1.35s
# 373:	learn: 0.2641129	total: 3.99s	remaining: 1.34s
# 374:	learn: 0.2640133	total: 4s	remaining: 1.33s
# 375:	learn: 0.2639335	total: 4.01s	remaining: 1.32s
# 376:	learn: 0.2638416	total: 4.02s	remaining: 1.31s
# 377:	learn: 0.2637537	total: 4.03s	remaining: 1.3s
# 378:	learn: 0.2636470	total: 4.04s	remaining: 1.29s
# 379:	learn: 0.2635724	total: 4.05s	remaining: 1.28s
# 380:	learn: 0.2635043	total: 4.06s	remaining: 1.27s
# 381:	learn: 0.2634378	total: 4.07s	remaining: 1.26s
# 382:	learn: 0.2633358	total: 4.08s	remaining: 1.25s
# 383:	learn: 0.2632828	total: 4.09s	remaining: 1.23s
# 384:	learn: 0.2631621	total: 4.1s	remaining: 1.22s
# 385:	learn: 0.2630809	total: 4.11s	remaining: 1.21s
# 386:	learn: 0.2629489	total: 4.12s	remaining: 1.2s
# 387:	learn: 0.2628473	total: 4.13s	remaining: 1.19s
# 388:	learn: 0.2627588	total: 4.14s	remaining: 1.18s
# 389:	learn: 0.2626496	total: 4.15s	remaining: 1.17s
# 390:	learn: 0.2625816	total: 4.16s	remaining: 1.16s
# 391:	learn: 0.2625006	total: 4.17s	remaining: 1.15s
# 392:	learn: 0.2624012	total: 4.18s	remaining: 1.14s
# 393:	learn: 0.2621143	total: 4.19s	remaining: 1.13s
# 394:	learn: 0.2620030	total: 4.2s	remaining: 1.12s
# 395:	learn: 0.2617862	total: 4.21s	remaining: 1.11s
# 396:	learn: 0.2616878	total: 4.22s	remaining: 1.09s
# 397:	learn: 0.2616075	total: 4.23s	remaining: 1.08s
# 398:	learn: 0.2615366	total: 4.24s	remaining: 1.07s
# 399:	learn: 0.2613593	total: 4.25s	remaining: 1.06s
# 400:	learn: 0.2612754	total: 4.26s	remaining: 1.05s
# 401:	learn: 0.2611903	total: 4.27s	remaining: 1.04s
# 402:	learn: 0.2611609	total: 4.28s	remaining: 1.03s
# 403:	learn: 0.2610989	total: 4.29s	remaining: 1.02s
# 404:	learn: 0.2610083	total: 4.3s	remaining: 1.01s
# 405:	learn: 0.2609379	total: 4.31s	remaining: 999ms
# 406:	learn: 0.2608550	total: 4.32s	remaining: 988ms
# 407:	learn: 0.2607658	total: 4.33s	remaining: 977ms
# 408:	learn: 0.2606861	total: 4.34s	remaining: 966ms
# 409:	learn: 0.2605958	total: 4.35s	remaining: 956ms
# 410:	learn: 0.2604440	total: 4.36s	remaining: 945ms
# 411:	learn: 0.2603441	total: 4.37s	remaining: 934ms
# 412:	learn: 0.2602306	total: 4.38s	remaining: 923ms
# 413:	learn: 0.2601214	total: 4.39s	remaining: 913ms
# 414:	learn: 0.2600311	total: 4.4s	remaining: 902ms
# 415:	learn: 0.2599369	total: 4.41s	remaining: 891ms
# 416:	learn: 0.2598361	total: 4.42s	remaining: 881ms
# 417:	learn: 0.2597179	total: 4.43s	remaining: 870ms
# 418:	learn: 0.2596501	total: 4.45s	remaining: 859ms
# 419:	learn: 0.2595895	total: 4.46s	remaining: 849ms
# 420:	learn: 0.2595336	total: 4.46s	remaining: 838ms
# 421:	learn: 0.2594556	total: 4.47s	remaining: 827ms
# 422:	learn: 0.2593566	total: 4.49s	remaining: 817ms
# 423:	learn: 0.2592914	total: 4.5s	remaining: 806ms
# 424:	learn: 0.2592183	total: 4.5s	remaining: 795ms
# 425:	learn: 0.2591064	total: 4.52s	remaining: 785ms
# 426:	learn: 0.2589721	total: 4.53s	remaining: 774ms
# 427:	learn: 0.2588860	total: 4.54s	remaining: 763ms
# 428:	learn: 0.2587754	total: 4.55s	remaining: 753ms
# 429:	learn: 0.2586675	total: 4.56s	remaining: 742ms
# 430:	learn: 0.2585332	total: 4.57s	remaining: 731ms
# 431:	learn: 0.2584404	total: 4.58s	remaining: 721ms
# 432:	learn: 0.2583480	total: 4.59s	remaining: 710ms
# 433:	learn: 0.2582548	total: 4.6s	remaining: 699ms
# 434:	learn: 0.2581921	total: 4.61s	remaining: 689ms
# 435:	learn: 0.2580853	total: 4.62s	remaining: 678ms
# 436:	learn: 0.2579963	total: 4.63s	remaining: 667ms
# 437:	learn: 0.2578744	total: 4.64s	remaining: 657ms
# 438:	learn: 0.2577969	total: 4.65s	remaining: 646ms
# 439:	learn: 0.2577611	total: 4.66s	remaining: 635ms
# 440:	learn: 0.2576878	total: 4.67s	remaining: 625ms
# 441:	learn: 0.2576115	total: 4.68s	remaining: 614ms
# 442:	learn: 0.2575232	total: 4.69s	remaining: 603ms
# 443:	learn: 0.2573553	total: 4.7s	remaining: 593ms
# 444:	learn: 0.2572624	total: 4.71s	remaining: 582ms
# 445:	learn: 0.2571875	total: 4.72s	remaining: 572ms
# 446:	learn: 0.2571187	total: 4.73s	remaining: 561ms
# 447:	learn: 0.2570522	total: 4.74s	remaining: 551ms
# 448:	learn: 0.2569465	total: 4.75s	remaining: 540ms
# 449:	learn: 0.2568594	total: 4.76s	remaining: 529ms
# 450:	learn: 0.2568016	total: 4.78s	remaining: 519ms
# 451:	learn: 0.2567324	total: 4.79s	remaining: 508ms
# 452:	learn: 0.2565930	total: 4.8s	remaining: 498ms
# 453:	learn: 0.2564767	total: 4.81s	remaining: 487ms
# 454:	learn: 0.2564120	total: 4.82s	remaining: 477ms
# 455:	learn: 0.2563280	total: 4.83s	remaining: 466ms
# 456:	learn: 0.2562547	total: 4.84s	remaining: 455ms
# 457:	learn: 0.2561689	total: 4.85s	remaining: 445ms
# 458:	learn: 0.2560743	total: 4.86s	remaining: 434ms
# 459:	learn: 0.2559661	total: 4.87s	remaining: 424ms
# 460:	learn: 0.2558667	total: 4.88s	remaining: 413ms
# 461:	learn: 0.2557756	total: 4.89s	remaining: 402ms
# 462:	learn: 0.2557131	total: 4.9s	remaining: 392ms
# 463:	learn: 0.2556489	total: 4.91s	remaining: 381ms
# 464:	learn: 0.2555463	total: 4.92s	remaining: 371ms
# 465:	learn: 0.2553960	total: 4.93s	remaining: 360ms
# 466:	learn: 0.2552594	total: 4.95s	remaining: 349ms
# 467:	learn: 0.2551575	total: 4.96s	remaining: 339ms
# 468:	learn: 0.2550712	total: 4.97s	remaining: 328ms
# 469:	learn: 0.2549553	total: 4.98s	remaining: 318ms
# 470:	learn: 0.2548878	total: 4.99s	remaining: 307ms
# 471:	learn: 0.2548128	total: 5s	remaining: 297ms
# 472:	learn: 0.2546669	total: 5.01s	remaining: 286ms
# 473:	learn: 0.2545539	total: 5.02s	remaining: 275ms
# 474:	learn: 0.2544632	total: 5.03s	remaining: 265ms
# 475:	learn: 0.2543966	total: 5.04s	remaining: 254ms
# 476:	learn: 0.2543614	total: 5.05s	remaining: 244ms
# 477:	learn: 0.2542598	total: 5.06s	remaining: 233ms
# 478:	learn: 0.2541800	total: 5.07s	remaining: 222ms
# 479:	learn: 0.2541260	total: 5.08s	remaining: 212ms
# 480:	learn: 0.2540543	total: 5.09s	remaining: 201ms
# 481:	learn: 0.2539494	total: 5.1s	remaining: 191ms
# 482:	learn: 0.2538859	total: 5.11s	remaining: 180ms
# 483:	learn: 0.2537810	total: 5.12s	remaining: 169ms
# 484:	learn: 0.2537099	total: 5.13s	remaining: 159ms
# 485:	learn: 0.2536297	total: 5.14s	remaining: 148ms
# 486:	learn: 0.2535699	total: 5.15s	remaining: 137ms
# 487:	learn: 0.2535045	total: 5.16s	remaining: 127ms
# 488:	learn: 0.2534375	total: 5.17s	remaining: 116ms
# 489:	learn: 0.2533425	total: 5.18s	remaining: 106ms
# 490:	learn: 0.2532002	total: 5.19s	remaining: 95.2ms
# 491:	learn: 0.2531168	total: 5.2s	remaining: 84.6ms
# 492:	learn: 0.2530680	total: 5.21s	remaining: 74ms
# 493:	learn: 0.2529785	total: 5.22s	remaining: 63.5ms
# 494:	learn: 0.2528867	total: 5.23s	remaining: 52.9ms
# 495:	learn: 0.2527939	total: 5.25s	remaining: 42.3ms
# 496:	learn: 0.2527167	total: 5.25s	remaining: 31.7ms
# 497:	learn: 0.2526458	total: 5.26s	remaining: 21.1ms
# 498:	learn: 0.2525227	total: 5.28s	remaining: 10.6ms
# 499:	learn: 0.2524223	total: 5.29s	remaining: 0us
# 0:	learn: 0.6426396	total: 10.6ms	remaining: 5.27s
# 1:	learn: 0.5975633	total: 20.9ms	remaining: 5.2s
# 2:	learn: 0.5631192	total: 31ms	remaining: 5.14s
# 3:	learn: 0.5306500	total: 41.6ms	remaining: 5.15s
# 4:	learn: 0.5063410	total: 52.9ms	remaining: 5.23s
# 5:	learn: 0.4859394	total: 63ms	remaining: 5.18s
# 6:	learn: 0.4692069	total: 74.4ms	remaining: 5.24s
# 7:	learn: 0.4559464	total: 85ms	remaining: 5.22s
# 8:	learn: 0.4442155	total: 96.3ms	remaining: 5.25s
# 9:	learn: 0.4351637	total: 108ms	remaining: 5.27s
# 10:	learn: 0.4271648	total: 119ms	remaining: 5.29s
# 11:	learn: 0.4186803	total: 130ms	remaining: 5.29s
# 12:	learn: 0.4106566	total: 141ms	remaining: 5.27s
# 13:	learn: 0.4048338	total: 151ms	remaining: 5.25s
# 14:	learn: 0.3987256	total: 162ms	remaining: 5.23s
# 15:	learn: 0.3921799	total: 172ms	remaining: 5.2s
# 16:	learn: 0.3876305	total: 182ms	remaining: 5.17s
# 17:	learn: 0.3829738	total: 193ms	remaining: 5.16s
# 18:	learn: 0.3793394	total: 204ms	remaining: 5.15s
# 19:	learn: 0.3763519	total: 214ms	remaining: 5.14s
# 20:	learn: 0.3738214	total: 224ms	remaining: 5.11s
# 21:	learn: 0.3705429	total: 234ms	remaining: 5.09s
# 22:	learn: 0.3678311	total: 245ms	remaining: 5.08s
# 23:	learn: 0.3655399	total: 255ms	remaining: 5.06s
# 24:	learn: 0.3625870	total: 265ms	remaining: 5.04s
# 25:	learn: 0.3591962	total: 276ms	remaining: 5.03s
# 26:	learn: 0.3572127	total: 286ms	remaining: 5.01s
# 27:	learn: 0.3552748	total: 296ms	remaining: 4.99s
# 28:	learn: 0.3529844	total: 307ms	remaining: 4.98s
# 29:	learn: 0.3518668	total: 317ms	remaining: 4.96s
# 30:	learn: 0.3496566	total: 327ms	remaining: 4.94s
# 31:	learn: 0.3483481	total: 337ms	remaining: 4.93s
# 32:	learn: 0.3465576	total: 347ms	remaining: 4.92s
# 33:	learn: 0.3453123	total: 358ms	remaining: 4.91s
# 34:	learn: 0.3439586	total: 368ms	remaining: 4.89s
# 35:	learn: 0.3427889	total: 379ms	remaining: 4.88s
# 36:	learn: 0.3421062	total: 389ms	remaining: 4.87s
# 37:	learn: 0.3410624	total: 399ms	remaining: 4.84s
# 38:	learn: 0.3399506	total: 409ms	remaining: 4.83s
# 39:	learn: 0.3391742	total: 418ms	remaining: 4.81s
# 40:	learn: 0.3382098	total: 427ms	remaining: 4.79s
# 41:	learn: 0.3367592	total: 447ms	remaining: 4.88s
# 42:	learn: 0.3358462	total: 457ms	remaining: 4.86s
# 43:	learn: 0.3349712	total: 467ms	remaining: 4.84s
# 44:	learn: 0.3337322	total: 478ms	remaining: 4.83s
# 45:	learn: 0.3325613	total: 488ms	remaining: 4.82s
# 46:	learn: 0.3319940	total: 499ms	remaining: 4.8s
# 47:	learn: 0.3312722	total: 510ms	remaining: 4.8s
# 48:	learn: 0.3308276	total: 521ms	remaining: 4.8s
# 49:	learn: 0.3301671	total: 531ms	remaining: 4.78s
# 50:	learn: 0.3288364	total: 542ms	remaining: 4.77s
# 51:	learn: 0.3284824	total: 551ms	remaining: 4.75s
# 52:	learn: 0.3278848	total: 560ms	remaining: 4.73s
# 53:	learn: 0.3274801	total: 571ms	remaining: 4.71s
# 54:	learn: 0.3267477	total: 580ms	remaining: 4.7s
# 55:	learn: 0.3259935	total: 591ms	remaining: 4.69s
# 56:	learn: 0.3246291	total: 602ms	remaining: 4.68s
# 57:	learn: 0.3240376	total: 612ms	remaining: 4.66s
# 58:	learn: 0.3233766	total: 622ms	remaining: 4.65s
# 59:	learn: 0.3227583	total: 633ms	remaining: 4.64s
# 60:	learn: 0.3218884	total: 642ms	remaining: 4.62s
# 61:	learn: 0.3213709	total: 652ms	remaining: 4.6s
# 62:	learn: 0.3201740	total: 661ms	remaining: 4.58s
# 63:	learn: 0.3198713	total: 670ms	remaining: 4.57s
# 64:	learn: 0.3192716	total: 680ms	remaining: 4.55s
# 65:	learn: 0.3185382	total: 690ms	remaining: 4.54s
# 66:	learn: 0.3182499	total: 701ms	remaining: 4.53s
# 67:	learn: 0.3179242	total: 711ms	remaining: 4.51s
# 68:	learn: 0.3175300	total: 720ms	remaining: 4.5s
# 69:	learn: 0.3166491	total: 731ms	remaining: 4.49s
# 70:	learn: 0.3164381	total: 740ms	remaining: 4.47s
# 71:	learn: 0.3161129	total: 751ms	remaining: 4.46s
# 72:	learn: 0.3156542	total: 760ms	remaining: 4.45s
# 73:	learn: 0.3154555	total: 770ms	remaining: 4.43s
# 74:	learn: 0.3147676	total: 782ms	remaining: 4.43s
# 75:	learn: 0.3142353	total: 791ms	remaining: 4.42s
# 76:	learn: 0.3138575	total: 801ms	remaining: 4.4s
# 77:	learn: 0.3133730	total: 812ms	remaining: 4.39s
# 78:	learn: 0.3130003	total: 823ms	remaining: 4.38s
# 79:	learn: 0.3124042	total: 833ms	remaining: 4.37s
# 80:	learn: 0.3120608	total: 842ms	remaining: 4.36s
# 81:	learn: 0.3115271	total: 852ms	remaining: 4.34s
# 82:	learn: 0.3112960	total: 862ms	remaining: 4.33s
# 83:	learn: 0.3106679	total: 873ms	remaining: 4.32s
# 84:	learn: 0.3103924	total: 882ms	remaining: 4.31s
# 85:	learn: 0.3100924	total: 893ms	remaining: 4.3s
# 86:	learn: 0.3094166	total: 902ms	remaining: 4.28s
# 87:	learn: 0.3092243	total: 912ms	remaining: 4.27s
# 88:	learn: 0.3090284	total: 921ms	remaining: 4.25s
# 89:	learn: 0.3088174	total: 931ms	remaining: 4.24s
# 90:	learn: 0.3085748	total: 940ms	remaining: 4.23s
# 91:	learn: 0.3082169	total: 950ms	remaining: 4.21s
# 92:	learn: 0.3080197	total: 960ms	remaining: 4.2s
# 93:	learn: 0.3077163	total: 970ms	remaining: 4.19s
# 94:	learn: 0.3074440	total: 980ms	remaining: 4.18s
# 95:	learn: 0.3072384	total: 991ms	remaining: 4.17s
# 96:	learn: 0.3068477	total: 1s	remaining: 4.16s
# 97:	learn: 0.3067120	total: 1.01s	remaining: 4.14s
# 98:	learn: 0.3064396	total: 1.02s	remaining: 4.13s
# 99:	learn: 0.3063232	total: 1.03s	remaining: 4.12s
# 100:	learn: 0.3060810	total: 1.04s	remaining: 4.1s
# 101:	learn: 0.3057090	total: 1.05s	remaining: 4.09s
# 102:	learn: 0.3054543	total: 1.06s	remaining: 4.08s
# 103:	learn: 0.3052074	total: 1.07s	remaining: 4.07s
# 104:	learn: 0.3049261	total: 1.08s	remaining: 4.05s
# 105:	learn: 0.3047507	total: 1.09s	remaining: 4.04s
# 106:	learn: 0.3043659	total: 1.1s	remaining: 4.03s
# 107:	learn: 0.3039571	total: 1.11s	remaining: 4.02s
# 108:	learn: 0.3037444	total: 1.12s	remaining: 4.01s
# 109:	learn: 0.3034923	total: 1.13s	remaining: 4s
# 110:	learn: 0.3029867	total: 1.14s	remaining: 4s
# 111:	learn: 0.3023078	total: 1.15s	remaining: 3.98s
# 112:	learn: 0.3021506	total: 1.16s	remaining: 3.97s
# 113:	learn: 0.3018806	total: 1.17s	remaining: 3.96s
# 114:	learn: 0.3017277	total: 1.18s	remaining: 3.95s
# 115:	learn: 0.3013956	total: 1.19s	remaining: 3.93s
# 116:	learn: 0.3011753	total: 1.2s	remaining: 3.92s
# 117:	learn: 0.3010375	total: 1.21s	remaining: 3.91s
# 118:	learn: 0.3008059	total: 1.22s	remaining: 3.9s
# 119:	learn: 0.3006990	total: 1.23s	remaining: 3.88s
# 120:	learn: 0.3004358	total: 1.24s	remaining: 3.87s
# 121:	learn: 0.3001236	total: 1.25s	remaining: 3.86s
# 122:	learn: 0.2999864	total: 1.25s	remaining: 3.85s
# 123:	learn: 0.2996856	total: 1.26s	remaining: 3.84s
# 124:	learn: 0.2994628	total: 1.27s	remaining: 3.83s
# 125:	learn: 0.2992978	total: 1.28s	remaining: 3.81s
# 126:	learn: 0.2990867	total: 1.29s	remaining: 3.8s
# 127:	learn: 0.2987825	total: 1.31s	remaining: 3.8s
# 128:	learn: 0.2985827	total: 1.32s	remaining: 3.79s
# 129:	learn: 0.2983349	total: 1.32s	remaining: 3.77s
# 130:	learn: 0.2979457	total: 1.34s	remaining: 3.76s
# 131:	learn: 0.2976968	total: 1.35s	remaining: 3.75s
# 132:	learn: 0.2974733	total: 1.36s	remaining: 3.74s
# 133:	learn: 0.2972063	total: 1.37s	remaining: 3.73s
# 134:	learn: 0.2971203	total: 1.37s	remaining: 3.72s
# 135:	learn: 0.2969813	total: 1.38s	remaining: 3.71s
# 136:	learn: 0.2967871	total: 1.39s	remaining: 3.69s
# 137:	learn: 0.2965361	total: 1.41s	remaining: 3.69s
# 138:	learn: 0.2964194	total: 1.42s	remaining: 3.67s
# 139:	learn: 0.2962677	total: 1.43s	remaining: 3.66s
# 140:	learn: 0.2961192	total: 1.44s	remaining: 3.65s
# 141:	learn: 0.2959874	total: 1.44s	remaining: 3.64s
# 142:	learn: 0.2957708	total: 1.46s	remaining: 3.63s
# 143:	learn: 0.2955773	total: 1.46s	remaining: 3.62s
# 144:	learn: 0.2953609	total: 1.48s	remaining: 3.61s
# 145:	learn: 0.2950998	total: 1.49s	remaining: 3.6s
# 146:	learn: 0.2947084	total: 1.5s	remaining: 3.6s
# 147:	learn: 0.2946252	total: 1.51s	remaining: 3.58s
# 148:	learn: 0.2945107	total: 1.52s	remaining: 3.57s
# 149:	learn: 0.2942219	total: 1.53s	remaining: 3.56s
# 150:	learn: 0.2939934	total: 1.54s	remaining: 3.56s
# 151:	learn: 0.2938462	total: 1.55s	remaining: 3.55s
# 152:	learn: 0.2936551	total: 1.56s	remaining: 3.54s
# 153:	learn: 0.2935904	total: 1.57s	remaining: 3.52s
# 154:	learn: 0.2934782	total: 1.58s	remaining: 3.52s
# 155:	learn: 0.2932901	total: 1.59s	remaining: 3.51s
# 156:	learn: 0.2931884	total: 1.6s	remaining: 3.5s
# 157:	learn: 0.2931049	total: 1.61s	remaining: 3.48s
# 158:	learn: 0.2929846	total: 1.62s	remaining: 3.47s
# 159:	learn: 0.2928355	total: 1.63s	remaining: 3.46s
# 160:	learn: 0.2926665	total: 1.64s	remaining: 3.46s
# 161:	learn: 0.2925021	total: 1.65s	remaining: 3.44s
# 162:	learn: 0.2923225	total: 1.66s	remaining: 3.43s
# 163:	learn: 0.2922399	total: 1.67s	remaining: 3.42s
# 164:	learn: 0.2917810	total: 1.68s	remaining: 3.41s
# 165:	learn: 0.2915548	total: 1.69s	remaining: 3.4s
# 166:	learn: 0.2913828	total: 1.7s	remaining: 3.39s
# 167:	learn: 0.2912268	total: 1.71s	remaining: 3.38s
# 168:	learn: 0.2910964	total: 1.72s	remaining: 3.38s
# 169:	learn: 0.2908395	total: 1.73s	remaining: 3.37s
# 170:	learn: 0.2907541	total: 1.74s	remaining: 3.35s
# 171:	learn: 0.2906606	total: 1.75s	remaining: 3.34s
# 172:	learn: 0.2905243	total: 1.76s	remaining: 3.33s
# 173:	learn: 0.2903298	total: 1.77s	remaining: 3.32s
# 174:	learn: 0.2898467	total: 1.78s	remaining: 3.31s
# 175:	learn: 0.2897880	total: 1.79s	remaining: 3.3s
# 176:	learn: 0.2895877	total: 1.8s	remaining: 3.29s
# 177:	learn: 0.2893800	total: 1.81s	remaining: 3.28s
# 178:	learn: 0.2892965	total: 1.82s	remaining: 3.27s
# 179:	learn: 0.2890965	total: 1.83s	remaining: 3.26s
# 180:	learn: 0.2890477	total: 1.84s	remaining: 3.25s
# 181:	learn: 0.2889235	total: 1.85s	remaining: 3.24s
# 182:	learn: 0.2887584	total: 1.86s	remaining: 3.23s
# 183:	learn: 0.2885670	total: 1.87s	remaining: 3.22s
# 184:	learn: 0.2884585	total: 1.88s	remaining: 3.2s
# 185:	learn: 0.2883735	total: 1.89s	remaining: 3.19s
# 186:	learn: 0.2881998	total: 1.9s	remaining: 3.18s
# 187:	learn: 0.2877574	total: 1.91s	remaining: 3.17s
# 188:	learn: 0.2875665	total: 1.92s	remaining: 3.16s
# 189:	learn: 0.2874486	total: 1.93s	remaining: 3.15s
# 190:	learn: 0.2873369	total: 1.94s	remaining: 3.14s
# 191:	learn: 0.2871683	total: 1.95s	remaining: 3.13s
# 192:	learn: 0.2871050	total: 1.96s	remaining: 3.12s
# 193:	learn: 0.2868785	total: 1.97s	remaining: 3.11s
# 194:	learn: 0.2866323	total: 1.98s	remaining: 3.1s
# 195:	learn: 0.2864696	total: 1.99s	remaining: 3.09s
# 196:	learn: 0.2863649	total: 2.02s	remaining: 3.1s
# 197:	learn: 0.2862459	total: 2.03s	remaining: 3.09s
# 198:	learn: 0.2861530	total: 2.04s	remaining: 3.08s
# 199:	learn: 0.2860701	total: 2.05s	remaining: 3.07s
# 200:	learn: 0.2859390	total: 2.06s	remaining: 3.06s
# 201:	learn: 0.2857777	total: 2.07s	remaining: 3.05s
# 202:	learn: 0.2856658	total: 2.08s	remaining: 3.04s
# 203:	learn: 0.2855774	total: 2.09s	remaining: 3.03s
# 204:	learn: 0.2853351	total: 2.1s	remaining: 3.02s
# 205:	learn: 0.2852272	total: 2.11s	remaining: 3.01s
# 206:	learn: 0.2849996	total: 2.12s	remaining: 3s
# 207:	learn: 0.2848297	total: 2.13s	remaining: 2.99s
# 208:	learn: 0.2845918	total: 2.14s	remaining: 2.98s
# 209:	learn: 0.2844426	total: 2.15s	remaining: 2.97s
# 210:	learn: 0.2843670	total: 2.16s	remaining: 2.96s
# 211:	learn: 0.2841876	total: 2.17s	remaining: 2.95s
# 212:	learn: 0.2840537	total: 2.18s	remaining: 2.94s
# 213:	learn: 0.2839994	total: 2.19s	remaining: 2.93s
# 214:	learn: 0.2838971	total: 2.2s	remaining: 2.92s
# 215:	learn: 0.2837645	total: 2.21s	remaining: 2.91s
# 216:	learn: 0.2835908	total: 2.22s	remaining: 2.9s
# 217:	learn: 0.2835422	total: 2.23s	remaining: 2.89s
# 218:	learn: 0.2834682	total: 2.24s	remaining: 2.88s
# 219:	learn: 0.2834100	total: 2.25s	remaining: 2.87s
# 220:	learn: 0.2832226	total: 2.26s	remaining: 2.85s
# 221:	learn: 0.2830996	total: 2.27s	remaining: 2.84s
# 222:	learn: 0.2830523	total: 2.28s	remaining: 2.83s
# 223:	learn: 0.2829240	total: 2.29s	remaining: 2.82s
# 224:	learn: 0.2828357	total: 2.3s	remaining: 2.81s
# 225:	learn: 0.2827656	total: 2.31s	remaining: 2.8s
# 226:	learn: 0.2826045	total: 2.32s	remaining: 2.79s
# 227:	learn: 0.2823662	total: 2.33s	remaining: 2.78s
# 228:	learn: 0.2821130	total: 2.34s	remaining: 2.77s
# 229:	learn: 0.2819901	total: 2.35s	remaining: 2.76s
# 230:	learn: 0.2818317	total: 2.36s	remaining: 2.75s
# 231:	learn: 0.2817104	total: 2.37s	remaining: 2.74s
# 232:	learn: 0.2815601	total: 2.38s	remaining: 2.73s
# 233:	learn: 0.2812631	total: 2.39s	remaining: 2.72s
# 234:	learn: 0.2811898	total: 2.4s	remaining: 2.71s
# 235:	learn: 0.2810390	total: 2.41s	remaining: 2.7s
# 236:	learn: 0.2809242	total: 2.42s	remaining: 2.69s
# 237:	learn: 0.2807798	total: 2.43s	remaining: 2.68s
# 238:	learn: 0.2804761	total: 2.44s	remaining: 2.67s
# 239:	learn: 0.2802925	total: 2.45s	remaining: 2.66s
# 240:	learn: 0.2801456	total: 2.46s	remaining: 2.65s
# 241:	learn: 0.2800322	total: 2.47s	remaining: 2.64s
# 242:	learn: 0.2798541	total: 2.48s	remaining: 2.63s
# 243:	learn: 0.2797320	total: 2.49s	remaining: 2.62s
# 244:	learn: 0.2794755	total: 2.51s	remaining: 2.61s
# 245:	learn: 0.2793049	total: 2.52s	remaining: 2.6s
# 246:	learn: 0.2791820	total: 2.53s	remaining: 2.59s
# 247:	learn: 0.2790705	total: 2.54s	remaining: 2.58s
# 248:	learn: 0.2789909	total: 2.55s	remaining: 2.57s
# 249:	learn: 0.2789314	total: 2.56s	remaining: 2.56s
# 250:	learn: 0.2787746	total: 2.57s	remaining: 2.55s
# 251:	learn: 0.2785605	total: 2.58s	remaining: 2.54s
# 252:	learn: 0.2783632	total: 2.59s	remaining: 2.53s
# 253:	learn: 0.2782458	total: 2.6s	remaining: 2.52s
# 254:	learn: 0.2781523	total: 2.61s	remaining: 2.51s
# 255:	learn: 0.2779292	total: 2.62s	remaining: 2.5s
# 256:	learn: 0.2778048	total: 2.63s	remaining: 2.49s
# 257:	learn: 0.2776802	total: 2.64s	remaining: 2.48s
# 258:	learn: 0.2775491	total: 2.65s	remaining: 2.46s
# 259:	learn: 0.2774495	total: 2.66s	remaining: 2.46s
# 260:	learn: 0.2773530	total: 2.67s	remaining: 2.44s
# 261:	learn: 0.2772346	total: 2.68s	remaining: 2.43s
# 262:	learn: 0.2771132	total: 2.69s	remaining: 2.42s
# 263:	learn: 0.2770075	total: 2.7s	remaining: 2.41s
# 264:	learn: 0.2768958	total: 2.71s	remaining: 2.4s
# 265:	learn: 0.2767544	total: 2.72s	remaining: 2.39s
# 266:	learn: 0.2766005	total: 2.73s	remaining: 2.38s
# 267:	learn: 0.2764487	total: 2.74s	remaining: 2.37s
# 268:	learn: 0.2762959	total: 2.75s	remaining: 2.36s
# 269:	learn: 0.2762183	total: 2.76s	remaining: 2.35s
# 270:	learn: 0.2761273	total: 2.77s	remaining: 2.34s
# 271:	learn: 0.2759721	total: 2.78s	remaining: 2.33s
# 272:	learn: 0.2758800	total: 2.79s	remaining: 2.32s
# 273:	learn: 0.2757607	total: 2.8s	remaining: 2.31s
# 274:	learn: 0.2756175	total: 2.81s	remaining: 2.3s
# 275:	learn: 0.2753454	total: 2.82s	remaining: 2.29s
# 276:	learn: 0.2751964	total: 2.83s	remaining: 2.28s
# 277:	learn: 0.2750958	total: 2.84s	remaining: 2.27s
# 278:	learn: 0.2749454	total: 2.85s	remaining: 2.26s
# 279:	learn: 0.2748501	total: 2.86s	remaining: 2.25s
# 280:	learn: 0.2747326	total: 2.87s	remaining: 2.23s
# 281:	learn: 0.2745895	total: 2.88s	remaining: 2.23s
# 282:	learn: 0.2744059	total: 2.89s	remaining: 2.21s
# 283:	learn: 0.2742360	total: 2.9s	remaining: 2.21s
# 284:	learn: 0.2740736	total: 2.91s	remaining: 2.2s
# 285:	learn: 0.2739500	total: 2.92s	remaining: 2.19s
# 286:	learn: 0.2738011	total: 2.93s	remaining: 2.18s
# 287:	learn: 0.2736316	total: 2.94s	remaining: 2.17s
# 288:	learn: 0.2733821	total: 2.95s	remaining: 2.15s
# 289:	learn: 0.2732673	total: 2.96s	remaining: 2.15s
# 290:	learn: 0.2731713	total: 2.97s	remaining: 2.13s
# 291:	learn: 0.2730567	total: 2.98s	remaining: 2.12s
# 292:	learn: 0.2729501	total: 2.99s	remaining: 2.11s
# 293:	learn: 0.2728154	total: 3s	remaining: 2.1s
# 294:	learn: 0.2726977	total: 3.01s	remaining: 2.09s
# 295:	learn: 0.2725004	total: 3.02s	remaining: 2.08s
# 296:	learn: 0.2724247	total: 3.03s	remaining: 2.07s
# 297:	learn: 0.2723244	total: 3.04s	remaining: 2.06s
# 298:	learn: 0.2722295	total: 3.05s	remaining: 2.05s
# 299:	learn: 0.2721191	total: 3.06s	remaining: 2.04s
# 300:	learn: 0.2719885	total: 3.07s	remaining: 2.03s
# 301:	learn: 0.2718233	total: 3.08s	remaining: 2.02s
# 302:	learn: 0.2716815	total: 3.1s	remaining: 2.01s
# 303:	learn: 0.2715865	total: 3.11s	remaining: 2s
# 304:	learn: 0.2714461	total: 3.12s	remaining: 1.99s
# 305:	learn: 0.2713397	total: 3.13s	remaining: 1.98s
# 306:	learn: 0.2712367	total: 3.14s	remaining: 1.97s
# 307:	learn: 0.2710814	total: 3.15s	remaining: 1.96s
# 308:	learn: 0.2709932	total: 3.16s	remaining: 1.95s
# 309:	learn: 0.2708760	total: 3.17s	remaining: 1.94s
# 310:	learn: 0.2708016	total: 3.18s	remaining: 1.93s
# 311:	learn: 0.2706669	total: 3.19s	remaining: 1.92s
# 312:	learn: 0.2705666	total: 3.2s	remaining: 1.91s
# 313:	learn: 0.2705098	total: 3.21s	remaining: 1.9s
# 314:	learn: 0.2703657	total: 3.22s	remaining: 1.89s
# 315:	learn: 0.2702389	total: 3.23s	remaining: 1.88s
# 316:	learn: 0.2701205	total: 3.24s	remaining: 1.87s
# 317:	learn: 0.2700446	total: 3.25s	remaining: 1.86s
# 318:	learn: 0.2699586	total: 3.26s	remaining: 1.85s
# 319:	learn: 0.2698395	total: 3.27s	remaining: 1.84s
# 320:	learn: 0.2697150	total: 3.28s	remaining: 1.83s
# 321:	learn: 0.2695906	total: 3.29s	remaining: 1.82s
# 322:	learn: 0.2695176	total: 3.3s	remaining: 1.81s
# 323:	learn: 0.2693988	total: 3.31s	remaining: 1.8s
# 324:	learn: 0.2693036	total: 3.32s	remaining: 1.79s
# 325:	learn: 0.2691819	total: 3.33s	remaining: 1.78s
# 326:	learn: 0.2690930	total: 3.34s	remaining: 1.77s
# 327:	learn: 0.2689724	total: 3.35s	remaining: 1.75s
# 328:	learn: 0.2688715	total: 3.36s	remaining: 1.75s
# 329:	learn: 0.2688007	total: 3.37s	remaining: 1.73s
# 330:	learn: 0.2686723	total: 3.38s	remaining: 1.72s
# 331:	learn: 0.2685741	total: 3.39s	remaining: 1.71s
# 332:	learn: 0.2684226	total: 3.4s	remaining: 1.7s
# 333:	learn: 0.2683336	total: 3.41s	remaining: 1.69s
# 334:	learn: 0.2682417	total: 3.42s	remaining: 1.68s
# 335:	learn: 0.2681289	total: 3.43s	remaining: 1.67s
# 336:	learn: 0.2680143	total: 3.44s	remaining: 1.66s
# 337:	learn: 0.2679061	total: 3.45s	remaining: 1.65s
# 338:	learn: 0.2678059	total: 3.46s	remaining: 1.64s
# 339:	learn: 0.2676468	total: 3.47s	remaining: 1.63s
# 340:	learn: 0.2675767	total: 3.48s	remaining: 1.62s
# 341:	learn: 0.2674669	total: 3.49s	remaining: 1.61s
# 342:	learn: 0.2673573	total: 3.5s	remaining: 1.6s
# 343:	learn: 0.2672113	total: 3.51s	remaining: 1.59s
# 344:	learn: 0.2670697	total: 3.52s	remaining: 1.58s
# 345:	learn: 0.2669020	total: 3.53s	remaining: 1.57s
# 346:	learn: 0.2668254	total: 3.54s	remaining: 1.56s
# 347:	learn: 0.2667217	total: 3.55s	remaining: 1.55s
# 348:	learn: 0.2666327	total: 3.56s	remaining: 1.54s
# 349:	learn: 0.2664958	total: 3.57s	remaining: 1.53s
# 350:	learn: 0.2663596	total: 3.58s	remaining: 1.52s
# 351:	learn: 0.2663123	total: 3.59s	remaining: 1.51s
# 352:	learn: 0.2661769	total: 3.6s	remaining: 1.5s
# 353:	learn: 0.2661181	total: 3.61s	remaining: 1.49s
# 354:	learn: 0.2660379	total: 3.62s	remaining: 1.48s
# 355:	learn: 0.2659323	total: 3.63s	remaining: 1.47s
# 356:	learn: 0.2658080	total: 3.64s	remaining: 1.46s
# 357:	learn: 0.2657250	total: 3.65s	remaining: 1.45s
# 358:	learn: 0.2656395	total: 3.67s	remaining: 1.44s
# 359:	learn: 0.2655486	total: 3.67s	remaining: 1.43s
# 360:	learn: 0.2654661	total: 3.69s	remaining: 1.42s
# 361:	learn: 0.2653599	total: 3.69s	remaining: 1.41s
# 362:	learn: 0.2652093	total: 3.71s	remaining: 1.4s
# 363:	learn: 0.2650899	total: 3.72s	remaining: 1.39s
# 364:	learn: 0.2649955	total: 3.73s	remaining: 1.38s
# 365:	learn: 0.2648501	total: 3.74s	remaining: 1.37s
# 366:	learn: 0.2646690	total: 3.75s	remaining: 1.36s
# 367:	learn: 0.2645458	total: 3.76s	remaining: 1.35s
# 368:	learn: 0.2644183	total: 3.77s	remaining: 1.34s
# 369:	learn: 0.2643289	total: 3.78s	remaining: 1.33s
# 370:	learn: 0.2642717	total: 3.79s	remaining: 1.32s
# 371:	learn: 0.2641270	total: 3.8s	remaining: 1.31s
# 372:	learn: 0.2639629	total: 3.81s	remaining: 1.3s
# 373:	learn: 0.2638248	total: 3.82s	remaining: 1.29s
# 374:	learn: 0.2637521	total: 3.83s	remaining: 1.28s
# 375:	learn: 0.2636478	total: 3.84s	remaining: 1.27s
# 376:	learn: 0.2635326	total: 3.85s	remaining: 1.26s
# 377:	learn: 0.2634587	total: 3.86s	remaining: 1.25s
# 378:	learn: 0.2633638	total: 3.87s	remaining: 1.24s
# 379:	learn: 0.2632569	total: 3.88s	remaining: 1.23s
# 380:	learn: 0.2631778	total: 3.89s	remaining: 1.22s
# 381:	learn: 0.2631020	total: 3.9s	remaining: 1.21s
# 382:	learn: 0.2629804	total: 3.91s	remaining: 1.2s
# 383:	learn: 0.2629042	total: 3.92s	remaining: 1.19s
# 384:	learn: 0.2628113	total: 3.93s	remaining: 1.18s
# 385:	learn: 0.2627548	total: 3.94s	remaining: 1.16s
# 386:	learn: 0.2626933	total: 3.95s	remaining: 1.15s
# 387:	learn: 0.2625540	total: 3.96s	remaining: 1.14s
# 388:	learn: 0.2624729	total: 3.97s	remaining: 1.13s
# 389:	learn: 0.2623640	total: 3.98s	remaining: 1.12s
# 390:	learn: 0.2622948	total: 3.99s	remaining: 1.11s
# 391:	learn: 0.2621894	total: 4s	remaining: 1.1s
# 392:	learn: 0.2621111	total: 4.01s	remaining: 1.09s
# 393:	learn: 0.2620293	total: 4.02s	remaining: 1.08s
# 394:	learn: 0.2619992	total: 4.03s	remaining: 1.07s
# 395:	learn: 0.2619373	total: 4.04s	remaining: 1.06s
# 396:	learn: 0.2618196	total: 4.05s	remaining: 1.05s
# 397:	learn: 0.2616946	total: 4.06s	remaining: 1.04s
# 398:	learn: 0.2615790	total: 4.07s	remaining: 1.03s
# 399:	learn: 0.2614845	total: 4.08s	remaining: 1.02s
# 400:	learn: 0.2613404	total: 4.09s	remaining: 1.01s
# 401:	learn: 0.2612446	total: 4.1s	remaining: 1s
# 402:	learn: 0.2611789	total: 4.11s	remaining: 990ms
# 403:	learn: 0.2611218	total: 4.12s	remaining: 980ms
# 404:	learn: 0.2610442	total: 4.14s	remaining: 971ms
# 405:	learn: 0.2609319	total: 4.15s	remaining: 962ms
# 406:	learn: 0.2608643	total: 4.17s	remaining: 952ms
# 407:	learn: 0.2607560	total: 4.18s	remaining: 942ms
# 408:	learn: 0.2606504	total: 4.18s	remaining: 931ms
# 409:	learn: 0.2605730	total: 4.2s	remaining: 921ms
# 410:	learn: 0.2604098	total: 4.21s	remaining: 911ms
# 411:	learn: 0.2603391	total: 4.22s	remaining: 901ms
# 412:	learn: 0.2602686	total: 4.23s	remaining: 890ms
# 413:	learn: 0.2601526	total: 4.24s	remaining: 880ms
# 414:	learn: 0.2600746	total: 4.25s	remaining: 870ms
# 415:	learn: 0.2599295	total: 4.26s	remaining: 860ms
# 416:	learn: 0.2598717	total: 4.27s	remaining: 849ms
# 417:	learn: 0.2597604	total: 4.28s	remaining: 839ms
# 418:	learn: 0.2596735	total: 4.29s	remaining: 829ms
# 419:	learn: 0.2595844	total: 4.3s	remaining: 818ms
# 420:	learn: 0.2594916	total: 4.31s	remaining: 808ms
# 421:	learn: 0.2593827	total: 4.32s	remaining: 798ms
# 422:	learn: 0.2593017	total: 4.33s	remaining: 787ms
# 423:	learn: 0.2592303	total: 4.33s	remaining: 777ms
# 424:	learn: 0.2590469	total: 4.35s	remaining: 767ms
# 425:	learn: 0.2589884	total: 4.36s	remaining: 757ms
# 426:	learn: 0.2588952	total: 4.37s	remaining: 746ms
# 427:	learn: 0.2588383	total: 4.38s	remaining: 736ms
# 428:	learn: 0.2587747	total: 4.38s	remaining: 726ms
# 429:	learn: 0.2586216	total: 4.4s	remaining: 716ms
# ...
# 206:	learn: 0.3301092	total: 1.53s	remaining: 2.16s
# 207:	learn: 0.3301077	total: 1.53s	remaining: 2.15s
# 208:	learn: 0.3300351	total: 1.54s	remaining: 2.14s
# 209:	learn: 0.3298629	total: 1.54s	remaining: 2.13s
# 210:	learn: 0.3297872	total: 1.55s	remaining: 2.13s
# 211:	learn: 0.3297473	total: 1.56s	remaining: 2.12s
# 212:	learn: 0.3296151	total: 1.57s	remaining: 2.11s
# 213:	learn: 0.3293219	total: 1.57s	remaining: 2.1s
# 214:	learn: 0.3292138	total: 1.58s	remaining: 2.1s
# 215:	learn: 0.3291071	total: 1.59s	remaining: 2.09s
# 216:	learn: 0.3290175	total: 1.6s	remaining: 2.08s
# 217:	learn: 0.3289076	total: 1.6s	remaining: 2.08s
# 218:	learn: 0.3287932	total: 1.61s	remaining: 2.07s
# 219:	learn: 0.3287008	total: 1.62s	remaining: 2.06s
# 220:	learn: 0.3286339	total: 1.63s	remaining: 2.06s
# 221:	learn: 0.3285234	total: 1.64s	remaining: 2.05s
# 222:	learn: 0.3284335	total: 1.64s	remaining: 2.04s
# 223:	learn: 0.3283726	total: 1.65s	remaining: 2.03s
# 224:	learn: 0.3281798	total: 1.66s	remaining: 2.03s
# 225:	learn: 0.3281278	total: 1.67s	remaining: 2.02s
# 226:	learn: 0.3280509	total: 1.67s	remaining: 2.01s
# 227:	learn: 0.3279655	total: 1.68s	remaining: 2.01s
# 228:	learn: 0.3279176	total: 1.69s	remaining: 2s
# 229:	learn: 0.3278584	total: 1.7s	remaining: 1.99s
# 230:	learn: 0.3278090	total: 1.7s	remaining: 1.98s
# 231:	learn: 0.3276713	total: 1.71s	remaining: 1.98s
# 232:	learn: 0.3275273	total: 1.72s	remaining: 1.97s
# 233:	learn: 0.3274024	total: 1.72s	remaining: 1.96s
# 234:	learn: 0.3273376	total: 1.73s	remaining: 1.95s
# 235:	learn: 0.3272806	total: 1.74s	remaining: 1.95s
# 236:	learn: 0.3271913	total: 1.75s	remaining: 1.94s
# 237:	learn: 0.3271546	total: 1.75s	remaining: 1.93s
# 238:	learn: 0.3270648	total: 1.76s	remaining: 1.92s
# 239:	learn: 0.3270009	total: 1.77s	remaining: 1.92s
# 240:	learn: 0.3268815	total: 1.77s	remaining: 1.91s
# 241:	learn: 0.3268072	total: 1.78s	remaining: 1.9s
# 242:	learn: 0.3266370	total: 1.79s	remaining: 1.89s
# 243:	learn: 0.3265683	total: 1.8s	remaining: 1.89s
# 244:	learn: 0.3264905	total: 1.8s	remaining: 1.88s
# 245:	learn: 0.3264399	total: 1.81s	remaining: 1.87s
# 246:	learn: 0.3263704	total: 1.82s	remaining: 1.86s
# 247:	learn: 0.3261692	total: 1.83s	remaining: 1.86s
# 248:	learn: 0.3260935	total: 1.83s	remaining: 1.85s
# 249:	learn: 0.3260206	total: 1.84s	remaining: 1.84s
# 250:	learn: 0.3258907	total: 1.85s	remaining: 1.83s
# 251:	learn: 0.3257960	total: 1.86s	remaining: 1.83s
# 252:	learn: 0.3257049	total: 1.86s	remaining: 1.82s
# 253:	learn: 0.3256262	total: 1.87s	remaining: 1.81s
# 254:	learn: 0.3255093	total: 1.88s	remaining: 1.81s
# 255:	learn: 0.3253569	total: 1.89s	remaining: 1.8s
# 256:	learn: 0.3252746	total: 1.9s	remaining: 1.79s
# 257:	learn: 0.3252188	total: 1.9s	remaining: 1.78s
# 258:	learn: 0.3250588	total: 1.91s	remaining: 1.78s
# 259:	learn: 0.3249354	total: 1.92s	remaining: 1.77s
# 260:	learn: 0.3247855	total: 1.93s	remaining: 1.76s
# 261:	learn: 0.3245930	total: 1.93s	remaining: 1.76s
# 262:	learn: 0.3245135	total: 1.94s	remaining: 1.75s
# 263:	learn: 0.3244200	total: 1.95s	remaining: 1.74s
# 264:	learn: 0.3243741	total: 1.96s	remaining: 1.73s
# 265:	learn: 0.3242574	total: 1.96s	remaining: 1.73s
# 266:	learn: 0.3241656	total: 1.97s	remaining: 1.72s
# 267:	learn: 0.3240748	total: 1.98s	remaining: 1.71s
# 268:	learn: 0.3240172	total: 1.98s	remaining: 1.7s
# 269:	learn: 0.3238990	total: 1.99s	remaining: 1.7s
# 270:	learn: 0.3238284	total: 2s	remaining: 1.69s
# 271:	learn: 0.3237635	total: 2.01s	remaining: 1.68s
# 272:	learn: 0.3236892	total: 2.01s	remaining: 1.68s
# 273:	learn: 0.3235980	total: 2.02s	remaining: 1.67s
# 274:	learn: 0.3235157	total: 2.03s	remaining: 1.66s
# 275:	learn: 0.3234242	total: 2.04s	remaining: 1.65s
# 276:	learn: 0.3233674	total: 2.04s	remaining: 1.65s
# 277:	learn: 0.3232869	total: 2.05s	remaining: 1.64s
# 278:	learn: 0.3232347	total: 2.06s	remaining: 1.63s
# 279:	learn: 0.3231697	total: 2.07s	remaining: 1.62s
# 280:	learn: 0.3230393	total: 2.07s	remaining: 1.61s
# 281:	learn: 0.3229108	total: 2.08s	remaining: 1.61s
# 282:	learn: 0.3227824	total: 2.09s	remaining: 1.6s
# 283:	learn: 0.3226944	total: 2.1s	remaining: 1.59s
# 284:	learn: 0.3226220	total: 2.1s	remaining: 1.59s
# 285:	learn: 0.3225073	total: 2.11s	remaining: 1.58s
# 286:	learn: 0.3224113	total: 2.12s	remaining: 1.57s
# 287:	learn: 0.3223343	total: 2.13s	remaining: 1.56s
# 288:	learn: 0.3222594	total: 2.13s	remaining: 1.56s
# 289:	learn: 0.3221577	total: 2.14s	remaining: 1.55s
# 290:	learn: 0.3220243	total: 2.15s	remaining: 1.54s
# 291:	learn: 0.3218185	total: 2.16s	remaining: 1.54s
# 292:	learn: 0.3217286	total: 2.16s	remaining: 1.53s
# 293:	learn: 0.3216202	total: 2.17s	remaining: 1.52s
# 294:	learn: 0.3214205	total: 2.18s	remaining: 1.51s
# 295:	learn: 0.3213400	total: 2.19s	remaining: 1.51s
# 296:	learn: 0.3211076	total: 2.19s	remaining: 1.5s
# 297:	learn: 0.3210364	total: 2.2s	remaining: 1.49s
# 298:	learn: 0.3209581	total: 2.21s	remaining: 1.49s
# 299:	learn: 0.3209029	total: 2.22s	remaining: 1.48s
# 300:	learn: 0.3207127	total: 2.22s	remaining: 1.47s
# 301:	learn: 0.3205738	total: 2.23s	remaining: 1.46s
# 302:	learn: 0.3204739	total: 2.24s	remaining: 1.46s
# 303:	learn: 0.3204349	total: 2.25s	remaining: 1.45s
# 304:	learn: 0.3203523	total: 2.25s	remaining: 1.44s
# 305:	learn: 0.3202957	total: 2.26s	remaining: 1.43s
# 306:	learn: 0.3202260	total: 2.27s	remaining: 1.43s
# 307:	learn: 0.3201852	total: 2.27s	remaining: 1.42s
# 308:	learn: 0.3201162	total: 2.28s	remaining: 1.41s
# 309:	learn: 0.3200376	total: 2.29s	remaining: 1.4s
# 310:	learn: 0.3199238	total: 2.3s	remaining: 1.4s
# 311:	learn: 0.3198068	total: 2.3s	remaining: 1.39s
# 312:	learn: 0.3197021	total: 2.31s	remaining: 1.38s
# 313:	learn: 0.3196209	total: 2.32s	remaining: 1.37s
# 314:	learn: 0.3195308	total: 2.33s	remaining: 1.37s
# 315:	learn: 0.3194901	total: 2.33s	remaining: 1.36s
# 316:	learn: 0.3194067	total: 2.34s	remaining: 1.35s
# 317:	learn: 0.3192855	total: 2.35s	remaining: 1.34s
# 318:	learn: 0.3191920	total: 2.35s	remaining: 1.34s
# 319:	learn: 0.3191086	total: 2.36s	remaining: 1.33s
# 320:	learn: 0.3189949	total: 2.37s	remaining: 1.32s
# 321:	learn: 0.3189213	total: 2.38s	remaining: 1.31s
# 322:	learn: 0.3187769	total: 2.38s	remaining: 1.31s
# 323:	learn: 0.3186944	total: 2.39s	remaining: 1.3s
# 324:	learn: 0.3186436	total: 2.4s	remaining: 1.29s
# 325:	learn: 0.3185341	total: 2.41s	remaining: 1.28s
# 326:	learn: 0.3184984	total: 2.42s	remaining: 1.28s
# 327:	learn: 0.3184500	total: 2.42s	remaining: 1.27s
# 328:	learn: 0.3183636	total: 2.43s	remaining: 1.26s
# 329:	learn: 0.3182961	total: 2.44s	remaining: 1.25s
# 330:	learn: 0.3181632	total: 2.44s	remaining: 1.25s
# 331:	learn: 0.3180571	total: 2.45s	remaining: 1.24s
# 332:	learn: 0.3179373	total: 2.46s	remaining: 1.23s
# 333:	learn: 0.3178610	total: 2.47s	remaining: 1.23s
# 334:	learn: 0.3177041	total: 2.48s	remaining: 1.22s
# 335:	learn: 0.3176107	total: 2.48s	remaining: 1.21s
# 336:	learn: 0.3175320	total: 2.49s	remaining: 1.21s
# 337:	learn: 0.3174801	total: 2.5s	remaining: 1.2s
# 338:	learn: 0.3173668	total: 2.51s	remaining: 1.19s
# 339:	learn: 0.3173014	total: 2.51s	remaining: 1.18s
# 340:	learn: 0.3171968	total: 2.52s	remaining: 1.18s
# 341:	learn: 0.3170517	total: 2.53s	remaining: 1.17s
# 342:	learn: 0.3169720	total: 2.54s	remaining: 1.16s
# 343:	learn: 0.3169246	total: 2.54s	remaining: 1.15s
# 344:	learn: 0.3168570	total: 2.55s	remaining: 1.15s
# 345:	learn: 0.3167565	total: 2.56s	remaining: 1.14s
# 346:	learn: 0.3166859	total: 2.56s	remaining: 1.13s
# 347:	learn: 0.3166018	total: 2.57s	remaining: 1.12s
# 348:	learn: 0.3165373	total: 2.58s	remaining: 1.12s
# 349:	learn: 0.3164761	total: 2.59s	remaining: 1.11s
# 350:	learn: 0.3164033	total: 2.6s	remaining: 1.1s
# 351:	learn: 0.3163284	total: 2.6s	remaining: 1.09s
# 352:	learn: 0.3162618	total: 2.61s	remaining: 1.09s
# 353:	learn: 0.3161885	total: 2.62s	remaining: 1.08s
# 354:	learn: 0.3161144	total: 2.63s	remaining: 1.07s
# 355:	learn: 0.3160455	total: 2.63s	remaining: 1.06s
# 356:	learn: 0.3159534	total: 2.64s	remaining: 1.06s
# 357:	learn: 0.3158875	total: 2.65s	remaining: 1.05s
# 358:	learn: 0.3158196	total: 2.66s	remaining: 1.04s
# 359:	learn: 0.3156965	total: 2.66s	remaining: 1.03s
# 360:	learn: 0.3156276	total: 2.67s	remaining: 1.03s
# 361:	learn: 0.3155645	total: 2.68s	remaining: 1.02s
# 362:	learn: 0.3154949	total: 2.69s	remaining: 1.01s
# 363:	learn: 0.3154507	total: 2.69s	remaining: 1.01s
# 364:	learn: 0.3153956	total: 2.7s	remaining: 999ms
# 365:	learn: 0.3152983	total: 2.71s	remaining: 992ms
# 366:	learn: 0.3152356	total: 2.72s	remaining: 984ms
# 367:	learn: 0.3151639	total: 2.72s	remaining: 977ms
# 368:	learn: 0.3150967	total: 2.73s	remaining: 970ms
# 369:	learn: 0.3150442	total: 2.74s	remaining: 962ms
# 370:	learn: 0.3149739	total: 2.74s	remaining: 954ms
# 371:	learn: 0.3148952	total: 2.75s	remaining: 947ms
# 372:	learn: 0.3148608	total: 2.76s	remaining: 940ms
# 373:	learn: 0.3147910	total: 2.77s	remaining: 932ms
# 374:	learn: 0.3147216	total: 2.77s	remaining: 925ms
# 375:	learn: 0.3146537	total: 2.78s	remaining: 917ms
# 376:	learn: 0.3145573	total: 2.79s	remaining: 910ms
# 377:	learn: 0.3144913	total: 2.8s	remaining: 902ms
# 378:	learn: 0.3144235	total: 2.8s	remaining: 895ms
# 379:	learn: 0.3143589	total: 2.81s	remaining: 887ms
# 380:	learn: 0.3142726	total: 2.82s	remaining: 880ms
# 381:	learn: 0.3142288	total: 2.82s	remaining: 873ms
# 382:	learn: 0.3141667	total: 2.83s	remaining: 865ms
# 383:	learn: 0.3140872	total: 2.84s	remaining: 858ms
# 384:	learn: 0.3140022	total: 2.85s	remaining: 851ms
# 385:	learn: 0.3139508	total: 2.85s	remaining: 843ms
# 386:	learn: 0.3138907	total: 2.86s	remaining: 836ms
# 387:	learn: 0.3137916	total: 2.87s	remaining: 828ms
# 388:	learn: 0.3137491	total: 2.88s	remaining: 821ms
# 389:	learn: 0.3136809	total: 2.88s	remaining: 814ms
# 390:	learn: 0.3135585	total: 2.89s	remaining: 806ms
# 391:	learn: 0.3134876	total: 2.9s	remaining: 799ms
# 392:	learn: 0.3134327	total: 2.91s	remaining: 792ms
# 393:	learn: 0.3134056	total: 2.91s	remaining: 784ms
# 394:	learn: 0.3132798	total: 2.92s	remaining: 777ms
# 395:	learn: 0.3132302	total: 2.93s	remaining: 769ms
# 396:	learn: 0.3131368	total: 2.94s	remaining: 762ms
# 397:	learn: 0.3130617	total: 2.94s	remaining: 755ms
# 398:	learn: 0.3129769	total: 2.95s	remaining: 747ms
# 399:	learn: 0.3129229	total: 2.96s	remaining: 740ms
# 400:	learn: 0.3128473	total: 2.97s	remaining: 732ms
# 401:	learn: 0.3127363	total: 2.97s	remaining: 725ms
# 402:	learn: 0.3126962	total: 2.98s	remaining: 717ms
# 403:	learn: 0.3126503	total: 2.99s	remaining: 710ms
# 404:	learn: 0.3125925	total: 3s	remaining: 703ms
# 405:	learn: 0.3125643	total: 3s	remaining: 695ms
# 406:	learn: 0.3124688	total: 3.01s	remaining: 688ms
# 407:	learn: 0.3123939	total: 3.02s	remaining: 680ms
# 408:	learn: 0.3122949	total: 3.02s	remaining: 673ms
# 409:	learn: 0.3122372	total: 3.03s	remaining: 665ms
# 410:	learn: 0.3121836	total: 3.04s	remaining: 658ms
# 411:	learn: 0.3121148	total: 3.05s	remaining: 651ms
# 412:	learn: 0.3120425	total: 3.05s	remaining: 643ms
# 413:	learn: 0.3119697	total: 3.06s	remaining: 636ms
# 414:	learn: 0.3118293	total: 3.07s	remaining: 628ms
# 415:	learn: 0.3117517	total: 3.08s	remaining: 621ms
# 416:	learn: 0.3117182	total: 3.08s	remaining: 614ms
# 417:	learn: 0.3116468	total: 3.09s	remaining: 606ms
# 418:	learn: 0.3116130	total: 3.1s	remaining: 599ms
# 419:	learn: 0.3115380	total: 3.1s	remaining: 591ms
# 420:	learn: 0.3114865	total: 3.11s	remaining: 584ms
# 421:	learn: 0.3113335	total: 3.12s	remaining: 576ms
# 422:	learn: 0.3112616	total: 3.13s	remaining: 569ms
# 423:	learn: 0.3112156	total: 3.13s	remaining: 562ms
# 424:	learn: 0.3111556	total: 3.14s	remaining: 554ms
# 425:	learn: 0.3111131	total: 3.15s	remaining: 547ms
# 426:	learn: 0.3110611	total: 3.15s	remaining: 539ms
# 427:	learn: 0.3109673	total: 3.16s	remaining: 532ms
# 428:	learn: 0.3109037	total: 3.17s	remaining: 525ms
# 429:	learn: 0.3108285	total: 3.18s	remaining: 517ms
# 430:	learn: 0.3107630	total: 3.18s	remaining: 510ms
# 431:	learn: 0.3107194	total: 3.19s	remaining: 502ms
# 432:	learn: 0.3106562	total: 3.2s	remaining: 495ms
# 433:	learn: 0.3106243	total: 3.21s	remaining: 488ms
# 434:	learn: 0.3105525	total: 3.21s	remaining: 480ms
# 435:	learn: 0.3105032	total: 3.22s	remaining: 473ms
# 436:	learn: 0.3104337	total: 3.23s	remaining: 465ms
# 437:	learn: 0.3103887	total: 3.23s	remaining: 458ms
# 438:	learn: 0.3103499	total: 3.24s	remaining: 451ms
# 439:	learn: 0.3102915	total: 3.25s	remaining: 443ms
# 440:	learn: 0.3101743	total: 3.26s	remaining: 436ms
# 441:	learn: 0.3101378	total: 3.27s	remaining: 428ms
# 442:	learn: 0.3101018	total: 3.27s	remaining: 421ms
# 443:	learn: 0.3100466	total: 3.28s	remaining: 414ms
# 444:	learn: 0.3099721	total: 3.29s	remaining: 406ms
# 445:	learn: 0.3099138	total: 3.29s	remaining: 399ms
# 446:	learn: 0.3097960	total: 3.3s	remaining: 391ms
# 447:	learn: 0.3097414	total: 3.31s	remaining: 384ms
# 448:	learn: 0.3096932	total: 3.32s	remaining: 377ms
# 449:	learn: 0.3096412	total: 3.32s	remaining: 369ms
# 450:	learn: 0.3095856	total: 3.33s	remaining: 362ms
# 451:	learn: 0.3095565	total: 3.34s	remaining: 355ms
# 452:	learn: 0.3094454	total: 3.35s	remaining: 347ms
# 453:	learn: 0.3093544	total: 3.35s	remaining: 340ms
# 454:	learn: 0.3093237	total: 3.36s	remaining: 332ms
# 455:	learn: 0.3092794	total: 3.37s	remaining: 325ms
# 456:	learn: 0.3092382	total: 3.38s	remaining: 318ms
# 457:	learn: 0.3091825	total: 3.38s	remaining: 310ms
# 458:	learn: 0.3091035	total: 3.39s	remaining: 303ms
# 459:	learn: 0.3090651	total: 3.4s	remaining: 296ms
# 460:	learn: 0.3089963	total: 3.41s	remaining: 288ms
# 461:	learn: 0.3089087	total: 3.41s	remaining: 281ms
# 462:	learn: 0.3088594	total: 3.42s	remaining: 273ms
# 463:	learn: 0.3088101	total: 3.43s	remaining: 266ms
# 464:	learn: 0.3087523	total: 3.44s	remaining: 259ms
# 465:	learn: 0.3086693	total: 3.44s	remaining: 251ms
# 466:	learn: 0.3085915	total: 3.45s	remaining: 244ms
# 467:	learn: 0.3085531	total: 3.46s	remaining: 236ms
# 468:	learn: 0.3085019	total: 3.46s	remaining: 229ms
# 469:	learn: 0.3084479	total: 3.47s	remaining: 222ms
# 470:	learn: 0.3084018	total: 3.48s	remaining: 214ms
# 471:	learn: 0.3083390	total: 3.49s	remaining: 207ms
# 472:	learn: 0.3082864	total: 3.49s	remaining: 199ms
# 473:	learn: 0.3082345	total: 3.5s	remaining: 192ms
# 474:	learn: 0.3081864	total: 3.51s	remaining: 185ms
# 475:	learn: 0.3080985	total: 3.52s	remaining: 177ms
# 476:	learn: 0.3080245	total: 3.52s	remaining: 170ms
# 477:	learn: 0.3079731	total: 3.53s	remaining: 163ms
# 478:	learn: 0.3079206	total: 3.54s	remaining: 155ms
# 479:	learn: 0.3078649	total: 3.54s	remaining: 148ms
# 480:	learn: 0.3077537	total: 3.55s	remaining: 140ms
# 481:	learn: 0.3076921	total: 3.56s	remaining: 133ms
# 482:	learn: 0.3076088	total: 3.57s	remaining: 126ms
# 483:	learn: 0.3075721	total: 3.57s	remaining: 118ms
# 484:	learn: 0.3074867	total: 3.58s	remaining: 111ms
# 485:	learn: 0.3074367	total: 3.59s	remaining: 103ms
# 486:	learn: 0.3073962	total: 3.6s	remaining: 96ms
# 487:	learn: 0.3073692	total: 3.6s	remaining: 88.6ms
# 488:	learn: 0.3073153	total: 3.61s	remaining: 81.2ms
# 489:	learn: 0.3072644	total: 3.62s	remaining: 73.8ms
# 490:	learn: 0.3072096	total: 3.63s	remaining: 66.5ms
# 491:	learn: 0.3071622	total: 3.63s	remaining: 59.1ms
# 492:	learn: 0.3070810	total: 3.64s	remaining: 51.7ms
# 493:	learn: 0.3070343	total: 3.65s	remaining: 44.3ms
# 494:	learn: 0.3069685	total: 3.65s	remaining: 36.9ms
# 495:	learn: 0.3068785	total: 3.66s	remaining: 29.5ms
# 496:	learn: 0.3068138	total: 3.67s	remaining: 22.2ms
# 497:	learn: 0.3067752	total: 3.68s	remaining: 14.8ms
# 498:	learn: 0.3067299	total: 3.68s	remaining: 7.38ms
# 499:	learn: 0.3066717	total: 3.69s	remaining: 0us
# CatBoost score: 0.8396013066420973
#
# Precision: 0.8212723409573803
# Recall: 0.7324712963995096
# F1-score: 0.7743341975017676
#
# K-Fold mean: 0.8185415067411871
# K-Fold std: 0.004440882700934378
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.90      0.88     14907
#            1       0.82      0.73      0.77      8971
#
#     accuracy                           0.84     23878
#    macro avg       0.84      0.82      0.82     23878
# weighted avg       0.84      0.84      0.84     23878
#
#
# Selected features: ['lead_time', 'country', 'market_segment', 'previous_cancellations', 'deposit_type', 'agent', 'customer_type', 'required_car_parking_spaces', 'adr_x_lead_time', 'needs_parking']

# %%
# Stacking & Voting MODELS
from sklearn.ensemble import (
    StackingClassifier,
    VotingClassifier
)

# %% [markdown]
# ## Stacking

# %%
base1 = RandomForestClassifier(random_state=42)
base2 = ExtraTreesClassifier(random_state=42)
base3 = LogisticRegression()

stacking = StackingClassifier(
    estimators=[
        ('rf', base1),
        ('et', base2),
        ('lr', base3)
    ],
    final_estimator=LogisticRegression()
)

stacking.fit(x_train, y_train)
y_pred = stacking.predict(x_test)

stacking_score = accuracy_score(y_test, y_pred)

stacking_precision = precision_score(y_test, y_pred)
stacking_recall = recall_score(y_test, y_pred)
stacking_f1 = f1_score(y_test, y_pred)

stacking_scores = cross_val_score(stacking, x_train, y_train, cv=kf, scoring='f1_macro')

print(f'Stacking score: {stacking_score}')

print(f'\nPrecision: {stacking_precision}')
print(f'Recall: {stacking_recall}')
print(f'F1-score: {stacking_f1}')

print("\nK-Fold mean:", stacking_scores.mean())
print("K-Fold std:", stacking_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# Stacking score: 0.8844124298517464
#
# Precision: 0.8739313666465984
# Recall: 0.80905138780515
# F1-score: 0.8402407964806669
#
# K-Fold mean: 0.8655017893798073
# K-Fold std: 0.0035505858992038127
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91     14907
#            1       0.87      0.81      0.84      8971
#
#     accuracy                           0.88     23878
#    macro avg       0.88      0.87      0.87     23878
# weighted avg       0.88      0.88      0.88     23878

# %% [markdown]
# ## Hard Voting

# %%
model1 = RandomForestClassifier(random_state=42)
model2 = ExtraTreesClassifier(random_state=42)
model3 = LogisticRegression()

hard_voting = VotingClassifier(
    estimators=[
        ('rf', model1),
        ('et', model2),
        ('lr', model3)
    ],
    voting='hard'
)

hard_voting.fit(x_train, y_train)
y_pred = hard_voting.predict(x_test)

hard_voting_score = accuracy_score(y_test, y_pred)

hard_voting_precision = precision_score(y_test, y_pred)
hard_voting_recall = recall_score(y_test, y_pred)
hard_voting_f1 = f1_score(y_test, y_pred)

hard_voting_scores = cross_val_score(hard_voting, x_train, y_train, cv=kf, scoring='f1_macro')

print(f'Hard Voting score: {hard_voting_score}')

print(f'\nPrecision: {hard_voting_precision}')
print(f'Recall: {hard_voting_recall}')
print(f'F1-score: {hard_voting_f1}')

print("\nK-Fold mean:", hard_voting_scores.mean())
print("K-Fold std:", hard_voting_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# Hard Voting score: 0.8793868833235614
#
# Precision: 0.8871234269734334
# Recall: 0.7779511760115929
# F1-score: 0.8289583085877182
#
# K-Fold mean: 0.8583853106829612
# K-Fold std: 0.002451116385778589
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91     14907
#            1       0.89      0.78      0.83      8971
#
#     accuracy                           0.88     23878
#    macro avg       0.88      0.86      0.87     23878
# weighted avg       0.88      0.88      0.88     23878

# %% [markdown]
# ## Soft Voting

# %%
model1 = RandomForestClassifier(random_state=42)
model2 = ExtraTreesClassifier(random_state=42)
model3 = LogisticRegression()

soft_voting = VotingClassifier(
    estimators=[
        ('rf', model1),
        ('et', model2),
        ('lr', model3)
    ],
    voting='soft'
)

soft_voting.fit(x_train, y_train)
y_pred = soft_voting.predict(x_test)

soft_voting_score = accuracy_score(y_test, y_pred)

soft_voting_precision = precision_score(y_test, y_pred)
soft_voting_recall = recall_score(y_test, y_pred)
soft_voting_f1 = f1_score(y_test, y_pred)

soft_voting_scores = cross_val_score(soft_voting, x_train, y_train, cv=kf, scoring='f1_macro')

print(f'Soft Voting score: {soft_voting_score}')

print(f'\nPrecision: {soft_voting_precision}')
print(f'Recall: {soft_voting_recall}')
print(f'F1-score: {soft_voting_f1}')

print("\nK-Fold mean:", soft_voting_scores.mean())
print("K-Fold std:", soft_voting_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# Soft Voting score: 0.8767065918418628
#
# Precision: 0.8904003109211037
# Recall: 0.7661353249359045
# F1-score: 0.8236069502696225
#
# K-Fold mean: 0.8555859310082038
# K-Fold std: 0.002725969649495273
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.94      0.91     14907
#            1       0.89      0.77      0.82      8971
#
#     accuracy                           0.88     23878
#    macro avg       0.88      0.85      0.86     23878
# weighted avg       0.88      0.88      0.87     23878

# %% [markdown]
# ## 👥 4. Neighbors-Based Models
#
# **Jami: `2ta` algoritm**
#
# - **K-Nearest Neighbors (KNN) Classifier**
# - **Radius Neighbors Classifier**

# %%
# Keighbors MODELS (2ta)
from sklearn.neighbors import (
    KNeighborsClassifier,
    RadiusNeighborsClassifier,
)

# %% [markdown]
# ## KNN

# %%
knn = KNeighborsClassifier(n_neighbors=1)

knn.fit(x_train, y_train)
y_pred = knn.predict(x_test)

knn_score = accuracy_score(y_test, y_pred)

knn_precision = precision_score(y_test, y_pred)
knn_recall = recall_score(y_test, y_pred)
knn_f1 = f1_score(y_test, y_pred)

knn_scores = cross_val_score(knn, x_train, y_train, cv=kf, scoring='f1_macro')

print(f'KNN score: {knn_score}')

print(f'\nPrecision: {knn_precision}')
print(f'Recall: {knn_recall}')
print(f'F1-score: {knn_f1}')

print("\nK-Fold mean:", knn_scores.mean())
print("K-Fold std:", knn_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\neighbors\_classification.py:239: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\neighbors\_classification.py:239: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\neighbors\_classification.py:239: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\neighbors\_classification.py:239: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNN score: 0.7739341653404808
#
# Precision: 0.6945442665795492
# Recall: 0.7109575298183034
# F1-score: 0.7026550622452352
#
# K-Fold mean: 0.7477000249888874
# K-Fold std: 0.0031805913615647477
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.82      0.81      0.82     14907
#            1       0.69      0.71      0.70      8971
#
#     accuracy                           0.77     23878
#    macro avg       0.76      0.76      0.76     23878
# weighted avg       0.78      0.77      0.77     23878

# %% [markdown]
# ## 📐 5. Support Vector Machine (SVM) Models
#
# **Jami: `1ta` algoritm**
#
# - **Support Vector Classifier (SVC)**

# %%
from sklearn.svm import SVC

svr = SVC(kernel='rbf', C=20.0)

svr.fit(x_train, y_train)
y_pred = svr.predict(x_test)

svr_score = accuracy_score(y_test, y_pred)

svr_precision = precision_score(y_test, y_pred)
svr_recall = recall_score(y_test, y_pred)
svr_f1 = f1_score(y_test, y_pred)

svr_scores = cross_val_score(svr, x_train, y_train, cv=kf, scoring='f1_macro')

print(f'SVC score: {svr_score}')

print(f'\nPrecision: {svr_precision}')
print(f'Recall: {svr_recall}')
print(f'F1-score: {svr_f1}')

print("\nK-Fold mean:", svr_scores.mean())
print("K-Fold std:", svr_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC score: 0.8439986598542591
#
# Precision: 0.8294398392363728
# Recall: 0.7361498160740163
# F1-score: 0.7800153546329652
#
# K-Fold mean: 0.8231301878898886
# K-Fold std: 0.002850198933429421
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.91      0.88     14907
#            1       0.83      0.74      0.78      8971
#
#     accuracy                           0.84     23878
#    macro avg       0.84      0.82      0.83     23878
# weighted avg       0.84      0.84      0.84     23878

# %% [markdown]
# ## 🧬 6. Neural Network Models
#
# **Jami: `1ta` algoritm**
#
# - **Multi-Layer Perceptron (MLP) Classifier**

# %%
# Neural Network MODEL
from sklearn.neural_network import MLPClassifier

# %% [markdown]
# ## MLPClassifier

# %%
mlpc = MLPClassifier(hidden_layer_sizes=(128, 64), activation="relu", max_iter=300, random_state=42)

mlpc.fit(x_train, y_train)
y_pred = mlpc.predict(x_test)

mlpc_score = accuracy_score(y_test, y_pred)

mlpc_precision = precision_score(y_test, y_pred)
mlpc_recall = recall_score(y_test, y_pred)
mlpc_f1 = f1_score(y_test, y_pred)

mlpc_scores = cross_val_score(mlpc, x_train, y_train, cv=kf, scoring='f1_macro')

print(f'MLPClassifier score: {mlpc_score}')

print(f'\nPrecision: {mlpc_precision}')
print(f'Recall: {mlpc_recall}')
print(f'F1-score: {mlpc_f1}')

print("\nK-Fold mean:", mlpc_scores.mean())
print("K-Fold std:", mlpc_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("\nSelected features:", list(selected_features))
# Out:
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\neural_network\_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\neural_network\_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\neural_network\_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# MLPClassifier score: 0.8380517631292403
#
# Precision: 0.782113641388459
# Recall: 0.7886523241556125
# F1-score: 0.7853693733695953
#
# K-Fold mean: 0.8068927449216163
# K-Fold std: 0.0014178092058384614
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.87      0.87     14907
#            1       0.78      0.79      0.79      8971
#
#     accuracy                           0.84     23878
#    macro avg       0.83      0.83      0.83     23878
# weighted avg       0.84      0.84      0.84     23878
#
#
# Selected features: ['lead_time', 'country', 'market_segment', 'previous_cancellations', 'deposit_type', 'agent', 'customer_type', 'required_car_parking_spaces', 'adr_x_lead_time', 'needs_parking']
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\neural_network\_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %% [markdown]
# ## 🎯 7. Naive & Simple Baseline Models
#
# **Jami: `1ta` algoritm**
#
# - **Dummy Classifier**

# %%
# Simple Baseline MODEL
from sklearn.dummy import DummyClassifier

# %% [markdown]
# ## DummyClassifier

# %%
dummy = DummyClassifier()

dummy.fit(x_train, y_train)
y_pred = dummy.predict(x_test)

dummy_score = accuracy_score(y_test, y_pred)

dummy_precision = precision_score(y_test, y_pred)
dummy_recall = recall_score(y_test, y_pred)
dummy_f1 = f1_score(y_test, y_pred)

dummy_scores = cross_val_score(dummy, x_train, y_train, cv=kf, scoring='f1_macro')

print(f'DummyClassifier score: {dummy_score}')

print(f'\nPrecision: {dummy_precision}')
print(f'Recall: {dummy_recall}')
print(f'F1-score: {dummy_f1}')

print("\nK-Fold mean:", dummy_scores.mean())
print("K-Fold std:", dummy_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("\nSelected features:", list(selected_features))
# Out:
# DummyClassifier score: 0.6242985174637742
#
# Precision: 0.0
# Recall: 0.0
# F1-score: 0.0
#
# K-Fold mean: 0.38684320260727606
# K-Fold std: 0.0004277210010969743
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.62      1.00      0.77     14907
#            1       0.00      0.00      0.00      8971
#
#     accuracy                           0.62     23878
#    macro avg       0.31      0.50      0.38     23878
# weighted avg       0.39      0.62      0.48     23878
#
#
# Selected features: ['lead_time', 'country', 'market_segment', 'previous_cancellations', 'deposit_type', 'agent', 'customer_type', 'required_car_parking_spaces', 'adr_x_lead_time', 'needs_parking']
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
from rich.table import Table
from rich.console import Console

console = Console()

results = [
    # Linear Family
    ['Logistic Regression', lr_score, lr_precision, lr_recall, lr_f1, lr_scores.mean(), lr_scores.std()],
    ['RidgeClassifier', ridge_score, ridge_precision, ridge_recall, ridge_f1, ridge_scores.mean(), ridge_scores.std()],
    ['SGDC', sgdc_score, sgdc_precision, sgdc_recall, sgdc_f1, sgdc_scores.mean(), sgdc_scores.std()],
    ['Passive Aggressive', pac_score, pac_precision, pac_recall, pac_f1, pac_scores.mean(), pac_scores.std()],

    # Tree-Based Family
    ['DecisionTree', dt_score, dt_precision, dt_recall, dt_f1, dt_scores.mean(), dt_scores.std()],

    # Bagging Family
    ['RandomForest', rf_score, rf_precision, rf_recall, rf_f1, rf_scores.mean(), rf_scores.std()],
    ['Bagging', bag_score, bag_precision, bag_recall, bag_f1, bag_scores.mean(), bag_scores.std()],
    ['Bagged DT', bag_dt_score, bag_dt_precision, bag_dt_recall, bag_dt_f1, bag_dt_scores.mean(), bag_dt_scores.std()],
    ['ExtraTrees', et_score, et_precision, et_recall, et_f1, et_scores.mean(), et_scores.std()],

    # Boosting Family
    ['GradientBoosting', gb_score, gb_precision, gb_recall, gb_f1, gb_scores.mean(), gb_scores.std()],
    ['HistGradientBoosting', hgb_score, hgb_precision, hgb_recall, hgb_f1, hgb_scores.mean(), hgb_scores.std()],
    ['XGBoost', xgb_score, xgb_precision, xgb_recall, xgb_f1, xgb_scores.mean(), xgb_scores.std()],
    ['AdaBoost', ab_score, ab_precision, ab_recall, ab_f1, ab_scores.mean(), ab_scores.std()],
    ['LGBMClassifier', lgbm_score, lgbm_precision, lgbm_recall, lgbm_f1, lgbm_scores.mean(), lgbm_scores.std()],
    ['CatBoost', cat_score, cat_precision, cat_recall, cat_f1, cat_scores.mean(), cat_scores.std()],

    # Stacking & Voting Family
    ['Hard Voting', hard_voting_score, hard_voting_precision, hard_voting_recall, hard_voting_f1, hard_voting_scores.mean(), hard_voting_scores.std()],
    ['Soft Voting', soft_voting_score, soft_voting_precision, soft_voting_recall, soft_voting_f1, soft_voting_scores.mean(), soft_voting_scores.std()],
    ['Stacking', stacking_score, stacking_precision, stacking_recall, stacking_f1, stacking_scores.mean(), stacking_scores.std()],

    # Neighbors Family
    ['KNN', knn_score, knn_precision, knn_recall, knn_f1, knn_scores.mean(), knn_scores.std()],

    # SVM Family
    ['SVC', svr_score, svr_precision, svr_recall, svr_f1, svr_scores.mean(), svr_scores.std()],

    # Neural Network Family
    ['MLPC', mlpc_score, mlpc_precision, mlpc_recall, mlpc_f1, mlpc_scores.mean(), mlpc_scores.std()],

    # Naive & Simple Family
    ['DummyClassifier', dummy_score, dummy_precision, dummy_recall, dummy_f1, dummy_scores.mean(), dummy_scores.std()],
]

result_sorted = sorted(results, key=lambda i: i[3], reverse=True)

best_model = max(results, key=lambda x: x[3])
worst_model = min(results, key=lambda x: x[3])

table = Table(title="Comparison with Wrapper Method", show_lines=True)
table.add_column("Algorithm")
table.add_column("Accuracy")
table.add_column("Precision")
table.add_column("Recall")
table.add_column("F1-score")
table.add_column("K-Fold mean")
table.add_column("K-Fold std")

for row in result_sorted:
    algo, acc, presicion, recall, f1, kmean, kstd = row

    if row == best_model:
        table.add_row(
            f"[bold green]{algo}[/bold green]",
            f"[bold green]{acc:.2f}[/bold green]",
            f"[bold green]{presicion:.2f}[/bold green]",
            f"[bold green]{recall:.2f}[/bold green]",
            f"[bold green]{f1:.2f}[/bold green]",
            f"[bold green]{kmean:.2f}[/bold green]",
            f"[bold green]{kstd:.2f}[/bold green]",
        )
    elif row == worst_model:
        table.add_row(
            f"[bold red]{algo}[/bold red]",
            f"[bold red]{acc:.2f}[/bold red]",
            f"[bold red]{presicion:.2f}[/bold red]",
            f"[bold red]{recall:.2f}[/bold red]",
            f"[bold red]{f1:.2f}[/bold red]",
            f"[bold red]{kmean:.2f}[/bold red]",
            f"[bold red]{kstd:.2f}[/bold red]",
        )
    else:
        table.add_row(algo, f"{acc:.2f}", f"{presicion:.2f}", f"{recall:.2f}", f"{f1:.2f}", f"{kmean:.2f}", f"{kstd:.2f}")

console.print(table)
# Out:
#                                 Comparison with Wrapper Method
# ┏━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Algorithm            ┃ Accuracy ┃ Precision ┃ Recall ┃ F1-score ┃ K-Fold mean ┃ K-Fold std ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ Bagging              │ 0.88     │ 0.87      │ 0.81   │ 0.84     │ 0.86        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ Stacking             │ 0.88     │ 0.87      │ 0.81   │ 0.84     │ 0.87        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ HistGradientBoosting │ 0.88     │ 0.86      │ 0.80   │ 0.83     │ 0.86        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ MLPC                 │ 0.84     │ 0.78      │ 0.79   │ 0.79     │ 0.81        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ Hard Voting          │ 0.88     │ 0.89      │ 0.78   │ 0.83     │ 0.86        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ Soft Voting          │ 0.88     │ 0.89      │ 0.77   │ 0.82     │ 0.86        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ Bagged DT            │ 0.85     │ 0.83      │ 0.75   │ 0.79     │ 0.83        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ RandomForest         │ 0.86     │ 0.85      │ 0.75   │ 0.80     │ 0.84        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ GradientBoosting     │ 0.85     │ 0.83      │ 0.74   │ 0.78     │ 0.83        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ SVC                  │ 0.84     │ 0.83      │ 0.74   │ 0.78     │ 0.82        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ XGBoost              │ 0.84     │ 0.82      │ 0.73   │ 0.77     │ 0.82        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ CatBoost             │ 0.84     │ 0.82      │ 0.73   │ 0.77     │ 0.82        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ KNN                  │ 0.77     │ 0.69      │ 0.71   │ 0.70     │ 0.75        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ ExtraTrees           │ 0.84     │ 0.83      │ 0.71   │ 0.77     │ 0.82        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ DecisionTree         │ 0.84     │ 0.85      │ 0.69   │ 0.76     │ 0.82        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ LGBMClassifier       │ 0.82     │ 0.82      │ 0.68   │ 0.75     │ 0.80        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ Passive Aggressive   │ 0.79     │ 0.79      │ 0.61   │ 0.69     │ 0.69        │ 0.03       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ Logistic Regression  │ 0.79     │ 0.89      │ 0.52   │ 0.65     │ 0.75        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ RidgeClassifier      │ 0.78     │ 0.89      │ 0.48   │ 0.62     │ 0.73        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ SGDC                 │ 0.77     │ 0.97      │ 0.39   │ 0.55     │ 0.69        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ AdaBoost             │ 0.75     │ 0.99      │ 0.33   │ 0.50     │ 0.67        │ 0.01       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ DummyClassifier      │ 0.62     │ 0.00      │ 0.00   │ 0.00     │ 0.39        │ 0.00       │
# └──────────────────────┴──────────┴───────────┴────────┴──────────┴─────────────┴────────────┘

# %%
os.makedirs('results', exist_ok=True)

temp_console = Console(record=True)
temp_console.print(table)
text = temp_console.export_text()
with open('results/feature_selection_compare.txt', 'a', encoding='utf-8') as f:
    f.write(text)
# Out:
#                                 Comparison with Wrapper Method
# ┏━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Algorithm            ┃ Accuracy ┃ Precision ┃ Recall ┃ F1-score ┃ K-Fold mean ┃ K-Fold std ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ Bagging              │ 0.88     │ 0.87      │ 0.81   │ 0.84     │ 0.86        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ Stacking             │ 0.88     │ 0.87      │ 0.81   │ 0.84     │ 0.87        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ HistGradientBoosting │ 0.88     │ 0.86      │ 0.80   │ 0.83     │ 0.86        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ MLPC                 │ 0.84     │ 0.78      │ 0.79   │ 0.79     │ 0.81        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ Hard Voting          │ 0.88     │ 0.89      │ 0.78   │ 0.83     │ 0.86        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ Soft Voting          │ 0.88     │ 0.89      │ 0.77   │ 0.82     │ 0.86        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ Bagged DT            │ 0.85     │ 0.83      │ 0.75   │ 0.79     │ 0.83        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ RandomForest         │ 0.86     │ 0.85      │ 0.75   │ 0.80     │ 0.84        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ GradientBoosting     │ 0.85     │ 0.83      │ 0.74   │ 0.78     │ 0.83        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ SVC                  │ 0.84     │ 0.83      │ 0.74   │ 0.78     │ 0.82        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ XGBoost              │ 0.84     │ 0.82      │ 0.73   │ 0.77     │ 0.82        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ CatBoost             │ 0.84     │ 0.82      │ 0.73   │ 0.77     │ 0.82        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ KNN                  │ 0.77     │ 0.69      │ 0.71   │ 0.70     │ 0.75        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ ExtraTrees           │ 0.84     │ 0.83      │ 0.71   │ 0.77     │ 0.82        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ DecisionTree         │ 0.84     │ 0.85      │ 0.69   │ 0.76     │ 0.82        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ LGBMClassifier       │ 0.82     │ 0.82      │ 0.68   │ 0.75     │ 0.80        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ Passive Aggressive   │ 0.79     │ 0.79      │ 0.61   │ 0.69     │ 0.69        │ 0.03       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ Logistic Regression  │ 0.79     │ 0.89      │ 0.52   │ 0.65     │ 0.75        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ RidgeClassifier      │ 0.78     │ 0.89      │ 0.48   │ 0.62     │ 0.73        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ SGDC                 │ 0.77     │ 0.97      │ 0.39   │ 0.55     │ 0.69        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ AdaBoost             │ 0.75     │ 0.99      │ 0.33   │ 0.50     │ 0.67        │ 0.01       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ DummyClassifier      │ 0.62     │ 0.00      │ 0.00   │ 0.00     │ 0.39        │ 0.00       │
# └──────────────────────┴──────────┴───────────┴────────┴──────────┴─────────────┴────────────┘

# %% [markdown]
# # Another Feature Selections

# %% [markdown]
# <a href="../FS/without_fs.ipynb" target="_blank" style="text-decoration: none;">
#     <button style="
#         background-color: #45a049;
#         color: white;
#         padding: 12px 24px;
#         font-size: 16px;
#         border: none;
#         border-radius: 8px;
#         cursor: pointer;
#         transition: background-color 0.3s;
#     " onmouseover="this.style.backgroundColor='#45a049'" onmouseout="this.style.backgroundColor='#4CAF50'">
#         Without Feature Selection
#     </button>
# </a>
#
# <a href="../FS/filter.ipynb" target="_blank" style="text-decoration: none;">
#     <button style="
#         background-color: #45a049;
#         color: white;
#         padding: 12px 24px;
#         font-size: 16px;
#         border: none;
#         border-radius: 8px;
#         cursor: pointer;
#         transition: background-color 0.3s;
#     " onmouseover="this.style.backgroundColor='#45a049'" onmouseout="this.style.backgroundColor='#4CAF50'">
#         Filter method
#     </button>
# </a>
#
# <a href="../FS/embedded.ipynb" target="_blank" style="text-decoration: none;">
#     <button style="
#         background-color: #45a049;
#         color: white;
#         padding: 12px 24px;
#         font-size: 16px;
#         border: none;
#         border-radius: 8px;
#         cursor: pointer;
#         transition: background-color 0.3s;
#     " onmouseover="this.style.backgroundColor='#45a049'" onmouseout="this.style.backgroundColor='#4CAF50'">
#         Embedded method
#     </button>
# </a>

# %% [markdown]
# # Next step - Feature selection

# %% [markdown]
# <a href="..\Tuning\bayesian_optimization.ipynb" target="_blank" style="text-decoration: none;">
#     <button style="
#         background-color: #45a049;
#         color: white;
#         padding: 12px 24px;
#         font-size: 16px;
#         border: none;
#         border-radius: 8px;
#         cursor: pointer;
#         transition: background-color 0.3s;
#     " onmouseover="this.style.backgroundColor='#45a049'" onmouseout="this.style.backgroundColor='#4CAF50'">
#         Bayesian Optimization
#     </button>
# </a>
#
# <a href="../Tuning/manual_search.ipynb" target="_blank" style="text-decoration: none;">
#     <button style="
#         background-color: #45a049;
#         color: white;
#         padding: 12px 24px;
#         font-size: 16px;
#         border: none;
#         border-radius: 8px;
#         cursor: pointer;
#         transition: background-color 0.3s;
#     " onmouseover="this.style.backgroundColor='#45a049'" onmouseout="this.style.backgroundColor='#4CAF50'">
#         Manual Search
#     </button>
# </a>
#
# <a href="../Tuning/optuna.ipynb" target="_blank" style="text-decoration: none;">
#     <button style="
#         background-color: #45a049;
#         color: white;
#         padding: 12px 24px;
#         font-size: 16px;
#         border: none;
#         border-radius: 8px;
#         cursor: pointer;
#         transition: background-color 0.3s;
#     " onmouseover="this.style.backgroundColor='#45a049'" onmouseout="this.style.backgroundColor='#4CAF50'">
#         optuna
#     </button>
# </a>
#
# <a href="../Tuning/random_search.ipynb" target="_blank" style="text-decoration: none;">
#     <button style="
#         background-color: #45a049;
#         color: white;
#         padding: 12px 24px;
#         font-size: 16px;
#         border: none;
#         border-radius: 8px;
#         cursor: pointer;
#         transition: background-color 0.3s;
#     " onmouseover="this.style.backgroundColor='#45a049'" onmouseout="this.style.backgroundColor='#4CAF50'">
#         Random Search
#     </button>
# </a>
