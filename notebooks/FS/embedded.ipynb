# %% [markdown]
# ## 🔹 Embedded Method Training — Algorithm Families Overview
#
# #### 📌 Ushbu bosqichda **Embedded feature selection** qo'llanilib, **FS - Embedded Method** asosida **classification** uchun **jami 23 ta algoritm** turli model oilalaridan foydalanilgan.
#
#
# Quyida loyihada qo‘llanilgan **asosiy algoritm oilalari** keltirilgan:
#
# - 📏 **Linear Models**
# - 🌳 **Tree-Based Models**
# - 🧠 **Ensemble Models**
# - 👥 **Neighbors-Based Models**
# - 📐 **Support Vector Machine (SVM) Models**
# - 🧬 **Neural Network Models**
# - 🎯 **Naive & Simple Baseline Models**
#
# 📈 Ushbu yondashuv feature selection’ning model performansiga bo‘lgan
# **dastlabki va tezkor ta’sirini baholash** imkonini beradi.
#
# 🌐 Ushbu model oilalari klassik **baseline** yondashuvlardan tortib,
# zamonaviy **ensemble** va **kernel-based** modellargacha bo‘lgan
# keng qamrovli yechimlarni o‘z ichiga oladi.
#
# 🔍 Barcha modellar o‘zaro solishtirish, barqarorlikni baholash
# va **eng optimal modelni aniqlash** maqsadida birgalikda sinovdan o‘tkazilgan.

# %%
import pandas as pd
import os
import numpy as np

# %%
os.chdir(r'C:\SML_Projects\SML_hotelBooking_cancelling_prediction')

# %%
x_train = pd.read_csv('data/preprocessed/preprocessed_x_train.csv')
x_test = pd.read_csv('data/preprocessed/preprocessed_x_test.csv')

y_train = pd.read_csv('data/split/y_train.csv')
y_test = pd.read_csv('data/split/y_test.csv')

# %%
from sklearn.model_selection import KFold, cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, precision_score, recall_score, f1_score

# %%
kf = KFold(n_splits=3, shuffle=True, random_state=42)

# %% [markdown]
# ### 📌 1. Linear Models
# **Jami: `4ta` algoritm**
#
# - **Logistic Regression**
# - **Ridge Classifier**
# - **SGD Classifier**
# - **Passive Aggressive Classifier**

# %%
# LINEAR MODELS - CLASSIFICATION (4ta)
from sklearn.linear_model import (
    LogisticRegression,
    RidgeClassifier,
    SGDClassifier,
    PassiveAggressiveClassifier
)

# %% [markdown]
# ## Linear Regression

# %%
lr = LogisticRegression()

lr.fit(x_train, y_train)
y_pred = lr.predict(x_test)

lr_score = accuracy_score(y_test, y_pred)

lr_precision = precision_score(y_test, y_pred)
lr_recall = recall_score(y_test, y_pred)
lr_f1 = f1_score(y_test, y_pred)

lr_scores = cross_val_score(lr, x_test, y_test, cv=kf, scoring='f1_macro')

print(f'Logistic Regression score: {lr_score}')

print(f'\nPrecision: {lr_precision}')
print(f'Recall: {lr_recall}')
print(f'F1-score: {lr_f1}')

print("\nK-Fold mean:", lr_scores.mean())
print("K-Fold std:", lr_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Logistic Regression score: 0.807228411089706
#
# Precision: 0.8136128661688685
# Recall: 0.6315906810834913
# F1-score: 0.711139002196423
#
# K-Fold mean: 0.7832583198850734
# K-Fold std: 0.001828573879108599
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.80      0.91      0.86     14907
#            1       0.81      0.63      0.71      8971
#
#     accuracy                           0.81     23878
#    macro avg       0.81      0.77      0.78     23878
# weighted avg       0.81      0.81      0.80     23878

# %% [markdown]
# ## RidgeClassifier

# %%
ridge = RidgeClassifier()
ridge.fit(x_train, y_train)

importance = np.abs(ridge.coef_)
selected_features = x_train.columns[importance > 0]

ridge.fit(x_train[selected_features], y_train)
y_pred = ridge.predict(x_test[selected_features])

ridge_score = accuracy_score(y_test, y_pred)

ridge_precision = precision_score(y_test, y_pred)
ridge_recall = recall_score(y_test, y_pred)
ridge_f1 = f1_score(y_test, y_pred)

ridge_scores = cross_val_score(ridge, x_test[selected_features], y_test, cv=kf, scoring='f1_macro')

print(f'RidgeClassifier score: {ridge_score}')

print(f'\nPrecision: {ridge_precision}')
print(f'Recall: {ridge_recall}')
print(f'F1-score: {ridge_f1}')

print("\nK-Fold mean:", ridge_scores.mean())
print("K-Fold std:", ridge_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# RidgeClassifier score: 0.7965072451629115
#
# Precision: 0.8595662819167541
# Recall: 0.5478764909151711
# F1-score: 0.6692082510722309
#
# K-Fold mean: 0.7633065562880011
# K-Fold std: 0.0016168066121508167
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.78      0.95      0.85     14907
#            1       0.86      0.55      0.67      8971
#
#     accuracy                           0.80     23878
#    macro avg       0.82      0.75      0.76     23878
# weighted avg       0.81      0.80      0.78     23878
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_ridge.py:1306: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_ridge.py:1306: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_ridge.py:1306: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_ridge.py:1306: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_ridge.py:1306: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# ## SGDClassifier

# %%
sgdc = SGDClassifier()
sgdc.fit(x_train, y_train)

importance = np.abs(sgdc.coef_).ravel() 
selected_features = x_train.columns[importance > 0]

sgdc.fit(x_train[selected_features], y_train)
y_pred = sgdc.predict(x_test[selected_features])

sgdc_score = accuracy_score(y_test, y_pred)

sgdc_precision = precision_score(y_test, y_pred)
sgdc_recall = recall_score(y_test, y_pred)
sgdc_f1 = f1_score(y_test, y_pred)

sgdc_scores = cross_val_score(sgdc, x_test[selected_features], y_test, cv=kf, scoring='f1_macro')

print(f'SGDClassifier score: {sgdc_score}')

print(f'\nPrecision: {sgdc_precision}')
print(f'Recall: {sgdc_recall}')
print(f'F1-score: {sgdc_f1}')

print("\nK-Fold mean:", sgdc_scores.mean())
print("K-Fold std:", sgdc_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SGDClassifier score: 0.7962559678365022
#
# Precision: 0.891793893129771
# Recall: 0.5209006799687883
# F1-score: 0.657659559496165
#
# K-Fold mean: 0.772410284886465
# K-Fold std: 0.0034142922643351364
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.77      0.96      0.85     14907
#            1       0.89      0.52      0.66      8971
#
#     accuracy                           0.80     23878
#    macro avg       0.83      0.74      0.76     23878
# weighted avg       0.82      0.80      0.78     23878
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# ## PassiveAggressiveClassifier

# %%
pac = PassiveAggressiveClassifier()
pac.fit(x_train, y_train)

importance = np.abs(pac.coef_).ravel()
selected_features = x_train.columns[importance > 0]

pac.fit(x_train[selected_features], y_train)
y_pred = pac.predict(x_test[selected_features])

pac_score = accuracy_score(y_test, y_pred)

pac_precision = precision_score(y_test, y_pred)
pac_recall = recall_score(y_test, y_pred)
pac_f1 = f1_score(y_test, y_pred)

pac_scores = cross_val_score(pac, x_test[selected_features], y_test, cv=kf, scoring='f1_macro')

print(f'SGDClassifier score: {pac_score}')

print(f'\nPrecision: {pac_precision}')
print(f'Recall: {pac_recall}')
print(f'F1-score: {pac_f1}')

print("\nK-Fold mean:", pac_scores.mean())
print("K-Fold std:", pac_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SGDClassifier score: 0.7691180165843036
#
# Precision: 0.9406218144750255
# Recall: 0.41143685207892094
# F1-score: 0.5724699495928655
#
# K-Fold mean: 0.7123061094590581
# K-Fold std: 0.02240938515611296
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.74      0.98      0.84     14907
#            1       0.94      0.41      0.57      8971
#
#     accuracy                           0.77     23878
#    macro avg       0.84      0.70      0.71     23878
# weighted avg       0.81      0.77      0.74     23878
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# ## 🌲 2. Tree-Based Models
#
# **Jami: `1ta` algoritm**
#
# - **Decision Tree**

# %%
# Tree MODELS (1ta)
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# ## Decision Tree

# %%
dt = DecisionTreeClassifier(max_depth=10, min_samples_split=5,random_state=42)

dt.fit(x_train, y_train)
y_pred = dt.predict(x_test)

dt_score = accuracy_score(y_test, y_pred)

dt_precision = precision_score(y_test, y_pred)
dt_recall = recall_score(y_test, y_pred)
dt_f1 = f1_score(y_test, y_pred)

dt_scores = cross_val_score(dt, x_test, y_test, cv=kf, scoring='f1_macro')

print(f'DecisionTree score: {dt_score}')

print(f'\nPrecision: {dt_precision}')
print(f'Recall: {dt_recall}')
print(f'F1-score: {dt_f1}')

print("\nK-Fold mean:", dt_scores.mean())
print("K-Fold std:", dt_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# DecisionTree score: 0.8412346092637575
#
# Precision: 0.8078202995008319
# Recall: 0.7576635826552224
# F1-score: 0.7819384526890998
#
# K-Fold mean: 0.8226429346350811
# K-Fold std: 0.0021023257231358584
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.89      0.88     14907
#            1       0.81      0.76      0.78      8971
#
#     accuracy                           0.84     23878
#    macro avg       0.83      0.82      0.83     23878
# weighted avg       0.84      0.84      0.84     23878

# %% [markdown]
# ## 🧠 3. Ensemble Models
#
# **Jami: `12ta` algoritm**
#
# ### 📦 Bagging Family (4ta)
# - **Random Forest**
# - **Bagging Classifier**
# - **Extra Trees**
# - **Bagged Decision Tree**
#
# ### 🚀 Boosting Family (6ta)
# - **Gradient Boosting**
# - **Hist Gradient Boosting**
# - **AdaBoost**
# - **CatBoost**
# - **XGBoost**
# - **LightGBM**
#
# ### 🧩 Meta-Ensemble Methods
# - **Stacking**
# - **Voting**

# %%
# Bagging MODELS (3ta)
from sklearn.ensemble import (
    RandomForestClassifier,
    BaggingClassifier,
    ExtraTreesClassifier
)

# %% [markdown]
# ## Random Forest

# %%
rf = RandomForestClassifier(n_estimators=300, max_depth=15, n_jobs=-1, random_state=42)
rf.fit(x_train, y_train)

importance = rf.feature_importances_
selected_features = x_train.columns[importance > np.mean(importance)]

rf.fit(x_train[selected_features], y_train)
y_pred = rf.predict(x_test[selected_features])

rf_score = accuracy_score(y_test, y_pred)

rf_precision = precision_score(y_test, y_pred)
rf_recall = recall_score(y_test, y_pred)
rf_f1 = f1_score(y_test, y_pred)

rf_scores = cross_val_score(rf, x_train[selected_features], y_train, cv=kf, scoring='f1_macro')

print(f'RandomForest score: {rf_score}')

print(f'\nPrecision: {rf_precision}')
print(f'Recall: {rf_recall}')
print(f'F1-score: {rf_f1}')

print("\nK-Fold mean:", rf_scores.mean())
print("K-Fold std:", rf_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForest score: 0.8679956445263423
#
# Precision: 0.8758558325797701
# Recall: 0.7557685876713855
# F1-score: 0.8113930110100527
#
# K-Fold mean: 0.8490731770281146
# K-Fold std: 0.0022707888005319295
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.94      0.90     14907
#            1       0.88      0.76      0.81      8971
#
#     accuracy                           0.87     23878
#    macro avg       0.87      0.85      0.85     23878
# weighted avg       0.87      0.87      0.87     23878

# %% [markdown]
# ## Bagging

# %%
bag = BaggingClassifier(n_estimators=200, random_state=42)

bag.fit(x_train, y_train)
y_pred = bag.predict(x_test)

bag_score = accuracy_score(y_test, y_pred)

bag_precision = precision_score(y_test, y_pred)
bag_recall = recall_score(y_test, y_pred)
bag_f1 = f1_score(y_test, y_pred)

bag_scores = cross_val_score(bag, x_train, y_train, cv=kf, scoring='f1_macro')

print(f'Bagging score: {bag_score}')

print(f'\nPrecision: {bag_precision}')
print(f'Recall: {bag_recall}')
print(f'F1-score: {bag_f1}')

print("\nK-Fold mean:", bag_scores.mean())
print("K-Fold std:", bag_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\ensemble\_bagging.py:930: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\ensemble\_bagging.py:930: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\ensemble\_bagging.py:930: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\ensemble\_bagging.py:930: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Bagging score: 0.8833235614373063
#
# Precision: 0.8696951583980873
# Recall: 0.8109463827889868
# F1-score: 0.8392939547761883
#
# K-Fold mean: 0.863529776425735
# K-Fold std: 0.0020729048508812413
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91     14907
#            1       0.87      0.81      0.84      8971
#
#     accuracy                           0.88     23878
#    macro avg       0.88      0.87      0.87     23878
# weighted avg       0.88      0.88      0.88     23878

# %% [markdown]
# ## Bagged DT

# %%
bag_dt = BaggingClassifier(
    estimator=DecisionTreeClassifier(max_depth=10),
    n_estimators=100,
    random_state=42
)

bag_dt.fit(x_train, y_train)
y_pred = bag_dt.predict(x_test)

bag_dt_score = accuracy_score(y_test, y_pred)

bag_dt_precision = precision_score(y_test, y_pred)
bag_dt_recall = recall_score(y_test, y_pred)
bag_dt_f1 = f1_score(y_test, y_pred)

bag_dt_scores = cross_val_score(bag_dt, x_train, y_train, cv=kf, scoring='f1_macro')

print(f'Bagged DT score: {bag_dt_score}')

print(f'\nPrecision: {bag_dt_precision}')
print(f'Recall: {bag_dt_recall}')
print(f'F1-score: {bag_dt_f1}')

print("\nK-Fold mean:", bag_dt_scores.mean())
print("K-Fold std:", bag_dt_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\ensemble\_bagging.py:930: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\ensemble\_bagging.py:930: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\ensemble\_bagging.py:930: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\ensemble\_bagging.py:930: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Bagged DT score: 0.8475584219783902
#
# Precision: 0.8260550458715596
# Recall: 0.75275888975588
# F1-score: 0.7877055873089933
#
# K-Fold mean: 0.8300327625670718
# K-Fold std: 0.0035730433703317376
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.90      0.88     14907
#            1       0.83      0.75      0.79      8971
#
#     accuracy                           0.85     23878
#    macro avg       0.84      0.83      0.83     23878
# weighted avg       0.85      0.85      0.85     23878

# %% [markdown]
# ## Extra Tree

# %%
et = ExtraTreesClassifier(n_estimators=200, max_depth=15, random_state=42)
et.fit(x_train, y_train)

importance = et.feature_importances_
selected_features = x_train.columns[importance > np.mean(importance)]

et.fit(x_train[selected_features], y_train)
y_pred = et.predict(x_test[selected_features])

et_score = accuracy_score(y_test, y_pred)

et_precision = precision_score(y_test, y_pred)
et_recall = recall_score(y_test, y_pred)
et_f1 = f1_score(y_test, y_pred)

et_scores = cross_val_score(et, x_train[selected_features], y_train, cv=kf, scoring='f1_macro')

print(f'ExtraTrees score: {et_score}')

print(f'\nPrecision: {et_precision}')
print(f'Recall: {et_recall}')
print(f'F1-score: {et_f1}')

print("\nK-Fold mean:", et_scores.mean())
print("K-Fold std:", et_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# ExtraTrees score: 0.8492336041544518
#
# Precision: 0.8602280348759223
# Recall: 0.7148589900791439
# F1-score: 0.7808352611713137
#
# K-Fold mean: 0.8308124317248421
# K-Fold std: 0.002407835588843413
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.84      0.93      0.89     14907
#            1       0.86      0.71      0.78      8971
#
#     accuracy                           0.85     23878
#    macro avg       0.85      0.82      0.83     23878
# weighted avg       0.85      0.85      0.85     23878

# %%
# Boosting MODELS (6ta)
from sklearn.ensemble import (
    GradientBoostingClassifier,
    HistGradientBoostingClassifier,
    AdaBoostClassifier
)

from catboost import CatBoostClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

# %% [markdown]
# ## Gradient Boosting

# %%
gb = GradientBoostingClassifier(n_estimators=300, learning_rate=0.05, max_depth=3, random_state=42)
gb.fit(x_train, y_train)

importance = gb.feature_importances_
selected_features = x_train.columns[importance > np.mean(importance)]

gb.fit(x_train[selected_features], y_train)
y_pred = gb.predict(x_test[selected_features])

gb_score = accuracy_score(y_test, y_pred)

gb_precision = precision_score(y_test, y_pred)
gb_recall = recall_score(y_test, y_pred)
gb_f1 = f1_score(y_test, y_pred)

gb_scores = cross_val_score(gb, x_train[selected_features], y_train, cv=kf, scoring='f1_macro')

print(f'GradientBoosting score: {gb_score}')

print(f'\nPrecision: {gb_precision}')
print(f'Recall: {gb_recall}')
print(f'F1-score: {gb_f1}')

print("\nK-Fold mean:", gb_scores.mean())
print("K-Fold std:", gb_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GradientBoosting score: 0.8473071446519809
#
# Precision: 0.8341071652654034
# Recall: 0.7409430386801917
# F1-score: 0.7847697756788666
#
# K-Fold mean: 0.827853654722665
# K-Fold std: 0.0025927896340429833
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.91      0.88     14907
#            1       0.83      0.74      0.78      8971
#
#     accuracy                           0.85     23878
#    macro avg       0.84      0.83      0.83     23878
# weighted avg       0.85      0.85      0.85     23878

# %% [markdown]
# ## Hist Gradient Boosting

# %%
hgb = HistGradientBoostingClassifier(max_iter=300, learning_rate=0.05, max_depth=7, random_state=42)

hgb.fit(x_train, y_train)
y_pred = hgb.predict(x_test)

hgb_score = accuracy_score(y_test, y_pred)

hgb_precision = precision_score(y_test, y_pred)
hgb_recall = recall_score(y_test, y_pred)
hgb_f1 = f1_score(y_test, y_pred)

hgb_scores = cross_val_score(hgb, x_train, y_train, cv=kf, scoring='f1_macro')

print(f'HistGradientBoosting score: {hgb_score}')

print(f'\nPrecision: {hgb_precision}')
print(f'Recall: {hgb_recall}')
print(f'F1-score: {hgb_f1}')

print("\nK-Fold mean:", hgb_scores.mean())
print("K-Fold std:", hgb_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# HistGradientBoosting score: 0.8755339643186196
#
# Precision: 0.8629159104658197
# Recall: 0.7950061308661241
# F1-score: 0.8275702019029937
#
# K-Fold mean: 0.8573226123804484
# K-Fold std: 0.00225542328399786
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.92      0.90     14907
#            1       0.86      0.80      0.83      8971
#
#     accuracy                           0.88     23878
#    macro avg       0.87      0.86      0.87     23878
# weighted avg       0.87      0.88      0.87     23878

# %% [markdown]
# # XGBoost

# %%
xgb = XGBClassifier(
    n_estimators=500,
    max_depth=6,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42
)
xgb.fit(x_train, y_train)

importance = xgb.feature_importances_
selected_features = x_train.columns[importance > np.mean(importance)]

xgb.fit(x_train[selected_features], y_train)
y_pred = xgb.predict(x_test[selected_features])

xgb_score = accuracy_score(y_test, y_pred)

xgb_precision = precision_score(y_test, y_pred)
xgb_recall = recall_score(y_test, y_pred)
xgb_f1 = f1_score(y_test, y_pred)

xgb_scores = cross_val_score(xgb, x_train[selected_features], y_train, cv=kf, scoring='f1_macro')

print(f'XGBoost score: {xgb_score}')

print(f'\nPrecision: {xgb_precision}')
print(f'Recall: {xgb_recall}')
print(f'F1-score: {xgb_f1}')

print("\nK-Fold mean:", xgb_scores.mean())
print("K-Fold std:", xgb_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# XGBoost score: 0.8092805092553815
#
# Precision: 0.762448009506833
# Recall: 0.7151934009586445
# F1-score: 0.7380651098585068
#
# K-Fold mean: 0.7889425196873953
# K-Fold std: 0.0016898497064726757
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.87      0.85     14907
#            1       0.76      0.72      0.74      8971
#
#     accuracy                           0.81     23878
#    macro avg       0.80      0.79      0.79     23878
# weighted avg       0.81      0.81      0.81     23878

# %% [markdown]
# ## AdaBoost

# %%
ab = AdaBoostClassifier(n_estimators=300, learning_rate=0.05, random_state=42)
ab.fit(x_train, y_train)

importance = ab.feature_importances_
selected_features = x_train.columns[importance > np.mean(importance)]

ab.fit(x_train[selected_features], y_train)
y_pred = ab.predict(x_test[selected_features])

ab_score = accuracy_score(y_test, y_pred)

ab_precision = precision_score(y_test, y_pred)
ab_recall = recall_score(y_test, y_pred)
ab_f1 = f1_score(y_test, y_pred)

ab_scores = cross_val_score(ab, x_train[selected_features], y_train, cv=kf, scoring='f1_macro')

print(f'AdaBoost score: {ab_score}')

print(f'\nPrecision: {ab_precision}')
print(f'Recall: {ab_recall}')
print(f'F1-score: {ab_f1}')

print("\nK-Fold mean:", ab_scores.mean())
print("K-Fold std:", ab_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# AdaBoost score: 0.7483876371555407
#
# Precision: 0.98749588680487
# Recall: 0.33452234979378
# F1-score: 0.49975020815986676
#
# K-Fold mean: 0.6698549538364471
# K-Fold std: 0.01295692921489107
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.71      1.00      0.83     14907
#            1       0.99      0.33      0.50      8971
#
#     accuracy                           0.75     23878
#    macro avg       0.85      0.67      0.67     23878
# weighted avg       0.82      0.75      0.71     23878

# %% [markdown]
# ## LightGBM

# %%
lgbm = LGBMClassifier(n_estimators=500, learning_rate=0.05, num_leaves=31, subsample=0.8, colsample_bytree=0.8, random_state=42)
lgbm.fit(x_train, y_train)

importance = lgbm.feature_importances_
selected_features = x_train.columns[importance > np.mean(importance)]

lgbm.fit(x_train[selected_features], y_train)
y_pred = lgbm.predict(x_test[selected_features])

lgbm_score = accuracy_score(y_test, y_pred)

lgbm_precision = precision_score(y_test, y_pred)
lgbm_recall = recall_score(y_test, y_pred)
lgbm_f1 = f1_score(y_test, y_pred)

lgbm_scores = cross_val_score(lgbm, x_train[selected_features], y_train, cv=kf, scoring='f1_macro')

print(f'\nLightGBM score: {lgbm_score}')

print(f'\nPrecision: {lgbm_precision}')
print(f'Recall: {lgbm_recall}')
print(f'F1-score: {lgbm_f1}')

print("\nK-Fold mean:", lgbm_scores.mean())
print("K-Fold std:", lgbm_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# [LightGBM] [Info] Number of positive: 35253, number of negative: 60259
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004754 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2145
# [LightGBM] [Info] Number of data points in the train set: 95512, number of used features: 49
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.369095 -> initscore=-0.536101
# [LightGBM] [Info] Start training from score -0.536101
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Number of positive: 35253, number of negative: 60259
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002116 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1848
# [LightGBM] [Info] Number of data points in the train set: 95512, number of used features: 17
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.369095 -> initscore=-0.536101
# [LightGBM] [Info] Start training from score -0.536101
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Number of positive: 23553, number of negative: 40121
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001726 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1830
# [LightGBM] [Info] Number of data points in the train set: 63674, number of used features: 17
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.369900 -> initscore=-0.532647
# [LightGBM] [Info] Start training from score -0.532647
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Number of positive: 23477, number of negative: 40198
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001278 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1828
# [LightGBM] [Info] Number of data points in the train set: 63675, number of used features: 17
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.368700 -> initscore=-0.537796
# [LightGBM] [Info] Start training from score -0.537796
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Number of positive: 23476, number of negative: 40199
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001414 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1831
# [LightGBM] [Info] Number of data points in the train set: 63675, number of used features: 17
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.368685 -> initscore=-0.537863
# [LightGBM] [Info] Start training from score -0.537863
#
# LightGBM score: 0.8619649886925204
#
# Precision: 0.8521782301104629
# Recall: 0.7653550328837365
# F1-score: 0.8064364575992483
#
# K-Fold mean: 0.8402740348914691
# K-Fold std: 0.0033046357945277446
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.92      0.89     14907
#            1       0.85      0.77      0.81      8971
#
#     accuracy                           0.86     23878
#    macro avg       0.86      0.84      0.85     23878
# weighted avg       0.86      0.86      0.86     23878

# %% [markdown]
# ## CatBoost

# %%
cat = CatBoostClassifier(iterations=500, depth=8,learning_rate=0.05, random_state=42)
cat.fit(x_train, y_train)

importance = cat.feature_importances_
selected_features = x_train.columns[importance > np.mean(importance)]

cat.fit(x_train[selected_features], y_train)
y_pred = cat.predict(x_test[selected_features])

cat_score = accuracy_score(y_test, y_pred)

cat_precision = precision_score(y_test, y_pred)
cat_recall = recall_score(y_test, y_pred)
cat_f1 = f1_score(y_test, y_pred)

cat_scores = cross_val_score(cat, x_train[selected_features], y_train, cv=kf, scoring='f1_macro')

print(f'CatBoost score: {cat_score}')

print(f'\nPrecision: {cat_precision}')
print(f'Recall: {cat_recall}')
print(f'F1-score: {cat_f1}')

print("\nK-Fold mean:", cat_scores.mean())
print("K-Fold std:", cat_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# 0:	learn: 0.6420115	total: 157ms	remaining: 1m 18s
# 1:	learn: 0.5947196	total: 168ms	remaining: 41.8s
# 2:	learn: 0.5581536	total: 178ms	remaining: 29.4s
# 3:	learn: 0.5303284	total: 188ms	remaining: 23.3s
# 4:	learn: 0.5064711	total: 198ms	remaining: 19.6s
# 5:	learn: 0.4877656	total: 208ms	remaining: 17.1s
# 6:	learn: 0.4709348	total: 219ms	remaining: 15.4s
# 7:	learn: 0.4570079	total: 230ms	remaining: 14.1s
# 8:	learn: 0.4453800	total: 240ms	remaining: 13.1s
# 9:	learn: 0.4348332	total: 250ms	remaining: 12.3s
# 10:	learn: 0.4258842	total: 260ms	remaining: 11.6s
# 11:	learn: 0.4176835	total: 270ms	remaining: 11s
# 12:	learn: 0.4114668	total: 282ms	remaining: 10.6s
# 13:	learn: 0.4054910	total: 293ms	remaining: 10.2s
# 14:	learn: 0.3977870	total: 304ms	remaining: 9.82s
# 15:	learn: 0.3929081	total: 314ms	remaining: 9.5s
# 16:	learn: 0.3885163	total: 324ms	remaining: 9.22s
# 17:	learn: 0.3840380	total: 334ms	remaining: 8.96s
# 18:	learn: 0.3815239	total: 345ms	remaining: 8.73s
# 19:	learn: 0.3764762	total: 355ms	remaining: 8.52s
# 20:	learn: 0.3724470	total: 366ms	remaining: 8.34s
# 21:	learn: 0.3691544	total: 377ms	remaining: 8.19s
# 22:	learn: 0.3662890	total: 388ms	remaining: 8.04s
# 23:	learn: 0.3631711	total: 398ms	remaining: 7.89s
# 24:	learn: 0.3614970	total: 408ms	remaining: 7.75s
# 25:	learn: 0.3583266	total: 419ms	remaining: 7.64s
# 26:	learn: 0.3556531	total: 429ms	remaining: 7.52s
# 27:	learn: 0.3537729	total: 438ms	remaining: 7.39s
# 28:	learn: 0.3518955	total: 449ms	remaining: 7.29s
# 29:	learn: 0.3503624	total: 459ms	remaining: 7.19s
# 30:	learn: 0.3489252	total: 469ms	remaining: 7.09s
# 31:	learn: 0.3472765	total: 479ms	remaining: 7s
# 32:	learn: 0.3458894	total: 489ms	remaining: 6.92s
# 33:	learn: 0.3441071	total: 499ms	remaining: 6.83s
# 34:	learn: 0.3428176	total: 508ms	remaining: 6.75s
# 35:	learn: 0.3415587	total: 518ms	remaining: 6.68s
# 36:	learn: 0.3406835	total: 528ms	remaining: 6.61s
# 37:	learn: 0.3391325	total: 538ms	remaining: 6.54s
# 38:	learn: 0.3380868	total: 548ms	remaining: 6.48s
# 39:	learn: 0.3373404	total: 558ms	remaining: 6.42s
# 40:	learn: 0.3361851	total: 568ms	remaining: 6.36s
# 41:	learn: 0.3348598	total: 577ms	remaining: 6.3s
# 42:	learn: 0.3343110	total: 587ms	remaining: 6.24s
# 43:	learn: 0.3335122	total: 598ms	remaining: 6.19s
# 44:	learn: 0.3328088	total: 608ms	remaining: 6.15s
# 45:	learn: 0.3322473	total: 618ms	remaining: 6.1s
# 46:	learn: 0.3307970	total: 628ms	remaining: 6.05s
# 47:	learn: 0.3295044	total: 638ms	remaining: 6s
# 48:	learn: 0.3282344	total: 649ms	remaining: 5.97s
# 49:	learn: 0.3271349	total: 659ms	remaining: 5.93s
# 50:	learn: 0.3264453	total: 670ms	remaining: 5.9s
# 51:	learn: 0.3256375	total: 681ms	remaining: 5.86s
# 52:	learn: 0.3252455	total: 693ms	remaining: 5.84s
# 53:	learn: 0.3242060	total: 705ms	remaining: 5.82s
# 54:	learn: 0.3236279	total: 717ms	remaining: 5.8s
# 55:	learn: 0.3229831	total: 729ms	remaining: 5.78s
# 56:	learn: 0.3225582	total: 741ms	remaining: 5.76s
# 57:	learn: 0.3221692	total: 753ms	remaining: 5.74s
# 58:	learn: 0.3218149	total: 765ms	remaining: 5.71s
# 59:	learn: 0.3212440	total: 777ms	remaining: 5.7s
# 60:	learn: 0.3208166	total: 788ms	remaining: 5.67s
# 61:	learn: 0.3202026	total: 800ms	remaining: 5.65s
# 62:	learn: 0.3196925	total: 809ms	remaining: 5.61s
# 63:	learn: 0.3192411	total: 819ms	remaining: 5.58s
# 64:	learn: 0.3189525	total: 828ms	remaining: 5.54s
# 65:	learn: 0.3183502	total: 838ms	remaining: 5.51s
# 66:	learn: 0.3173746	total: 849ms	remaining: 5.48s
# 67:	learn: 0.3171153	total: 858ms	remaining: 5.45s
# 68:	learn: 0.3166864	total: 869ms	remaining: 5.43s
# 69:	learn: 0.3157873	total: 881ms	remaining: 5.41s
# 70:	learn: 0.3153539	total: 893ms	remaining: 5.4s
# 71:	learn: 0.3150231	total: 904ms	remaining: 5.38s
# 72:	learn: 0.3143463	total: 915ms	remaining: 5.35s
# 73:	learn: 0.3139225	total: 926ms	remaining: 5.33s
# 74:	learn: 0.3135907	total: 936ms	remaining: 5.3s
# 75:	learn: 0.3130416	total: 945ms	remaining: 5.27s
# 76:	learn: 0.3127417	total: 955ms	remaining: 5.25s
# 77:	learn: 0.3123659	total: 965ms	remaining: 5.22s
# 78:	learn: 0.3120183	total: 974ms	remaining: 5.19s
# 79:	learn: 0.3116570	total: 985ms	remaining: 5.17s
# 80:	learn: 0.3113306	total: 995ms	remaining: 5.15s
# 81:	learn: 0.3110687	total: 1s	remaining: 5.13s
# 82:	learn: 0.3107745	total: 1.01s	remaining: 5.1s
# 83:	learn: 0.3104878	total: 1.02s	remaining: 5.08s
# 84:	learn: 0.3098917	total: 1.04s	remaining: 5.06s
# 85:	learn: 0.3092939	total: 1.05s	remaining: 5.04s
# 86:	learn: 0.3090578	total: 1.05s	remaining: 5.01s
# 87:	learn: 0.3084450	total: 1.06s	remaining: 4.99s
# 88:	learn: 0.3080951	total: 1.07s	remaining: 4.96s
# 89:	learn: 0.3073866	total: 1.08s	remaining: 4.95s
# 90:	learn: 0.3070151	total: 1.09s	remaining: 4.92s
# 91:	learn: 0.3068356	total: 1.1s	remaining: 4.9s
# 92:	learn: 0.3066104	total: 1.11s	remaining: 4.88s
# 93:	learn: 0.3062811	total: 1.13s	remaining: 4.86s
# 94:	learn: 0.3061215	total: 1.14s	remaining: 4.84s
# 95:	learn: 0.3060043	total: 1.15s	remaining: 4.82s
# 96:	learn: 0.3053985	total: 1.16s	remaining: 4.8s
# 97:	learn: 0.3052206	total: 1.17s	remaining: 4.78s
# 98:	learn: 0.3049783	total: 1.18s	remaining: 4.76s
# 99:	learn: 0.3046365	total: 1.19s	remaining: 4.75s
# 100:	learn: 0.3039873	total: 1.2s	remaining: 4.73s
# 101:	learn: 0.3037881	total: 1.21s	remaining: 4.71s
# 102:	learn: 0.3036496	total: 1.22s	remaining: 4.69s
# 103:	learn: 0.3033708	total: 1.23s	remaining: 4.67s
# 104:	learn: 0.3031807	total: 1.24s	remaining: 4.65s
# 105:	learn: 0.3028688	total: 1.25s	remaining: 4.63s
# 106:	learn: 0.3025616	total: 1.25s	remaining: 4.61s
# 107:	learn: 0.3023050	total: 1.27s	remaining: 4.59s
# 108:	learn: 0.3019910	total: 1.28s	remaining: 4.58s
# 109:	learn: 0.3018202	total: 1.29s	remaining: 4.56s
# 110:	learn: 0.3016034	total: 1.3s	remaining: 4.54s
# 111:	learn: 0.3014421	total: 1.31s	remaining: 4.52s
# 112:	learn: 0.3012772	total: 1.31s	remaining: 4.51s
# 113:	learn: 0.3007682	total: 1.32s	remaining: 4.49s
# 114:	learn: 0.3005553	total: 1.33s	remaining: 4.47s
# 115:	learn: 0.3003883	total: 1.35s	remaining: 4.46s
# 116:	learn: 0.3001167	total: 1.35s	remaining: 4.44s
# 117:	learn: 0.2999315	total: 1.36s	remaining: 4.42s
# 118:	learn: 0.2996585	total: 1.38s	remaining: 4.41s
# 119:	learn: 0.2994655	total: 1.39s	remaining: 4.39s
# 120:	learn: 0.2993632	total: 1.4s	remaining: 4.37s
# 121:	learn: 0.2991204	total: 1.41s	remaining: 4.36s
# 122:	learn: 0.2989216	total: 1.42s	remaining: 4.34s
# 123:	learn: 0.2985363	total: 1.43s	remaining: 4.33s
# 124:	learn: 0.2982795	total: 1.44s	remaining: 4.31s
# 125:	learn: 0.2980765	total: 1.45s	remaining: 4.29s
# 126:	learn: 0.2976429	total: 1.46s	remaining: 4.28s
# 127:	learn: 0.2974451	total: 1.47s	remaining: 4.26s
# 128:	learn: 0.2971744	total: 1.48s	remaining: 4.25s
# 129:	learn: 0.2969860	total: 1.49s	remaining: 4.23s
# 130:	learn: 0.2968494	total: 1.5s	remaining: 4.21s
# 131:	learn: 0.2966388	total: 1.5s	remaining: 4.2s
# 132:	learn: 0.2963556	total: 1.51s	remaining: 4.18s
# 133:	learn: 0.2961808	total: 1.52s	remaining: 4.17s
# 134:	learn: 0.2959890	total: 1.53s	remaining: 4.15s
# 135:	learn: 0.2959375	total: 1.54s	remaining: 4.13s
# 136:	learn: 0.2956840	total: 1.55s	remaining: 4.12s
# 137:	learn: 0.2956146	total: 1.56s	remaining: 4.1s
# 138:	learn: 0.2953712	total: 1.57s	remaining: 4.08s
# 139:	learn: 0.2949915	total: 1.58s	remaining: 4.07s
# 140:	learn: 0.2948202	total: 1.59s	remaining: 4.05s
# 141:	learn: 0.2947222	total: 1.6s	remaining: 4.04s
# 142:	learn: 0.2945103	total: 1.61s	remaining: 4.02s
# 143:	learn: 0.2940899	total: 1.62s	remaining: 4.01s
# 144:	learn: 0.2940240	total: 1.63s	remaining: 4s
# 145:	learn: 0.2939281	total: 1.64s	remaining: 3.98s
# 146:	learn: 0.2937279	total: 1.65s	remaining: 3.97s
# 147:	learn: 0.2936412	total: 1.66s	remaining: 3.95s
# 148:	learn: 0.2934514	total: 1.67s	remaining: 3.94s
# 149:	learn: 0.2932966	total: 1.68s	remaining: 3.92s
# 150:	learn: 0.2931811	total: 1.69s	remaining: 3.91s
# 151:	learn: 0.2929119	total: 1.7s	remaining: 3.9s
# 152:	learn: 0.2927867	total: 1.71s	remaining: 3.88s
# 153:	learn: 0.2925614	total: 1.72s	remaining: 3.87s
# 154:	learn: 0.2923945	total: 1.73s	remaining: 3.85s
# 155:	learn: 0.2922162	total: 1.74s	remaining: 3.84s
# 156:	learn: 0.2921493	total: 1.75s	remaining: 3.82s
# 157:	learn: 0.2919189	total: 1.76s	remaining: 3.81s
# 158:	learn: 0.2917690	total: 1.77s	remaining: 3.8s
# 159:	learn: 0.2916065	total: 1.78s	remaining: 3.78s
# 160:	learn: 0.2915274	total: 1.79s	remaining: 3.77s
# 161:	learn: 0.2914053	total: 1.8s	remaining: 3.75s
# 162:	learn: 0.2910006	total: 1.81s	remaining: 3.74s
# 163:	learn: 0.2907684	total: 1.82s	remaining: 3.73s
# 164:	learn: 0.2907506	total: 1.83s	remaining: 3.71s
# 165:	learn: 0.2904313	total: 1.84s	remaining: 3.7s
# 166:	learn: 0.2902710	total: 1.85s	remaining: 3.69s
# 167:	learn: 0.2901029	total: 1.86s	remaining: 3.67s
# 168:	learn: 0.2900047	total: 1.87s	remaining: 3.66s
# 169:	learn: 0.2898057	total: 1.88s	remaining: 3.65s
# 170:	learn: 0.2896791	total: 1.89s	remaining: 3.63s
# 171:	learn: 0.2894442	total: 1.9s	remaining: 3.62s
# 172:	learn: 0.2892855	total: 1.91s	remaining: 3.6s
# 173:	learn: 0.2891070	total: 1.92s	remaining: 3.59s
# 174:	learn: 0.2890099	total: 1.93s	remaining: 3.58s
# 175:	learn: 0.2886872	total: 1.94s	remaining: 3.57s
# 176:	learn: 0.2885433	total: 1.95s	remaining: 3.56s
# 177:	learn: 0.2884461	total: 1.96s	remaining: 3.54s
# 178:	learn: 0.2882014	total: 1.97s	remaining: 3.53s
# 179:	learn: 0.2879823	total: 1.98s	remaining: 3.52s
# 180:	learn: 0.2878477	total: 1.99s	remaining: 3.5s
# 181:	learn: 0.2877376	total: 2s	remaining: 3.49s
# 182:	learn: 0.2876544	total: 2.01s	remaining: 3.48s
# 183:	learn: 0.2875675	total: 2.02s	remaining: 3.46s
# 184:	learn: 0.2873534	total: 2.03s	remaining: 3.45s
# 185:	learn: 0.2872867	total: 2.04s	remaining: 3.44s
# 186:	learn: 0.2871444	total: 2.05s	remaining: 3.43s
# 187:	learn: 0.2870504	total: 2.06s	remaining: 3.42s
# 188:	learn: 0.2866473	total: 2.07s	remaining: 3.4s
# 189:	learn: 0.2864084	total: 2.08s	remaining: 3.39s
# 190:	learn: 0.2862901	total: 2.09s	remaining: 3.38s
# 191:	learn: 0.2860582	total: 2.1s	remaining: 3.37s
# 192:	learn: 0.2859582	total: 2.11s	remaining: 3.35s
# 193:	learn: 0.2857934	total: 2.12s	remaining: 3.34s
# 194:	learn: 0.2856940	total: 2.13s	remaining: 3.33s
# 195:	learn: 0.2855706	total: 2.14s	remaining: 3.31s
# 196:	learn: 0.2854575	total: 2.15s	remaining: 3.3s
# 197:	learn: 0.2853104	total: 2.16s	remaining: 3.29s
# 198:	learn: 0.2851806	total: 2.17s	remaining: 3.27s
# 199:	learn: 0.2850760	total: 2.17s	remaining: 3.26s
# 200:	learn: 0.2849381	total: 2.19s	remaining: 3.25s
# 201:	learn: 0.2847206	total: 2.19s	remaining: 3.24s
# 202:	learn: 0.2845489	total: 2.21s	remaining: 3.23s
# 203:	learn: 0.2844519	total: 2.21s	remaining: 3.21s
# 204:	learn: 0.2843069	total: 2.23s	remaining: 3.2s
# 205:	learn: 0.2842020	total: 2.23s	remaining: 3.19s
# 206:	learn: 0.2840465	total: 2.25s	remaining: 3.18s
# 207:	learn: 0.2837531	total: 2.25s	remaining: 3.17s
# 208:	learn: 0.2836633	total: 2.27s	remaining: 3.15s
# 209:	learn: 0.2835520	total: 2.27s	remaining: 3.14s
# 210:	learn: 0.2833524	total: 2.28s	remaining: 3.13s
# 211:	learn: 0.2832280	total: 2.29s	remaining: 3.12s
# 212:	learn: 0.2831445	total: 2.3s	remaining: 3.1s
# 213:	learn: 0.2830150	total: 2.31s	remaining: 3.09s
# 214:	learn: 0.2828567	total: 2.33s	remaining: 3.08s
# 215:	learn: 0.2827485	total: 2.33s	remaining: 3.07s
# 216:	learn: 0.2825642	total: 2.35s	remaining: 3.06s
# 217:	learn: 0.2823376	total: 2.35s	remaining: 3.05s
# 218:	learn: 0.2821895	total: 2.37s	remaining: 3.03s
# 219:	learn: 0.2821296	total: 2.37s	remaining: 3.02s
# 220:	learn: 0.2820537	total: 2.38s	remaining: 3.01s
# 221:	learn: 0.2819737	total: 2.39s	remaining: 3s
# 222:	learn: 0.2818749	total: 2.4s	remaining: 2.98s
# 223:	learn: 0.2817476	total: 2.41s	remaining: 2.97s
# 224:	learn: 0.2816708	total: 2.42s	remaining: 2.96s
# 225:	learn: 0.2815181	total: 2.43s	remaining: 2.95s
# 226:	learn: 0.2814220	total: 2.44s	remaining: 2.94s
# 227:	learn: 0.2813194	total: 2.45s	remaining: 2.93s
# 228:	learn: 0.2809905	total: 2.46s	remaining: 2.92s
# 229:	learn: 0.2808660	total: 2.47s	remaining: 2.9s
# 230:	learn: 0.2805588	total: 2.48s	remaining: 2.89s
# 231:	learn: 0.2803881	total: 2.49s	remaining: 2.88s
# 232:	learn: 0.2803008	total: 2.5s	remaining: 2.87s
# 233:	learn: 0.2801585	total: 2.51s	remaining: 2.85s
# 234:	learn: 0.2800772	total: 2.52s	remaining: 2.84s
# 235:	learn: 0.2798887	total: 2.53s	remaining: 2.83s
# 236:	learn: 0.2797682	total: 2.54s	remaining: 2.82s
# 237:	learn: 0.2796866	total: 2.55s	remaining: 2.81s
# 238:	learn: 0.2796194	total: 2.56s	remaining: 2.79s
# 239:	learn: 0.2795158	total: 2.57s	remaining: 2.78s
# 240:	learn: 0.2794055	total: 2.58s	remaining: 2.77s
# 241:	learn: 0.2791708	total: 2.59s	remaining: 2.76s
# 242:	learn: 0.2790586	total: 2.6s	remaining: 2.75s
# 243:	learn: 0.2789068	total: 2.61s	remaining: 2.74s
# 244:	learn: 0.2788299	total: 2.62s	remaining: 2.73s
# 245:	learn: 0.2787196	total: 2.63s	remaining: 2.71s
# 246:	learn: 0.2786310	total: 2.64s	remaining: 2.7s
# 247:	learn: 0.2783381	total: 2.65s	remaining: 2.69s
# 248:	learn: 0.2782330	total: 2.66s	remaining: 2.68s
# 249:	learn: 0.2781584	total: 2.67s	remaining: 2.67s
# 250:	learn: 0.2779799	total: 2.68s	remaining: 2.66s
# 251:	learn: 0.2778182	total: 2.69s	remaining: 2.65s
# 252:	learn: 0.2777582	total: 2.7s	remaining: 2.63s
# 253:	learn: 0.2776764	total: 2.71s	remaining: 2.62s
# 254:	learn: 0.2775952	total: 2.72s	remaining: 2.61s
# 255:	learn: 0.2774376	total: 2.73s	remaining: 2.6s
# 256:	learn: 0.2772656	total: 2.74s	remaining: 2.59s
# 257:	learn: 0.2770749	total: 2.75s	remaining: 2.58s
# 258:	learn: 0.2769471	total: 2.76s	remaining: 2.56s
# 259:	learn: 0.2768634	total: 2.77s	remaining: 2.55s
# 260:	learn: 0.2767541	total: 2.78s	remaining: 2.54s
# 261:	learn: 0.2765996	total: 2.79s	remaining: 2.53s
# 262:	learn: 0.2764478	total: 2.8s	remaining: 2.52s
# 263:	learn: 0.2763576	total: 2.81s	remaining: 2.51s
# 264:	learn: 0.2762430	total: 2.82s	remaining: 2.5s
# 265:	learn: 0.2761548	total: 2.83s	remaining: 2.49s
# 266:	learn: 0.2760440	total: 2.84s	remaining: 2.48s
# 267:	learn: 0.2758080	total: 2.85s	remaining: 2.46s
# 268:	learn: 0.2756413	total: 2.86s	remaining: 2.45s
# 269:	learn: 0.2755746	total: 2.87s	remaining: 2.44s
# 270:	learn: 0.2753864	total: 2.88s	remaining: 2.43s
# 271:	learn: 0.2752346	total: 2.89s	remaining: 2.42s
# 272:	learn: 0.2751449	total: 2.9s	remaining: 2.41s
# 273:	learn: 0.2750404	total: 2.91s	remaining: 2.4s
# 274:	learn: 0.2748964	total: 2.92s	remaining: 2.38s
# 275:	learn: 0.2747683	total: 2.92s	remaining: 2.37s
# 276:	learn: 0.2746405	total: 2.94s	remaining: 2.36s
# 277:	learn: 0.2745146	total: 2.94s	remaining: 2.35s
# 278:	learn: 0.2743928	total: 2.95s	remaining: 2.34s
# 279:	learn: 0.2742521	total: 2.96s	remaining: 2.33s
# 280:	learn: 0.2741044	total: 2.98s	remaining: 2.32s
# 281:	learn: 0.2739713	total: 2.98s	remaining: 2.31s
# 282:	learn: 0.2738469	total: 3s	remaining: 2.3s
# 283:	learn: 0.2737619	total: 3.01s	remaining: 2.29s
# 284:	learn: 0.2736190	total: 3.02s	remaining: 2.28s
# 285:	learn: 0.2735750	total: 3.03s	remaining: 2.26s
# 286:	learn: 0.2734724	total: 3.04s	remaining: 2.25s
# 287:	learn: 0.2733651	total: 3.04s	remaining: 2.24s
# 288:	learn: 0.2732435	total: 3.06s	remaining: 2.23s
# 289:	learn: 0.2731467	total: 3.06s	remaining: 2.22s
# 290:	learn: 0.2730768	total: 3.08s	remaining: 2.21s
# 291:	learn: 0.2729741	total: 3.08s	remaining: 2.2s
# 292:	learn: 0.2728688	total: 3.1s	remaining: 2.19s
# 293:	learn: 0.2727984	total: 3.1s	remaining: 2.17s
# 294:	learn: 0.2727009	total: 3.12s	remaining: 2.16s
# 295:	learn: 0.2726396	total: 3.12s	remaining: 2.15s
# 296:	learn: 0.2723923	total: 3.13s	remaining: 2.14s
# 297:	learn: 0.2723365	total: 3.14s	remaining: 2.13s
# 298:	learn: 0.2721805	total: 3.15s	remaining: 2.12s
# 299:	learn: 0.2720357	total: 3.16s	remaining: 2.11s
# 300:	learn: 0.2718494	total: 3.17s	remaining: 2.1s
# 301:	learn: 0.2717935	total: 3.18s	remaining: 2.09s
# 302:	learn: 0.2717245	total: 3.19s	remaining: 2.08s
# 303:	learn: 0.2716158	total: 3.2s	remaining: 2.06s
# 304:	learn: 0.2714727	total: 3.21s	remaining: 2.05s
# 305:	learn: 0.2713644	total: 3.22s	remaining: 2.04s
# 306:	learn: 0.2712841	total: 3.23s	remaining: 2.03s
# 307:	learn: 0.2711673	total: 3.24s	remaining: 2.02s
# 308:	learn: 0.2710766	total: 3.25s	remaining: 2.01s
# 309:	learn: 0.2709333	total: 3.26s	remaining: 2s
# 310:	learn: 0.2708303	total: 3.27s	remaining: 1.99s
# 311:	learn: 0.2707128	total: 3.28s	remaining: 1.98s
# 312:	learn: 0.2706183	total: 3.29s	remaining: 1.97s
# 313:	learn: 0.2705110	total: 3.3s	remaining: 1.96s
# 314:	learn: 0.2703718	total: 3.31s	remaining: 1.94s
# 315:	learn: 0.2701810	total: 3.32s	remaining: 1.93s
# 316:	learn: 0.2700642	total: 3.33s	remaining: 1.92s
# 317:	learn: 0.2699897	total: 3.34s	remaining: 1.91s
# 318:	learn: 0.2698824	total: 3.35s	remaining: 1.9s
# 319:	learn: 0.2697459	total: 3.36s	remaining: 1.89s
# 320:	learn: 0.2696420	total: 3.37s	remaining: 1.88s
# 321:	learn: 0.2695371	total: 3.38s	remaining: 1.87s
# 322:	learn: 0.2694197	total: 3.39s	remaining: 1.86s
# 323:	learn: 0.2691806	total: 3.4s	remaining: 1.85s
# 324:	learn: 0.2690864	total: 3.41s	remaining: 1.84s
# 325:	learn: 0.2690354	total: 3.42s	remaining: 1.83s
# 326:	learn: 0.2688936	total: 3.43s	remaining: 1.81s
# 327:	learn: 0.2687677	total: 3.44s	remaining: 1.8s
# 328:	learn: 0.2686728	total: 3.45s	remaining: 1.79s
# 329:	learn: 0.2685858	total: 3.46s	remaining: 1.78s
# 330:	learn: 0.2684042	total: 3.47s	remaining: 1.77s
# 331:	learn: 0.2683576	total: 3.48s	remaining: 1.76s
# 332:	learn: 0.2682608	total: 3.49s	remaining: 1.75s
# 333:	learn: 0.2681458	total: 3.5s	remaining: 1.74s
# 334:	learn: 0.2680070	total: 3.51s	remaining: 1.73s
# 335:	learn: 0.2679351	total: 3.52s	remaining: 1.72s
# 336:	learn: 0.2678116	total: 3.53s	remaining: 1.71s
# 337:	learn: 0.2677135	total: 3.54s	remaining: 1.7s
# 338:	learn: 0.2675995	total: 3.55s	remaining: 1.69s
# 339:	learn: 0.2675435	total: 3.56s	remaining: 1.68s
# 340:	learn: 0.2674763	total: 3.57s	remaining: 1.66s
# 341:	learn: 0.2673690	total: 3.58s	remaining: 1.65s
# 342:	learn: 0.2673072	total: 3.59s	remaining: 1.64s
# 343:	learn: 0.2671871	total: 3.6s	remaining: 1.63s
# 344:	learn: 0.2671273	total: 3.61s	remaining: 1.62s
# 345:	learn: 0.2670249	total: 3.62s	remaining: 1.61s
# 346:	learn: 0.2668664	total: 3.63s	remaining: 1.6s
# 347:	learn: 0.2667632	total: 3.64s	remaining: 1.59s
# 348:	learn: 0.2666301	total: 3.65s	remaining: 1.58s
# 349:	learn: 0.2665593	total: 3.66s	remaining: 1.57s
# 350:	learn: 0.2664377	total: 3.67s	remaining: 1.56s
# 351:	learn: 0.2663994	total: 3.68s	remaining: 1.55s
# 352:	learn: 0.2662844	total: 3.69s	remaining: 1.53s
# 353:	learn: 0.2661898	total: 3.7s	remaining: 1.52s
# 354:	learn: 0.2660253	total: 3.71s	remaining: 1.51s
# 355:	learn: 0.2659076	total: 3.72s	remaining: 1.5s
# 356:	learn: 0.2658200	total: 3.73s	remaining: 1.49s
# 357:	learn: 0.2657419	total: 3.74s	remaining: 1.48s
# 358:	learn: 0.2656544	total: 3.75s	remaining: 1.47s
# 359:	learn: 0.2655349	total: 3.76s	remaining: 1.46s
# 360:	learn: 0.2654296	total: 3.77s	remaining: 1.45s
# 361:	learn: 0.2653358	total: 3.79s	remaining: 1.44s
# 362:	learn: 0.2652536	total: 3.8s	remaining: 1.43s
# 363:	learn: 0.2651459	total: 3.81s	remaining: 1.42s
# 364:	learn: 0.2650751	total: 3.82s	remaining: 1.41s
# 365:	learn: 0.2649497	total: 3.83s	remaining: 1.4s
# 366:	learn: 0.2648713	total: 3.84s	remaining: 1.39s
# 367:	learn: 0.2647695	total: 3.85s	remaining: 1.38s
# 368:	learn: 0.2646040	total: 3.87s	remaining: 1.37s
# 369:	learn: 0.2644424	total: 3.88s	remaining: 1.36s
# 370:	learn: 0.2643668	total: 3.89s	remaining: 1.35s
# 371:	learn: 0.2642793	total: 3.9s	remaining: 1.34s
# 372:	learn: 0.2641946	total: 3.91s	remaining: 1.33s
# 373:	learn: 0.2641129	total: 3.92s	remaining: 1.32s
# 374:	learn: 0.2640133	total: 3.93s	remaining: 1.31s
# 375:	learn: 0.2639335	total: 3.94s	remaining: 1.3s
# 376:	learn: 0.2638416	total: 3.95s	remaining: 1.29s
# 377:	learn: 0.2637537	total: 3.96s	remaining: 1.28s
# 378:	learn: 0.2636470	total: 3.97s	remaining: 1.27s
# 379:	learn: 0.2635724	total: 3.98s	remaining: 1.26s
# 380:	learn: 0.2635043	total: 3.99s	remaining: 1.25s
# 381:	learn: 0.2634378	total: 4.01s	remaining: 1.24s
# 382:	learn: 0.2633358	total: 4.02s	remaining: 1.23s
# 383:	learn: 0.2632828	total: 4.03s	remaining: 1.22s
# 384:	learn: 0.2631621	total: 4.04s	remaining: 1.21s
# 385:	learn: 0.2630809	total: 4.05s	remaining: 1.2s
# 386:	learn: 0.2629489	total: 4.07s	remaining: 1.19s
# 387:	learn: 0.2628473	total: 4.08s	remaining: 1.18s
# 388:	learn: 0.2627588	total: 4.09s	remaining: 1.17s
# 389:	learn: 0.2626496	total: 4.1s	remaining: 1.16s
# 390:	learn: 0.2625816	total: 4.11s	remaining: 1.15s
# 391:	learn: 0.2625006	total: 4.12s	remaining: 1.14s
# 392:	learn: 0.2624012	total: 4.13s	remaining: 1.13s
# 393:	learn: 0.2621143	total: 4.15s	remaining: 1.11s
# 394:	learn: 0.2620030	total: 4.16s	remaining: 1.1s
# 395:	learn: 0.2617862	total: 4.17s	remaining: 1.09s
# 396:	learn: 0.2616878	total: 4.18s	remaining: 1.08s
# 397:	learn: 0.2616075	total: 4.19s	remaining: 1.07s
# 398:	learn: 0.2615366	total: 4.2s	remaining: 1.06s
# 399:	learn: 0.2613593	total: 4.21s	remaining: 1.05s
# 400:	learn: 0.2612754	total: 4.22s	remaining: 1.04s
# 401:	learn: 0.2611903	total: 4.24s	remaining: 1.03s
# 402:	learn: 0.2611609	total: 4.25s	remaining: 1.02s
# 403:	learn: 0.2610989	total: 4.26s	remaining: 1.01s
# 404:	learn: 0.2610083	total: 4.27s	remaining: 1s
# 405:	learn: 0.2609379	total: 4.28s	remaining: 992ms
# 406:	learn: 0.2608550	total: 4.29s	remaining: 981ms
# 407:	learn: 0.2607658	total: 4.31s	remaining: 971ms
# 408:	learn: 0.2606861	total: 4.32s	remaining: 961ms
# 409:	learn: 0.2605958	total: 4.33s	remaining: 950ms
# 410:	learn: 0.2604440	total: 4.34s	remaining: 940ms
# 411:	learn: 0.2603441	total: 4.35s	remaining: 929ms
# 412:	learn: 0.2602306	total: 4.36s	remaining: 919ms
# 413:	learn: 0.2601214	total: 4.37s	remaining: 909ms
# 414:	learn: 0.2600311	total: 4.38s	remaining: 898ms
# 415:	learn: 0.2599369	total: 4.4s	remaining: 888ms
# 416:	learn: 0.2598361	total: 4.41s	remaining: 877ms
# 417:	learn: 0.2597179	total: 4.42s	remaining: 867ms
# 418:	learn: 0.2596501	total: 4.43s	remaining: 857ms
# 419:	learn: 0.2595895	total: 4.44s	remaining: 847ms
# 420:	learn: 0.2595336	total: 4.46s	remaining: 836ms
# 421:	learn: 0.2594556	total: 4.47s	remaining: 826ms
# 422:	learn: 0.2593566	total: 4.48s	remaining: 815ms
# 423:	learn: 0.2592914	total: 4.49s	remaining: 805ms
# 424:	learn: 0.2592183	total: 4.5s	remaining: 795ms
# 425:	learn: 0.2591064	total: 4.51s	remaining: 784ms
# 426:	learn: 0.2589721	total: 4.53s	remaining: 774ms
# 427:	learn: 0.2588860	total: 4.54s	remaining: 764ms
# 428:	learn: 0.2587754	total: 4.55s	remaining: 753ms
# 429:	learn: 0.2586675	total: 4.56s	remaining: 743ms
# 430:	learn: 0.2585332	total: 4.57s	remaining: 732ms
# 431:	learn: 0.2584404	total: 4.58s	remaining: 722ms
# 432:	learn: 0.2583480	total: 4.6s	remaining: 711ms
# 433:	learn: 0.2582548	total: 4.61s	remaining: 701ms
# 434:	learn: 0.2581921	total: 4.62s	remaining: 690ms
# 435:	learn: 0.2580853	total: 4.63s	remaining: 680ms
# 436:	learn: 0.2579963	total: 4.64s	remaining: 670ms
# 437:	learn: 0.2578744	total: 4.66s	remaining: 659ms
# 438:	learn: 0.2577969	total: 4.67s	remaining: 649ms
# 439:	learn: 0.2577611	total: 4.68s	remaining: 638ms
# 440:	learn: 0.2576878	total: 4.69s	remaining: 628ms
# 441:	learn: 0.2576115	total: 4.7s	remaining: 617ms
# 442:	learn: 0.2575232	total: 4.71s	remaining: 607ms
# 443:	learn: 0.2573553	total: 4.73s	remaining: 596ms
# 444:	learn: 0.2572624	total: 4.74s	remaining: 586ms
# 445:	learn: 0.2571875	total: 4.75s	remaining: 575ms
# 446:	learn: 0.2571187	total: 4.76s	remaining: 565ms
# 447:	learn: 0.2570522	total: 4.77s	remaining: 554ms
# 448:	learn: 0.2569465	total: 4.79s	remaining: 544ms
# 449:	learn: 0.2568594	total: 4.8s	remaining: 533ms
# 450:	learn: 0.2568016	total: 4.81s	remaining: 523ms
# 451:	learn: 0.2567324	total: 4.82s	remaining: 512ms
# 452:	learn: 0.2565930	total: 4.83s	remaining: 502ms
# 453:	learn: 0.2564767	total: 4.85s	remaining: 491ms
# 454:	learn: 0.2564120	total: 4.86s	remaining: 480ms
# 455:	learn: 0.2563280	total: 4.87s	remaining: 470ms
# 456:	learn: 0.2562547	total: 4.88s	remaining: 459ms
# 457:	learn: 0.2561689	total: 4.89s	remaining: 449ms
# 458:	learn: 0.2560743	total: 4.9s	remaining: 438ms
# 459:	learn: 0.2559661	total: 4.92s	remaining: 428ms
# 460:	learn: 0.2558667	total: 4.93s	remaining: 417ms
# 461:	learn: 0.2557756	total: 4.94s	remaining: 406ms
# 462:	learn: 0.2557131	total: 4.95s	remaining: 396ms
# 463:	learn: 0.2556489	total: 4.96s	remaining: 385ms
# 464:	learn: 0.2555463	total: 4.97s	remaining: 374ms
# 465:	learn: 0.2553960	total: 4.99s	remaining: 364ms
# 466:	learn: 0.2552594	total: 5s	remaining: 353ms
# 467:	learn: 0.2551575	total: 5.01s	remaining: 343ms
# 468:	learn: 0.2550712	total: 5.02s	remaining: 332ms
# 469:	learn: 0.2549553	total: 5.04s	remaining: 321ms
# 470:	learn: 0.2548878	total: 5.05s	remaining: 311ms
# 471:	learn: 0.2548128	total: 5.06s	remaining: 300ms
# 472:	learn: 0.2546669	total: 5.07s	remaining: 289ms
# 473:	learn: 0.2545539	total: 5.08s	remaining: 279ms
# 474:	learn: 0.2544632	total: 5.09s	remaining: 268ms
# 475:	learn: 0.2543966	total: 5.11s	remaining: 258ms
# 476:	learn: 0.2543614	total: 5.12s	remaining: 247ms
# 477:	learn: 0.2542598	total: 5.13s	remaining: 236ms
# 478:	learn: 0.2541800	total: 5.14s	remaining: 226ms
# 479:	learn: 0.2541260	total: 5.16s	remaining: 215ms
# 480:	learn: 0.2540543	total: 5.17s	remaining: 204ms
# 481:	learn: 0.2539494	total: 5.18s	remaining: 193ms
# 482:	learn: 0.2538859	total: 5.19s	remaining: 183ms
# 483:	learn: 0.2537810	total: 5.2s	remaining: 172ms
# 484:	learn: 0.2537099	total: 5.21s	remaining: 161ms
# 485:	learn: 0.2536297	total: 5.22s	remaining: 150ms
# 486:	learn: 0.2535699	total: 5.24s	remaining: 140ms
# 487:	learn: 0.2535045	total: 5.25s	remaining: 129ms
# 488:	learn: 0.2534375	total: 5.26s	remaining: 118ms
# 489:	learn: 0.2533425	total: 5.27s	remaining: 108ms
# 490:	learn: 0.2532002	total: 5.28s	remaining: 96.8ms
# 491:	learn: 0.2531168	total: 5.29s	remaining: 86.1ms
# 492:	learn: 0.2530680	total: 5.31s	remaining: 75.4ms
# 493:	learn: 0.2529785	total: 5.32s	remaining: 64.6ms
# 494:	learn: 0.2528867	total: 5.33s	remaining: 53.8ms
# 495:	learn: 0.2527939	total: 5.34s	remaining: 43.1ms
# 496:	learn: 0.2527167	total: 5.35s	remaining: 32.3ms
# 497:	learn: 0.2526458	total: 5.37s	remaining: 21.5ms
# 498:	learn: 0.2525227	total: 5.38s	remaining: 10.8ms
# 499:	learn: 0.2524223	total: 5.39s	remaining: 0us
# 0:	learn: 0.6416514	total: 11.5ms	remaining: 5.73s
# 1:	learn: 0.5992982	total: 22.1ms	remaining: 5.51s
# 2:	learn: 0.5639422	total: 33.1ms	remaining: 5.47s
# 3:	learn: 0.5330676	total: 43.3ms	remaining: 5.37s
# 4:	learn: 0.5077946	total: 54.4ms	remaining: 5.38s
# 5:	learn: 0.4870707	total: 65.1ms	remaining: 5.36s
# 6:	learn: 0.4691696	total: 75.5ms	remaining: 5.32s
# 7:	learn: 0.4549483	total: 86.5ms	remaining: 5.32s
# 8:	learn: 0.4429518	total: 97.3ms	remaining: 5.3s
# 9:	learn: 0.4326128	total: 108ms	remaining: 5.3s
# 10:	learn: 0.4235997	total: 119ms	remaining: 5.31s
# 11:	learn: 0.4150068	total: 130ms	remaining: 5.29s
# 12:	learn: 0.4093643	total: 142ms	remaining: 5.3s
# 13:	learn: 0.4039748	total: 153ms	remaining: 5.29s
# 14:	learn: 0.3981077	total: 164ms	remaining: 5.31s
# 15:	learn: 0.3935251	total: 175ms	remaining: 5.3s
# 16:	learn: 0.3890449	total: 186ms	remaining: 5.29s
# 17:	learn: 0.3839704	total: 197ms	remaining: 5.27s
# 18:	learn: 0.3799909	total: 211ms	remaining: 5.34s
# 19:	learn: 0.3766159	total: 220ms	remaining: 5.28s
# 20:	learn: 0.3727921	total: 240ms	remaining: 5.47s
# 21:	learn: 0.3699917	total: 252ms	remaining: 5.47s
# 22:	learn: 0.3676730	total: 261ms	remaining: 5.42s
# 23:	learn: 0.3651730	total: 271ms	remaining: 5.37s
# 24:	learn: 0.3627834	total: 280ms	remaining: 5.31s
# 25:	learn: 0.3613904	total: 289ms	remaining: 5.26s
# 26:	learn: 0.3597157	total: 299ms	remaining: 5.24s
# 27:	learn: 0.3569949	total: 315ms	remaining: 5.31s
# 28:	learn: 0.3552503	total: 326ms	remaining: 5.3s
# 29:	learn: 0.3535109	total: 336ms	remaining: 5.27s
# 30:	learn: 0.3525260	total: 347ms	remaining: 5.25s
# 31:	learn: 0.3499243	total: 357ms	remaining: 5.23s
# 32:	learn: 0.3487850	total: 368ms	remaining: 5.21s
# 33:	learn: 0.3472570	total: 379ms	remaining: 5.19s
# 34:	learn: 0.3457182	total: 390ms	remaining: 5.18s
# 35:	learn: 0.3449324	total: 401ms	remaining: 5.17s
# 36:	learn: 0.3438606	total: 412ms	remaining: 5.16s
# 37:	learn: 0.3424698	total: 423ms	remaining: 5.14s
# 38:	learn: 0.3414588	total: 434ms	remaining: 5.13s
# 39:	learn: 0.3404342	total: 445ms	remaining: 5.12s
# 40:	learn: 0.3400404	total: 456ms	remaining: 5.11s
# 41:	learn: 0.3394226	total: 467ms	remaining: 5.09s
# 42:	learn: 0.3382803	total: 478ms	remaining: 5.08s
# 43:	learn: 0.3372516	total: 488ms	remaining: 5.05s
# 44:	learn: 0.3363147	total: 498ms	remaining: 5.03s
# 45:	learn: 0.3350478	total: 508ms	remaining: 5.01s
# 46:	learn: 0.3340692	total: 518ms	remaining: 4.99s
# 47:	learn: 0.3329192	total: 528ms	remaining: 4.98s
# 48:	learn: 0.3321743	total: 538ms	remaining: 4.95s
# 49:	learn: 0.3316084	total: 548ms	remaining: 4.93s
# 50:	learn: 0.3310260	total: 559ms	remaining: 4.92s
# 51:	learn: 0.3305475	total: 569ms	remaining: 4.9s
# 52:	learn: 0.3297278	total: 579ms	remaining: 4.88s
# 53:	learn: 0.3291414	total: 589ms	remaining: 4.87s
# 54:	learn: 0.3284686	total: 600ms	remaining: 4.85s
# 55:	learn: 0.3279545	total: 610ms	remaining: 4.83s
# 56:	learn: 0.3273615	total: 619ms	remaining: 4.81s
# 57:	learn: 0.3270475	total: 629ms	remaining: 4.79s
# 58:	learn: 0.3266688	total: 640ms	remaining: 4.78s
# 59:	learn: 0.3263049	total: 650ms	remaining: 4.76s
# 60:	learn: 0.3259901	total: 659ms	remaining: 4.74s
# 61:	learn: 0.3252858	total: 670ms	remaining: 4.73s
# 62:	learn: 0.3249055	total: 680ms	remaining: 4.71s
# 63:	learn: 0.3245013	total: 689ms	remaining: 4.7s
# 64:	learn: 0.3236167	total: 699ms	remaining: 4.68s
# 65:	learn: 0.3231769	total: 709ms	remaining: 4.66s
# 66:	learn: 0.3227360	total: 720ms	remaining: 4.65s
# 67:	learn: 0.3224511	total: 730ms	remaining: 4.64s
# 68:	learn: 0.3217688	total: 741ms	remaining: 4.63s
# 69:	learn: 0.3214195	total: 751ms	remaining: 4.61s
# 70:	learn: 0.3210931	total: 761ms	remaining: 4.6s
# 71:	learn: 0.3207843	total: 771ms	remaining: 4.58s
# 72:	learn: 0.3204530	total: 781ms	remaining: 4.57s
# 73:	learn: 0.3199611	total: 791ms	remaining: 4.55s
# 74:	learn: 0.3192472	total: 802ms	remaining: 4.54s
# 75:	learn: 0.3190848	total: 812ms	remaining: 4.53s
# 76:	learn: 0.3187485	total: 823ms	remaining: 4.52s
# 77:	learn: 0.3184895	total: 833ms	remaining: 4.51s
# 78:	learn: 0.3181320	total: 843ms	remaining: 4.49s
# 79:	learn: 0.3176161	total: 854ms	remaining: 4.48s
# 80:	learn: 0.3173918	total: 864ms	remaining: 4.47s
# 81:	learn: 0.3171458	total: 878ms	remaining: 4.48s
# 82:	learn: 0.3165018	total: 891ms	remaining: 4.47s
# 83:	learn: 0.3162426	total: 902ms	remaining: 4.47s
# 84:	learn: 0.3159175	total: 912ms	remaining: 4.45s
# 85:	learn: 0.3155620	total: 922ms	remaining: 4.44s
# 86:	learn: 0.3154136	total: 932ms	remaining: 4.42s
# 87:	learn: 0.3149624	total: 942ms	remaining: 4.41s
# 88:	learn: 0.3147437	total: 952ms	remaining: 4.39s
# 89:	learn: 0.3146278	total: 961ms	remaining: 4.38s
# 90:	learn: 0.3143564	total: 971ms	remaining: 4.36s
# 91:	learn: 0.3141393	total: 981ms	remaining: 4.35s
# 92:	learn: 0.3139515	total: 991ms	remaining: 4.33s
# 93:	learn: 0.3137702	total: 1s	remaining: 4.32s
# 94:	learn: 0.3136176	total: 1.01s	remaining: 4.3s
# 95:	learn: 0.3135081	total: 1.02s	remaining: 4.29s
# 96:	learn: 0.3133013	total: 1.03s	remaining: 4.27s
# 97:	learn: 0.3131617	total: 1.04s	remaining: 4.25s
# 98:	learn: 0.3129098	total: 1.05s	remaining: 4.24s
# 99:	learn: 0.3126641	total: 1.06s	remaining: 4.23s
# 100:	learn: 0.3124530	total: 1.07s	remaining: 4.22s
# 101:	learn: 0.3121304	total: 1.08s	remaining: 4.2s
# 102:	learn: 0.3119357	total: 1.09s	remaining: 4.19s
# 103:	learn: 0.3117968	total: 1.1s	remaining: 4.18s
# 104:	learn: 0.3113798	total: 1.11s	remaining: 4.17s
# 105:	learn: 0.3112072	total: 1.12s	remaining: 4.16s
# 106:	learn: 0.3109932	total: 1.13s	remaining: 4.14s
# 107:	learn: 0.3108174	total: 1.14s	remaining: 4.13s
# 108:	learn: 0.3106978	total: 1.14s	remaining: 4.1s
# 109:	learn: 0.3105278	total: 1.15s	remaining: 4.09s
# 110:	learn: 0.3101487	total: 1.16s	remaining: 4.07s
# 111:	learn: 0.3099555	total: 1.17s	remaining: 4.06s
# 112:	learn: 0.3098198	total: 1.18s	remaining: 4.05s
# 113:	learn: 0.3096836	total: 1.19s	remaining: 4.04s
# 114:	learn: 0.3095805	total: 1.2s	remaining: 4.03s
# 115:	learn: 0.3094221	total: 1.21s	remaining: 4.02s
# 116:	learn: 0.3093150	total: 1.22s	remaining: 4.01s
# 117:	learn: 0.3091977	total: 1.23s	remaining: 3.99s
# 118:	learn: 0.3089776	total: 1.24s	remaining: 3.98s
# 119:	learn: 0.3088369	total: 1.25s	remaining: 3.97s
# 120:	learn: 0.3087326	total: 1.26s	remaining: 3.95s
# 121:	learn: 0.3086268	total: 1.27s	remaining: 3.94s
# 122:	learn: 0.3085054	total: 1.28s	remaining: 3.93s
# 123:	learn: 0.3082733	total: 1.29s	remaining: 3.92s
# 124:	learn: 0.3082531	total: 1.3s	remaining: 3.9s
# 125:	learn: 0.3078793	total: 1.31s	remaining: 3.89s
# 126:	learn: 0.3078120	total: 1.32s	remaining: 3.87s
# 127:	learn: 0.3077462	total: 1.33s	remaining: 3.86s
# 128:	learn: 0.3076010	total: 1.34s	remaining: 3.85s
# 129:	learn: 0.3074809	total: 1.35s	remaining: 3.84s
# 130:	learn: 0.3073274	total: 1.36s	remaining: 3.82s
# 131:	learn: 0.3071799	total: 1.37s	remaining: 3.81s
# 132:	learn: 0.3070292	total: 1.38s	remaining: 3.8s
# 133:	learn: 0.3068074	total: 1.39s	remaining: 3.79s
# 134:	learn: 0.3064623	total: 1.4s	remaining: 3.78s
# 135:	learn: 0.3063668	total: 1.41s	remaining: 3.77s
# 136:	learn: 0.3060026	total: 1.42s	remaining: 3.76s
# 137:	learn: 0.3056644	total: 1.43s	remaining: 3.75s
# 138:	learn: 0.3055570	total: 1.44s	remaining: 3.74s
# 139:	learn: 0.3055028	total: 1.45s	remaining: 3.73s
# 140:	learn: 0.3053006	total: 1.46s	remaining: 3.72s
# 141:	learn: 0.3051564	total: 1.47s	remaining: 3.7s
# 142:	learn: 0.3050028	total: 1.48s	remaining: 3.69s
# 143:	learn: 0.3049006	total: 1.49s	remaining: 3.68s
# 144:	learn: 0.3046904	total: 1.5s	remaining: 3.67s
# 145:	learn: 0.3044647	total: 1.51s	remaining: 3.66s
# 146:	learn: 0.3042766	total: 1.52s	remaining: 3.65s
# 147:	learn: 0.3041056	total: 1.53s	remaining: 3.64s
# 148:	learn: 0.3039824	total: 1.54s	remaining: 3.63s
# 149:	learn: 0.3036198	total: 1.55s	remaining: 3.62s
# 150:	learn: 0.3035013	total: 1.56s	remaining: 3.61s
# 151:	learn: 0.3033524	total: 1.57s	remaining: 3.6s
# 152:	learn: 0.3032592	total: 1.58s	remaining: 3.58s
# 153:	learn: 0.3031452	total: 1.59s	remaining: 3.57s
# 154:	learn: 0.3030824	total: 1.6s	remaining: 3.56s
# 155:	learn: 0.3029289	total: 1.61s	remaining: 3.55s
# 156:	learn: 0.3028099	total: 1.62s	remaining: 3.54s
# 157:	learn: 0.3027427	total: 1.63s	remaining: 3.53s
# 158:	learn: 0.3024941	total: 1.64s	remaining: 3.53s
# 159:	learn: 0.3023982	total: 1.66s	remaining: 3.52s
# 160:	learn: 0.3021464	total: 1.68s	remaining: 3.54s
# 161:	learn: 0.3020449	total: 1.69s	remaining: 3.52s
# 162:	learn: 0.3018248	total: 1.7s	remaining: 3.51s
# 163:	learn: 0.3016959	total: 1.71s	remaining: 3.5s
# 164:	learn: 0.3016069	total: 1.72s	remaining: 3.48s
# 165:	learn: 0.3014455	total: 1.73s	remaining: 3.48s
# 166:	learn: 0.3013131	total: 1.74s	remaining: 3.48s
# 167:	learn: 0.3011204	total: 1.75s	remaining: 3.47s
# 168:	learn: 0.3009870	total: 1.76s	remaining: 3.46s
# 169:	learn: 0.3008870	total: 1.77s	remaining: 3.45s
# 170:	learn: 0.3008372	total: 1.78s	remaining: 3.44s
# 171:	learn: 0.3008266	total: 1.79s	remaining: 3.42s
# 172:	learn: 0.3006655	total: 1.8s	remaining: 3.4s
# 173:	learn: 0.3005280	total: 1.81s	remaining: 3.4s
# 174:	learn: 0.3004402	total: 1.82s	remaining: 3.38s
# 175:	learn: 0.3003343	total: 1.83s	remaining: 3.37s
# 176:	learn: 0.3000360	total: 1.84s	remaining: 3.36s
# 177:	learn: 0.2999195	total: 1.85s	remaining: 3.35s
# 178:	learn: 0.2997583	total: 1.86s	remaining: 3.34s
# 179:	learn: 0.2996349	total: 1.87s	remaining: 3.33s
# 180:	learn: 0.2996277	total: 1.88s	remaining: 3.31s
# 181:	learn: 0.2995370	total: 1.89s	remaining: 3.3s
# 182:	learn: 0.2994644	total: 1.9s	remaining: 3.29s
# 183:	learn: 0.2993321	total: 1.91s	remaining: 3.28s
# 184:	learn: 0.2992041	total: 1.92s	remaining: 3.26s
# 185:	learn: 0.2990743	total: 1.93s	remaining: 3.25s
# 186:	learn: 0.2990185	total: 1.94s	remaining: 3.24s
# 187:	learn: 0.2988925	total: 1.95s	remaining: 3.23s
# 188:	learn: 0.2988293	total: 1.96s	remaining: 3.22s
# 189:	learn: 0.2986116	total: 1.97s	remaining: 3.21s
# 190:	learn: 0.2984963	total: 1.98s	remaining: 3.19s
# 191:	learn: 0.2984022	total: 1.99s	remaining: 3.18s
# 192:	learn: 0.2983290	total: 2s	remaining: 3.17s
# 193:	learn: 0.2982203	total: 2s	remaining: 3.16s
# 194:	learn: 0.2982155	total: 2.01s	remaining: 3.15s
# 195:	learn: 0.2980516	total: 2.02s	remaining: 3.13s
# 196:	learn: 0.2979573	total: 2.03s	remaining: 3.12s
# 197:	learn: 0.2978552	total: 2.04s	remaining: 3.11s
# 198:	learn: 0.2977901	total: 2.05s	remaining: 3.1s
# 199:	learn: 0.2975773	total: 2.06s	remaining: 3.09s
# 200:	learn: 0.2974262	total: 2.07s	remaining: 3.08s
# 201:	learn: 0.2972497	total: 2.08s	remaining: 3.07s
# 202:	learn: 0.2968963	total: 2.09s	remaining: 3.06s
# 203:	learn: 0.2968517	total: 2.1s	remaining: 3.05s
# 204:	learn: 0.2967805	total: 2.11s	remaining: 3.04s
# 205:	learn: 0.2967104	total: 2.12s	remaining: 3.03s
# 206:	learn: 0.2965981	total: 2.13s	remaining: 3.02s
# 207:	learn: 0.2964050	total: 2.14s	remaining: 3s
# 208:	learn: 0.2963217	total: 2.15s	remaining: 2.99s
# 209:	learn: 0.2961777	total: 2.16s	remaining: 2.98s
# 210:	learn: 0.2960460	total: 2.17s	remaining: 2.97s
# 211:	learn: 0.2959784	total: 2.18s	remaining: 2.96s
# 212:	learn: 0.2958364	total: 2.19s	remaining: 2.95s
# 213:	learn: 0.2958107	total: 2.2s	remaining: 2.94s
# 214:	learn: 0.2956512	total: 2.21s	remaining: 2.93s
# 215:	learn: 0.2955702	total: 2.22s	remaining: 2.92s
# 216:	learn: 0.2954500	total: 2.23s	remaining: 2.91s
# 217:	learn: 0.2953011	total: 2.24s	remaining: 2.9s
# 218:	learn: 0.2951919	total: 2.25s	remaining: 2.89s
# 219:	learn: 0.2951098	total: 2.26s	remaining: 2.88s
# 220:	learn: 0.2950514	total: 2.27s	remaining: 2.86s
# 221:	learn: 0.2949907	total: 2.28s	remaining: 2.85s
# 222:	learn: 0.2948286	total: 2.29s	remaining: 2.84s
# 223:	learn: 0.2947598	total: 2.3s	remaining: 2.83s
# 224:	learn: 0.2947100	total: 2.31s	remaining: 2.82s
# 225:	learn: 0.2946128	total: 2.32s	remaining: 2.81s
# 226:	learn: 0.2945182	total: 2.33s	remaining: 2.8s
# 227:	learn: 0.2944796	total: 2.34s	remaining: 2.79s
# 228:	learn: 0.2943724	total: 2.35s	remaining: 2.78s
# 229:	learn: 0.2942467	total: 2.36s	remaining: 2.77s
# 230:	learn: 0.2941464	total: 2.37s	remaining: 2.76s
# 231:	learn: 0.2940729	total: 2.38s	remaining: 2.75s
# 232:	learn: 0.2939963	total: 2.39s	remaining: 2.74s
# 233:	learn: 0.2938565	total: 2.4s	remaining: 2.73s
# 234:	learn: 0.2937312	total: 2.41s	remaining: 2.72s
# 235:	learn: 0.2934243	total: 2.42s	remaining: 2.71s
# 236:	learn: 0.2932898	total: 2.43s	remaining: 2.7s
# 237:	learn: 0.2931401	total: 2.44s	remaining: 2.69s
# 238:	learn: 0.2930446	total: 2.45s	remaining: 2.68s
# 239:	learn: 0.2929285	total: 2.46s	remaining: 2.67s
# 240:	learn: 0.2927887	total: 2.47s	remaining: 2.66s
# 241:	learn: 0.2927356	total: 2.48s	remaining: 2.65s
# 242:	learn: 0.2926332	total: 2.49s	remaining: 2.63s
# 243:	learn: 0.2925193	total: 2.5s	remaining: 2.62s
# 244:	learn: 0.2923984	total: 2.51s	remaining: 2.61s
# 245:	learn: 0.2923115	total: 2.52s	remaining: 2.6s
# 246:	learn: 0.2922102	total: 2.53s	remaining: 2.59s
# 247:	learn: 0.2920793	total: 2.54s	remaining: 2.58s
# 248:	learn: 0.2920009	total: 2.55s	remaining: 2.57s
# 249:	learn: 0.2919046	total: 2.56s	remaining: 2.56s
# 250:	learn: 0.2917901	total: 2.57s	remaining: 2.55s
# 251:	learn: 0.2917191	total: 2.58s	remaining: 2.54s
# 252:	learn: 0.2916497	total: 2.59s	remaining: 2.53s
# 253:	learn: 0.2915857	total: 2.6s	remaining: 2.52s
# 254:	learn: 0.2915127	total: 2.61s	remaining: 2.51s
# 255:	learn: 0.2914192	total: 2.62s	remaining: 2.5s
# 256:	learn: 0.2913227	total: 2.63s	remaining: 2.49s
# 257:	learn: 0.2912488	total: 2.64s	remaining: 2.48s
# 258:	learn: 0.2911343	total: 2.65s	remaining: 2.47s
# 259:	learn: 0.2910858	total: 2.66s	remaining: 2.46s
# 260:	learn: 0.2909983	total: 2.67s	remaining: 2.45s
# 261:	learn: 0.2909087	total: 2.68s	remaining: 2.44s
# 262:	learn: 0.2908219	total: 2.69s	remaining: 2.42s
# 263:	learn: 0.2906884	total: 2.7s	remaining: 2.42s
# 264:	learn: 0.2906162	total: 2.71s	remaining: 2.4s
# 265:	learn: 0.2905400	total: 2.72s	remaining: 2.4s
# 266:	learn: 0.2904716	total: 2.73s	remaining: 2.38s
# 267:	learn: 0.2903874	total: 2.74s	remaining: 2.37s
# 268:	learn: 0.2903064	total: 2.75s	remaining: 2.36s
# 269:	learn: 0.2901935	total: 2.76s	remaining: 2.35s
# 270:	learn: 0.2900991	total: 2.77s	remaining: 2.34s
# 271:	learn: 0.2899299	total: 2.78s	remaining: 2.33s
# 272:	learn: 0.2898287	total: 2.79s	remaining: 2.32s
# 273:	learn: 0.2897511	total: 2.8s	remaining: 2.31s
# 274:	learn: 0.2895550	total: 2.81s	remaining: 2.3s
# 275:	learn: 0.2894770	total: 2.82s	remaining: 2.29s
# 276:	learn: 0.2893997	total: 2.83s	remaining: 2.28s
# 277:	learn: 0.2893422	total: 2.84s	remaining: 2.27s
# 278:	learn: 0.2891905	total: 2.85s	remaining: 2.26s
# 279:	learn: 0.2890730	total: 2.86s	remaining: 2.25s
# 280:	learn: 0.2889766	total: 2.87s	remaining: 2.24s
# 281:	learn: 0.2888675	total: 2.88s	remaining: 2.23s
# 282:	learn: 0.2887460	total: 2.89s	remaining: 2.22s
# 283:	learn: 0.2886211	total: 2.9s	remaining: 2.21s
# 284:	learn: 0.2885546	total: 2.91s	remaining: 2.2s
# 285:	learn: 0.2884614	total: 2.92s	remaining: 2.19s
# 286:	learn: 0.2883609	total: 2.94s	remaining: 2.18s
# 287:	learn: 0.2882518	total: 2.94s	remaining: 2.17s
# 288:	learn: 0.2881857	total: 2.96s	remaining: 2.16s
# 289:	learn: 0.2880900	total: 2.97s	remaining: 2.15s
# 290:	learn: 0.2880064	total: 2.98s	remaining: 2.14s
# 291:	learn: 0.2879222	total: 3s	remaining: 2.14s
# 292:	learn: 0.2878575	total: 3.01s	remaining: 2.13s
# 293:	learn: 0.2877741	total: 3.02s	remaining: 2.12s
# 294:	learn: 0.2877253	total: 3.03s	remaining: 2.1s
# 295:	learn: 0.2875947	total: 3.04s	remaining: 2.09s
# 296:	learn: 0.2875134	total: 3.05s	remaining: 2.09s
# 297:	learn: 0.2874649	total: 3.06s	remaining: 2.08s
# 298:	learn: 0.2874264	total: 3.08s	remaining: 2.07s
# 299:	learn: 0.2873513	total: 3.09s	remaining: 2.06s
# 300:	learn: 0.2872526	total: 3.1s	remaining: 2.05s
# 301:	learn: 0.2871777	total: 3.11s	remaining: 2.04s
# 302:	learn: 0.2870964	total: 3.12s	remaining: 2.03s
# 303:	learn: 0.2869415	total: 3.13s	remaining: 2.02s
# 304:	learn: 0.2868581	total: 3.14s	remaining: 2s
# 305:	learn: 0.2867884	total: 3.15s	remaining: 2s
# 306:	learn: 0.2867636	total: 3.16s	remaining: 1.98s
# 307:	learn: 0.2866842	total: 3.17s	remaining: 1.97s
# 308:	learn: 0.2865312	total: 3.18s	remaining: 1.96s
# 309:	learn: 0.2864178	total: 3.19s	remaining: 1.95s
# 310:	learn: 0.2863521	total: 3.2s	remaining: 1.94s
# 311:	learn: 0.2861885	total: 3.21s	remaining: 1.93s
# 312:	learn: 0.2861106	total: 3.22s	remaining: 1.92s
# 313:	learn: 0.2860471	total: 3.23s	remaining: 1.91s
# 314:	learn: 0.2859940	total: 3.24s	remaining: 1.9s
# 315:	learn: 0.2859370	total: 3.25s	remaining: 1.89s
# 316:	learn: 0.2857962	total: 3.26s	remaining: 1.88s
# 317:	learn: 0.2857350	total: 3.27s	remaining: 1.87s
# 318:	learn: 0.2856598	total: 3.28s	remaining: 1.86s
# 319:	learn: 0.2856015	total: 3.29s	remaining: 1.85s
# 320:	learn: 0.2855213	total: 3.3s	remaining: 1.84s
# 321:	learn: 0.2854439	total: 3.31s	remaining: 1.83s
# 322:	learn: 0.2853932	total: 3.32s	remaining: 1.82s
# 323:	learn: 0.2853705	total: 3.33s	remaining: 1.81s
# 324:	learn: 0.2852966	total: 3.34s	remaining: 1.8s
# 325:	learn: 0.2852283	total: 3.35s	remaining: 1.79s
# 326:	learn: 0.2851597	total: 3.36s	remaining: 1.78s
# 327:	learn: 0.2851021	total: 3.37s	remaining: 1.76s
# 328:	learn: 0.2850430	total: 3.38s	remaining: 1.75s
# 329:	learn: 0.2849685	total: 3.39s	remaining: 1.74s
# 330:	learn: 0.2848936	total: 3.4s	remaining: 1.73s
# 331:	learn: 0.2848328	total: 3.41s	remaining: 1.72s
# 332:	learn: 0.2847418	total: 3.42s	remaining: 1.71s
# 333:	learn: 0.2846234	total: 3.43s	remaining: 1.7s
# 334:	learn: 0.2845401	total: 3.44s	remaining: 1.69s
# 335:	learn: 0.2844732	total: 3.45s	remaining: 1.68s
# 336:	learn: 0.2842717	total: 3.46s	remaining: 1.67s
# 337:	learn: 0.2841913	total: 3.47s	remaining: 1.66s
# 338:	learn: 0.2840925	total: 3.48s	remaining: 1.65s
# 339:	learn: 0.2840150	total: 3.49s	remaining: 1.64s
# 340:	learn: 0.2839527	total: 3.5s	remaining: 1.63s
# 341:	learn: 0.2838921	total: 3.51s	remaining: 1.62s
# 342:	learn: 0.2838343	total: 3.52s	remaining: 1.61s
# 343:	learn: 0.2836718	total: 3.53s	remaining: 1.6s
# 344:	learn: 0.2835844	total: 3.54s	remaining: 1.59s
# 345:	learn: 0.2834597	total: 3.55s	remaining: 1.58s
# 346:	learn: 0.2833663	total: 3.56s	remaining: 1.57s
# 347:	learn: 0.2832969	total: 3.57s	remaining: 1.56s
# 348:	learn: 0.2832329	total: 3.58s	remaining: 1.55s
# 349:	learn: 0.2831378	total: 3.59s	remaining: 1.54s
# 350:	learn: 0.2830803	total: 3.6s	remaining: 1.53s
# 351:	learn: 0.2830101	total: 3.61s	remaining: 1.52s
# 352:	learn: 0.2829382	total: 3.62s	remaining: 1.51s
# 353:	learn: 0.2828654	total: 3.63s	remaining: 1.5s
# 354:	learn: 0.2828053	total: 3.64s	remaining: 1.49s
# 355:	learn: 0.2827235	total: 3.65s	remaining: 1.48s
# 356:	learn: 0.2826876	total: 3.66s	remaining: 1.47s
# 357:	learn: 0.2826265	total: 3.67s	remaining: 1.46s
# 358:	learn: 0.2826127	total: 3.68s	remaining: 1.45s
# 359:	learn: 0.2825562	total: 3.69s	remaining: 1.44s
# 360:	learn: 0.2824906	total: 3.7s	remaining: 1.43s
# 361:	learn: 0.2824249	total: 3.71s	remaining: 1.42s
# 362:	learn: 0.2823604	total: 3.73s	remaining: 1.41s
# 363:	learn: 0.2823076	total: 3.73s	remaining: 1.4s
# 364:	learn: 0.2822442	total: 3.74s	remaining: 1.39s
# 365:	learn: 0.2821809	total: 3.75s	remaining: 1.37s
# 366:	learn: 0.2821012	total: 3.77s	remaining: 1.36s
# 367:	learn: 0.2820362	total: 3.77s	remaining: 1.35s
# 368:	learn: 0.2819138	total: 3.79s	remaining: 1.34s
# 369:	learn: 0.2818637	total: 3.79s	remaining: 1.33s
# 370:	learn: 0.2818203	total: 3.81s	remaining: 1.32s
# 371:	learn: 0.2817541	total: 3.82s	remaining: 1.31s
# 372:	learn: 0.2817157	total: 3.83s	remaining: 1.3s
# 373:	learn: 0.2816449	total: 3.83s	remaining: 1.29s
# 374:	learn: 0.2815870	total: 3.85s	remaining: 1.28s
# 375:	learn: 0.2815246	total: 3.86s	remaining: 1.27s
# 376:	learn: 0.2814763	total: 3.87s	remaining: 1.26s
# 377:	learn: 0.2813517	total: 3.88s	remaining: 1.25s
# 378:	learn: 0.2813012	total: 3.89s	remaining: 1.24s
# 379:	learn: 0.2812070	total: 3.9s	remaining: 1.23s
# 380:	learn: 0.2811321	total: 3.91s	remaining: 1.22s
# 381:	learn: 0.2810622	total: 3.92s	remaining: 1.21s
# 382:	learn: 0.2810041	total: 3.93s	remaining: 1.2s
# 383:	learn: 0.2809537	total: 3.94s	remaining: 1.19s
# 384:	learn: 0.2808994	total: 3.95s	remaining: 1.18s
# 385:	learn: 0.2808452	total: 3.96s	remaining: 1.17s
# 386:	learn: 0.2807604	total: 3.97s	remaining: 1.16s
# 387:	learn: 0.2806991	total: 3.98s	remaining: 1.15s
# 388:	learn: 0.2806509	total: 3.99s	remaining: 1.14s
# 389:	learn: 0.2805874	total: 4s	remaining: 1.13s
# 390:	learn: 0.2805432	total: 4.01s	remaining: 1.12s
# 391:	learn: 0.2804936	total: 4.02s	remaining: 1.11s
# 392:	learn: 0.2804341	total: 4.03s	remaining: 1.1s
# 393:	learn: 0.2803200	total: 4.04s	remaining: 1.09s
# 394:	learn: 0.2802628	total: 4.05s	remaining: 1.08s
# 395:	learn: 0.2802011	total: 4.06s	remaining: 1.07s
# 396:	learn: 0.2801575	total: 4.07s	remaining: 1.06s
# 397:	learn: 0.2800835	total: 4.08s	remaining: 1.05s
# 398:	learn: 0.2800410	total: 4.09s	remaining: 1.03s
# 399:	learn: 0.2800283	total: 4.1s	remaining: 1.02s
# 400:	learn: 0.2799310	total: 4.11s	remaining: 1.01s
# 401:	learn: 0.2798563	total: 4.12s	remaining: 1s
# 402:	learn: 0.2797951	total: 4.13s	remaining: 995ms
# 403:	learn: 0.2797451	total: 4.14s	remaining: 985ms
# 404:	learn: 0.2797052	total: 4.15s	remaining: 974ms
# 405:	learn: 0.2796499	total: 4.16s	remaining: 964ms
# 406:	learn: 0.2795837	total: 4.17s	remaining: 954ms
# 407:	learn: 0.2795188	total: 4.18s	remaining: 944ms
# 408:	learn: 0.2794435	total: 4.2s	remaining: 933ms
# 409:	learn: 0.2793910	total: 4.21s	remaining: 923ms
# 410:	learn: 0.2793413	total: 4.21s	remaining: 913ms
# 411:	learn: 0.2793330	total: 4.22s	remaining: 902ms
# 412:	learn: 0.2792935	total: 4.23s	remaining: 892ms
# 413:	learn: 0.2792337	total: 4.24s	remaining: 882ms
# 414:	learn: 0.2791827	total: 4.25s	remaining: 871ms
# 415:	learn: 0.2791006	total: 4.26s	remaining: 861ms
# 416:	learn: 0.2790323	total: 4.28s	remaining: 851ms
# 417:	learn: 0.2789670	total: 4.29s	remaining: 841ms
# 418:	learn: 0.2789601	total: 4.29s	remaining: 830ms
# 419:	learn: 0.2788772	total: 4.3s	remaining: 820ms
# 420:	learn: 0.2788250	total: 4.32s	remaining: 810ms
# 421:	learn: 0.2787725	total: 4.33s	remaining: 800ms
# 422:	learn: 0.2786655	total: 4.34s	remaining: 790ms
# 423:	learn: 0.2785594	total: 4.35s	remaining: 780ms
# 424:	learn: 0.2784673	total: 4.37s	remaining: 771ms
# 425:	learn: 0.2784117	total: 4.38s	remaining: 761ms
# 426:	learn: 0.2783667	total: 4.39s	remaining: 750ms
# 427:	learn: 0.2782966	total: 4.4s	remaining: 740ms
# 428:	learn: 0.2782641	total: 4.41s	remaining: 729ms
# 429:	learn: 0.2782217	total: 4.42s	remaining: 719ms
# ...
# 202:	learn: 0.2943036	total: 1.56s	remaining: 2.28s
# 203:	learn: 0.2941842	total: 1.56s	remaining: 2.27s
# 204:	learn: 0.2941281	total: 1.57s	remaining: 2.26s
# 205:	learn: 0.2940318	total: 1.58s	remaining: 2.25s
# 206:	learn: 0.2939539	total: 1.59s	remaining: 2.25s
# 207:	learn: 0.2938837	total: 1.59s	remaining: 2.24s
# 208:	learn: 0.2938220	total: 1.6s	remaining: 2.23s
# 209:	learn: 0.2937632	total: 1.61s	remaining: 2.22s
# 210:	learn: 0.2937059	total: 1.62s	remaining: 2.22s
# 211:	learn: 0.2933863	total: 1.63s	remaining: 2.21s
# 212:	learn: 0.2932618	total: 1.63s	remaining: 2.2s
# 213:	learn: 0.2931259	total: 1.64s	remaining: 2.19s
# 214:	learn: 0.2930100	total: 1.65s	remaining: 2.19s
# 215:	learn: 0.2927534	total: 1.66s	remaining: 2.18s
# 216:	learn: 0.2926217	total: 1.67s	remaining: 2.17s
# 217:	learn: 0.2925220	total: 1.67s	remaining: 2.17s
# 218:	learn: 0.2924146	total: 1.68s	remaining: 2.16s
# 219:	learn: 0.2923554	total: 1.69s	remaining: 2.15s
# 220:	learn: 0.2922670	total: 1.7s	remaining: 2.14s
# 221:	learn: 0.2921608	total: 1.71s	remaining: 2.13s
# 222:	learn: 0.2920498	total: 1.71s	remaining: 2.13s
# 223:	learn: 0.2919559	total: 1.72s	remaining: 2.12s
# 224:	learn: 0.2918174	total: 1.73s	remaining: 2.11s
# 225:	learn: 0.2917668	total: 1.74s	remaining: 2.1s
# 226:	learn: 0.2915922	total: 1.74s	remaining: 2.1s
# 227:	learn: 0.2914936	total: 1.75s	remaining: 2.09s
# 228:	learn: 0.2914056	total: 1.76s	remaining: 2.08s
# 229:	learn: 0.2912517	total: 1.77s	remaining: 2.07s
# 230:	learn: 0.2911470	total: 1.77s	remaining: 2.07s
# 231:	learn: 0.2911035	total: 1.78s	remaining: 2.06s
# 232:	learn: 0.2910482	total: 1.79s	remaining: 2.05s
# 233:	learn: 0.2909785	total: 1.8s	remaining: 2.04s
# 234:	learn: 0.2908745	total: 1.8s	remaining: 2.04s
# 235:	learn: 0.2907684	total: 1.81s	remaining: 2.03s
# 236:	learn: 0.2906408	total: 1.82s	remaining: 2.02s
# 237:	learn: 0.2905732	total: 1.83s	remaining: 2.01s
# 238:	learn: 0.2904004	total: 1.83s	remaining: 2s
# 239:	learn: 0.2903245	total: 1.84s	remaining: 2s
# 240:	learn: 0.2902456	total: 1.85s	remaining: 1.99s
# 241:	learn: 0.2901534	total: 1.86s	remaining: 1.98s
# 242:	learn: 0.2900838	total: 1.86s	remaining: 1.97s
# 243:	learn: 0.2899713	total: 1.87s	remaining: 1.96s
# 244:	learn: 0.2898432	total: 1.88s	remaining: 1.96s
# 245:	learn: 0.2897461	total: 1.89s	remaining: 1.95s
# 246:	learn: 0.2896932	total: 1.89s	remaining: 1.94s
# 247:	learn: 0.2894466	total: 1.9s	remaining: 1.93s
# 248:	learn: 0.2894347	total: 1.91s	remaining: 1.92s
# 249:	learn: 0.2893019	total: 1.92s	remaining: 1.92s
# 250:	learn: 0.2892461	total: 1.92s	remaining: 1.91s
# 251:	learn: 0.2891387	total: 1.93s	remaining: 1.9s
# 252:	learn: 0.2890463	total: 1.94s	remaining: 1.89s
# 253:	learn: 0.2888912	total: 1.95s	remaining: 1.89s
# 254:	learn: 0.2888256	total: 1.95s	remaining: 1.88s
# 255:	learn: 0.2886930	total: 1.96s	remaining: 1.87s
# 256:	learn: 0.2885934	total: 1.97s	remaining: 1.86s
# 257:	learn: 0.2884826	total: 1.98s	remaining: 1.85s
# 258:	learn: 0.2883863	total: 1.98s	remaining: 1.85s
# 259:	learn: 0.2883071	total: 1.99s	remaining: 1.84s
# 260:	learn: 0.2882637	total: 2s	remaining: 1.83s
# 261:	learn: 0.2881291	total: 2.01s	remaining: 1.82s
# 262:	learn: 0.2880405	total: 2.01s	remaining: 1.81s
# 263:	learn: 0.2879452	total: 2.02s	remaining: 1.81s
# 264:	learn: 0.2878231	total: 2.03s	remaining: 1.8s
# 265:	learn: 0.2877603	total: 2.04s	remaining: 1.79s
# 266:	learn: 0.2876993	total: 2.04s	remaining: 1.78s
# 267:	learn: 0.2876476	total: 2.05s	remaining: 1.78s
# 268:	learn: 0.2875771	total: 2.06s	remaining: 1.77s
# 269:	learn: 0.2873327	total: 2.07s	remaining: 1.76s
# 270:	learn: 0.2872274	total: 2.07s	remaining: 1.75s
# 271:	learn: 0.2870411	total: 2.08s	remaining: 1.75s
# 272:	learn: 0.2869377	total: 2.09s	remaining: 1.74s
# 273:	learn: 0.2867833	total: 2.1s	remaining: 1.73s
# 274:	learn: 0.2866676	total: 2.1s	remaining: 1.72s
# 275:	learn: 0.2865821	total: 2.11s	remaining: 1.71s
# 276:	learn: 0.2864892	total: 2.12s	remaining: 1.71s
# 277:	learn: 0.2864397	total: 2.13s	remaining: 1.7s
# 278:	learn: 0.2863759	total: 2.13s	remaining: 1.69s
# 279:	learn: 0.2862955	total: 2.14s	remaining: 1.68s
# 280:	learn: 0.2862524	total: 2.15s	remaining: 1.68s
# 281:	learn: 0.2861996	total: 2.16s	remaining: 1.67s
# 282:	learn: 0.2860893	total: 2.17s	remaining: 1.66s
# 283:	learn: 0.2859968	total: 2.17s	remaining: 1.65s
# 284:	learn: 0.2859380	total: 2.18s	remaining: 1.65s
# 285:	learn: 0.2858476	total: 2.19s	remaining: 1.64s
# 286:	learn: 0.2858054	total: 2.19s	remaining: 1.63s
# 287:	learn: 0.2856871	total: 2.2s	remaining: 1.62s
# 288:	learn: 0.2856075	total: 2.21s	remaining: 1.61s
# 289:	learn: 0.2855587	total: 2.22s	remaining: 1.6s
# 290:	learn: 0.2854592	total: 2.22s	remaining: 1.6s
# 291:	learn: 0.2852866	total: 2.23s	remaining: 1.59s
# 292:	learn: 0.2852103	total: 2.24s	remaining: 1.58s
# 293:	learn: 0.2851338	total: 2.25s	remaining: 1.57s
# 294:	learn: 0.2849827	total: 2.25s	remaining: 1.57s
# 295:	learn: 0.2849116	total: 2.26s	remaining: 1.56s
# 296:	learn: 0.2848957	total: 2.27s	remaining: 1.55s
# 297:	learn: 0.2848733	total: 2.27s	remaining: 1.54s
# 298:	learn: 0.2847459	total: 2.28s	remaining: 1.53s
# 299:	learn: 0.2846524	total: 2.29s	remaining: 1.53s
# 300:	learn: 0.2845809	total: 2.3s	remaining: 1.52s
# 301:	learn: 0.2844385	total: 2.31s	remaining: 1.51s
# 302:	learn: 0.2843347	total: 2.31s	remaining: 1.5s
# 303:	learn: 0.2842533	total: 2.32s	remaining: 1.5s
# 304:	learn: 0.2842257	total: 2.33s	remaining: 1.49s
# 305:	learn: 0.2841550	total: 2.33s	remaining: 1.48s
# 306:	learn: 0.2841077	total: 2.34s	remaining: 1.47s
# 307:	learn: 0.2840471	total: 2.35s	remaining: 1.46s
# 308:	learn: 0.2839068	total: 2.36s	remaining: 1.46s
# 309:	learn: 0.2838506	total: 2.36s	remaining: 1.45s
# 310:	learn: 0.2837956	total: 2.37s	remaining: 1.44s
# 311:	learn: 0.2837887	total: 2.38s	remaining: 1.43s
# 312:	learn: 0.2836563	total: 2.38s	remaining: 1.42s
# 313:	learn: 0.2835869	total: 2.39s	remaining: 1.42s
# 314:	learn: 0.2834426	total: 2.4s	remaining: 1.41s
# 315:	learn: 0.2833634	total: 2.41s	remaining: 1.4s
# 316:	learn: 0.2833229	total: 2.42s	remaining: 1.39s
# 317:	learn: 0.2832401	total: 2.42s	remaining: 1.39s
# 318:	learn: 0.2832044	total: 2.43s	remaining: 1.38s
# 319:	learn: 0.2831415	total: 2.44s	remaining: 1.37s
# 320:	learn: 0.2830480	total: 2.44s	remaining: 1.36s
# 321:	learn: 0.2829133	total: 2.45s	remaining: 1.36s
# 322:	learn: 0.2827886	total: 2.46s	remaining: 1.35s
# 323:	learn: 0.2827370	total: 2.47s	remaining: 1.34s
# 324:	learn: 0.2825498	total: 2.48s	remaining: 1.33s
# 325:	learn: 0.2824666	total: 2.48s	remaining: 1.32s
# 326:	learn: 0.2823953	total: 2.49s	remaining: 1.32s
# 327:	learn: 0.2823278	total: 2.5s	remaining: 1.31s
# 328:	learn: 0.2822811	total: 2.51s	remaining: 1.3s
# 329:	learn: 0.2821706	total: 2.51s	remaining: 1.29s
# 330:	learn: 0.2820987	total: 2.52s	remaining: 1.29s
# 331:	learn: 0.2819987	total: 2.53s	remaining: 1.28s
# 332:	learn: 0.2819328	total: 2.54s	remaining: 1.27s
# 333:	learn: 0.2818690	total: 2.55s	remaining: 1.26s
# 334:	learn: 0.2817828	total: 2.55s	remaining: 1.26s
# 335:	learn: 0.2816472	total: 2.56s	remaining: 1.25s
# 336:	learn: 0.2815828	total: 2.57s	remaining: 1.24s
# 337:	learn: 0.2815299	total: 2.58s	remaining: 1.24s
# 338:	learn: 0.2814499	total: 2.58s	remaining: 1.23s
# 339:	learn: 0.2813769	total: 2.59s	remaining: 1.22s
# 340:	learn: 0.2812887	total: 2.6s	remaining: 1.21s
# 341:	learn: 0.2812498	total: 2.6s	remaining: 1.2s
# 342:	learn: 0.2811632	total: 2.61s	remaining: 1.2s
# 343:	learn: 0.2811032	total: 2.62s	remaining: 1.19s
# 344:	learn: 0.2810166	total: 2.63s	remaining: 1.18s
# 345:	learn: 0.2809606	total: 2.64s	remaining: 1.17s
# 346:	learn: 0.2809068	total: 2.64s	remaining: 1.17s
# 347:	learn: 0.2808257	total: 2.65s	remaining: 1.16s
# 348:	learn: 0.2807882	total: 2.66s	remaining: 1.15s
# 349:	learn: 0.2806576	total: 2.67s	remaining: 1.14s
# 350:	learn: 0.2806476	total: 2.67s	remaining: 1.13s
# 351:	learn: 0.2805742	total: 2.68s	remaining: 1.13s
# 352:	learn: 0.2804982	total: 2.69s	remaining: 1.12s
# 353:	learn: 0.2804235	total: 2.69s	remaining: 1.11s
# 354:	learn: 0.2803441	total: 2.7s	remaining: 1.1s
# 355:	learn: 0.2802462	total: 2.71s	remaining: 1.1s
# 356:	learn: 0.2801584	total: 2.72s	remaining: 1.09s
# 357:	learn: 0.2800956	total: 2.73s	remaining: 1.08s
# 358:	learn: 0.2800426	total: 2.73s	remaining: 1.07s
# 359:	learn: 0.2799203	total: 2.74s	remaining: 1.06s
# 360:	learn: 0.2798056	total: 2.75s	remaining: 1.06s
# 361:	learn: 0.2796737	total: 2.75s	remaining: 1.05s
# 362:	learn: 0.2795934	total: 2.76s	remaining: 1.04s
# 363:	learn: 0.2795414	total: 2.77s	remaining: 1.03s
# 364:	learn: 0.2794399	total: 2.78s	remaining: 1.03s
# 365:	learn: 0.2793686	total: 2.79s	remaining: 1.02s
# 366:	learn: 0.2793273	total: 2.79s	remaining: 1.01s
# 367:	learn: 0.2792552	total: 2.8s	remaining: 1s
# 368:	learn: 0.2790519	total: 2.81s	remaining: 997ms
# 369:	learn: 0.2789689	total: 2.81s	remaining: 989ms
# 370:	learn: 0.2788740	total: 2.82s	remaining: 982ms
# 371:	learn: 0.2788052	total: 2.83s	remaining: 974ms
# 372:	learn: 0.2787568	total: 2.84s	remaining: 967ms
# 373:	learn: 0.2786643	total: 2.85s	remaining: 959ms
# 374:	learn: 0.2785355	total: 2.85s	remaining: 951ms
# 375:	learn: 0.2784561	total: 2.86s	remaining: 944ms
# 376:	learn: 0.2783969	total: 2.87s	remaining: 936ms
# 377:	learn: 0.2783337	total: 2.88s	remaining: 928ms
# 378:	learn: 0.2782596	total: 2.88s	remaining: 921ms
# 379:	learn: 0.2781535	total: 2.89s	remaining: 913ms
# 380:	learn: 0.2781381	total: 2.9s	remaining: 905ms
# 381:	learn: 0.2780852	total: 2.91s	remaining: 898ms
# 382:	learn: 0.2780047	total: 2.91s	remaining: 890ms
# 383:	learn: 0.2779005	total: 2.92s	remaining: 883ms
# 384:	learn: 0.2778300	total: 2.93s	remaining: 875ms
# 385:	learn: 0.2777652	total: 2.94s	remaining: 867ms
# 386:	learn: 0.2776950	total: 2.94s	remaining: 860ms
# 387:	learn: 0.2775786	total: 2.95s	remaining: 852ms
# 388:	learn: 0.2775132	total: 2.96s	remaining: 844ms
# 389:	learn: 0.2774718	total: 2.97s	remaining: 837ms
# 390:	learn: 0.2773728	total: 2.97s	remaining: 829ms
# 391:	learn: 0.2773249	total: 2.98s	remaining: 821ms
# 392:	learn: 0.2772219	total: 2.99s	remaining: 814ms
# 393:	learn: 0.2772169	total: 2.99s	remaining: 806ms
# 394:	learn: 0.2771641	total: 3s	remaining: 798ms
# 395:	learn: 0.2770999	total: 3.01s	remaining: 790ms
# 396:	learn: 0.2769407	total: 3.02s	remaining: 783ms
# 397:	learn: 0.2768425	total: 3.02s	remaining: 775ms
# 398:	learn: 0.2767088	total: 3.03s	remaining: 768ms
# 399:	learn: 0.2766939	total: 3.04s	remaining: 760ms
# 400:	learn: 0.2766409	total: 3.05s	remaining: 752ms
# 401:	learn: 0.2765574	total: 3.05s	remaining: 745ms
# 402:	learn: 0.2765224	total: 3.06s	remaining: 737ms
# 403:	learn: 0.2764135	total: 3.07s	remaining: 729ms
# 404:	learn: 0.2763379	total: 3.08s	remaining: 722ms
# 405:	learn: 0.2762857	total: 3.08s	remaining: 714ms
# 406:	learn: 0.2762308	total: 3.09s	remaining: 707ms
# 407:	learn: 0.2761598	total: 3.1s	remaining: 699ms
# 408:	learn: 0.2760980	total: 3.11s	remaining: 691ms
# 409:	learn: 0.2760288	total: 3.11s	remaining: 684ms
# 410:	learn: 0.2759628	total: 3.12s	remaining: 676ms
# 411:	learn: 0.2758550	total: 3.13s	remaining: 668ms
# 412:	learn: 0.2757722	total: 3.14s	remaining: 661ms
# 413:	learn: 0.2756931	total: 3.14s	remaining: 653ms
# 414:	learn: 0.2756443	total: 3.15s	remaining: 646ms
# 415:	learn: 0.2755845	total: 3.16s	remaining: 638ms
# 416:	learn: 0.2755322	total: 3.17s	remaining: 630ms
# 417:	learn: 0.2754696	total: 3.17s	remaining: 623ms
# 418:	learn: 0.2753401	total: 3.18s	remaining: 615ms
# 419:	learn: 0.2752966	total: 3.19s	remaining: 608ms
# 420:	learn: 0.2752151	total: 3.2s	remaining: 600ms
# 421:	learn: 0.2751266	total: 3.2s	remaining: 592ms
# 422:	learn: 0.2750508	total: 3.21s	remaining: 585ms
# 423:	learn: 0.2749846	total: 3.22s	remaining: 577ms
# 424:	learn: 0.2749145	total: 3.23s	remaining: 569ms
# 425:	learn: 0.2748218	total: 3.23s	remaining: 562ms
# 426:	learn: 0.2747371	total: 3.24s	remaining: 554ms
# 427:	learn: 0.2747229	total: 3.25s	remaining: 546ms
# 428:	learn: 0.2746573	total: 3.25s	remaining: 539ms
# 429:	learn: 0.2745712	total: 3.26s	remaining: 531ms
# 430:	learn: 0.2745175	total: 3.27s	remaining: 524ms
# 431:	learn: 0.2743597	total: 3.28s	remaining: 516ms
# 432:	learn: 0.2743031	total: 3.29s	remaining: 508ms
# 433:	learn: 0.2742522	total: 3.29s	remaining: 501ms
# 434:	learn: 0.2741733	total: 3.3s	remaining: 493ms
# 435:	learn: 0.2741102	total: 3.31s	remaining: 486ms
# 436:	learn: 0.2740399	total: 3.32s	remaining: 478ms
# 437:	learn: 0.2739861	total: 3.32s	remaining: 470ms
# 438:	learn: 0.2739193	total: 3.33s	remaining: 463ms
# 439:	learn: 0.2739117	total: 3.34s	remaining: 455ms
# 440:	learn: 0.2738721	total: 3.35s	remaining: 448ms
# 441:	learn: 0.2738118	total: 3.35s	remaining: 440ms
# 442:	learn: 0.2737295	total: 3.36s	remaining: 432ms
# 443:	learn: 0.2736487	total: 3.37s	remaining: 425ms
# 444:	learn: 0.2735610	total: 3.38s	remaining: 417ms
# 445:	learn: 0.2735225	total: 3.38s	remaining: 410ms
# 446:	learn: 0.2734756	total: 3.39s	remaining: 402ms
# 447:	learn: 0.2734268	total: 3.4s	remaining: 394ms
# 448:	learn: 0.2733036	total: 3.4s	remaining: 387ms
# 449:	learn: 0.2732730	total: 3.41s	remaining: 379ms
# 450:	learn: 0.2732430	total: 3.42s	remaining: 371ms
# 451:	learn: 0.2731989	total: 3.43s	remaining: 364ms
# 452:	learn: 0.2731424	total: 3.43s	remaining: 356ms
# 453:	learn: 0.2730794	total: 3.44s	remaining: 349ms
# 454:	learn: 0.2730137	total: 3.45s	remaining: 341ms
# 455:	learn: 0.2729760	total: 3.46s	remaining: 334ms
# 456:	learn: 0.2728948	total: 3.46s	remaining: 326ms
# 457:	learn: 0.2728406	total: 3.47s	remaining: 318ms
# 458:	learn: 0.2727967	total: 3.48s	remaining: 311ms
# 459:	learn: 0.2727571	total: 3.49s	remaining: 303ms
# 460:	learn: 0.2726978	total: 3.49s	remaining: 296ms
# 461:	learn: 0.2726133	total: 3.5s	remaining: 288ms
# 462:	learn: 0.2725110	total: 3.51s	remaining: 281ms
# 463:	learn: 0.2724595	total: 3.52s	remaining: 273ms
# 464:	learn: 0.2723916	total: 3.52s	remaining: 265ms
# 465:	learn: 0.2723342	total: 3.53s	remaining: 258ms
# 466:	learn: 0.2722828	total: 3.54s	remaining: 250ms
# 467:	learn: 0.2721759	total: 3.55s	remaining: 243ms
# 468:	learn: 0.2720948	total: 3.55s	remaining: 235ms
# 469:	learn: 0.2720104	total: 3.56s	remaining: 227ms
# 470:	learn: 0.2719417	total: 3.57s	remaining: 220ms
# 471:	learn: 0.2718937	total: 3.58s	remaining: 212ms
# 472:	learn: 0.2718322	total: 3.58s	remaining: 205ms
# 473:	learn: 0.2718185	total: 3.59s	remaining: 197ms
# 474:	learn: 0.2717577	total: 3.6s	remaining: 189ms
# 475:	learn: 0.2717231	total: 3.61s	remaining: 182ms
# 476:	learn: 0.2716603	total: 3.61s	remaining: 174ms
# 477:	learn: 0.2716139	total: 3.62s	remaining: 167ms
# 478:	learn: 0.2715507	total: 3.63s	remaining: 159ms
# 479:	learn: 0.2714736	total: 3.64s	remaining: 152ms
# 480:	learn: 0.2714153	total: 3.64s	remaining: 144ms
# 481:	learn: 0.2713374	total: 3.65s	remaining: 136ms
# 482:	learn: 0.2712759	total: 3.66s	remaining: 129ms
# 483:	learn: 0.2712016	total: 3.67s	remaining: 121ms
# 484:	learn: 0.2710972	total: 3.67s	remaining: 114ms
# 485:	learn: 0.2710286	total: 3.68s	remaining: 106ms
# 486:	learn: 0.2709261	total: 3.69s	remaining: 98.5ms
# 487:	learn: 0.2708277	total: 3.7s	remaining: 90.9ms
# 488:	learn: 0.2707411	total: 3.7s	remaining: 83.3ms
# 489:	learn: 0.2706113	total: 3.71s	remaining: 75.8ms
# 490:	learn: 0.2705701	total: 3.72s	remaining: 68.2ms
# 491:	learn: 0.2705435	total: 3.73s	remaining: 60.6ms
# 492:	learn: 0.2704920	total: 3.73s	remaining: 53ms
# 493:	learn: 0.2704388	total: 3.74s	remaining: 45.5ms
# 494:	learn: 0.2703574	total: 3.75s	remaining: 37.9ms
# 495:	learn: 0.2702619	total: 3.76s	remaining: 30.3ms
# 496:	learn: 0.2701710	total: 3.77s	remaining: 22.7ms
# 497:	learn: 0.2700496	total: 3.77s	remaining: 15.2ms
# 498:	learn: 0.2699848	total: 3.78s	remaining: 7.58ms
# 499:	learn: 0.2699301	total: 3.79s	remaining: 0us
# CatBoost score: 0.8722254795208979
#
# Precision: 0.8600973236009732
# Recall: 0.7880949726897781
# F1-score: 0.8225234134139957
#
# K-Fold mean: 0.8541954274144173
# K-Fold std: 0.0029036544998472225
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.92      0.90     14907
#            1       0.86      0.79      0.82      8971
#
#     accuracy                           0.87     23878
#    macro avg       0.87      0.86      0.86     23878
# weighted avg       0.87      0.87      0.87     23878

# %%
# Stacking & Voting MODELS
from sklearn.ensemble import (
    StackingClassifier,
    VotingClassifier
)

# %% [markdown]
# ## Stacking

# %%
rf_fs = RandomForestClassifier(n_estimators=200, random_state=42)
rf_fs.fit(x_train, y_train)

importance = rf_fs.feature_importances_
selected_features = x_train.columns[importance > np.mean(importance)]

base1 = RandomForestClassifier(random_state=42)
base2 = ExtraTreesClassifier(random_state=42)
base3 = LogisticRegression()

stacking = StackingClassifier(
    estimators=[
        ('rf', base1),
        ('et', base2),
        ('lr', base3)
    ],
    final_estimator=LogisticRegression()
)

stacking.fit(x_train[selected_features], y_train)
y_pred = stacking.predict(x_test[selected_features])

stacking_score = accuracy_score(y_test, y_pred)

stacking_precision = precision_score(y_test, y_pred)
stacking_recall = recall_score(y_test, y_pred)
stacking_f1 = f1_score(y_test, y_pred)

stacking_scores = cross_val_score(stacking, x_train[selected_features], y_train, cv=kf, scoring='f1_macro')

print(f'Stacking score: {stacking_score}')

print(f'\nPrecision: {stacking_precision}')
print(f'Recall: {stacking_recall}')
print(f'F1-score: {stacking_f1}')

print("\nK-Fold mean:", stacking_scores.mean())
print("K-Fold std:", stacking_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# Stacking score: 0.8723511181841025
#
# Precision: 0.8620858295635163
# Recall: 0.7859770371196076
# F1-score: 0.8222740524781341
#
# K-Fold mean: 0.850547240963286
# K-Fold std: 0.002725371395067416
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.92      0.90     14907
#            1       0.86      0.79      0.82      8971
#
#     accuracy                           0.87     23878
#    macro avg       0.87      0.86      0.86     23878
# weighted avg       0.87      0.87      0.87     23878

# %% [markdown]
# ## Hard Voting

# %%
rf_fs = RandomForestClassifier(n_estimators=200, random_state=42)
rf_fs.fit(x_train, y_train)

importance = rf_fs.feature_importances_
selected_features = x_train.columns[importance > np.mean(importance)]

model1 = RandomForestClassifier(random_state=42)
model2 = ExtraTreesClassifier(random_state=42)
model3 = LogisticRegression()

hard_voting = VotingClassifier(
    estimators=[
        ('rf', model1),
        ('et', model2),
        ('lr', model3)
    ],
    voting='hard'
)

hard_voting.fit(x_train[selected_features], y_train)
y_pred = hard_voting.predict(x_test[selected_features])

hard_voting_score = accuracy_score(y_test, y_pred)

hard_voting_precision = precision_score(y_test, y_pred)
hard_voting_recall = recall_score(y_test, y_pred)
hard_voting_f1 = f1_score(y_test, y_pred)

hard_voting_scores = cross_val_score(hard_voting, x_train[selected_features], y_train, cv=kf, scoring='f1_macro')

print(f'Hard Voting score: {hard_voting_score}')

print(f'\nPrecision: {hard_voting_precision}')
print(f'Recall: {hard_voting_recall}')
print(f'F1-score: {hard_voting_f1}')

print("\nK-Fold mean:", hard_voting_scores.mean())
print("K-Fold std:", hard_voting_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# Hard Voting score: 0.867744367199933
#
# Precision: 0.8752743705616527
# Recall: 0.7556571173782187
# F1-score: 0.8110792055515673
#
# K-Fold mean: 0.8451587801454443
# K-Fold std: 0.0027191017371007635
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.94      0.90     14907
#            1       0.88      0.76      0.81      8971
#
#     accuracy                           0.87     23878
#    macro avg       0.87      0.85      0.85     23878
# weighted avg       0.87      0.87      0.87     23878

# %% [markdown]
# ## Soft Voting

# %%
rf_fs = RandomForestClassifier(n_estimators=200, random_state=42)
rf_fs.fit(x_train, y_train)

importance = rf_fs.feature_importances_
selected_features = x_train.columns[importance > np.mean(importance)]

model1 = RandomForestClassifier(random_state=42)
model2 = ExtraTreesClassifier(random_state=42)
model3 = LogisticRegression()

soft_voting = VotingClassifier(
    estimators=[
        ('rf', model1),
        ('et', model2),
        ('lr', model3)
    ],
    voting='soft'
)

soft_voting.fit(x_train[selected_features], y_train)
y_pred = soft_voting.predict(x_test[selected_features])

soft_voting_score = accuracy_score(y_test, y_pred)

soft_voting_precision = precision_score(y_test, y_pred)
soft_voting_recall = recall_score(y_test, y_pred)
soft_voting_f1 = f1_score(y_test, y_pred)

soft_voting_scores = cross_val_score(soft_voting, x_train[selected_features], y_train, cv=kf, scoring='f1_macro')

print(f'Soft Voting score: {soft_voting_score}')

print(f'\nPrecision: {soft_voting_precision}')
print(f'Recall: {soft_voting_recall}')
print(f'F1-score: {soft_voting_f1}')

print("\nK-Fold mean:", soft_voting_scores.mean())
print("K-Fold std:", soft_voting_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# Soft Voting score: 0.865734148588659
#
# Precision: 0.8807290978734645
# Recall: 0.743283914836696
# F1-score: 0.8061903034699552
#
# K-Fold mean: 0.8431529309614362
# K-Fold std: 0.0028307135032097325
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.94      0.90     14907
#            1       0.88      0.74      0.81      8971
#
#     accuracy                           0.87     23878
#    macro avg       0.87      0.84      0.85     23878
# weighted avg       0.87      0.87      0.86     23878

# %% [markdown]
# ## 👥 4. Neighbors-Based Models
#
# **Jami: `2ta` algoritm**
#
# - **K-Nearest Neighbors (KNN) Classifier**
# - **Radius Neighbors Classifier**

# %%
# Keighbors MODELS (2ta)
from sklearn.neighbors import (
    KNeighborsClassifier,
)

# %% [markdown]
# ## KNN

# %%
knn = KNeighborsClassifier(n_neighbors=1)

knn.fit(x_train, y_train)
y_pred = knn.predict(x_test)

knn_score = accuracy_score(y_test, y_pred)

knn_precision = precision_score(y_test, y_pred)
knn_recall = recall_score(y_test, y_pred)
knn_f1 = f1_score(y_test, y_pred)

knn_scores = cross_val_score(knn, x_train, y_train, cv=kf, scoring='f1_macro')

print(f'KNN score: {knn_score}')

print(f'\nPrecision: {knn_precision}')
print(f'Recall: {knn_recall}')
print(f'F1-score: {knn_f1}')

print("\nK-Fold mean:", knn_scores.mean())
print("K-Fold std:", knn_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\neighbors\_classification.py:239: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\neighbors\_classification.py:239: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\neighbors\_classification.py:239: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\neighbors\_classification.py:239: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNN score: 0.7739341653404808
#
# Precision: 0.6945442665795492
# Recall: 0.7109575298183034
# F1-score: 0.7026550622452352
#
# K-Fold mean: 0.7477000249888874
# K-Fold std: 0.0031805913615647477
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.82      0.81      0.82     14907
#            1       0.69      0.71      0.70      8971
#
#     accuracy                           0.77     23878
#    macro avg       0.76      0.76      0.76     23878
# weighted avg       0.78      0.77      0.77     23878

# %% [markdown]
# ## 📐 5. Support Vector Machine (SVM) Models
#
# **Jami: `1ta` algoritm**
#
# - **Support Vector Classifier (SVC)**

# %%
from sklearn.svm import SVC

svr = SVC(kernel='rbf', C=20.0)

svr.fit(x_train, y_train)
y_pred = svr.predict(x_test)

svr_score = accuracy_score(y_test, y_pred)

svr_precision = precision_score(y_test, y_pred)
svr_recall = recall_score(y_test, y_pred)
svr_f1 = f1_score(y_test, y_pred)

svr_scores = cross_val_score(svr, x_train, y_train, cv=kf, scoring='f1_macro')

print(f'SVC score: {svr_score}')

print(f'\nPrecision: {svr_precision}')
print(f'Recall: {svr_recall}')
print(f'F1-score: {svr_f1}')

print("\nK-Fold mean:", svr_scores.mean())
print("K-Fold std:", svr_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC score: 0.8439986598542591
#
# Precision: 0.8294398392363728
# Recall: 0.7361498160740163
# F1-score: 0.7800153546329652
#
# K-Fold mean: 0.8231301878898886
# K-Fold std: 0.002850198933429421
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.91      0.88     14907
#            1       0.83      0.74      0.78      8971
#
#     accuracy                           0.84     23878
#    macro avg       0.84      0.82      0.83     23878
# weighted avg       0.84      0.84      0.84     23878

# %% [markdown]
# ## 🧬 6. Neural Network Models
#
# **Jami: `1ta` algoritm**
#
# - **Multi-Layer Perceptron (MLP) Classifier**

# %%
# Neural Network MODEL
from sklearn.neural_network import MLPClassifier

# %% [markdown]
# ## MLPClassifier

# %%
mlpc = MLPClassifier(hidden_layer_sizes=(128, 64), activation="relu", max_iter=300, random_state=42)

mlpc.fit(x_train, y_train)
y_pred = mlpc.predict(x_test)

mlpc_score = accuracy_score(y_test, y_pred)

mlpc_precision = precision_score(y_test, y_pred)
mlpc_recall = recall_score(y_test, y_pred)
mlpc_f1 = f1_score(y_test, y_pred)

mlpc_scores = cross_val_score(mlpc, x_train, y_train, cv=kf, scoring='f1_macro')

print(f'MLPClassifier score: {mlpc_score}')

print(f'\nPrecision: {mlpc_precision}')
print(f'Recall: {mlpc_recall}')
print(f'F1-score: {mlpc_f1}')

print("\nK-Fold mean:", mlpc_scores.mean())
print("K-Fold std:", mlpc_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\neural_network\_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\neural_network\_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\neural_network\_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# MLPClassifier score: 0.8380517631292403
#
# Precision: 0.782113641388459
# Recall: 0.7886523241556125
# F1-score: 0.7853693733695953
#
# K-Fold mean: 0.8068927449216163
# K-Fold std: 0.0014178092058384614
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.87      0.87     14907
#            1       0.78      0.79      0.79      8971
#
#     accuracy                           0.84     23878
#    macro avg       0.83      0.83      0.83     23878
# weighted avg       0.84      0.84      0.84     23878
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\neural_network\_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %% [markdown]
# ## 🎯 7. Naive & Simple Baseline Models
#
# **Jami: `1ta` algoritm**
#
# - **Dummy Classifier**

# %%
# Simple Baseline MODEL
from sklearn.dummy import DummyClassifier

# %% [markdown]
# ## DummyClassifier

# %%
dummy = DummyClassifier()
dummy.fit(x_train, y_train)

dummy.fit(x_train, y_train)
y_pred = dummy.predict(x_test)

dummy_score = accuracy_score(y_test, y_pred)

dummy_precision = precision_score(y_test, y_pred)
dummy_recall = recall_score(y_test, y_pred)
dummy_f1 = f1_score(y_test, y_pred)

dummy_scores = cross_val_score(dummy, x_train, y_train, cv=kf, scoring='f1_macro')

print(f'DummyClassifier score: {dummy_score}')

print(f'\nPrecision: {dummy_precision}')
print(f'Recall: {dummy_recall}')
print(f'F1-score: {dummy_f1}')

print("\nK-Fold mean:", dummy_scores.mean())
print("K-Fold std:", dummy_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# DummyClassifier score: 0.6242985174637742
#
# Precision: 0.0
# Recall: 0.0
# F1-score: 0.0
#
# K-Fold mean: 0.38684320260727606
# K-Fold std: 0.0004277210010969743
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.62      1.00      0.77     14907
#            1       0.00      0.00      0.00      8971
#
#     accuracy                           0.62     23878
#    macro avg       0.31      0.50      0.38     23878
# weighted avg       0.39      0.62      0.48     23878
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
from rich.table import Table
from rich.console import Console

console = Console()

results = [
    # Linear Family
    ['Logistic Regression', lr_score, lr_precision, lr_recall, lr_f1, lr_scores.mean(), lr_scores.std()],
    ['RidgeClassifier', ridge_score, ridge_precision, ridge_recall, ridge_f1, ridge_scores.mean(), ridge_scores.std()],
    ['SGDC', sgdc_score, sgdc_precision, sgdc_recall, sgdc_f1, sgdc_scores.mean(), sgdc_scores.std()],
    ['Passive Aggressive', pac_score, pac_precision, pac_recall, pac_f1, pac_scores.mean(), pac_scores.std()],

    # Tree-Based Family
    ['DecisionTree', dt_score, dt_precision, dt_recall, dt_f1, dt_scores.mean(), dt_scores.std()],

    # Bagging Family
    ['RandomForest', rf_score, rf_precision, rf_recall, rf_f1, rf_scores.mean(), rf_scores.std()],
    ['Bagging', bag_score, bag_precision, bag_recall, bag_f1, bag_scores.mean(), bag_scores.std()],
    ['Bagged DT', bag_dt_score, bag_dt_precision, bag_dt_recall, bag_dt_f1, bag_dt_scores.mean(), bag_dt_scores.std()],
    ['ExtraTrees', et_score, et_precision, et_recall, et_f1, et_scores.mean(), et_scores.std()],

    # Boosting Family
    ['GradientBoosting', gb_score, gb_precision, gb_recall, gb_f1, gb_scores.mean(), gb_scores.std()],
    ['HistGradientBoosting', hgb_score, hgb_precision, hgb_recall, hgb_f1, hgb_scores.mean(), hgb_scores.std()],
    ['XGBoost', xgb_score, xgb_precision, xgb_recall, xgb_f1, xgb_scores.mean(), xgb_scores.std()],
    ['AdaBoost', ab_score, ab_precision, ab_recall, ab_f1, ab_scores.mean(), ab_scores.std()],
    ['LGBMClassifier', lgbm_score, lgbm_precision, lgbm_recall, lgbm_f1, lgbm_scores.mean(), lgbm_scores.std()],
    ['CatBoost', cat_score, cat_precision, cat_recall, cat_f1, cat_scores.mean(), cat_scores.std()],

    # Stacking & Voting Family
    ['Hard Voting', hard_voting_score, hard_voting_precision, hard_voting_recall, hard_voting_f1, hard_voting_scores.mean(), hard_voting_scores.std()],
    ['Soft Voting', soft_voting_score, soft_voting_precision, soft_voting_recall, soft_voting_f1, soft_voting_scores.mean(), soft_voting_scores.std()],
    ['Stacking', stacking_score, stacking_precision, stacking_recall, stacking_f1, stacking_scores.mean(), stacking_scores.std()],

    # Neighbors Family
    ['KNN', knn_score, knn_precision, knn_recall, knn_f1, knn_scores.mean(), knn_scores.std()],

    # SVM Family
    ['SVC', svr_score, svr_precision, svr_recall, svr_f1, svr_scores.mean(), svr_scores.std()],

    # Neural Network Family
    ['MLPC', mlpc_score, mlpc_precision, mlpc_recall, mlpc_f1, mlpc_scores.mean(), mlpc_scores.std()],

    # Naive & Simple Family
    ['DummyClassifier', dummy_score, dummy_precision, dummy_recall, dummy_f1, dummy_scores.mean(), dummy_scores.std()],
]

result_sorted = sorted(results, key=lambda i: i[3], reverse=True)

best_model = max(results, key=lambda x: x[3])
worst_model = min(results, key=lambda x: x[3])

table = Table(title="Comparison with Embedded Method", show_lines=True)
table.add_column("Algorithm")
table.add_column("Accuracy")
table.add_column("Precision")
table.add_column("Recall")
table.add_column("F1-score")
table.add_column("K-Fold mean")
table.add_column("K-Fold std")

for row in result_sorted:
    algo, acc, presicion, recall, f1, kmean, kstd = row

    if row == best_model:
        table.add_row(
            f"[bold green]{algo}[/bold green]",
            f"[bold green]{acc:.2f}[/bold green]",
            f"[bold green]{presicion:.2f}[/bold green]",
            f"[bold green]{recall:.2f}[/bold green]",
            f"[bold green]{f1:.2f}[/bold green]",
            f"[bold green]{kmean:.2f}[/bold green]",
            f"[bold green]{kstd:.2f}[/bold green]",
        )
    elif row == worst_model:
        table.add_row(
            f"[bold red]{algo}[/bold red]",
            f"[bold red]{acc:.2f}[/bold red]",
            f"[bold red]{presicion:.2f}[/bold red]",
            f"[bold red]{recall:.2f}[/bold red]",
            f"[bold red]{f1:.2f}[/bold red]",
            f"[bold red]{kmean:.2f}[/bold red]",
            f"[bold red]{kstd:.2f}[/bold red]",
        )
    else:
        table.add_row(algo, f"{acc:.2f}", f"{presicion:.2f}", f"{recall:.2f}", f"{f1:.2f}", f"{kmean:.2f}", f"{kstd:.2f}")

console.print(table)
# Out:
#                                Comparison with Embedded Method
# ┏━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Algorithm            ┃ Accuracy ┃ Precision ┃ Recall ┃ F1-score ┃ K-Fold mean ┃ K-Fold std ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ Bagging              │ 0.88     │ 0.87      │ 0.81   │ 0.84     │ 0.86        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ HistGradientBoosting │ 0.88     │ 0.86      │ 0.80   │ 0.83     │ 0.86        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ MLPC                 │ 0.84     │ 0.78      │ 0.79   │ 0.79     │ 0.81        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ CatBoost             │ 0.87     │ 0.86      │ 0.79   │ 0.82     │ 0.85        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ Stacking             │ 0.87     │ 0.86      │ 0.79   │ 0.82     │ 0.85        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ LGBMClassifier       │ 0.86     │ 0.85      │ 0.77   │ 0.81     │ 0.84        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ DecisionTree         │ 0.84     │ 0.81      │ 0.76   │ 0.78     │ 0.82        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ RandomForest         │ 0.87     │ 0.88      │ 0.76   │ 0.81     │ 0.85        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ Hard Voting          │ 0.87     │ 0.88      │ 0.76   │ 0.81     │ 0.85        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ Bagged DT            │ 0.85     │ 0.83      │ 0.75   │ 0.79     │ 0.83        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ Soft Voting          │ 0.87     │ 0.88      │ 0.74   │ 0.81     │ 0.84        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ GradientBoosting     │ 0.85     │ 0.83      │ 0.74   │ 0.78     │ 0.83        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ SVC                  │ 0.84     │ 0.83      │ 0.74   │ 0.78     │ 0.82        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ XGBoost              │ 0.81     │ 0.76      │ 0.72   │ 0.74     │ 0.79        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ ExtraTrees           │ 0.85     │ 0.86      │ 0.71   │ 0.78     │ 0.83        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ KNN                  │ 0.77     │ 0.69      │ 0.71   │ 0.70     │ 0.75        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ Logistic Regression  │ 0.81     │ 0.81      │ 0.63   │ 0.71     │ 0.78        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ RidgeClassifier      │ 0.80     │ 0.86      │ 0.55   │ 0.67     │ 0.76        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ SGDC                 │ 0.80     │ 0.89      │ 0.52   │ 0.66     │ 0.77        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ Passive Aggressive   │ 0.77     │ 0.94      │ 0.41   │ 0.57     │ 0.71        │ 0.02       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ AdaBoost             │ 0.75     │ 0.99      │ 0.33   │ 0.50     │ 0.67        │ 0.01       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ DummyClassifier      │ 0.62     │ 0.00      │ 0.00   │ 0.00     │ 0.39        │ 0.00       │
# └──────────────────────┴──────────┴───────────┴────────┴──────────┴─────────────┴────────────┘

# %%
os.makedirs('results', exist_ok=True)

temp_console = Console(record=True)
temp_console.print(table)
text = temp_console.export_text()
with open('results/feature_selection_compare.txt', 'a', encoding='utf-8') as f:
    f.write(text)
# Out:
#                                Comparison with Embedded Method
# ┏━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Algorithm            ┃ Accuracy ┃ Precision ┃ Recall ┃ F1-score ┃ K-Fold mean ┃ K-Fold std ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ Bagging              │ 0.88     │ 0.87      │ 0.81   │ 0.84     │ 0.86        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ HistGradientBoosting │ 0.88     │ 0.86      │ 0.80   │ 0.83     │ 0.86        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ MLPC                 │ 0.84     │ 0.78      │ 0.79   │ 0.79     │ 0.81        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ CatBoost             │ 0.87     │ 0.86      │ 0.79   │ 0.82     │ 0.85        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ Stacking             │ 0.87     │ 0.86      │ 0.79   │ 0.82     │ 0.85        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ LGBMClassifier       │ 0.86     │ 0.85      │ 0.77   │ 0.81     │ 0.84        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ DecisionTree         │ 0.84     │ 0.81      │ 0.76   │ 0.78     │ 0.82        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ RandomForest         │ 0.87     │ 0.88      │ 0.76   │ 0.81     │ 0.85        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ Hard Voting          │ 0.87     │ 0.88      │ 0.76   │ 0.81     │ 0.85        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ Bagged DT            │ 0.85     │ 0.83      │ 0.75   │ 0.79     │ 0.83        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ Soft Voting          │ 0.87     │ 0.88      │ 0.74   │ 0.81     │ 0.84        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ GradientBoosting     │ 0.85     │ 0.83      │ 0.74   │ 0.78     │ 0.83        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ SVC                  │ 0.84     │ 0.83      │ 0.74   │ 0.78     │ 0.82        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ XGBoost              │ 0.81     │ 0.76      │ 0.72   │ 0.74     │ 0.79        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ ExtraTrees           │ 0.85     │ 0.86      │ 0.71   │ 0.78     │ 0.83        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ KNN                  │ 0.77     │ 0.69      │ 0.71   │ 0.70     │ 0.75        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ Logistic Regression  │ 0.81     │ 0.81      │ 0.63   │ 0.71     │ 0.78        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ RidgeClassifier      │ 0.80     │ 0.86      │ 0.55   │ 0.67     │ 0.76        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ SGDC                 │ 0.80     │ 0.89      │ 0.52   │ 0.66     │ 0.77        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ Passive Aggressive   │ 0.77     │ 0.94      │ 0.41   │ 0.57     │ 0.71        │ 0.02       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ AdaBoost             │ 0.75     │ 0.99      │ 0.33   │ 0.50     │ 0.67        │ 0.01       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ DummyClassifier      │ 0.62     │ 0.00      │ 0.00   │ 0.00     │ 0.39        │ 0.00       │
# └──────────────────────┴──────────┴───────────┴────────┴──────────┴─────────────┴────────────┘

# %% [markdown]
# # Another Feature Selections

# %% [markdown]
# <a href="../FS/without_fs.ipynb" target="_blank" style="text-decoration: none;">
#     <button style="
#         background-color: #45a049;
#         color: white;
#         padding: 12px 24px;
#         font-size: 16px;
#         border: none;
#         border-radius: 8px;
#         cursor: pointer;
#         transition: background-color 0.3s;
#     " onmouseover="this.style.backgroundColor='#45a049'" onmouseout="this.style.backgroundColor='#4CAF50'">
#         Without Feature selection
#     </button>
# </a>
#
# <a href="../FS/filter.ipynb" target="_blank" style="text-decoration: none;">
#     <button style="
#         background-color: #45a049;
#         color: white;
#         padding: 12px 24px;
#         font-size: 16px;
#         border: none;
#         border-radius: 8px;
#         cursor: pointer;
#         transition: background-color 0.3s;
#     " onmouseover="this.style.backgroundColor='#45a049'" onmouseout="this.style.backgroundColor='#4CAF50'">
#         Filter method
#     </button>
# </a>
#
# <a href="../FS/without_fs.ipynb" target="_blank" style="text-decoration: none;">
#     <button style="
#         background-color: #45a049;
#         color: white;
#         padding: 12px 24px;
#         font-size: 16px;
#         border: none;
#         border-radius: 8px;
#         cursor: pointer;
#         transition: background-color 0.3s;
#     " onmouseover="this.style.backgroundColor='#45a049'" onmouseout="this.style.backgroundColor='#4CAF50'">
#         Wrapper method
#     </button>
# </a>

# %% [markdown]
# # Next Step - Tuning

# %% [markdown]
# <a href="..\Tuning\bayesian_optimization.ipynb" target="_blank" style="text-decoration: none;">
#     <button style="
#         background-color: #45a049;
#         color: white;
#         padding: 12px 24px;
#         font-size: 16px;
#         border: none;
#         border-radius: 8px;
#         cursor: pointer;
#         transition: background-color 0.3s;
#     " onmouseover="this.style.backgroundColor='#45a049'" onmouseout="this.style.backgroundColor='#4CAF50'">
#         Bayesian Optimization
#     </button>
# </a>
#
# <a href="../Tuning/manual_search.ipynb" target="_blank" style="text-decoration: none;">
#     <button style="
#         background-color: #45a049;
#         color: white;
#         padding: 12px 24px;
#         font-size: 16px;
#         border: none;
#         border-radius: 8px;
#         cursor: pointer;
#         transition: background-color 0.3s;
#     " onmouseover="this.style.backgroundColor='#45a049'" onmouseout="this.style.backgroundColor='#4CAF50'">
#         Manual Search
#     </button>
# </a>
#
# <a href="../Tuning/optuna.ipynb" target="_blank" style="text-decoration: none;">
#     <button style="
#         background-color: #45a049;
#         color: white;
#         padding: 12px 24px;
#         font-size: 16px;
#         border: none;
#         border-radius: 8px;
#         cursor: pointer;
#         transition: background-color 0.3s;
#     " onmouseover="this.style.backgroundColor='#45a049'" onmouseout="this.style.backgroundColor='#4CAF50'">
#         optuna
#     </button>
# </a>
#
# <a href="../Tuning/random_search.ipynb" target="_blank" style="text-decoration: none;">
#     <button style="
#         background-color: #45a049;
#         color: white;
#         padding: 12px 24px;
#         font-size: 16px;
#         border: none;
#         border-radius: 8px;
#         cursor: pointer;
#         transition: background-color 0.3s;
#     " onmouseover="this.style.backgroundColor='#45a049'" onmouseout="this.style.backgroundColor='#4CAF50'">
#         Random Search
#     </button>
# </a>
