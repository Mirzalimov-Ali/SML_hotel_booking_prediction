# %% [markdown]
# ## 🔹 Without Feature Selection Training — Algorithm Families Overview
#
# #### 📌 Ushbu bosqichda **feature selection qo‘llanilmasdan**, **engineered features** asosida **classification** uchun **jami 25 ta algoritm** turli model oilalaridan foydalanilgan.
#
#
# Quyida loyihada qo‘llanilgan **asosiy algoritm oilalari** keltirilgan:
#
# - 📏 **Linear Models**
# - 🌳 **Tree-Based Models**
# - 🧠 **Ensemble Models**
# - 👥 **Neighbors-Based Models**
# - 📐 **Support Vector Machine (SVM) Models**
# - 🌀 **Kernel-Based Models**
# - 🧬 **Neural Network Models**
# - 🎯 **Naive & Simple Baseline Models**
#
# 📊 Ushbu bosqich **feature selection qo‘llanilmagan holatda**
# model performansini baholash va
# feature engineering’ning real ta’sirini aniqlashga xizmat qiladi.
#
# 🌐 Ushbu model oilalari klassik **baseline** yondashuvlardan tortib,
# zamonaviy **ensemble** va **kernel-based** modellargacha bo‘lgan
# keng qamrovli yechimlarni o‘z ichiga oladi.
#
# 🔍 Barcha modellar o‘zaro solishtirish, barqarorlikni baholash
# va **eng optimal modelni aniqlash** maqsadida birgalikda sinovdan o‘tkazilgan.

# %%
import pandas as pd
import os

# %%
os.chdir(r'C:\SML_Projects\SML_hotelBooking_cancelling_prediction')

# %%
x_train = pd.read_csv('data/preprocessed/preprocessed_x_train.csv')
x_test = pd.read_csv('data/preprocessed/preprocessed_x_test.csv')

y_train = pd.read_csv('data/split/y_train.csv')
y_test = pd.read_csv('data/split/y_test.csv')

# %%
from sklearn.model_selection import KFold, cross_val_score
from sklearn.metrics import accuracy_score, classification_report, precision_score, recall_score, f1_score

# %%
kf = KFold(n_splits=3, shuffle=True, random_state=42)

# %% [markdown]
# ### 📌 1. Linear Models
# **Jami: `4ta` algoritm**
#
# - **Logistic Regression**
# - **Ridge Classifier**
# - **SGD Classifier**
# - **Passive Aggressive Classifier**

# %%
# LINEAR MODELS - CLASSIFICATION (4ta)
from sklearn.linear_model import (
    LogisticRegression,
    RidgeClassifier,
    SGDClassifier,
    PassiveAggressiveClassifier
)

# %% [markdown]
# ## Logistic Regression

# %%
lr = LogisticRegression()

lr.fit(x_train, y_train)
y_pred = lr.predict(x_test)

lr_score = accuracy_score(y_test, y_pred)

lr_precision = precision_score(y_test, y_pred)
lr_recall = recall_score(y_test, y_pred)
lr_f1 = f1_score(y_test, y_pred)

lr_scores = cross_val_score(lr, x_train, y_train, cv=kf, scoring='f1_macro')

print(f'Logistic Regression score: {lr_score}')

print(f'\nPrecision: {lr_precision}')
print(f'Recall: {lr_recall}')
print(f'F1-score: {lr_f1}')

print("\nK-Fold mean:", lr_scores.mean())
print("K-Fold std:", lr_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Logistic Regression score: 0.807228411089706
#
# Precision: 0.8136128661688685
# Recall: 0.6315906810834913
# F1-score: 0.711139002196423
#
# K-Fold mean: 0.7796583569737446
# K-Fold std: 0.0012365504924804597
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.80      0.91      0.86     14907
#            1       0.81      0.63      0.71      8971
#
#     accuracy                           0.81     23878
#    macro avg       0.81      0.77      0.78     23878
# weighted avg       0.81      0.81      0.80     23878

# %% [markdown]
# ## RidgeClassifier

# %%
ridge = RidgeClassifier(alpha=1.0, class_weight='balanced', max_iter=300, random_state=42)

ridge.fit(x_train, y_train)
y_pred = ridge.predict(x_test)

ridge_score = accuracy_score(y_test, y_pred)

ridge_precision = precision_score(y_test, y_pred)
ridge_recall = recall_score(y_test, y_pred)
ridge_f1 = f1_score(y_test, y_pred)

ridge_scores = cross_val_score(ridge, x_train, y_train, cv=kf, scoring='f1_macro')

print(f'RidgeClassifier score: {ridge_score}')

print(f'\nPrecision: {ridge_precision}')
print(f'Recall: {ridge_recall}')
print(f'F1-score: {ridge_f1}')

print("\nK-Fold mean:", ridge_scores.mean())
print("K-Fold std:", ridge_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_ridge.py:1306: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_ridge.py:1306: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# RidgeClassifier score: 0.7978055113493593
#
# Precision: 0.7156689224362311
# Recall: 0.7662467952290715
# F1-score: 0.7400947459086994
#
# K-Fold mean: 0.781509426878311
# K-Fold std: 0.0023742781744168946
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.82      0.83     14907
#            1       0.72      0.77      0.74      8971
#
#     accuracy                           0.80     23878
#    macro avg       0.78      0.79      0.79     23878
# weighted avg       0.80      0.80      0.80     23878
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_ridge.py:1306: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_ridge.py:1306: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# ## SGDClassifier

# %%
sgdc = SGDClassifier(alpha=0.1, class_weight='balanced', max_iter=300, random_state=42)

sgdc.fit(x_train, y_train)
y_pred = sgdc.predict(x_test)

sgdc_score = accuracy_score(y_test, y_pred)

sgdc_precision = precision_score(y_test, y_pred)
sgdc_recall = recall_score(y_test, y_pred)
sgdc_f1 = f1_score(y_test, y_pred)

sgdc_scores = cross_val_score(sgdc, x_train, y_train, cv=kf, scoring='f1_macro')

print(f'SGDClassifier score: {sgdc_score}')

print(f'\nPrecision: {sgdc_precision}')
print(f'Recall: {sgdc_recall}')
print(f'F1-score: {sgdc_f1}')

print("\nK-Fold mean:", sgdc_scores.mean())
print("K-Fold std:", sgdc_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SGDClassifier score: 0.6912639249518385
#
# Precision: 0.5591827670441928
# Recall: 0.8420465945825437
# F1-score: 0.6720640569395018
#
# K-Fold mean: 0.6837398057095955
# K-Fold std: 0.003468713318815686
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.60      0.71     14907
#            1       0.56      0.84      0.67      8971
#
#     accuracy                           0.69     23878
#    macro avg       0.71      0.72      0.69     23878
# weighted avg       0.75      0.69      0.69     23878

# %% [markdown]
# ## PassiveAggressiveClassifier

# %%
pac = PassiveAggressiveClassifier(C=1.0, max_iter=300, class_weight='balanced', validation_fraction=0.1, random_state=42)

pac.fit(x_train, y_train)
y_pred = pac.predict(x_test)

pac_score = accuracy_score(y_test, y_pred)

pac_precision = precision_score(y_test, y_pred)
pac_recall = recall_score(y_test, y_pred)
pac_f1 = f1_score(y_test, y_pred)

pac_scores = cross_val_score(pac, x_train, y_train, cv=kf, scoring='f1_macro')

print(f'PassiveAggressive score: {pac_score}')

print(f'\nPrecision: {pac_precision}')
print(f'Recall: {pac_recall}')
print(f'F1-score: {pac_f1}')

print("\nK-Fold mean:", pac_scores.mean())
print("K-Fold std:", pac_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# PassiveAggressive score: 0.7851997654744953
#
# Precision: 0.7507178282432785
# Recall: 0.6411771262958421
# F1-score: 0.6916371069560512
#
# K-Fold mean: 0.6448816640457015
# K-Fold std: 0.0918730578601475
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.80      0.87      0.84     14907
#            1       0.75      0.64      0.69      8971
#
#     accuracy                           0.79     23878
#    macro avg       0.78      0.76      0.76     23878
# weighted avg       0.78      0.79      0.78     23878

# %% [markdown]
# ## 🌲 2. Tree-Based Models
#
# **Jami: `1ta` algoritm**
#
# - **Decision Tree**

# %%
# Tree MODELS (1ta)
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# ## Decision Tree

# %%
dt = DecisionTreeClassifier(max_depth=10, min_samples_split=5,random_state=42)

dt.fit(x_train, y_train)
y_pred = dt.predict(x_test)

dt_score = accuracy_score(y_test, y_pred)

dt_precision = precision_score(y_test, y_pred)
dt_recall = recall_score(y_test, y_pred)
dt_f1 = f1_score(y_test, y_pred)

dt_scores = cross_val_score(dt, x_train, y_train, cv=kf, scoring='f1_macro')

print(f'DecisionTree score: {dt_score}')

print(f'\nPrecision: {dt_precision}')
print(f'Recall: {dt_recall}')
print(f'F1-score: {dt_f1}')

print("\nK-Fold mean:", dt_scores.mean())
print("K-Fold std:", dt_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# DecisionTree score: 0.8412346092637575
#
# Precision: 0.8078202995008319
# Recall: 0.7576635826552224
# F1-score: 0.7819384526890998
#
# K-Fold mean: 0.8224471850589535
# K-Fold std: 0.0032801690196691694
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.89      0.88     14907
#            1       0.81      0.76      0.78      8971
#
#     accuracy                           0.84     23878
#    macro avg       0.83      0.82      0.83     23878
# weighted avg       0.84      0.84      0.84     23878

# %% [markdown]
# ## 🧠 3. Ensemble Models
#
# **Jami: `12ta` algoritm**
#
# ### 📦 Bagging Family (4ta)
# - **Random Forest**
# - **Bagging Classifier**
# - **Extra Trees**
# - **Bagged Decision Tree**
#
# ### 🚀 Boosting Family (6ta)
# - **Gradient Boosting**
# - **Hist Gradient Boosting**
# - **AdaBoost**
# - **CatBoost**
# - **XGBoost**
# - **LightGBM**
#
# ### 🧩 Meta-Ensemble Methods
# - **Stacking**
# - **Voting**

# %%
# Bagging MODELS (3ta)
from sklearn.ensemble import (
    RandomForestClassifier,
    BaggingClassifier,
    ExtraTreesClassifier
)

# %% [markdown]
# ## RandomForest

# %%
rf = RandomForestClassifier(n_estimators=300, max_depth=15, n_jobs=-1, random_state=42)

rf.fit(x_train, y_train)
y_pred = rf.predict(x_test)

rf_score = accuracy_score(y_test, y_pred)

rf_precision = precision_score(y_test, y_pred)
rf_recall = recall_score(y_test, y_pred)
rf_f1 = f1_score(y_test, y_pred)

rf_scores = cross_val_score(rf, x_train, y_train, cv=kf, scoring='f1_macro')

print(f'RandomForest score: {rf_score}')

print(f'\nPrecision: {rf_precision}')
print(f'Recall: {rf_recall}')
print(f'F1-score: {rf_f1}')

print("\nK-Fold mean:", rf_scores.mean())
print("K-Fold std:", rf_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForest score: 0.8713460088784656
#
# Precision: 0.8830022075055187
# Recall: 0.757997993534723
# F1-score: 0.8157389635316699
#
# K-Fold mean: 0.852175711001182
# K-Fold std: 0.003262054293089543
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.94      0.90     14907
#            1       0.88      0.76      0.82      8971
#
#     accuracy                           0.87     23878
#    macro avg       0.87      0.85      0.86     23878
# weighted avg       0.87      0.87      0.87     23878

# %% [markdown]
# ## Bagging

# %%
bag = BaggingClassifier(n_estimators=200, random_state=42)

bag.fit(x_train, y_train)
y_pred = bag.predict(x_test)

bag_score = accuracy_score(y_test, y_pred)

bag_precision = precision_score(y_test, y_pred)
bag_recall = recall_score(y_test, y_pred)
bag_f1 = f1_score(y_test, y_pred)

bag_scores = cross_val_score(bag, x_train, y_train, cv=kf, scoring='f1_macro')

print(f'Bagging score: {bag_score}')

print(f'\nPrecision: {bag_precision}')
print(f'Recall: {bag_recall}')
print(f'F1-score: {bag_f1}')

print("\nK-Fold mean:", bag_scores.mean())
print("K-Fold std:", bag_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\ensemble\_bagging.py:930: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\ensemble\_bagging.py:930: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\ensemble\_bagging.py:930: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\ensemble\_bagging.py:930: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Bagging score: 0.8833235614373063
#
# Precision: 0.8696951583980873
# Recall: 0.8109463827889868
# F1-score: 0.8392939547761883
#
# K-Fold mean: 0.863529776425735
# K-Fold std: 0.0020729048508812413
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91     14907
#            1       0.87      0.81      0.84      8971
#
#     accuracy                           0.88     23878
#    macro avg       0.88      0.87      0.87     23878
# weighted avg       0.88      0.88      0.88     23878

# %% [markdown]
# ## Bagged DT

# %%
bag_dt = BaggingClassifier(
    estimator=DecisionTreeClassifier(max_depth=10),
    n_estimators=100,
    random_state=42
)

bag_dt.fit(x_train, y_train)
y_pred = bag_dt.predict(x_test)

bag_dt_score = accuracy_score(y_test, y_pred)

bag_dt_precision = precision_score(y_test, y_pred)
bag_dt_recall = recall_score(y_test, y_pred)
bag_dt_f1 = f1_score(y_test, y_pred)

bag_dt_scores = cross_val_score(bag_dt, x_train, y_train, cv=kf, scoring='f1_macro')

print(f'Bagged DT score: {bag_dt_score}')

print(f'\nPrecision: {bag_dt_precision}')
print(f'Recall: {bag_dt_recall}')
print(f'F1-score: {bag_dt_f1}')

print("\nK-Fold mean:", bag_dt_scores.mean())
print("K-Fold std:", bag_dt_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\ensemble\_bagging.py:930: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\ensemble\_bagging.py:930: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\ensemble\_bagging.py:930: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\ensemble\_bagging.py:930: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Bagged DT score: 0.8475584219783902
#
# Precision: 0.8260550458715596
# Recall: 0.75275888975588
# F1-score: 0.7877055873089933
#
# K-Fold mean: 0.8300327625670718
# K-Fold std: 0.0035730433703317376
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.90      0.88     14907
#            1       0.83      0.75      0.79      8971
#
#     accuracy                           0.85     23878
#    macro avg       0.84      0.83      0.83     23878
# weighted avg       0.85      0.85      0.85     23878

# %% [markdown]
# ## ExtraTree

# %%
et = ExtraTreesClassifier(n_estimators=200, max_depth=15, random_state=42)

et.fit(x_train, y_train)
y_pred = et.predict(x_test)

et_score = accuracy_score(y_test, y_pred)

et_precision = precision_score(y_test, y_pred)
et_recall = recall_score(y_test, y_pred)
et_f1 = f1_score(y_test, y_pred)

et_scores = cross_val_score(et, x_train, y_train, cv=kf, scoring='f1_macro')

print(f'ExtraTrees score: {et_score}')

print(f'\nPrecision: {et_precision}')
print(f'Recall: {et_recall}')
print(f'F1-score: {et_f1}')

print("\nK-Fold mean:", et_scores.mean())
print("K-Fold std:", et_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# ExtraTrees score: 0.8421140799061898
#
# Precision: 0.8968411414619258
# Recall: 0.655110912941701
# F1-score: 0.7571502190157176
#
# K-Fold mean: 0.8182398555160413
# K-Fold std: 0.00404885276174658
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.82      0.95      0.88     14907
#            1       0.90      0.66      0.76      8971
#
#     accuracy                           0.84     23878
#    macro avg       0.86      0.80      0.82     23878
# weighted avg       0.85      0.84      0.84     23878

# %%
# Boosting MODELS (6ta)
from sklearn.ensemble import (
    GradientBoostingClassifier,
    HistGradientBoostingClassifier,
    AdaBoostClassifier
)

from catboost import CatBoostClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

# %% [markdown]
# ## Gradient Boosting

# %%
gb = GradientBoostingClassifier(n_estimators=300, learning_rate=0.05, max_depth=3, random_state=42)

gb.fit(x_train, y_train)
y_pred = gb.predict(x_test)

gb_score = accuracy_score(y_test, y_pred)

gb_precision = precision_score(y_test, y_pred)
gb_recall = recall_score(y_test, y_pred)
gb_f1 = f1_score(y_test, y_pred)

gb_scores = cross_val_score(gb, x_train, y_train, cv=kf, scoring='f1_macro')

print(f'GradientBoosting score: {gb_score}')

print(f'\nPrecision: {gb_precision}')
print(f'Recall: {gb_recall}')
print(f'F1-score: {gb_f1}')

print("\nK-Fold mean:", gb_scores.mean())
print("K-Fold std:", gb_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GradientBoosting score: 0.8555992964234861
#
# Precision: 0.8447996004494943
# Recall: 0.7542080035670494
# F1-score: 0.7969375736160188
#
# K-Fold mean: 0.8378158938801062
# K-Fold std: 0.0026520759467376677
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.92      0.89     14907
#            1       0.84      0.75      0.80      8971
#
#     accuracy                           0.86     23878
#    macro avg       0.85      0.84      0.84     23878
# weighted avg       0.85      0.86      0.85     23878

# %% [markdown]
# ## Hist Gradient Boosting

# %%
hgb = HistGradientBoostingClassifier(max_iter=300, learning_rate=0.05, max_depth=7, random_state=42)

hgb.fit(x_train, y_train)
y_pred = hgb.predict(x_test)

hgb_score = accuracy_score(y_test, y_pred)

hgb_precision = precision_score(y_test, y_pred)
hgb_recall = recall_score(y_test, y_pred)
hgb_f1 = f1_score(y_test, y_pred)

hgb_scores = cross_val_score(hgb, x_train, y_train, cv=kf, scoring='f1_macro')

print(f'HistGradientBoosting score: {hgb_score}')

print(f'\nPrecision: {hgb_precision}')
print(f'Recall: {hgb_recall}')
print(f'F1-score: {hgb_f1}')

print("\nK-Fold mean:", hgb_scores.mean())
print("K-Fold std:", hgb_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# HistGradientBoosting score: 0.8755339643186196
#
# Precision: 0.8629159104658197
# Recall: 0.7950061308661241
# F1-score: 0.8275702019029937
#
# K-Fold mean: 0.8573226123804484
# K-Fold std: 0.00225542328399786
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.92      0.90     14907
#            1       0.86      0.80      0.83      8971
#
#     accuracy                           0.88     23878
#    macro avg       0.87      0.86      0.87     23878
# weighted avg       0.87      0.88      0.87     23878

# %% [markdown]
# ## XGBoost

# %%
xgb = XGBClassifier(
    n_estimators=500,
    max_depth=6,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42
)

xgb.fit(x_train, y_train)
y_pred = xgb.predict(x_test)

xgb_score = accuracy_score(y_test, y_pred)

xgb_precision = precision_score(y_test, y_pred)
xgb_recall = recall_score(y_test, y_pred)
xgb_f1 = f1_score(y_test, y_pred)

xgb_scores = cross_val_score(xgb, x_train, y_train, cv=kf, scoring='f1_macro')

print(f'XGBoost score: {xgb_score}')

print(f'\nPrecision: {xgb_precision}')
print(f'Recall: {xgb_recall}')
print(f'F1-score: {xgb_f1}')

print("\nK-Fold mean:", xgb_scores.mean())
print("K-Fold std:", xgb_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# XGBoost score: 0.8797637993131753
#
# Precision: 0.8642225937425364
# Recall: 0.8067105116486456
# F1-score: 0.8344767944652638
#
# K-Fold mean: 0.8619808383326806
# K-Fold std: 0.0025130136106991142
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.92      0.91     14907
#            1       0.86      0.81      0.83      8971
#
#     accuracy                           0.88     23878
#    macro avg       0.88      0.87      0.87     23878
# weighted avg       0.88      0.88      0.88     23878

# %% [markdown]
# ## AdaBoost

# %%
ab = AdaBoostClassifier(n_estimators=300, learning_rate=0.05, random_state=42)

ab.fit(x_train, y_train)
y_pred = ab.predict(x_test)

ab_score = accuracy_score(y_test, y_pred)

ab_precision = precision_score(y_test, y_pred)
ab_recall = recall_score(y_test, y_pred)
ab_f1 = f1_score(y_test, y_pred)

ab_scores = cross_val_score(ab, x_train, y_train, cv=kf, scoring='f1_macro')

print(f'AdaBoost score: {ab_score}')

print(f'\nPrecision: {ab_precision}')
print(f'Recall: {ab_recall}')
print(f'F1-score: {ab_f1}')

print("\nK-Fold mean:", ab_scores.mean())
print("K-Fold std:", ab_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# AdaBoost score: 0.7494765055699807
#
# Precision: 0.9876019575856444
# Recall: 0.3374205774161186
# F1-score: 0.5029910269192422
#
# K-Fold mean: 0.6686343975443109
# K-Fold std: 0.01048413738826898
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.71      1.00      0.83     14907
#            1       0.99      0.34      0.50      8971
#
#     accuracy                           0.75     23878
#    macro avg       0.85      0.67      0.67     23878
# weighted avg       0.82      0.75      0.71     23878

# %% [markdown]
# ## LightGBM

# %%
lgbm = LGBMClassifier(n_estimators=500, learning_rate=0.05, num_leaves=31, subsample=0.8, colsample_bytree=0.8, random_state=42)

lgbm.fit(x_train, y_train)
y_pred = lgbm.predict(x_test)

lgbm_score = accuracy_score(y_test, y_pred)

lgbm_precision = precision_score(y_test, y_pred)
lgbm_recall = recall_score(y_test, y_pred)
lgbm_f1 = f1_score(y_test, y_pred)

lgbm_scores = cross_val_score(lgbm, x_train, y_train, cv=kf, scoring='f1_macro')

print(f'\nLightGBM score: {lgbm_score}')

print(f'\nPrecision: {lgbm_precision}')
print(f'Recall: {lgbm_recall}')
print(f'F1-score: {lgbm_f1}')

print("\nK-Fold mean:", lgbm_scores.mean())
print("K-Fold std:", lgbm_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# [LightGBM] [Info] Number of positive: 35253, number of negative: 60259
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004923 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2145
# [LightGBM] [Info] Number of data points in the train set: 95512, number of used features: 49
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.369095 -> initscore=-0.536101
# [LightGBM] [Info] Start training from score -0.536101
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Number of positive: 23553, number of negative: 40121
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003007 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2110
# [LightGBM] [Info] Number of data points in the train set: 63674, number of used features: 49
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.369900 -> initscore=-0.532647
# [LightGBM] [Info] Start training from score -0.532647
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Number of positive: 23477, number of negative: 40198
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003138 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2112
# [LightGBM] [Info] Number of data points in the train set: 63675, number of used features: 49
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.368700 -> initscore=-0.537796
# [LightGBM] [Info] Start training from score -0.537796
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Number of positive: 23476, number of negative: 40199
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003277 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2111
# [LightGBM] [Info] Number of data points in the train set: 63675, number of used features: 49
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.368685 -> initscore=-0.537863
# [LightGBM] [Info] Start training from score -0.537863
#
# LightGBM score: 0.8801825948571907
#
# Precision: 0.8650812619502868
# Recall: 0.8069334522349794
# F1-score: 0.8349962512255609
#
# K-Fold mean: 0.8616799147241799
# K-Fold std: 0.002723937142635171
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.92      0.91     14907
#            1       0.87      0.81      0.83      8971
#
#     accuracy                           0.88     23878
#    macro avg       0.88      0.87      0.87     23878
# weighted avg       0.88      0.88      0.88     23878

# %% [markdown]
# ## CatBoost

# %%
cat = CatBoostClassifier(iterations=500, depth=8,learning_rate=0.05, random_state=42)

cat.fit(x_train, y_train)
y_pred = cat.predict(x_test)

cat_score = accuracy_score(y_test, y_pred)

cat_precision = precision_score(y_test, y_pred)
cat_recall = recall_score(y_test, y_pred)
cat_f1 = f1_score(y_test, y_pred)

cat_scores = cross_val_score(cat, x_train, y_train, cv=kf, scoring='f1_macro')

print(f'CatBoost score: {cat_score}')

print(f'\nPrecision: {cat_precision}')
print(f'Recall: {cat_recall}')
print(f'F1-score: {cat_f1}')

print("\nK-Fold mean:", cat_scores.mean())
print("K-Fold std:", cat_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# 0:	learn: 0.6420115	total: 155ms	remaining: 1m 17s
# 1:	learn: 0.5947196	total: 167ms	remaining: 41.5s
# 2:	learn: 0.5581536	total: 176ms	remaining: 29.2s
# 3:	learn: 0.5303284	total: 186ms	remaining: 23.1s
# 4:	learn: 0.5064711	total: 196ms	remaining: 19.4s
# 5:	learn: 0.4877656	total: 206ms	remaining: 16.9s
# 6:	learn: 0.4709348	total: 215ms	remaining: 15.2s
# 259:	learn: 0.2734728	total: 2.23s	remaining: 2.05s
# 260:	learn: 0.2733072	total: 2.23s	remaining: 2.05s
# 261:	learn: 0.2731078	total: 2.24s	remaining: 2.04s
# 262:	learn: 0.2729964	total: 2.25s	remaining: 2.03s
# 263:	learn: 0.2727839	total: 2.26s	remaining: 2.02s
# 264:	learn: 0.2726816	total: 2.27s	remaining: 2.01s
# 265:	learn: 0.2725000	total: 2.28s	remaining: 2s
# 266:	learn: 0.2724521	total: 2.29s	remaining: 1.99s
# 267:	learn: 0.2723260	total: 2.29s	remaining: 1.99s
# 268:	learn: 0.2721681	total: 2.3s	remaining: 1.98s
# 269:	learn: 0.2720291	total: 2.31s	remaining: 1.97s
# 270:	learn: 0.2718222	total: 2.32s	remaining: 1.96s
# 271:	learn: 0.2716923	total: 2.33s	remaining: 1.95s
# 272:	learn: 0.2715176	total: 2.34s	remaining: 1.94s
# 273:	learn: 0.2711714	total: 2.35s	remaining: 1.93s
# 274:	learn: 0.2710310	total: 2.35s	remaining: 1.93s
# 275:	learn: 0.2708528	total: 2.36s	remaining: 1.92s
# 276:	learn: 0.2707092	total: 2.37s	remaining: 1.91s
# 277:	learn: 0.2706162	total: 2.38s	remaining: 1.9s
# 278:	learn: 0.2705154	total: 2.39s	remaining: 1.89s
# 279:	learn: 0.2704060	total: 2.4s	remaining: 1.88s
# 280:	learn: 0.2702295	total: 2.4s	remaining: 1.87s
# 281:	learn: 0.2701268	total: 2.41s	remaining: 1.86s
# 282:	learn: 0.2699357	total: 2.42s	remaining: 1.86s
# 283:	learn: 0.2698912	total: 2.43s	remaining: 1.85s
# 284:	learn: 0.2696907	total: 2.44s	remaining: 1.84s
# 285:	learn: 0.2694954	total: 2.45s	remaining: 1.83s
# 286:	learn: 0.2693522	total: 2.46s	remaining: 1.82s
# 287:	learn: 0.2692435	total: 2.46s	remaining: 1.81s
# 288:	learn: 0.2691109	total: 2.47s	remaining: 1.8s
# 289:	learn: 0.2689677	total: 2.48s	remaining: 1.8s
# 290:	learn: 0.2688133	total: 2.49s	remaining: 1.79s
# 291:	learn: 0.2686857	total: 2.5s	remaining: 1.78s
# 292:	learn: 0.2685888	total: 2.51s	remaining: 1.77s
# 293:	learn: 0.2683197	total: 2.52s	remaining: 1.76s
# 294:	learn: 0.2682031	total: 2.52s	remaining: 1.75s
# 295:	learn: 0.2680316	total: 2.53s	remaining: 1.75s
# 296:	learn: 0.2679038	total: 2.54s	remaining: 1.74s
# 297:	learn: 0.2677734	total: 2.55s	remaining: 1.73s
# 298:	learn: 0.2676173	total: 2.56s	remaining: 1.72s
# 299:	learn: 0.2674793	total: 2.57s	remaining: 1.71s
# 300:	learn: 0.2674486	total: 2.57s	remaining: 1.7s
# 301:	learn: 0.2673195	total: 2.58s	remaining: 1.69s
# 302:	learn: 0.2672553	total: 2.59s	remaining: 1.68s
# 303:	learn: 0.2671634	total: 2.6s	remaining: 1.68s
# 304:	learn: 0.2669899	total: 2.61s	remaining: 1.67s
# 493:	learn: 0.2451715	total: 4.22s	remaining: 51.3ms
# 494:	learn: 0.2450450	total: 4.23s	remaining: 42.7ms
# 495:	learn: 0.2449512	total: 4.24s	remaining: 34.2ms
# 496:	learn: 0.2448990	total: 4.25s	remaining: 25.6ms
# 497:	learn: 0.2448133	total: 4.25s	remaining: 17.1ms
# 498:	learn: 0.2447047	total: 4.26s	remaining: 8.54ms
# 499:	learn: 0.2446323	total: 4.27s	remaining: 0us
# CatBoost score: 0.8785492922355306
#
# Precision: 0.867538442910764
# Recall: 0.7986846505406309
# F1-score: 0.8316889146836912
#
# K-Fold mean: 0.8608673765016904
# K-Fold std: 0.0025914324942435496
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.93      0.90     14907
#            1       0.87      0.80      0.83      8971
#
#     accuracy                           0.88     23878
#    macro avg       0.88      0.86      0.87     23878
# weighted avg       0.88      0.88      0.88     23878

# %%
# Stacking & Voting MODELS
from sklearn.ensemble import (
    StackingClassifier,
    VotingClassifier
)

# %% [markdown]
# ## Stacking

# %%
base1 = RandomForestClassifier(random_state=42)
base2 = ExtraTreesClassifier(random_state=42)
base3 = LogisticRegression()

stacking = StackingClassifier(
    estimators=[
        ('rf', base1),
        ('et', base2),
        ('lr', base3)
    ],
    final_estimator=LogisticRegression()
)

stacking.fit(x_train, y_train)
y_pred = stacking.predict(x_test)

stacking_score = accuracy_score(y_test, y_pred)

stacking_precision = precision_score(y_test, y_pred)
stacking_recall = recall_score(y_test, y_pred)
stacking_f1 = f1_score(y_test, y_pred)

stacking_scores = cross_val_score(stacking, x_train, y_train, cv=kf, scoring='f1_macro')

print(f'Stacking score: {stacking_score}')

print(f'\nPrecision: {stacking_precision}')
print(f'Recall: {stacking_recall}')
print(f'F1-score: {stacking_f1}')

print("\nK-Fold mean:", stacking_scores.mean())
print("K-Fold std:", stacking_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# Stacking score: 0.8844124298517464
#
# Precision: 0.8739313666465984
# Recall: 0.80905138780515
# F1-score: 0.8402407964806669
#
# K-Fold mean: 0.8655017893798073
# K-Fold std: 0.0035505858992038127
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91     14907
#            1       0.87      0.81      0.84      8971
#
#     accuracy                           0.88     23878
#    macro avg       0.88      0.87      0.87     23878
# weighted avg       0.88      0.88      0.88     23878

# %% [markdown]
# ## Hard Voting

# %%
model1 = RandomForestClassifier(random_state=42)
model2 = ExtraTreesClassifier(random_state=42)
model3 = LogisticRegression()

hard_voting = VotingClassifier(
    estimators=[
        ('rf', model1),
        ('et', model2),
        ('lr', model3)
    ],
    voting='hard'
)

hard_voting.fit(x_train, y_train)
y_pred = hard_voting.predict(x_test)

hard_voting_score = accuracy_score(y_test, y_pred)

hard_voting_precision = precision_score(y_test, y_pred)
hard_voting_recall = recall_score(y_test, y_pred)
hard_voting_f1 = f1_score(y_test, y_pred)

hard_voting_scores = cross_val_score(hard_voting, x_train, y_train, cv=kf, scoring='f1_macro')

print(f'Hard Voting score: {hard_voting_score}')

print(f'\nPrecision: {hard_voting_precision}')
print(f'Recall: {hard_voting_recall}')
print(f'F1-score: {hard_voting_f1}')

print("\nK-Fold mean:", hard_voting_scores.mean())
print("K-Fold std:", hard_voting_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# Hard Voting score: 0.8793868833235614
#
# Precision: 0.8871234269734334
# Recall: 0.7779511760115929
# F1-score: 0.8289583085877182
#
# K-Fold mean: 0.8583853106829612
# K-Fold std: 0.002451116385778589
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91     14907
#            1       0.89      0.78      0.83      8971
#
#     accuracy                           0.88     23878
#    macro avg       0.88      0.86      0.87     23878
# weighted avg       0.88      0.88      0.88     23878

# %% [markdown]
# ## Soft Voting

# %%
model1 = RandomForestClassifier(random_state=42)
model2 = ExtraTreesClassifier(random_state=42)
model3 = LogisticRegression()

soft_voting = VotingClassifier(
    estimators=[
        ('rf', model1),
        ('et', model2),
        ('lr', model3)
    ],
    voting='soft'
)

soft_voting.fit(x_train, y_train)
y_pred = soft_voting.predict(x_test)

soft_voting_score = accuracy_score(y_test, y_pred)

soft_voting_precision = precision_score(y_test, y_pred)
soft_voting_recall = recall_score(y_test, y_pred)
soft_voting_f1 = f1_score(y_test, y_pred)

soft_voting_scores = cross_val_score(soft_voting, x_train, y_train, cv=kf, scoring='f1_macro')

print(f'Soft Voting score: {soft_voting_score}')

print(f'\nPrecision: {soft_voting_precision}')
print(f'Recall: {soft_voting_recall}')
print(f'F1-score: {soft_voting_f1}')

print("\nK-Fold mean:", soft_voting_scores.mean())
print("K-Fold std:", soft_voting_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# Soft Voting score: 0.8767065918418628
#
# Precision: 0.8904003109211037
# Recall: 0.7661353249359045
# F1-score: 0.8236069502696225
#
# K-Fold mean: 0.8555859310082038
# K-Fold std: 0.002725969649495273
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.94      0.91     14907
#            1       0.89      0.77      0.82      8971
#
#     accuracy                           0.88     23878
#    macro avg       0.88      0.85      0.86     23878
# weighted avg       0.88      0.88      0.87     23878

# %% [markdown]
# ## 👥 4. Neighbors-Based Models
#
# **Jami: `2ta` algoritm**
#
# - **K-Nearest Neighbors (KNN) Classifier**
# - **Radius Neighbors Classifier**

# %%
# Keighbors MODELS (2ta)
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# ## KNN

# %%
knn = KNeighborsClassifier(n_neighbors=1)

knn.fit(x_train, y_train)
y_pred = knn.predict(x_test)

knn_score = accuracy_score(y_test, y_pred)

knn_precision = precision_score(y_test, y_pred)
knn_recall = recall_score(y_test, y_pred)
knn_f1 = f1_score(y_test, y_pred)

knn_scores = cross_val_score(knn, x_train, y_train, cv=kf, scoring='f1_macro')

print(f'KNN score: {knn_score}')

print(f'\nPrecision: {knn_precision}')
print(f'Recall: {knn_recall}')
print(f'F1-score: {knn_f1}')

print("\nK-Fold mean:", knn_scores.mean())
print("K-Fold std:", knn_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\neighbors\_classification.py:239: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\neighbors\_classification.py:239: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\neighbors\_classification.py:239: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\neighbors\_classification.py:239: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNN score: 0.7739341653404808
#
# Precision: 0.6945442665795492
# Recall: 0.7109575298183034
# F1-score: 0.7026550622452352
#
# K-Fold mean: 0.7477000249888874
# K-Fold std: 0.0031805913615647477
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.82      0.81      0.82     14907
#            1       0.69      0.71      0.70      8971
#
#     accuracy                           0.77     23878
#    macro avg       0.76      0.76      0.76     23878
# weighted avg       0.78      0.77      0.77     23878

# %% [markdown]
# ## 📐 5. Support Vector Machine (SVM) Models
#
# **Jami: `1ta` algoritm**
#
# - **Support Vector Classifier (SVC)**

# %%
from sklearn.svm import SVC

svr = SVC(kernel='rbf', C=20.0)

svr.fit(x_train, y_train)
y_pred = svr.predict(x_test)

svr_score = accuracy_score(y_test, y_pred)

svr_precision = precision_score(y_test, y_pred)
svr_recall = recall_score(y_test, y_pred)
svr_f1 = f1_score(y_test, y_pred)

svr_scores = cross_val_score(svr, x_train, y_train, cv=kf, scoring='f1_macro')

print(f'SVC score: {svr_score}')

print(f'\nPrecision: {svr_precision}')
print(f'Recall: {svr_recall}')
print(f'F1-score: {svr_f1}')

print("\nK-Fold mean:", svr_scores.mean())
print("K-Fold std:", svr_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC score: 0.8439986598542591
#
# Precision: 0.8294398392363728
# Recall: 0.7361498160740163
# F1-score: 0.7800153546329652
#
# K-Fold mean: 0.8231301878898886
# K-Fold std: 0.002850198933429421
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.91      0.88     14907
#            1       0.83      0.74      0.78      8971
#
#     accuracy                           0.84     23878
#    macro avg       0.84      0.82      0.83     23878
# weighted avg       0.84      0.84      0.84     23878

# %% [markdown]
# ## 🧬 6. Neural Network Models
#
# **Jami: `1ta` algoritm**
#
# - **Multi-Layer Perceptron (MLP) Classifier**

# %%
# Neural Network MODEL
from sklearn.neural_network import MLPClassifier

# %% [markdown]
# ## MLPClassifier

# %%
mlpc = MLPClassifier(hidden_layer_sizes=(128, 64), activation="relu", max_iter=300, random_state=42)

mlpc.fit(x_train, y_train)
y_pred = mlpc.predict(x_test)

mlpc_score = accuracy_score(y_test, y_pred)

mlpc_precision = precision_score(y_test, y_pred)
mlpc_recall = recall_score(y_test, y_pred)
mlpc_f1 = f1_score(y_test, y_pred)

mlpc_scores = cross_val_score(mlpc, x_train, y_train, cv=kf, scoring='f1_macro')

print(f'MLPClassifier score: {mlpc_score}')

print(f'\nPrecision: {mlpc_precision}')
print(f'Recall: {mlpc_recall}')
print(f'F1-score: {mlpc_f1}')

print("\nK-Fold mean:", mlpc_scores.mean())
print("K-Fold std:", mlpc_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\neural_network\_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\neural_network\_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\neural_network\_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# MLPClassifier score: 0.8380517631292403
#
# Precision: 0.782113641388459
# Recall: 0.7886523241556125
# F1-score: 0.7853693733695953
#
# K-Fold mean: 0.8068927449216163
# K-Fold std: 0.0014178092058384614
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.87      0.87     14907
#            1       0.78      0.79      0.79      8971
#
#     accuracy                           0.84     23878
#    macro avg       0.83      0.83      0.83     23878
# weighted avg       0.84      0.84      0.84     23878
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\neural_network\_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %% [markdown]
# ## 🎯 7. Naive & Simple Baseline Models
#
# **Jami: `1ta` algoritm**
#
# - **Dummy Classifier**

# %%
# Simple Baseline MODEL
from sklearn.dummy import DummyClassifier

# %% [markdown]
# ## DummyClassifier

# %%
dummy = DummyClassifier()

dummy.fit(x_train, y_train)
y_pred = dummy.predict(x_test)

dummy_score = accuracy_score(y_test, y_pred)

dummy_precision = precision_score(y_test, y_pred)
dummy_recall = recall_score(y_test, y_pred)
dummy_f1 = f1_score(y_test, y_pred)

dummy_scores = cross_val_score(dummy, x_train, y_train, cv=kf, scoring='f1_macro')

print(f'DummyClassifier score: {dummy_score}')

print(f'\nPrecision: {dummy_precision}')
print(f'Recall: {dummy_recall}')
print(f'F1-score: {dummy_f1}')

print("\nK-Fold mean:", dummy_scores.mean())
print("K-Fold std:", dummy_scores.std()) 

print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# DummyClassifier score: 0.6242985174637742
#
# Precision: 0.0
# Recall: 0.0
# F1-score: 0.0
#
# K-Fold mean: 0.38684320260727606
# K-Fold std: 0.0004277210010969743
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.62      1.00      0.77     14907
#            1       0.00      0.00      0.00      8971
#
#     accuracy                           0.62     23878
#    macro avg       0.31      0.50      0.38     23878
# weighted avg       0.39      0.62      0.48     23878
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
from rich.table import Table
from rich.console import Console

console = Console()

results = [
    # Linear Family
    ['Logistic Regression', lr_score, lr_precision, lr_recall, lr_f1, lr_scores.mean(), lr_scores.std()],
    ['RidgeClassifier', ridge_score, ridge_precision, ridge_recall, ridge_f1, ridge_scores.mean(), ridge_scores.std()],
    ['SGDC', sgdc_score, sgdc_precision, sgdc_recall, sgdc_f1, sgdc_scores.mean(), sgdc_scores.std()],
    ['Passive Aggressive', pac_score, pac_precision, pac_recall, pac_f1, pac_scores.mean(), pac_scores.std()],

    # Tree-Based Family
    ['DecisionTree', dt_score, dt_precision, dt_recall, dt_f1, dt_scores.mean(), dt_scores.std()],

    # Bagging Family
    ['RandomForest', rf_score, rf_precision, rf_recall, rf_f1, rf_scores.mean(), rf_scores.std()],
    ['Bagging', bag_score, bag_precision, bag_recall, bag_f1, bag_scores.mean(), bag_scores.std()],
    ['Bagged DT', bag_dt_score, bag_dt_precision, bag_dt_recall, bag_dt_f1, bag_dt_scores.mean(), bag_dt_scores.std()],
    ['ExtraTrees', et_score, et_precision, et_recall, et_f1, et_scores.mean(), et_scores.std()],

    # Boosting Family
    ['GradientBoosting', gb_score, gb_precision, gb_recall, gb_f1, gb_scores.mean(), gb_scores.std()],
    ['HistGradientBoosting', hgb_score, hgb_precision, hgb_recall, hgb_f1, hgb_scores.mean(), hgb_scores.std()],
    ['XGBoost', xgb_score, xgb_precision, xgb_recall, xgb_f1, xgb_scores.mean(), xgb_scores.std()],
    ['AdaBoost', ab_score, ab_precision, ab_recall, ab_f1, ab_scores.mean(), ab_scores.std()],
    ['LGBMClassifier', lgbm_score, lgbm_precision, lgbm_recall, lgbm_f1, lgbm_scores.mean(), lgbm_scores.std()],
    ['CatBoost', cat_score, cat_precision, cat_recall, cat_f1, cat_scores.mean(), cat_scores.std()],

    # Stacking & Voting Family
    ['Hard Voting', hard_voting_score, hard_voting_precision, hard_voting_recall, hard_voting_f1, hard_voting_scores.mean(), hard_voting_scores.std()],
    ['Soft Voting', soft_voting_score, soft_voting_precision, soft_voting_recall, soft_voting_f1, soft_voting_scores.mean(), soft_voting_scores.std()],
    ['Stacking', stacking_score, stacking_precision, stacking_recall, stacking_f1, stacking_scores.mean(), stacking_scores.std()],

    # Neighbors Family
    ['KNN', knn_score, knn_precision, knn_recall, knn_f1, knn_scores.mean(), knn_scores.std()],

    # SVM Family
    ['SVC', svr_score, svr_precision, svr_recall, svr_f1, svr_scores.mean(), svr_scores.std()],

    # Neural Network Family
    ['MLPC', mlpc_score, mlpc_precision, mlpc_recall, mlpc_f1, mlpc_scores.mean(), mlpc_scores.std()],

    # Naive & Simple Family
    ['DummyClassifier', dummy_score, dummy_precision, dummy_recall, dummy_f1, dummy_scores.mean(), dummy_scores.std()],
]

result_sorted = sorted(results, key=lambda i: i[3], reverse=True)

best_model = max(results, key=lambda x: x[3])
worst_model = min(results, key=lambda x: x[3])

table = Table(title="Comparison Without Feature Selection", show_lines=True)
table.add_column("Algorithm")
table.add_column("Accuracy")
table.add_column("Precision")
table.add_column("Recall")
table.add_column("F1-score")
table.add_column("K-Fold mean")
table.add_column("K-Fold std")

for row in result_sorted:
    algo, acc, presicion, recall, f1, kmean, kstd = row

    if row == best_model:
        table.add_row(
            f"[bold green]{algo}[/bold green]",
            f"[bold green]{acc:.2f}[/bold green]",
            f"[bold green]{presicion:.2f}[/bold green]",
            f"[bold green]{recall:.2f}[/bold green]",
            f"[bold green]{f1:.2f}[/bold green]",
            f"[bold green]{kmean:.2f}[/bold green]",
            f"[bold green]{kstd:.2f}[/bold green]",
        )
    elif row == worst_model:
        table.add_row(
            f"[bold red]{algo}[/bold red]",
            f"[bold red]{acc:.2f}[/bold red]",
            f"[bold red]{presicion:.2f}[/bold red]",
            f"[bold red]{recall:.2f}[/bold red]",
            f"[bold red]{f1:.2f}[/bold red]",
            f"[bold red]{kmean:.2f}[/bold red]",
            f"[bold red]{kstd:.2f}[/bold red]",
        )
    else:
        table.add_row(algo, f"{acc:.2f}", f"{presicion:.2f}", f"{recall:.2f}", f"{f1:.2f}", f"{kmean:.2f}", f"{kstd:.2f}")

console.print(table)
# Out:
#                              Comparison Without Feature Selection
# ┏━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Algorithm            ┃ Accuracy ┃ Precision ┃ Recall ┃ F1-score ┃ K-Fold mean ┃ K-Fold std ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ SGDC                 │ 0.69     │ 0.56      │ 0.84   │ 0.67     │ 0.68        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ Bagging              │ 0.88     │ 0.87      │ 0.81   │ 0.84     │ 0.86        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ Stacking             │ 0.88     │ 0.87      │ 0.81   │ 0.84     │ 0.87        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ LGBMClassifier       │ 0.88     │ 0.87      │ 0.81   │ 0.83     │ 0.86        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ XGBoost              │ 0.88     │ 0.86      │ 0.81   │ 0.83     │ 0.86        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ CatBoost             │ 0.88     │ 0.87      │ 0.80   │ 0.83     │ 0.86        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ HistGradientBoosting │ 0.88     │ 0.86      │ 0.80   │ 0.83     │ 0.86        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ MLPC                 │ 0.84     │ 0.78      │ 0.79   │ 0.79     │ 0.81        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ Hard Voting          │ 0.88     │ 0.89      │ 0.78   │ 0.83     │ 0.86        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ RidgeClassifier      │ 0.80     │ 0.72      │ 0.77   │ 0.74     │ 0.78        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ Soft Voting          │ 0.88     │ 0.89      │ 0.77   │ 0.82     │ 0.86        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ RandomForest         │ 0.87     │ 0.88      │ 0.76   │ 0.82     │ 0.85        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ DecisionTree         │ 0.84     │ 0.81      │ 0.76   │ 0.78     │ 0.82        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ GradientBoosting     │ 0.86     │ 0.84      │ 0.75   │ 0.80     │ 0.84        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ Bagged DT            │ 0.85     │ 0.83      │ 0.75   │ 0.79     │ 0.83        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ SVC                  │ 0.84     │ 0.83      │ 0.74   │ 0.78     │ 0.82        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ KNN                  │ 0.77     │ 0.69      │ 0.71   │ 0.70     │ 0.75        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ ExtraTrees           │ 0.84     │ 0.90      │ 0.66   │ 0.76     │ 0.82        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ Passive Aggressive   │ 0.79     │ 0.75      │ 0.64   │ 0.69     │ 0.64        │ 0.09       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ Logistic Regression  │ 0.81     │ 0.81      │ 0.63   │ 0.71     │ 0.78        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ AdaBoost             │ 0.75     │ 0.99      │ 0.34   │ 0.50     │ 0.67        │ 0.01       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ DummyClassifier      │ 0.62     │ 0.00      │ 0.00   │ 0.00     │ 0.39        │ 0.00       │
# └──────────────────────┴──────────┴───────────┴────────┴──────────┴─────────────┴────────────┘

# %%
os.makedirs('results', exist_ok=True)

temp_console = Console(record=True)
temp_console.print(table)
text = temp_console.export_text()
with open('results/feature_selection_compare.txt', 'a', encoding='utf-8') as f:
    f.write(text)
# Out:
#                              Comparison Without Feature Selection
# ┏━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Algorithm            ┃ Accuracy ┃ Precision ┃ Recall ┃ F1-score ┃ K-Fold mean ┃ K-Fold std ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ SGDC                 │ 0.69     │ 0.56      │ 0.84   │ 0.67     │ 0.68        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ Bagging              │ 0.88     │ 0.87      │ 0.81   │ 0.84     │ 0.86        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ Stacking             │ 0.88     │ 0.87      │ 0.81   │ 0.84     │ 0.87        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ LGBMClassifier       │ 0.88     │ 0.87      │ 0.81   │ 0.83     │ 0.86        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ XGBoost              │ 0.88     │ 0.86      │ 0.81   │ 0.83     │ 0.86        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ CatBoost             │ 0.88     │ 0.87      │ 0.80   │ 0.83     │ 0.86        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ HistGradientBoosting │ 0.88     │ 0.86      │ 0.80   │ 0.83     │ 0.86        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ MLPC                 │ 0.84     │ 0.78      │ 0.79   │ 0.79     │ 0.81        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ Hard Voting          │ 0.88     │ 0.89      │ 0.78   │ 0.83     │ 0.86        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ RidgeClassifier      │ 0.80     │ 0.72      │ 0.77   │ 0.74     │ 0.78        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ Soft Voting          │ 0.88     │ 0.89      │ 0.77   │ 0.82     │ 0.86        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ RandomForest         │ 0.87     │ 0.88      │ 0.76   │ 0.82     │ 0.85        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ DecisionTree         │ 0.84     │ 0.81      │ 0.76   │ 0.78     │ 0.82        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ GradientBoosting     │ 0.86     │ 0.84      │ 0.75   │ 0.80     │ 0.84        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ Bagged DT            │ 0.85     │ 0.83      │ 0.75   │ 0.79     │ 0.83        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ SVC                  │ 0.84     │ 0.83      │ 0.74   │ 0.78     │ 0.82        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ KNN                  │ 0.77     │ 0.69      │ 0.71   │ 0.70     │ 0.75        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ ExtraTrees           │ 0.84     │ 0.90      │ 0.66   │ 0.76     │ 0.82        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ Passive Aggressive   │ 0.79     │ 0.75      │ 0.64   │ 0.69     │ 0.64        │ 0.09       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ Logistic Regression  │ 0.81     │ 0.81      │ 0.63   │ 0.71     │ 0.78        │ 0.00       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ AdaBoost             │ 0.75     │ 0.99      │ 0.34   │ 0.50     │ 0.67        │ 0.01       │
# ├──────────────────────┼──────────┼───────────┼────────┼──────────┼─────────────┼────────────┤
# │ DummyClassifier      │ 0.62     │ 0.00      │ 0.00   │ 0.00     │ 0.39        │ 0.00       │
# └──────────────────────┴──────────┴───────────┴────────┴──────────┴─────────────┴────────────┘

# %% [markdown]
# # Another Feature Selections

# %% [markdown]
# <a href="../FS/wrapper.ipynb" target="_blank" style="text-decoration: none;">
#     <button style="
#         background-color: #45a049;
#         color: white;
#         padding: 12px 24px;
#         font-size: 16px;
#         border: none;
#         border-radius: 8px;
#         cursor: pointer;
#         transition: background-color 0.3s;
#     " onmouseover="this.style.backgroundColor='#45a049'" onmouseout="this.style.backgroundColor='#4CAF50'">
#         Wrapper Method
#     </button>
# </a>
#
# <a href="../FS/filter.ipynb" target="_blank" style="text-decoration: none;">
#     <button style="
#         background-color: #45a049;
#         color: white;
#         padding: 12px 24px;
#         font-size: 16px;
#         border: none;
#         border-radius: 8px;
#         cursor: pointer;
#         transition: background-color 0.3s;
#     " onmouseover="this.style.backgroundColor='#45a049'" onmouseout="this.style.backgroundColor='#4CAF50'">
#         Filter method
#     </button>
# </a>
#
# <a href="../FS/embedded.ipynb" target="_blank" style="text-decoration: none;">
#     <button style="
#         background-color: #45a049;
#         color: white;
#         padding: 12px 24px;
#         font-size: 16px;
#         border: none;
#         border-radius: 8px;
#         cursor: pointer;
#         transition: background-color 0.3s;
#     " onmouseover="this.style.backgroundColor='#45a049'" onmouseout="this.style.backgroundColor='#4CAF50'">
#         Embedded method
#     </button>
# </a>

# %% [markdown]
# # Next step - Feature selection

# %% [markdown]
# <a href="..\Tuning\bayesian_optimization.ipynb" target="_blank" style="text-decoration: none;">
#     <button style="
#         background-color: #45a049;
#         color: white;
#         padding: 12px 24px;
#         font-size: 16px;
#         border: none;
#         border-radius: 8px;
#         cursor: pointer;
#         transition: background-color 0.3s;
#     " onmouseover="this.style.backgroundColor='#45a049'" onmouseout="this.style.backgroundColor='#4CAF50'">
#         Bayesian Optimization
#     </button>
# </a>
#
# <a href="../Tuning/manual_search.ipynb" target="_blank" style="text-decoration: none;">
#     <button style="
#         background-color: #45a049;
#         color: white;
#         padding: 12px 24px;
#         font-size: 16px;
#         border: none;
#         border-radius: 8px;
#         cursor: pointer;
#         transition: background-color 0.3s;
#     " onmouseover="this.style.backgroundColor='#45a049'" onmouseout="this.style.backgroundColor='#4CAF50'">
#         Manual Search
#     </button>
# </a>
#
# <a href="../Tuning/optuna.ipynb" target="_blank" style="text-decoration: none;">
#     <button style="
#         background-color: #45a049;
#         color: white;
#         padding: 12px 24px;
#         font-size: 16px;
#         border: none;
#         border-radius: 8px;
#         cursor: pointer;
#         transition: background-color 0.3s;
#     " onmouseover="this.style.backgroundColor='#45a049'" onmouseout="this.style.backgroundColor='#4CAF50'">
#         optuna
#     </button>
# </a>
#
# <a href="../Tuning/random_search.ipynb" target="_blank" style="text-decoration: none;">
#     <button style="
#         background-color: #45a049;
#         color: white;
#         padding: 12px 24px;
#         font-size: 16px;
#         border: none;
#         border-radius: 8px;
#         cursor: pointer;
#         transition: background-color 0.3s;
#     " onmouseover="this.style.backgroundColor='#45a049'" onmouseout="this.style.backgroundColor='#4CAF50'">
#         Random Search
#     </button>
# </a>
