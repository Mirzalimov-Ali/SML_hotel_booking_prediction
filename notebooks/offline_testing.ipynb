# %%
from joblib import load
import os

# %%
import pandas as pd

# %%
os.chdir(r'C:\SML_Projects\SML_hotelBooking_cancelling_prediction')

# %%
model = load('pipeline/full_pipeline.joblib')

# %% [markdown]
# # Pipeline

# %% [markdown]
# <a href="../scripts/use_fillMissingValues.py" target="_blank" style="text-decoration: none;">
#     <button style="
#         background-color: #67b0e0ff;
#         color: white;
#         padding: 12px 24px;
#         font-size: 16px;
#         border: none;
#         border-radius: 8px;
#         cursor: pointer;
#         transition: background-color 0.3s;
#     " onmouseover="this.style.backgroundColor='#67b0e0ff'" onmouseout="this.style.backgroundColor='#67b0e0ff'">
#         Handle filled pipeline
#     </button>
# </a>
#
# <a href="../scripts/use_feature_engineering.py" target="_blank" style="text-decoration: none;">
#     <button style="
#         background-color: #67b0e0ff;
#         color: white;
#         padding: 12px 24px;
#         font-size: 16px;
#         border: none;
#         border-radius: 8px;
#         cursor: pointer;
#         transition: background-color 0.3s;
#     " onmouseover="this.style.backgroundColor='#67b0e0ff'" onmouseout="this.style.backgroundColor='#67b0e0ff'">
#         Handle engineered pipeline
#     </button>
# </a>
#
# <a href="../scripts/use_preprocessing.py" target="_blank" style="text-decoration: none;">
#     <button style="
#         background-color: #67b0e0ff;
#         color: white;
#         padding: 12px 24px;
#         font-size: 16px;
#         border: none;
#         border-radius: 8px;
#         cursor: pointer;
#         transition: background-color 0.3s;
#     " onmouseover="this.style.backgroundColor='#67b0e0ff'" onmouseout="this.style.backgroundColor='#67b0e0ff'">
#         Handle preprocessed pipeline
#     </button>
# </a>
#
# <a href="../scripts/use_model_training.py" target="_blank" style="text-decoration: none;">
#     <button style="
#         background-color: #67b0e0ff;
#         color: white;
#         padding: 12px 24px;
#         font-size: 16px;
#         border: none;
#         border-radius: 8px;
#         cursor: pointer;
#         transition: background-color 0.3s;
#     " onmouseover="this.style.backgroundColor='#67b0e0ff'" onmouseout="this.style.backgroundColor='#67b0e0ff'">
#         Handle train pipeline
#     </button>
# </a>
#
# <a href="../scripts/use_join_pipeline.py" target="_blank" style="text-decoration: none;">
#     <button style="
#         background-color: #67b0e0ff;
#         color: white;
#         padding: 12px 24px;
#         font-size: 16px;
#         border: none;
#         border-radius: 8px;
#         cursor: pointer;
#         transition: background-color 0.3s;
#     " onmouseover="this.style.backgroundColor='#67b0e0ff'" onmouseout="this.style.backgroundColor='#67b0e0ff'">
#         Handle full pipeline
#     </button>
# </a>

# %% [markdown]
# # User data

# %%
user = pd.DataFrame({
    'hotel': ['Resort Hotel - Delhi'],
    'lead_time': [85],
    'arrival_date_month': ['August'],
    'arrival_date_week_number': [34],
    'arrival_date_day_of_month': [25],
    'stays_in_weekend_nights': [0],
    'stays_in_week_nights': [3],
    'adults': [2],
    'children': [0],
    'babies': [0],
    'meal': ['BB'],
    'country': ['PRT'],
    'market_segment': ['Online TA'],
    'distribution_channel': ['TA/TO'],
    'is_repeated_guest': [0],
    'previous_cancellations': [0],
    'previous_bookings_not_canceled': [0],
    'reserved_room_type': ['A'],
    'assigned_room_type': ['A'],
    'booking_changes': [0],
    'deposit_type': ['No Deposit'],
    'agent': [240],
    'days_in_waiting_list': [0],
    'customer_type': ['Transient'],
    'adr': [82],
    'required_car_parking_spaces': [0],
    'total_of_special_requests': [1],
    'city': ['Delhi']
})

# %%
pred = int(model.predict(user)[0])
proba = model.predict_proba(user)[0][1]

if proba >= 0.8:
    risk = "HIGH 🔴"
elif proba >= 0.5:
    risk = "MEDIUM 🟠"
else:
    risk = "LOW 🟢"

label = "Cancelled ❌" if pred == 1 else "Not Cancelled ✅"

print(f"Predicted booking: {label}")
print(f"Cancellation probability: {proba:.2%}")
print(f"Risk level: {risk}")
# Out:
# Predicted booking: Cancelled ❌
# Cancellation probability: 88.70%
# Risk level: HIGH 🔴

# %% [markdown]
# <a href="../demo/app.py" target="_blank" style="text-decoration: none;">
#     <button style="
#         background-color: #50a1ffff;
#         color: white;
#         padding: 12px 24px;
#         font-size: 16px;
#         border: none;
#         border-radius: 8px;
#         cursor: pointer;
#         transition: background-color 0.3s;
#     " onmouseover="this.style.backgroundColor='#50a1ffff'" onmouseout="this.style.backgroundColor='#50a1ffff'">
#         Gradio
#     </button>
# </a>
#
# <a href="../app/main.py" target="_blank" style="text-decoration: none;">
#     <button style="
#         background-color: #50a1ffff;
#         color: white;
#         padding: 12px 24px;
#         font-size: 16px;
#         border: none;
#         border-radius: 8px;
#         cursor: pointer;
#         transition: background-color 0.3s;
#         margin-left: 20px;
#     " onmouseover="this.style.backgroundColor='#50a1ffff'" onmouseout="this.style.backgroundColor='#50a1ffff'">
#         FastAPI
#     </button>
# </a>
