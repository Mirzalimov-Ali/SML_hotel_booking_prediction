# %% [markdown]
# <div style="
#   font-family: 'Segoe UI', sans-serif;
#   line-height: 1.8;
#   max-width: 900px;
#   margin: auto;
#   color: #e6e6e6;
# ">
#
#   <h2 style="color:#f2f2f2;">🏨 Hotel Booking Cancelling Prediction</h2>
#
#   <p style="color:#d0d0d0;">
#     So‘nggi yillarda hotel booking tizimlari juda qulay bo‘lib ketdi.
#     Lekin bu qulaylik bilan birga mehmonxonalar uchun bitta jiddiy muammo paydo bo‘ldi —
#     <b style="color:#ffffff;">booking’larning bekor qilinishi</b>.
#   </p>
#
#   <p style="color:#d0d0d0;">
#     Ayniqsa oxirgi daqiqada bekor qilingan buyurtmalar bo‘sh xonalar,
#     rejalashtirilmagan zarar va noto‘g‘ri resurs taqsimotiga olib keladi.
#     Shu sababli
#     <span style="color:#6cb6ff; font-weight:600;">
#       booking bekor qilinadimi yoki yo‘qmi
#     </span>
#     degan savol oldindan bilish juda muhim.
#   </p>
#
#   <div style="
#     background: #1f2933;
#     padding: 14px 18px;
#     border-radius: 10px;
#     margin: 18px 0;
#     border: 1px solid #2d3748;
#   ">
#     <p style="margin:0; color:#eaeaea;">
#       🎯 <b>Loyiha maqsadi</b> — hotel booking ma’lumotlari asosida
#       <code style="color:#a5d6ff;">is_canceled</code>
#       ustunini bashorat qiladigan Machine Learning model yasash.
#     </p>
#   </div>
#
#   <p style="color:#d0d0d0;">
#     Ushbu loyiha mashinani o‘rganish nuqtai nazaridan
#     <b style="color:#ffffff;">Binary Classification</b> muammosi hisoblanadi:
#   </p>
#
#   <ul style="color:#d0d0d0; padding-left:22px;">
#     <li>✅ <b>0</b> — booking bekor qilinmagan</li>
#     <li>❌ <b>1</b> — booking bekor qilingan</li>
#   </ul>
#
#   <ul style="color:#d1d5db; line-height:1.7; padding-left:20px;">
#     <li>📁 <b>Total rows:</b> 119,390</li>
#     <li>🧩 <b>Total features:</b> 32</li>
#     <li>🎯 <b>Target variable:</b> <code style="color:#93c5fd;">is_canceled</code></li>
#     <li>📌 <b>Problem type:</b> Binary Classification</li>
#   </ul>
#
#   <p style="color:#d1d5db;">
#     Dataset jami <b>32 ta feature</b> ustunidan iborat.
#     Quyidagi jadvalda har bir feature nomi, mavjud qiymatlar soni,
#     ma’lumot turi va qisqacha izohi keltirilgan.
#   </p>
#
#   <div style="overflow-x:auto; margin-top:16px;">
#   <table style="
#     width:100%;
#     border-collapse:collapse;
#     font-family: 'Segoe UI', sans-serif;
#     font-size:14px;
#     background:#020617;
#     color:#e5e7eb;
#     border-radius:12px;
#     overflow:hidden;
#   ">
#
#   <thead style="background:#0f172a;">
#   <tr>
#     <th style="padding:10px;">Feature name</th>
#     <th style="padding:10px;">Non-null count</th>
#     <th style="padding:10px;">Type</th>
#     <th style="padding:10px;">Izoh</th>
#   </tr>
#   </thead>
#
#   <tbody>
#
#   <tr><td>hotel</td><td>119,390</td><td>object</td><td>Mehmonxona turi (City / Resort)</td></tr>
#   <tr><td><b>is_canceled</b></td><td>119,390</td><td>int</td><td>🎯 Target — booking bekor qilinganmi</td></tr>
#   <tr><td>lead_time</td><td>119,390</td><td>int</td><td>Booking va kelish oralig‘idagi kunlar</td></tr>
#
#   <tr><td>arrival_date_year</td><td>119,390</td><td>int</td><td>Kelish yili</td></tr>
#   <tr><td>arrival_date_month</td><td>119,390</td><td>object</td><td>Kelish oyi</td></tr>
#   <tr><td>arrival_date_week_number</td><td>119,390</td><td>int</td><td>Yil bo‘yicha hafta raqami</td></tr>
#   <tr><td>arrival_date_day_of_month</td><td>119,390</td><td>int</td><td>Oy ichidagi kelish kuni</td></tr>
#
#   <tr><td>stays_in_weekend_nights</td><td>119,390</td><td>int</td><td>Dam olish kunlari tunlar soni</td></tr>
#   <tr><td>stays_in_week_nights</td><td>119,390</td><td>int</td><td>Ish kunlari tunlar soni</td></tr>
#
#   <tr><td>adults</td><td>119,390</td><td>int</td><td>Katta mehmonlar soni</td></tr>
#   <tr><td>children</td><td>119,386</td><td>float</td><td>Bolalar soni</td></tr>
#   <tr><td>babies</td><td>119,390</td><td>int</td><td>Chaqaloqlar soni</td></tr>
#
#   <tr><td>meal</td><td>119,390</td><td>object</td><td>Ovqat rejasi</td></tr>
#   <tr><td>country</td><td>118,902</td><td>object</td><td>Mijoz mamlakati</td></tr>
#   <tr><td>market_segment</td><td>119,390</td><td>object</td><td>Marketing segmenti</td></tr>
#   <tr><td>distribution_channel</td><td>119,390</td><td>object</td><td>Booking kanali</td></tr>
#
#   <tr><td>is_repeated_guest</td><td>119,390</td><td>int</td><td>Qayta kelgan mijozmi</td></tr>
#   <tr><td>previous_cancellations</td><td>119,390</td><td>int</td><td>Oldingi bekor qilishlar soni</td></tr>
#   <tr><td>previous_bookings_not_canceled</td><td>119,390</td><td>int</td><td>Oldin bekor qilinmagan bookinglar</td></tr>
#
#   <tr><td>reserved_room_type</td><td>119,390</td><td>object</td><td>Band qilingan xona turi</td></tr>
#   <tr><td>assigned_room_type</td><td>119,390</td><td>object</td><td>Berilgan haqiqiy xona turi</td></tr>
#   <tr><td>booking_changes</td><td>119,390</td><td>int</td><td>Booking o‘zgarishlari soni</td></tr>
#
#   <tr><td>deposit_type</td><td>119,390</td><td>object</td><td>Depozit turi</td></tr>
#   <tr><td>agent</td><td>103,050</td><td>float</td><td>Booking agent ID</td></tr>
#   <tr><td>company</td><td>6,797</td><td>float</td><td>Kompaniya ID</td></tr>
#
#   <tr><td>days_in_waiting_list</td><td>119,390</td><td>int</td><td>Kutish ro‘yxatidagi kunlar</td></tr>
#   <tr><td>customer_type</td><td>119,390</td><td>object</td><td>Mijoz turi</td></tr>
#   <tr><td>adr</td><td>119,390</td><td>float</td><td>Kunlik o‘rtacha narx</td></tr>
#
#   <tr><td>required_car_parking_spaces</td><td>119,390</td><td>int</td><td>Avtoturargoh ehtiyoji</td></tr>
#   <tr><td>total_of_special_requests</td><td>119,390</td><td>int</td><td>Maxsus so‘rovlar soni</td></tr>
#
#   <tr><td>reservation_status_date</td><td>119,390</td><td>object</td><td>Booking holati sanasi</td></tr>
#   <tr><td>city</td><td>119,390</td><td>object</td><td>Mehmonxona joylashgan shahar</td></tr>
#
#   </tbody>
#   </table>
#   </div>
#
#
#
# </p>
#
# <div style="
#   border-left: 4px solid #3fb950;
#   padding-left: 14px;
#   margin-top: 16px;
# ">
#   <p style="margin:0; color:#dcdcdc;">
#     💡 Loyiha jarayonida turli preprocessing va modeling yondashuvlari
#     sinab ko‘rildi va ularning natijalari solishtirildi.
#   </p>
# </div>
#
# <p style="color:#9ca3af; margin-top:16px;">
#   📌 Jupyter Notebook’larda loyiha bo‘limlari orasida tez harakatlanish uchun
#   maxsus navigation button’lar qo‘shilgan.
# </p>
#
#
# </div>
#
# <!-- ey gandon shunday qilib nimani aynan qayerga yozishni gapirib ket bu codega tegmay dedim sen cho'chqaga mol -->

# %% [markdown]
# <div style="
#   font-family: 'Segoe UI', sans-serif;
#   line-height: 1.8;
#   max-width: 900px;
#   margin: auto;
#   color: #e6e6e6;
# ">
#
#   <div style="display: flex">
#     <h2 style="color:#f2f2f2;">🧩 Data Splitting</h2>
#     <a href="../scripts/use_split_data.py" target="_blank" style="text-decoration: none;">
#       <p style="color: #85e26dff">View Code</p>
#     </a>
#   </div>
#
#
#   <p style="color:#d0d0d0;">
#     Data Leakageni oldini olish uchun bizda
#     <b style="color:#ffffff;">train</b> va
#     <b style="color:#ffffff;">test</b> qismlarga bo‘lindi.
#   </p>
#
#   <p style="color:#d0d0d0;">
#     Data splitting jarayoni modelning
#     <span style="color:#6cb6ff; font-weight:600;">
#       yangi, ko‘rilmagan ma’lumotlar
#     </span>
#     ustida qanday ishlashini tekshirish imkonini beradi.
#   </p>
#
#   <div style="
#     background: #1f2933;
#     padding: 14px 18px;
#     border-radius: 10px;
#     margin: 18px 0;
#     border: 1px solid #2d3748;
#   ">
#     <p style="margin:0; color:#eaeaea;">
#       📌 Dataset quyidagi nisbatda bo‘lindi:
#     </p>
#
#   <ul style="margin:8px 0 0 18px; color:#d1d5db;">
#     <li>🧠 <b>Training set:</b> 80%</li>
#     <li>🧪 <b>Test set:</b> 20%</li>
#   </ul>
#   </div>
#
#   <p style="color:#d0d0d0;">
#     Target variable sifatida
#     <code style="color:#93c5fd;">is_canceled</code>
#     tanlandi va u
#     <b style="color:#ffffff;">x_train</b> (featurelar) hamda
#     <b style="color:#ffffff;">x_test</b> (featurelar),
#     <b style="color:#ffffff;">y_train</b> (target),
#     <b style="color:#ffffff;">y_test</b> (target) ga ajratildi.
#   </p>
#
#   <div style="
#     background:#020617;
#     padding:12px 16px;
#     border-radius:10px;
#     border:1px solid #0f172a;
#     margin-top:16px;
#   ">
#     <p style="margin:0; color:#e5e7eb;">
#       🔹 <b>x_train</b> — 31 ta feature<br>
#       🔹 <b>x_test</b> — 31 ta feature<br>
#       🔹 <b>y_train</b> — <code style="color:#93c5fd;">is_canceled</code> (Binary target)<br>
#       🔹 <b>y_test</b> — <code style="color:#93c5fd;">is_canceled</code> (Binary target)
#     </p>
#   </div>
#   <div style="
#     background:#020617;
#     padding:14px 18px;
#     border-radius:10px;
#     border:1px solid #0f172a;
#     margin-top:16px;
#   ">
#
#   <p style="margin:0; color:#e5e7eb;">
#     💾 <b>Data Splitting’dan so‘ng ma’lumotlar alohida fayllar sifatida saqlandi:</b>
#   </p>
#
#   <ul style="margin:10px 0 0 20px; color:#d1d5db; line-height:1.7;">
#     <li>
#       <code style="color:#93c5fd;">data/split/x_train.csv</code> —
#       training featurelar
#     </li>
#     <li>
#       <code style="color:#93c5fd;">data/split/x_test.csv</code> —
#       test featurelar
#     </li>
#     <li>
#       <code style="color:#93c5fd;">data/split/y_train.csv</code> —
#       training target (<b>is_canceled</b>)
#     </li>
#     <li>
#       <code style="color:#93c5fd;">data/split/y_test.csv</code> —
#       test target (<b>is_canceled</b>)
#     </li>
#   </ul>
#
#   </div>
#
#
#   <p style="color:#9ca3af; margin-top:14px;">
#     📌 Data’ni alohida fayllarga saqlash orqali
#     preprocessing, feature selection va modeling bosqichlari
#     bir-biridan mustaqil va qayta ishlatish uchun qulay qilindi.
#   </p>
# </div>

# %% [markdown]
# <div style="
#   font-family: 'Segoe UI', sans-serif;
#   line-height: 1.8;
#   max-width: 900px;
#   margin: auto;
#   color: #e6e6e6;
# ">
#   <div style='display: flex'>
#     <h2 style="color:#f9fafb; margin-top:0;">
#       🧩 Missing Values Handling
#     </h2>
#         <a href="../scripts/use_filling.py" target="_blank" style="text-decoration: none;">
#         <p style="color: #85e26dff">View Code</p>
#       </a>
#   </div>
#
#   <p style="color:#d1d5db;">
#     Real hayotdagi dataset’larda <b>bo‘sh (missing) qiymatlar</b> bo‘lishi odatiy hol.
#     Ushbu loyiha dataset’ida ham ayrim feature’larda to‘liq bo‘lmagan ma’lumotlar mavjud.
#   </p>
#
#   <p style="color:#d1d5db;">
#     Missing value’lar model natijasiga salbiy ta’sir qilmasligi uchun
#     ularni <b>ma’lumot turiga mos ravishda</b> qayta ishlash muhim.
#   </p>
#
#   <ul style="color:#e5e7eb; line-height:1.7; padding-left:22px;">
#     <li>
#       🔢 <b>Numerical feature’lar</b> —
#       5ta qushni atrofida istaydigon KNNImputer orqali tuldirildi
#     </li>
#     <li>
#       🔤 <b>Categorical feature’lar</b> —
#       eng ko‘p uchraydigan qiymat (mode) bilan to‘ldirildi
#     </li>
#   </ul>
#
#   <p style="color:#d1d5db;">
#     Bu jarayon modelga <b>barqarorlik</b> va
#     <b>realistik bashorat</b> berishga yordam berdi.
#   </p>
#
# </div>

# %% [markdown]
# <div style="
#   font-family: 'Segoe UI', sans-serif;
#   line-height: 1.8;
#   max-width: 900px;
#   margin: auto;
#   color: #e6e6e6;
# ">
#
#   <div style='display: flex'>
#     <h2 style="color:#f9fafb; margin-top:0;">
#       🧠 Feature Engineering
#     </h2>
#         <a href="../scripts/use_feature_engineering.py" target="_blank" style="text-decoration: none;">
#         <p style="color: #85e26dff">View Code</p>
#       </a>
#   </div>
#
#   <p style="color:#d1d5db;">
#     29 ta Feature yasaldi
#     Model faqat xom (raw) feature’lar bilan cheklanib qolmasligi uchun
#     loyiha davomida <b>qo‘shimcha ma’noli feature’lar</b> yasaldi.
#     Bu jarayon <b>Feature Engineering</b> deb ataladi.
#   </p>
#
#   <p style="color:#d1d5db;">
#     Yaratilgan feature’lar mijoz xatti-harakati, booking vaqti,
#     narx mantiqi va risk omillarini yaxshiroq ifodalashga qaratilgan.
#     Natijada model <b>murakkab naqshlarni</b> osonroq o‘rganadi.
#   </p>
#
#   <p style="color:#9ca3af;">
#     Quyida ushbu loyihada qo‘llanilgan barcha engineered feature’lar,
#     ularning turi va qisqacha ma’nosi keltirilgan.
#   </p>
#
#   <div style="overflow-x:auto; margin-top:16px;">
#   <table style="
#     width:100%;
#     border-collapse:collapse;
#     font-size:14px;
#     background:#020617;
#     color:#e5e7eb;
#     border-radius:12px;
#     overflow:hidden;
#   ">
#
#   <thead style="background:#0f172a;">
#     <tr>
#       <th style="padding:10px;">Feature name</th>
#       <th style="padding:10px;">Type</th>
#       <th style="padding:10px;">Izoh</th>
#     </tr>
#   </thead>
#
# <tbody>
#
#   <tr><td>total_nights</td><td>int</td><td>Jami tunlar soni (weekend + weekday)</td></tr>
#   <tr><td>lead_time_log</td><td>float</td><td>Lead time’ning log-transformatsiyasi</td></tr>
#   <tr><td>is_extreme_lead</td><td>int</td><td>1 yildan oldin qilingan booking belgisi</td></tr>
#
#   <tr><td>total_guests</td><td>int</td><td>Jami mehmonlar soni</td></tr>
#   <tr><td>is_free_booking</td><td>int</td><td>Narxi 0 bo‘lgan booking</td></tr>
#   <tr><td>has_previous_cancel</td><td>int</td><td>Oldin bekor qilgan mijozmi</td></tr>
#   <tr><td>is_loyal_customer</td><td>int</td><td>Sodiq yoki qayta kelgan mijoz</td></tr>
#
#   <tr><td>room_changed</td><td>int</td><td>Band qilingan va berilgan xona mos kelmasligi</td></tr>
#   <tr><td>has_agent</td><td>int</td><td>Booking agent orqali qilinganmi</td></tr>
#
#   <tr><td>is_short_stay</td><td>int</td><td>Qisqa muddatli turar joy (≤2 tun)</td></tr>
#   <tr><td>is_long_stay</td><td>int</td><td>Uzoq muddatli turar joy (≥7 tun)</td></tr>
#   <tr><td>weekend_ratio</td><td>float</td><td>Weekend tunlar ulushi</td></tr>
#
#   <tr><td>is_last_minute</td><td>int</td><td>Oxirgi daqiqadagi booking (≤7 kun)</td></tr>
#   <tr><td>adr_x_lead_time</td><td>float</td><td>Narx va lead time kombinatsiyasi</td></tr>
#   <tr><td>high_adr</td><td>int</td><td>O‘rtachadan yuqori narxli booking</td></tr>
#   <tr><td>adr_per_person</td><td>float</td><td>Bir kishiga to‘g‘ri keladigan narx</td></tr>
#
#   <tr><td>is_suspicious_price</td><td>int</td><td>0 narx + maxsus so‘rov yo‘q (shubhali)</td></tr>
#
#   <tr><td>has_children</td><td>int</td><td>Bolali mijoz</td></tr>
#   <tr><td>has_babies</td><td>int</td><td>Chaqaloqli mijoz</td></tr>
#   <tr><td>solo_traveler</td><td>int</td><td>Yolg‘iz sayohatchi</td></tr>
#
#   <tr><td>many_booking_changes</td><td>int</td><td>Ko‘p marta booking o‘zgartirilgan</td></tr>
#   <tr><td>was_waitlisted</td><td>int</td><td>Kutish ro‘yxatida bo‘lgan booking</td></tr>
#
#   <tr><td>many_special_requests</td><td>int</td><td>Ko‘p maxsus so‘rovlar mavjud</td></tr>
#   <tr><td>needs_parking</td><td>int</td><td>Avtoturargoh talab qilingan</td></tr>
#
#   <tr><td>is_high_season</td><td>int</td><td>Yuqori mavsumda qilingan booking</td></tr>
#   <tr><td>online_booking</td><td>int</td><td>Online kanal orqali qilingan booking</td></tr>
#   <tr><td>agent_booking</td><td>int</td><td>Agent + online segment kombinatsiyasi</td></tr>
#
#   <tr><td>risky_customer</td><td>int</td><td>Faqat bekor qilish tarixi bor mijoz</td></tr>
#   <tr><td>room_mismatch_online</td><td>int</td><td>Online booking + xona mos kelmasligi</td></tr>
#
# </tbody>
#   </table>
#   </div>
#
#   <p style="color:#9ca3af; margin-top:14px;">
#     Ushbu feature’lar yordamida model booking bekor qilinishini
#     <b>chuqurroq kontekst</b> asosida o‘rganadi.
#   </p>
#
# </div>

# %% [markdown]
# <div style="
#   font-family: 'Segoe UI', sans-serif;
#   line-height: 1.8;
#   max-width: 900px;
#   margin: auto;
#   color: #e6e6e6;
# ">
#
#   <div style='display: flex'>
#     <h2 style="margin-top:32px; color:#f1f5f9;">
#     ⚙️ Encoding, Log Transformation & Scaling
#     </h2>
#         <a href="../scripts/use_preprocessing.py" target="_blank" style="text-decoration: none;">
#         <p style="color: #85e26dff">View Code</p>
#       </a>
#   </div>
#
# <p style="color:#d1d5db;">
# Modelga ma’lumot berishdan oldin barcha feature’lar
# sonli ko‘rinishga keltirildi va bir xil masshtabda
# normalizatsiya qilindi.
# </p>
#
# <!-- Ordinal Encoding -->
# <div style="
#   background:#020617;
#   border:1px solid #1e293b;
#   border-radius:10px;
#   padding:14px 16px;
#   margin-top:18px;
# ">
#   <p style="margin:0; color:#e5e7eb;">
#     🔤 <b>Ordinal Encoding</b>
#   </p>
#   <p style="margin-top:6px; color:#cbd5f5;">
#     Tartibga ega bo‘lgan kategorik feature’lar
#     (masalan, customer type yoki deposit type)
#     ordinal encoding yordamida raqamli qiymatlarga o‘tkazildi.
#     Bu modelga kategoriyalar o‘rtasidagi mantiqiy tartibni
#     saqlab qolishga yordam beradi.
#   </p>
# </div>
#
# <!-- Log Transformation -->
# <div style="
#   background:#020617;
#   border:1px solid #1e293b;
#   border-radius:10px;
#   padding:14px 16px;
#   margin-top:14px;
# ">
#   <p style="margin:0; color:#e5e7eb;">
#     🔁 <b>Log Transformation</b>
#   </p>
#   <p style="margin-top:6px; color:#cbd5f5;">
#     Taqsimoti o‘ta notekis bo‘lgan sonli feature’lar
#     uchun <code style="color:#93c5fd;">log(1 + x)</code>
#     transformatsiyasi qo‘llanildi.
#     Bu juda katta qiymatlarning modelga bo‘lgan
#     salbiy ta’sirini kamaytiradi.
#   </p>
# </div>
#
# <!-- Standard Scaling -->
# <div style="
#   background:#020617;
#   border:1px solid #1e293b;
#   border-radius:10px;
#   padding:14px 16px;
#   margin-top:14px;
# ">
#   <p style="margin:0; color:#e5e7eb;">
#     ⚖️ <b>Standard Scaling</b>
#   </p>
#   <p style="margin-top:6px; color:#cbd5f5;">
#     Barcha raqamli feature’lar Standard Scaler yordamida
#     o‘rtacha qiymati 0, dispersiyasi 1 bo‘lgan
#     masshtabga keltirildi.
#     Bu ayniqsa gradient-based modellarda
#     trening jarayonini barqarorlashtiradi.
#   </p>
# </div>
# </div>

# %% [markdown]
# <div style="
#   font-family: 'Segoe UI', sans-serif;
#   line-height: 1.8;
#   max-width: 900px;
#   margin: auto;
#   color: #e6e6e6;
# ">
#
#   <div style='display: flex'>
#     <h2 style="margin-top:32px; color:#f1f5f9;">
#     🚀 Baseline Model Training
#     </h2>
#         <a href="../notebooks/base_model_training.ipynb" target="_blank" style="text-decoration: none;">
#         <p style="color: #85e26dff">View Code</p>
#       </a>
#   </div>
#
#   <p style="
#     color:#d1d5db;
#     margin-bottom:20px;
#   ">
#     Model performance’ni baholash uchun dastlab
#     oddiy va tushunarli baseline model’lar o‘rgatildi.
#     Bu bosqich keyingi murakkab model’lar bilan
#     solishtirish uchun asos bo‘lib xizmat qiladi.
#   </p>
#
#   <div style="
#     background:#020617;
#     border:1px solid #1e293b;
#     border-radius:12px;
#     padding:16px;
#     margin-bottom:28px;
#   ">
#     <ul style="
#       margin:0;
#       padding-left:22px;
#       color:#cbd5f5;
#       line-height:1.7;
#       text-align:left;
#     ">
#       <li>📌 <b>Logistic Regression</b> — sodda va interpretatsiyasi oson model</li>
#       <li>🌳 <b>Decision Tree Classifier</b> — nolinear munosabatlarni tez aniqlash uchun</li>
#     </ul>
#   </div>

# %% [markdown]
# <div style="
#   font-family: 'Segoe UI', sans-serif;
#   line-height: 1.8;
#   max-width: 900px;
#   margin: auto;
#   color: #e6e6e6;
# ">
#
#   <div style='display: flex'>
#     <h2 style="margin-top:32px; color:#f1f5f9;">
#       🧠 Feature Selection Experiments
#     </h2>
#         <a href="../notebooks/FS" target="_blank" style="text-decoration: none;">
#         <p style="color: #85e26dff">View Code</p>
#       </a>
#   </div>
#
# <p style="color:#d1d5db; margin-top:12px;">
#   Ushbu bosqichda feature’lar sonini kamaytirish yoki
#   eng muhim ustunlarni ajratib olish model natijasiga
#   qanday ta’sir qilishini tekshirish maqsad qilingan.
# </p>
#
# <div style="
#   background:#020617;
#   border:1px solid #1e293b;
#   border-radius:12px;
#   padding:16px;
#   margin-top:16px;
# ">
#   <ul style="
#     margin:0;
#     padding-left:22px;
#     color:#cbd5f5;
#     line-height:1.7;
#   ">
#     <li>🧪 <b>Filter methods</b> — statistik ko‘rsatkichlar asosida feature tanlash</li>
#     <li>🧩 <b>Embedded methods</b> — model ichida avtomatik tanlash</li>
#     <li>🔍 <b>Wrapper methods</b> — feature kombinatsiyalarini ketma-ket sinash</li>
#   </ul>
# </div>
#
# <p style="color:#d1d5db; margin-top:14px;">
#   Har bir yondashuv <code style="color:#93c5fd;">/notebook</code> papkasida
#   alohida test qilinib, model natijalari o‘zaro solishtirildi.
# </p>
#
# <div style="
#   background:#052e16;
#   border:1px solid #166534;
#   border-radius:12px;
#   padding:16px;
#   margin-top:16px;
# ">
#   <p style="margin:0; color:#dcfce7;">
#     ✅ Tajribalar natijasida <b>feature selection qo‘llanilmagan holat</b>
#     (ya’ni barcha feature’lardan foydalanilgan model)
#     eng yaxshi natija ko‘rsatdi.
#   </p>
# </div>
#
# <p style="color:#9ca3af; margin-top:12px;">
#   Shu sababli yakuniy model yaratishda
#   feature selection bosqichi tashlab ketildi.
# </p>
#
# </div>

# %% [markdown]
# <div style="
#   font-family: 'Segoe UI', sans-serif;
#   line-height: 1.8;
#   max-width: 900px;
#   margin: auto;
#   color: #e6e6e6;
# ">
#
#   <h2 style="margin-top:32px; color:#f1f5f9;">
#     ⚙️ Advanced Modeling Steps
#   </h2>
#
#   <!-- Class Imbalance Handling -->
#   <div style="
#     background:#1f2933;
#     padding:16px 20px;
#     border-radius:12px;
#     margin:20px 0;
#     border:1px solid #2d3748;
#     text-align:left;
#   ">
#     <h3 style="color:#facc15;">📊 Class Imbalance Handling (SMOTE)</h3>
#     <p style="color:#e5e7eb; line-height:1.7;">
#       Target class’da imbalance mavjudligi sababli, train dataset’da <b>SMOTE</b> qo‘llandi.
#       Bu model’ning minority class’ni yaxshiroq o‘rganishiga yordam berdi.
#     </p>
#   </div>
#
#   <!-- Hyperparameter Tuning -->
#   <div style="
#     background:#1f2933;
#     padding:16px 20px;
#     border-radius:12px;
#     margin:20px 0;
#     border:1px solid #2d3748;
#     text-align:left;
#   ">
#     <h3 style="color:#f87171;">⚡ Hyperparameter Tuning (Optuna)</h3>
#     <p style="color:#e5e7eb; line-height:1.7;">
#       Model’larning optimal parametrlarini topish uchun <b>Optuna</b> yordamida hyperparameter tuning amalga oshirildi.
#       Bu bosqich model performance’ni sezilarli yaxshilashga xizmat qildi.
#     </p>
#   </div>
#
# </div>

# %% [markdown]
# <div style="
#   font-family: 'Segoe UI', sans-serif;
#   line-height: 1.8;
#   max-width: 900px;
#   margin: auto;
#   color: #e6e6e6;
# ">
#
#   <div style='display: flex'>
#       <h2 style="margin-top:32px; color:#f1f5f9;">
#         🚀 Final Model Training (Production-level)
#       </h2>
#         <a href="../scripts/use_model_training.py" target="_blank" style="text-decoration: none;">
#         <p style="color: #85e26dff">View Code</p>
#       </a>
#   </div>
#
#   <div style="
#     padding:16px 20px;
#     border-radius:12px;
#     margin:20px 0;
#     border:1px solid #2d3748;
#     text-align:left;
#   ">
#     <h3 style="color:#f87171;">🔥 PROJECT PEAK</h3>
#     <p style="color:#e5e7eb; line-height:1.7;">
#       Yakuniy model train qilish uchun alohida <code style="color:#93c5fd;">use_training.py</code> pipeline yozildi.
#       Ushbu pipeline quyidagilarni o‘z ichiga oladi:
#     </p>
#     <ul style="color:#e5e7eb; line-height:1.7; padding-left:20px;">
#       <li>🧹 Preprocessing</li>
#       <li>📊 SMOTE</li>
#       <li>⚡ Tuned hyperparameter’lar</li>
#     </ul>
#
#   <p style="color:#e5e7eb; line-height:1.7;">
#     Yakuniy tanlangan model — <b>Stacking Classifier</b>, uning tarkibida:
#   </p>
#   <ul style="color:#e5e7eb; line-height:1.7; padding-left:20px;">
#     <li>🛠 Base models: Random Forest, XGBoost, LightGBM</li>
#     <li>🏁 Final estimator: BaggingClassifier
#       <ul style="padding-left:20px; color:#e5e7eb;">
#         <li>Base estimator: Logistic Regression</li>
#       </ul>
#     </li>
#   </ul>
#   <div style="
#   font-family: 'Segoe UI', sans-serif;
#   line-height: 1.8;
#   max-width: 900px;
#   margin: auto;
#   color: #e6e6e6;
#   text-align: center;
# ">
#
#   <h2 style="margin-top:32px; color:#f1f5f9;">
#     🏆 Final Model Results
#   </h2>
#
#   <div style="
#     background:#1f2933;
#     padding:16px 0px;
#     border-radius:12px;
#     border:1px solid #2d3748;
#     overflow-x:auto;
#   ">
#     <p style="color:#e5e7eb; line-height:1.7;">
#       Yakuniy model natijalari (improvements bilan) quyidagicha:
#     </p>
#
#   <table style="
#     width:99%;
#     border-collapse:collapse;
#     font-family: 'Segoe UI', sans-serif;
#     font-size:14px;
#     background:#0f172a;
#     color:#e5e7eb;
#     overflow:hidden;
#     text-align:center;
#     margin-top:12px;
#     margin-left: 4px;
#   ">
#     <thead style="background:#111827;">
#       <tr>
#         <th style="padding:10px;">Algorithm</th>
#         <th style="padding:10px;">Accuracy</th>
#         <th style="padding:10px;">Precision</th>
#         <th style="padding:10px;">Recall</th>
#         <th style="padding:10px;">F1-score</th>
#         <th style="padding:10px;">K-Fold mean</th>
#         <th style="padding:10px;">K-Fold std</th>
#       </tr>
#     </thead>
#     <tbody>
#       <tr>
#         <td>Stacking</td>
#         <td>0.86</td>
#         <td>0.77</td>
#         <td>0.91</td>
#         <td>0.83</td>
#         <td>0.91</td>
#         <td>0.00</td>
#       </tr>
#     </tbody>
#   </table>
#   </div>
#
# </div>
#
#   </div>
#
# </div>

# %% [markdown]
# <!-- Offline Testing (Real User Data) -->
# <div style="
#   font-family: 'Segoe UI', sans-serif;
#   line-height:1.8;
#   max-width: 900px;
#   margin:auto;
#   color:#e6e6e6;
# ">
#
#
#   <div style='display: flex'>
#     <h2 style="color:#f1f5f9; margin-top:24px;">📌 Offline Testing</h2>
#         <a href="../notebooks/offline_testing.ipynb" target="_blank" style="text-decoration: none;">
#         <p style="color: #85e26dff">View Code</p>
#       </a>
#   </div>
#
#   <div style="
#     background:#1f2933;
#     padding:20px;
#     border-radius:12px;
#     border:1px solid #2d3748;
#     margin-top:16px;
#   ">
#     <p style="color:#e5e7eb; font-size:20px; margin-bottom:12px;">
#       Model real user ma’lumotlari asosida predict qilindi:
#     </p>
#
#   <p style="color:#f87171; font-size:18px; margin:4px 0;">
#     Predicted booking: <b>Cancelled ❌</b>
#   </p>
#   <p style="color:#60a5fa; font-size:18px; margin:4px 0;">
#     Cancellation probability: <b>88.70%</b>
#   </p>
#   <p style="color:#fbbf24; font-size:18px; margin:4px 0;">
#     Risk level: <b>HIGH 🔴</b>
#   </p>
#   </div>
#
# </div>

# %% [markdown]
# <div style="
#   font-family: 'Segoe UI', sans-serif;
#   line-height: 1.8;
#   max-width: 900px;
#   margin: auto;
#   color: #e6e6e6;
# ">
#
#   <h2 style="margin-top:32px; color:#f1f5f9;">🚀 API/UI</h2>
#   <div style="
#     background:#1f2933;
#     padding:16px 20px;
#     border-radius:12px;
#     margin:16px 0;
#     border:1px solid #2d3748;
#   ">
#     <p style="color:#e5e7eb; line-height:1.7;">
#       Model real foydalanish uchun deploy qilindi:
#     </p>
#     <ul style="color:#d1d5db; line-height:1.7; padding-left:20px; text-align:left;">
#       <li>⚡ FastAPI / Gradio yordamida API va UI ko‘rinishida.</li>
#       <li>👤 Foydalanuvchilar real vaqtda <b>booking cancellation prediction</b> qilishi mumkin.</li>
#     </ul>
#   </div>
#
# </div>
