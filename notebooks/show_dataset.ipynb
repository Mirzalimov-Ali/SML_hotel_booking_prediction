# %%
import pandas as pd
import os

# %%
os.chdir(r'C:\SML_Projects\SML_hotelBooking_cancelling_prediction')

# %% [markdown]
# # Raw Dataset (119,390 row)

# %%
print("=================== Raw dataset =================== \n")
df = pd.read_csv("data/raw/hotel_bookings_updated_2024.csv")
df.info()
# Out:
# =================== Raw dataset ===================
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 33 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
# ...

# %% [markdown]
# <a href="../data/raw/autos.csv" target="_blank" style="text-decoration: none;">
#     <button style="
#         background-color: #2626f7ff;
#         color: white;
#         padding: 12px 24px;
#         font-size: 16px;
#         border: none;
#         border-radius: 8px;
#         cursor: pointer;
#         transition: background-color 0.3s;
#     " onmouseover="this.style.backgroundColor='#3434f5ff'" onmouseout="this.style.backgroundColor='#1e1ec8ff'">
#         Show Raw Dataset (.csv)
#     </button>
# </a>

# %% [markdown]
# # TRAIN/TEST split dataset (sum 119,390 row)

# %% [markdown]
# ## x_train dataset (80%, 95,512 row)

# %%
print("=================== x_train =================== \n")
x_train = pd.read_csv("data/split/x_train.csv")
x_train.info()
# Out:
# =================== x_train ===================
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95512 entries, 0 to 95511
# Data columns (total 28 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           95512 non-null  object
#  1   lead_time                       95512 non-null  int64
#  2   arrival_date_month              95512 non-null  object
#  3   arrival_date_week_number        95512 non-null  int64
#  4   arrival_date_day_of_month       95512 non-null  int64
#  5   stays_in_weekend_nights         95512 non-null  int64
#  6   stays_in_week_nights            95512 non-null  int64
#  7   adults                          95512 non-null  int64
#  8   children                        95508 non-null  float64
#  9   babies                          95512 non-null  int64
#  10  meal                            95512 non-null  object
# ...

# %% [markdown]
# ## y_train dataset (only target - is_canceled 95,512 row)

# %%
print("=================== y_train =================== \n")
y_train = pd.read_csv("data/split/y_train.csv")
y_train.info()
# Out:
# =================== y_train ===================
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95512 entries, 0 to 95511
# Data columns (total 1 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   is_canceled  95512 non-null  int64
# dtypes: int64(1)
# memory usage: 746.3 KB

# %% [markdown]
# ## x_test dataset (20%, 23,878 row)

# %%
print("=================== x_test =================== \n")
x_test = pd.read_csv("data/split/x_test.csv")
x_test.info()
# Out:
# =================== x_test ===================
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23878 entries, 0 to 23877
# Data columns (total 28 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           23878 non-null  object
#  1   lead_time                       23878 non-null  int64
#  2   arrival_date_month              23878 non-null  object
#  3   arrival_date_week_number        23878 non-null  int64
#  4   arrival_date_day_of_month       23878 non-null  int64
#  5   stays_in_weekend_nights         23878 non-null  int64
#  6   stays_in_week_nights            23878 non-null  int64
#  7   adults                          23878 non-null  int64
#  8   children                        23878 non-null  float64
#  9   babies                          23878 non-null  int64
#  10  meal                            23878 non-null  object
# ...

# %% [markdown]
# ## y_test dataset (only target - is_canceled 23,878 row)

# %%
print("=================== y_test =================== \n")
y_test = pd.read_csv("data/split/y_test.csv")
y_test.info()
# Out:
# =================== y_test ===================
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23878 entries, 0 to 23877
# Data columns (total 1 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   is_canceled  23878 non-null  int64
# dtypes: int64(1)
# memory usage: 186.7 KB

# %% [markdown]
# # Filled Dataset (sum 119,390 row)

# %% [markdown]
# ## Filled x_train dataset

# %%
print("=================== Filled x_train =================== \n")
filled_x_train = pd.read_csv("data/filled/filled_x_train.csv")
filled_x_train.info()
# Out:
# =================== Filled x_train ===================
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95512 entries, 0 to 95511
# Data columns (total 28 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           95512 non-null  object
#  1   lead_time                       95512 non-null  int64
#  2   arrival_date_month              95512 non-null  object
#  3   arrival_date_week_number        95512 non-null  int64
#  4   arrival_date_day_of_month       95512 non-null  int64
#  5   stays_in_weekend_nights         95512 non-null  int64
#  6   stays_in_week_nights            95512 non-null  int64
#  7   adults                          95512 non-null  int64
#  8   children                        95512 non-null  float64
#  9   babies                          95512 non-null  int64
#  10  meal                            95512 non-null  object
# ...

# %% [markdown]
# <a href="../data/filled/filled_dataset.csv" target="_blank" style="text-decoration: none;">
#     <button style="
#         background-color: #2626f7ff;
#         color: white;
#         padding: 12px 24px;
#         font-size: 16px;
#         border: none;
#         border-radius: 8px;
#         cursor: pointer;
#         transition: background-color 0.3s;
#     " onmouseover="this.style.backgroundColor='#3434f5ff'" onmouseout="this.style.backgroundColor='#1e1ec8ff'">
#         Show Filled Dataset (.csv)
#     </button>
# </a>
#
# <a href="../src/preprocessing.py" target="_blank" style="text-decoration: none;">
#     <button style="
#         background-color: #4CAF50;
#         color: white;
#         padding: 12px 24px;
#         font-size: 16px;
#         border: none;
#         border-radius: 8px;
#         cursor: pointer;
#         transition: background-color 0.3s;
#         margin-left: 10px;
#     " onmouseover="this.style.backgroundColor='#45a049'" onmouseout="this.style.backgroundColor='#4CAF50'">
#         Preprocessing Class
#     </button>
# </a>
#
# <a href="../scripts/use_fillMissingValues.py" target="_blank" style="text-decoration: none;">
#     <button style="
#         background-color: #4CAF50;
#         color: white;
#         padding: 12px 24px;
#         font-size: 16px;
#         border: none;
#         border-radius: 8px;
#         cursor: pointer;
#         transition: background-color 0.3s;
#         margin-left: 10px;
#     " onmouseover="this.style.backgroundColor='#45a049'" onmouseout="this.style.backgroundColor='#4CAF50'">
#         Handle missing values
#     </button>
# </a>

# %% [markdown]
# ## Filled x_test dataset

# %%
print("=================== Filled x_test =================== \n")
filled_x_test = pd.read_csv("data/filled/filled_x_test.csv")
filled_x_test.info()
# Out:
# =================== Filled x_test ===================
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23878 entries, 0 to 23877
# Data columns (total 28 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           23878 non-null  object
#  1   lead_time                       23878 non-null  int64
#  2   arrival_date_month              23878 non-null  object
#  3   arrival_date_week_number        23878 non-null  int64
#  4   arrival_date_day_of_month       23878 non-null  int64
#  5   stays_in_weekend_nights         23878 non-null  int64
#  6   stays_in_week_nights            23878 non-null  int64
#  7   adults                          23878 non-null  int64
#  8   children                        23878 non-null  float64
#  9   babies                          23878 non-null  int64
#  10  meal                            23878 non-null  object
# ...

# %% [markdown]
# # Engineered Dataset

# %%
print("=================== Engineered x_train =================== \n")
engineered_x_train = pd.read_csv("data/engineered/engineered_x_train.csv")
engineered_x_train.info()
# Out:
# =================== Engineered x_train ===================
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95512 entries, 0 to 95511
# Data columns (total 54 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           95512 non-null  object
#  1   lead_time                       95512 non-null  int64
#  2   arrival_date_year               95512 non-null  int64
#  3   arrival_date_month              95512 non-null  object
#  4   arrival_date_week_number        95512 non-null  int64
#  5   arrival_date_day_of_month       95512 non-null  int64
#  6   stays_in_weekend_nights         95512 non-null  int64
#  7   stays_in_week_nights            95512 non-null  int64
#  8   adults                          95512 non-null  int64
#  9   children                        95512 non-null  float64
#  10  babies                          95512 non-null  int64
# ...

# %%
print("=================== Engineered x_test =================== \n")
engineered_x_test = pd.read_csv("data/engineered/engineered_x_test.csv")
engineered_x_test.info()
# Out:
# =================== Engineered x_test ===================
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23878 entries, 0 to 23877
# Data columns (total 54 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           23878 non-null  object
#  1   lead_time                       23878 non-null  int64
#  2   arrival_date_year               23878 non-null  int64
#  3   arrival_date_month              23878 non-null  object
#  4   arrival_date_week_number        23878 non-null  int64
#  5   arrival_date_day_of_month       23878 non-null  int64
#  6   stays_in_weekend_nights         23878 non-null  int64
#  7   stays_in_week_nights            23878 non-null  int64
#  8   adults                          23878 non-null  int64
#  9   children                        23878 non-null  float64
#  10  babies                          23878 non-null  int64
# ...

# %% [markdown]
# <a href="../data/engineered/engineered_dataset.csv" target="_blank" style="text-decoration: none;">
#     <button style="
#         background-color: #2626f7ff;
#         color: white;
#         padding: 12px 24px;
#         font-size: 16px;
#         border: none;
#         border-radius: 8px;
#         cursor: pointer;
#         transition: background-color 0.3s;
#     " onmouseover="this.style.backgroundColor='#3434f5ff'" onmouseout="this.style.backgroundColor='#1e1ec8ff'">
#         Show Engineered Dataset (.csv)
#     </button>
# </a>
#
# <a href="../src/feature_engineering.py" target="_blank" style="text-decoration: none;">
#     <button style="
#         background-color: #4CAF50;
#         color: white;
#         padding: 12px 24px;
#         font-size: 16px;
#         border: none;
#         border-radius: 8px;
#         cursor: pointer;
#         transition: background-color 0.3s;
#         margin-left: 10px;
#     " onmouseover="this.style.backgroundColor='#45a049'" onmouseout="this.style.backgroundColor='#4CAF50'">
#         FE Class
#     </button>
# </a>
#
# <a href="../scripts/use_feature_engineering.py" target="_blank" style="text-decoration: none;">
#     <button style="
#         background-color: #4CAF50;
#         color: white;
#         padding: 12px 24px;
#         font-size: 16px;
#         border: none;
#         border-radius: 8px;
#         cursor: pointer;
#         transition: background-color 0.3s;
#         margin-left: 10px;
#     " onmouseover="this.style.backgroundColor='#45a049'" onmouseout="this.style.backgroundColor='#4CAF50'">
#         Create features
#     </button>
# </a>

# %% [markdown]
# # Preprocessed Dataset

# %%
print("=================== Preprocessed x_train =================== \n")
preprocessed_x_train = pd.read_csv("data/preprocessed/preprocessed_x_train.csv")
preprocessed_x_train.info()
# Out:
# =================== Preprocessed x_train ===================
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95512 entries, 0 to 95511
# Data columns (total 54 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           95512 non-null  float64
#  1   lead_time                       95512 non-null  float64
#  2   arrival_date_year               95512 non-null  float64
#  3   arrival_date_month              95512 non-null  float64
#  4   arrival_date_week_number        95512 non-null  float64
#  5   arrival_date_day_of_month       95512 non-null  float64
#  6   stays_in_weekend_nights         95512 non-null  float64
#  7   stays_in_week_nights            95512 non-null  float64
#  8   adults                          95512 non-null  float64
#  9   children                        95512 non-null  float64
#  10  babies                          95512 non-null  float64
# ...

# %%
print("=================== Preprocessed x_test =================== \n")
preprocessed_x_test = pd.read_csv("data/preprocessed/preprocessed_x_test.csv")
preprocessed_x_test.info()
# Out:
# =================== Preprocessed x_test ===================
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23878 entries, 0 to 23877
# Data columns (total 54 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           23878 non-null  float64
#  1   lead_time                       23878 non-null  float64
#  2   arrival_date_year               23878 non-null  float64
#  3   arrival_date_month              23878 non-null  float64
#  4   arrival_date_week_number        23878 non-null  float64
#  5   arrival_date_day_of_month       23878 non-null  float64
#  6   stays_in_weekend_nights         23878 non-null  float64
#  7   stays_in_week_nights            23878 non-null  float64
#  8   adults                          23878 non-null  float64
#  9   children                        23878 non-null  float64
#  10  babies                          23878 non-null  float64
# ...

# %% [markdown]
# <a href="../data/preprocessed/preprocessed_dataset.csv" target="_blank" style="text-decoration: none;">
#     <button style="
#         background-color: #2626f7ff;
#         color: white;
#         padding: 12px 24px;
#         font-size: 16px;
#         border: none;
#         border-radius: 8px;
#         cursor: pointer;
#         transition: background-color 0.3s;
#     " onmouseover="this.style.backgroundColor='#3434f5ff'" onmouseout="this.style.backgroundColor='#1e1ec8ff'">
#         Show Preprocessed Dataset (.csv)
#     </button>
# </a>
#
# <a href="../src/preprocessing.py" target="_blank" style="text-decoration: none;">
#     <button style="
#         background-color: #4CAF50;
#         color: white;
#         padding: 12px 24px;
#         font-size: 16px;
#         border: none;
#         border-radius: 8px;
#         cursor: pointer;
#         transition: background-color 0.3s;
#         margin-left: 10px;
#     " onmouseover="this.style.backgroundColor='#45a049'" onmouseout="this.style.backgroundColor='#4CAF50'">
#         Preprocessing Class
#     </button>
# </a>
#
# <a href="../scripts/use_preprocessing.py" target="_blank" style="text-decoration: none;">
#     <button style="
#         background-color: #4CAF50;
#         color: white;
#         padding: 12px 24px;
#         font-size: 16px;
#         border: none;
#         border-radius: 8px;
#         cursor: pointer;
#         transition: background-color 0.3s;
#         margin-left: 10px;
#     " onmouseover="this.style.backgroundColor='#45a049'" onmouseout="this.style.backgroundColor='#4CAF50'">
#         Use encoding, scaling
#     </button>
# </a>
